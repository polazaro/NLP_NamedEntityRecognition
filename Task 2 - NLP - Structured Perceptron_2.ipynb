# %% [markdown]
# # Task 2 - Natural Language Processing
#
# ## Structured Perceptron
#
# ### Rubén Barco Terrones - Aleix Casellas Comas - Andreu Masdeu Ninot - Pablo Lázaro Herrasti

# %% [markdown]
# ##### Imports

# %%
#### Basics
import pandas as pd
import numpy as np
# %matplotlib inline

import pickle
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

#### skseq Sequences
import scipy
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
import skseq
from skseq.sequences import sequence
from skseq.sequences.sequence import Sequence
from skseq.sequences.sequence_list import SequenceList
from skseq.sequences.label_dictionary import LabelDictionary

#### Feature mapper
import pprint
from skseq.sequences import extended_feature

#### Structured perceptron
import skseq.readers.pos_corpus
import skseq.sequences.structured_perceptron as spc

# %% [markdown]
# #### Functions:

# %%
from sklearn.utils.multiclass import unique_labels
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data

    fig, ax = plt.subplots()
    fig.set_figheight(20)
    fig.set_figwidth(20)
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %% [markdown]
# # TRAINING/TEST PREPROCESSING (NER_DATASET)

# %%
# data = pd.read_csv("ner_dataset.csv",encoding="latin1")
# data.head()

# %% [markdown]
# ### Preparing data

# %%
def build_word_to_pos(X):

    word_to_pos = {}
    i = 0
    for s in X:
        for w in s:
            if w not in word_to_pos:
                word_to_pos[w] = i
                i +=1
                
    pos_to_word = {v: k for k, v in word_to_pos.items()}
    return word_to_pos, pos_to_word
            
def build_tag_to_pos(Y):
    tag_to_pos = {}
    i = 0
    for s in Y:
        for t in s:
            if t not in tag_to_pos:
                tag_to_pos[t] = i
                i +=1
    pos_to_tag = {v: k for k, v in tag_to_pos.items()}

    return tag_to_pos, pos_to_tag

# %% [markdown]
# ### Train

# %%
# sentence_formatter = "Sentence: {}"

# last_n_train = 35971
# end_train   = data.index[data["Sentence #"] == sentence_formatter.format(last_n_train)][0]
# train = data[0:end_train]

# n_sentences_train = len(list(set(train["Sentence #"])))
# first_n_train = 1
# last_n_train = last_n_train -1
# print(n_sentences)

# %%
# n_sentences_train = len(list(set(train["Sentence #"])))

# %%
# %%time 
# sentence_formatter = "Sentence: {}"

# for s_id in  range(first_n_train, last_n_train):
#     print("current {}/{}".format(s_id,last_n_train), end="\r")
#     sentence_id = sentence_formatter.format(s_id)
#     sentence_id_next = sentence_formatter.format(s_id + 1)
#     start = train.index[train["Sentence #"] == sentence_id][0]
#     end   = train.index[train["Sentence #"] == sentence_id_next][0]
#     train["Sentence #"][start:end] = sentence_id
    
# sentence_id = sentence_formatter.format(last_n_train)
# start = train.index[train["Sentence #"] == sentence_id][0]
# end   = train.shape[0]
# train["Sentence #"][start:end] = sentence_id

# %%
# train.to_csv('train.csv', sep='\t')

# %%
# X_train = []
# Y_train = []

# sentence_formatter = "Sentence: {}"

# for i in range(1,n_sentences_train):
#     s = sentence_formatter.format(i)
#     X_train.append(list(train[train["Sentence #"]==s]["Word"].values))
#     Y_train.append(list(train[train["Sentence #"]==s]["Tag"].values))

# %%
# with open("X_train.txt", "wb") as fp:   #Pickling
#     pickle.dump(X_train, fp)
# with open("Y_train.txt", "wb") as fp:   #Pickling
#     pickle.dump(Y_train, fp)

# %%
with open("X_train.txt", "rb") as fp:   # Unpickling
    X_train = pickle.load(fp)
with open("Y_train.txt", "rb") as fp:   # Unpickling
    Y_train = pickle.load(fp)

# %%
i = 0
xy = ["{}/{}".format(x,y) for x,y in zip(X_train[i],Y_train[i])]
" ".join(xy)
# Out:
# 'Thousands/O of/O demonstrators/O have/O marched/O through/O London/B-geo to/O protest/O the/O war/O in/O Iraq/B-geo and/O demand/O the/O withdrawal/O of/O British/B-gpe troops/O from/O that/O country/O ./O'

# %%
word_to_pos, pos_to_word = build_word_to_pos(X_train)
tag_to_pos, pos_to_tag  = build_tag_to_pos(Y_train)

len(word_to_pos), len(tag_to_pos)
# Out:
# (30863, 17)

# %%
X_ids_train = [[word_to_pos[w] for w in s] for s in X_train]
Y_ids_train = [[tag_to_pos[t] for t in s] for s in Y_train]

# %%
# sequence_list = SequenceList(LabelDictionary(word_to_pos), LabelDictionary(tag_to_pos))
# for x,y in zip(X_train,Y_train):
#     sequence_list.add_sequence(x,y, LabelDictionary(word_to_pos), LabelDictionary(tag_to_pos))

# %%
# sequence_list[0].to_words(sequence_list=sequence_list)

# %%
# with open('sequence_list_train', 'wb') as sqq:
 
#     pickle.dump(sequence_list, sqq)

# %%
with open("sequence_list_train", "rb") as fp:   # Unpickling
    sequence_list_train = pickle.load(fp)

# %%
sequence_list_train[3]
# Out:
# 49/0 50/0 9/0 51/0 1/0 52/0 53/0 54/0 55/0 56/0 57/0 58/0 59/0 60/0 21/0

# %% [markdown]
# ### Test

# %%
# sentence_formatter = "Sentence: {}"

# test = data[end_train:len(data)]

# n_sentences_test = len(list(set(test["Sentence #"])))
# first_n_test = last_n_train + 1
# last_n_test = 47959
# print(n_sentences_test)

# %%
# %%time 
# sentence_formatter = "Sentence: {}"

# for s_id in  range(first_n_test, last_n_test):
#     print("current {}/{}".format(s_id,last_n_test), end="\r")
#     sentence_id = sentence_formatter.format(s_id)
#     sentence_id_next = sentence_formatter.format(s_id + 1)
#     start = data.index[data["Sentence #"] == sentence_id][0]
#     end   = data.index[data["Sentence #"] == sentence_id_next][0]
#     data["Sentence #"][start:end] = sentence_id
    
# sentence_id = sentence_formatter.format(last_n_test)
# start = data.index[data["Sentence #"] == sentence_id][0]
# end   = data.shape[0]
# data["Sentence #"][start:end] = sentence_id

# %%
# test.to_csv('test.csv', sep='\t')

# %%
# X_test = []
# Y_test = []

# sentence_formatter = "Sentence: {}"

# for i in range(n_sentences_train+1,n_sentences_train+n_sentences_test-1):
#     s = sentence_formatter.format(i)
#     X_test.append(list(data[data["Sentence #"]==s]["Word"].values))
#     Y_test.append(list(data[data["Sentence #"]==s]["Tag"].values))

# %%
# with open("X_test.txt", "wb") as fp:   #Pickling
#     pickle.dump(X_test, fp)
# with open("Y_test.txt", "wb") as fp:   #Pickling
#     pickle.dump(Y_test, fp)

# %%
with open("X_test.txt", "rb") as fp:   # Unpickling
    X_test = pickle.load(fp)
with open("Y_test.txt", "rb") as fp:   # Unpickling
    Y_test = pickle.load(fp)

# %%
i = 0
xy = ["{}/{}".format(x,y) for x,y in zip(X_test[i],Y_test[i])]
" ".join(xy)
# Out:
# 'Officials/O said/O Sunday/B-tim Jean/B-per Rene/I-per Anthony/I-per was/O killed/O in/O a/O shootout/O with/O police/O near/O the/O capital/O city/O of/O Port-au-Prince/B-geo ./O'

# %%
Y_ids_test = [[tag_to_pos[t] for t in s] for s in Y_test]

# %%
test_sentences = ["The programmers from Barcelona might write a sentence without a spell checker.", 
                  "The programmers from Barchelona cannot write a sentence without a spell checker.",
                  "Jack London went to Parris.",
                  "Jack London went to Paris.",
                  "We never though Microsoft would become such a big company.",
                  "We never though Microsof would become such a big company.",
                  "The president of U.S.A though they could win the war",
                  "The president of the United States of America though they could win the war",
                  "The king of Saudi Arabia wanted total control.",
                  "Robin does not want to go to Saudi Arabia."]

test_tags = [['O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['B-per', 'I-per', 'O', 'O', 'O'],
            ['B-per', 'I-per', 'O', 'O', 'B-geo'],
            ['O', 'O', 'O', 'B-org', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['O', 'O', 'O', 'O', 'B-geo', 'I-geo', 'I-geo', 'I-geo', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['O', 'O', 'O', 'B-geo', 'I-geo', 'O', 'O', 'O'],
            ['B-per', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'I-geo']]

# %%
def print_all_test_sentences(test_sents, model):
    for sentence in test_sents:
        new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
        print(model.viterbi_decode(new_seq)[0].to_words(sequence_list_train, only_tag_translation=True))
            
def compare_one_test_sentence(test_sents, test_tgs, model, pos_to_tag, i):
    sentence = test_sents[i-1]
    new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
    preds = model.viterbi_decode(new_seq)[0].y
    print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
    for word, true_tag, pred_tag in zip(sentence.split(), test_tgs[i-1], preds):
        print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))

# %% [markdown]
# # EXPERIMENT 1: Basic features

# %% [markdown]
# ##### Comments:
# In this first experiment we are going to use only the **default features** in the ExtendedFeatures class. We want to have this experiment as the base experiment in order to be able to see the errors and how to solve them and to compare the future results with this one.

# %% [markdown]
# ### Extended features

# %%
ex_feature_mapper = skseq.sequences.extended_feature.ExtendedFeatures(sequence_list_train) 
ex_feature_mapper.build_features()
pprint.pprint(list(ex_feature_mapper.__dict__.keys()))
# Out:
# ['feature_dict',
#  'feature_list',
#  'add_features',
#  'dataset',
#  'node_feature_cache',
#  'initial_state_feature_cache',
#  'final_state_feature_cache',
#  'edge_feature_cache']

# %%
len(ex_feature_mapper.feature_dict)
# Out:
# 38298

# %%
ex_feature_mapper.feature_dict
# Out:
# {'init_tag:O': 0,
#  'id:Thousands::O': 1,
#  'id:of::O': 2,
#  'prev_tag:O::O': 3,
#  'id:demonstrators::O': 4,
#  'id:have::O': 5,
#  'id:marched::O': 6,
#  'id:through::O': 7,
#  'id:London::B-geo': 8,
#  'prev_tag:O::B-geo': 9,
#  'id:to::O': 10,
#  'prev_tag:B-geo::O': 11,
#  'id:protest::O': 12,
#  'id:the::O': 13,
#  'id:war::O': 14,
#  'id:in::O': 15,
#  'id:Iraq::B-geo': 16,
#  'id:and::O': 17,
#  'id:demand::O': 18,
#  'id:withdrawal::O': 19,
#  'id:British::B-gpe': 20,
#  'prev_tag:O::B-gpe': 21,
#  'id:troops::O': 22,
#  'prev_tag:B-gpe::O': 23,
#  'id:from::O': 24,
#  'id:that::O': 25,
#  'id:country::O': 26,
#  'id:.::O': 27,
#  'final_prev_tag:O': 28,
#  'id:Families::O': 29,
#  'id:soldiers::O': 30,
#  'id:killed::O': 31,
#  'id:conflict::O': 32,
#  'id:joined::O': 33,
#  'id:protesters::O': 34,
#  'id:who::O': 35,
#  'id:carried::O': 36,
#  'id:banners::O': 37,
#  'id:with::O': 38,
#  'id:such::O': 39,
#  'id:slogans::O': 40,
#  'id:as::O': 41,
#  'id:"::O': 42,
#  'id:Bush::B-per': 43,
#  'prev_tag:O::B-per': 44,
#  'id:Number::O': 45,
#  'prev_tag:B-per::O': 46,
#  'id:One::O': 47,
#  'id:Terrorist::O': 48,
#  'id:Stop::O': 49,
#  'id:Bombings::O': 50,
#  'id:They::O': 51,
#  'id:Houses::O': 52,
#  'id:Parliament::O': 53,
#  'id:a::O': 54,
#  'id:rally::O': 55,
#  'id:Hyde::B-geo': 56,
#  'id:Park::I-geo': 57,
#  'prev_tag:B-geo::I-geo': 58,
#  'prev_tag:I-geo::O': 59,
#  'id:Police::O': 60,
#  'id:put::O': 61,
#  'id:number::O': 62,
#  'id:marchers::O': 63,
#  'id:at::O': 64,
#  'id:10,000::O': 65,
#  'id:while::O': 66,
#  'id:organizers::O': 67,
#  'id:claimed::O': 68,
#  'id:it::O': 69,
#  'id:was::O': 70,
#  'id:1,00,000::O': 71,
#  'id:The::O': 72,
#  'id:comes::O': 73,
#  'id:on::O': 74,
#  'id:eve::O': 75,
#  'id:annual::O': 76,
#  'id:conference::O': 77,
#  'id:Britain::B-geo': 78,
#  "id:'s::O": 79,
#  'id:ruling::O': 80,
#  'id:Labor::B-org': 81,
#  'prev_tag:O::B-org': 82,
#  'id:Party::I-org': 83,
#  'prev_tag:B-org::I-org': 84,
#  'prev_tag:I-org::O': 85,
#  'id:southern::O': 86,
#  'id:English::B-gpe': 87,
#  'id:seaside::O': 88,
#  'id:resort::O': 89,
#  'id:Brighton::B-geo': 90,
#  'id:party::O': 91,
#  'id:is::O': 92,
#  'id:divided::O': 93,
#  'id:over::O': 94,
#  'id:Britain::B-gpe': 95,
#  'id:participation::O': 96,
#  'id:continued::O': 97,
#  'id:deployment::O': 98,
#  'id:8,500::O': 99,
#  'id:march::O': 100,
#  'id:came::O': 101,
#  'id:ahead::O': 102,
#  'id:anti-war::O': 103,
#  'id:protests::O': 104,
#  'id:today::O': 105,
#  'id:other::O': 106,
#  'id:cities::O': 107,
#  'id:,::O': 108,
#  'id:including::O': 109,
#  'id:Rome::B-geo': 110,
#  'id:Paris::B-geo': 111,
#  'id:Madrid::B-geo': 112,
#  'id:International::B-org': 113,
#  'id:Atomic::I-org': 114,
#  'id:Energy::I-org': 115,
#  'prev_tag:I-org::I-org': 116,
#  'id:Agency::I-org': 117,
#  'id:hold::O': 118,
#  'id:second::O': 119,
#  'id:day::O': 120,
#  'id:talks::O': 121,
#  'id:Vienna::B-geo': 122,
#  'id:Wednesday::B-tim': 123,
#  'prev_tag:B-geo::B-tim': 124,
#  'prev_tag:B-tim::O': 125,
#  'id:how::O': 126,
#  'id:respond::O': 127,
#  'id:Iran::B-gpe': 128,
#  'id:resumption::O': 129,
#  'id:low-level::O': 130,
#  'id:uranium::O': 131,
#  'id:conversion::O': 132,
#  'init_tag:B-gpe': 133,
#  'id:this::O': 134,
#  'id:week::O': 135,
#  'id:restarted::O': 136,
#  'id:parts::O': 137,
#  'id:process::O': 138,
#  'id:its::O': 139,
#  'id:Isfahan::B-geo': 140,
#  'id:nuclear::O': 141,
#  'id:plant::O': 142,
#  'id:Iranian::B-gpe': 143,
#  'id:officials::O': 144,
#  'id:say::O': 145,
#  'id:they::O': 146,
#  'id:expect::O': 147,
#  'id:get::O': 148,
#  'id:access::O': 149,
#  'id:sealed::O': 150,
#  'id:sensitive::O': 151,
#  'prev_tag:O::B-tim': 152,
#  'id:after::O': 153,
#  'id:an::O': 154,
#  'id:IAEA::B-org': 155,
#  'id:surveillance::O': 156,
#  'prev_tag:B-org::O': 157,
#  'id:system::O': 158,
#  'id:begins::O': 159,
#  'id:functioning::O': 160,
#  'id:step::O': 161,
#  'id:will::O': 162,
#  'id:allow::O': 163,
#  'id:facility::O': 164,
#  'id:operate::O': 165,
#  'id:full::O': 166,
#  'id:capacity::O': 167,
#  'id:European::B-org': 168,
#  'id:Union::I-org': 169,
#  'id:U.S.::B-gpe': 170,
#  'id:backing::O': 171,
#  'id:has::O': 172,
#  'id:threatened::O': 173,
#  'id:refer::O': 174,
#  'id:U.N.::B-org': 175,
#  'id:Security::I-org': 176,
#  'id:Council::I-org': 177,
#  'id:which::O': 178,
#  'id:could::O': 179,
#  'id:impose::O': 180,
#  'id:sanctions::O': 181,
#  'id:if::O': 182,
#  'id:finds::O': 183,
#  'id:Tehran::B-gpe': 184,
#  'id:violated::O': 185,
#  'id:Nuclear::B-art': 186,
#  'prev_tag:O::B-art': 187,
#  'id:Non-Proliferation::I-art': 188,
#  'prev_tag:B-art::I-art': 189,
#  'id:treaty::O': 190,
#  'prev_tag:I-art::O': 191,
#  'id:new::O': 192,
#  'id:President::B-per': 193,
#  'id:Mahmoud::I-per': 194,
#  'prev_tag:B-per::I-per': 195,
#  'id:Ahmadinejad::I-per': 196,
#  'prev_tag:I-per::I-per': 197,
#  'id:said::O': 198,
#  'prev_tag:I-per::O': 199,
#  'id:Tuesday::B-tim': 200,
#  'id:European::B-gpe': 201,
#  'id:incentives::O': 202,
#  'id:aimed::O': 203,
#  'id:persuading::O': 204,
#  'id:end::O': 205,
#  'id:fuel::O': 206,
#  'id:program::O': 207,
#  'id:are::O': 208,
#  'id:insult::O': 209,
#  'id:nation::O': 210,
#  'id:Two::O': 211,
#  'id:Germans::B-gpe': 212,
#  'id:four::O': 213,
#  'id:Nigerian::B-gpe': 214,
#  'id:oil::O': 215,
#  'id:workers::O': 216,
#  'id:were::O': 217,
#  'id:kidnapped::O': 218,
#  'id:by::O': 219,
#  'id:armed::O': 220,
#  'id:militants::O': 221,
#  'id:during::O': 222,
#  'id:raid::O': 223,
#  'id:boat::O': 224,
#  'id:Nigeria::B-geo': 225,
#  'id:oil-rich::O': 226,
#  'id:Delta::B-geo': 227,
#  'id:region::O': 228,
#  'id:An::O': 229,
#  'id:official::O': 230,
#  'id:German::B-gpe': 231,
#  'id:firm::O': 232,
#  'id:Bilfinger::B-org': 233,
#  'id:Berger::I-org': 234,
#  'id:Thomas::B-per': 235,
#  'id:Horbach::I-per': 236,
#  'id:gunmen::O': 237,
#  'id:stopped::O': 238,
#  'id:supply::O': 239,
#  'id:sailed::O': 240,
#  'id:State::I-geo': 241,
#  'id:Bayelsa::B-geo': 242,
#  'id:inspect::O': 243,
#  'id:offshore::O': 244,
#  'id:field::O': 245,
#  'id:owned::O': 246,
#  'id:Royal-Dutch::B-org': 247,
#  'id:Shell::I-org': 248,
#  'id:works::O': 249,
#  'id:sub-contractor::O': 250,
#  'id:for::O': 251,
#  'id:Shell::B-org': 252,
#  'id:Militant::O': 253,
#  'id:groups::O': 254,
#  'id:frequently::O': 255,
#  'id:attack::O': 256,
#  'id:operations::O': 257,
#  'id:Niger::B-geo': 258,
#  'id:Delta::I-geo': 259,
#  'id:social::O': 260,
#  'id:services::O': 261,
#  'id:better::O': 262,
#  'id:job::O': 263,
#  'id:opportunities::O': 264,
#  'id:multinational::O': 265,
#  'id:companies::O': 266,
#  'id:Poor::O': 267,
#  'id:residents::O': 268,
#  'id:often::O': 269,
#  'id:complain::O': 270,
#  'id:been::O': 271,
#  'id:cheated::O': 272,
#  'id:out::O': 273,
#  'id:huge::O': 274,
#  'id:riches::O': 275,
#  'id:extracted::O': 276,
#  'id:their::O': 277,
#  'id:tribal::O': 278,
#  'id:lands::O': 279,
#  'id:-::O': 280,
#  'id:where::O': 281,
#  'id:bulk::O': 282,
#  'id:Nigeria::B-gpe': 283,
#  'id:2.3::O': 284,
#  'id:million::O': 285,
#  'id:barrels::O': 286,
#  'id:petroleum::O': 287,
#  'id:pumped::O': 288,
#  'id:daily::O': 289,
#  'id:Suspected::O': 290,
#  'id:Islamist::O': 291,
#  'id:rebels::O': 292,
#  'id:fired::O': 293,
#  'id:mortar::O': 294,
#  'id:shells::O': 295,
#  'id:palace::O': 296,
#  'id:used::O': 297,
#  'id:Somalia::B-geo': 298,
#  'id:interim::O': 299,
#  'id:Abdullahi::I-per': 300,
#  'id:Yusuf::I-per': 301,
#  'id:Ahmad::I-per': 302,
#  'id:It::O': 303,
#  'id:not::O': 304,
#  'id:immediately::O': 305,
#  'id:clear::O': 306,
#  'id:president::O': 307,
#  'id:Mogadishu::B-geo': 308,
#  'id:when::O': 309,
#  'id:occurred::O': 310,
#  'id:or::O': 311,
#  'id:anyone::O': 312,
#  'id:hurt::O': 313,
#  'id:Local::O': 314,
#  'id:news::O': 315,
#  'id:reports::O': 316,
#  'id:least::O': 317,
#  'id:five::O': 318,
#  'id:hit::O': 319,
#  'id:compound::O': 320,
#  'id:mortars::O': 321,
#  'id:elsewhere::O': 322,
#  'id:attacks::O': 323,
#  'id:government::O': 324,
#  'id:go::O': 325,
#  'id:reconciliation::O': 326,
#  'id:more::O': 327,
#  'id:than::O': 328,
#  'id:1,300::O': 329,
#  'id:Somali::B-gpe': 330,
#  'id:elders::O': 331,
#  'id:warlords::O': 332,
#  'id:politicians::O': 333,
#  'id:invited::O': 334,
#  'id:Iraqi::B-gpe': 335,
#  'id:military::O': 336,
#  'id:tanks::O': 337,
#  'id:arrived::O': 338,
#  'id:northern::O': 339,
#  'id:city::O': 340,
#  'id:Mosul::B-geo': 341,
#  'id:offensive::O': 342,
#  'id:against::O': 343,
#  'id:al::B-org': 344,
#  'id:Qaida::I-org': 345,
#  'id:in::I-org': 346,
#  'id:Iraq::I-org': 347,
#  'id:fighters::O': 348,
#  'id:Officials::O': 349,
#  'id:many::O': 350,
#  'id:Sunni::B-geo': 351,
#  'id:Arab::I-geo': 352,
#  'id:Kurdish::B-geo': 353,
#  'id:bombings::O': 354,
#  'id:last::O': 355,
#  'id:34::O': 356,
#  'id:people::O': 357,
#  'id:wounded::O': 358,
#  'id:200::O': 359,
#  'id:commanders::O': 360,
#  'id:explained::O': 361,
#  'id:American::B-gpe': 362,
#  'id:forces::O': 363,
#  'id:participate::O': 364,
#  'id:fled::O': 365,
#  'id:successful::O': 366,
#  'id:campaigns::O': 367,
#  'id:them::O': 368,
#  'id:Anbar::B-geo': 369,
#  'id:province::O': 370,
#  'id:Baghdad::B-geo': 371,
#  'id:provinces::O': 372,
#  'init_tag:B-geo': 373,
#  'id:largest::O': 374,
#  'id:north::O': 375,
#  'id:long::O': 376,
#  'id:stronghold::O': 377,
#  'id:Sunni::B-org': 378,
#  'id:militant::O': 379,
#  'id:In::O': 380,
#  'id:violence::O': 381,
#  'id:one::O': 382,
#  'id:soldier::O': 383,
#  'id:patrol::O': 384,
#  'id:Sunday::B-tim': 385,
#  'id:Egyptian::B-gpe': 386,
#  'id:police::O': 387,
#  'id:arrested::O': 388,
#  'id:16::O': 389,
#  'id:members::O': 390,
#  'id:opposition::O': 391,
#  'id:Muslim::B-org': 392,
#  'id:Brotherhood::I-org': 393,
#  'id:prepare::O': 394,
#  'id:parliamentary::O': 395,
#  'id:runoff::O': 396,
#  'id:elections::O': 397,
#  'id:Saturday::B-tim': 398,
#  'id:arrests::O': 399,
#  'id:Friday::B-tim': 400,
#  'id:Alexandria::B-geo': 401,
#  'id:A::O': 402,
#  'id:spokesman::O': 403,
#  'id:Brotherhood::B-org': 404,
#  'id:attempt::O': 405,
#  'id:cut::O': 406,
#  'id:off::O': 407,
#  'id:supporters::O': 408,
#  'id:punishment::O': 409,
#  'id:winning::O': 410,
#  'id:seats::O': 411,
#  'id:earlier::O': 412,
#  'id:tripled::O': 413,
#  'id:strength::O': 414,
#  'id:parliament::O': 415,
#  'id:recent::O': 416,
#  'id:raising::O': 417,
#  'id:total::O': 418,
#  'id:47::O': 419,
#  'id:voters::O': 420,
#  'id:cast::O': 421,
#  'id:ballots::O': 422,
#  'id:nine::O': 423,
#  'id:no::O': 424,
#  'id:candidate::O': 425,
#  'id:won::O': 426,
#  'id:majority::O': 427,
#  'id:previous::O': 428,
#  'id:round::O': 429,
#  'id:voting::O': 430,
#  'id:banned::O': 431,
#  'id:political::O': 432,
#  'id:but::O': 433,
#  'id:endorses::O': 434,
#  'id:so-called::O': 435,
#  'id:independent::O': 436,
#  'id:candidates::O': 437,
#  'id:whose::O': 438,
#  'id:allegiance::O': 439,
#  'id:known::O': 440,
#  'id:Hardline::O': 441,
#  'id:lawmakers::O': 442,
#  'id:Pakistan::B-geo': 443,
#  'id:North::B-geo': 444,
#  'id:West::I-geo': 445,
#  'id:Frontier::I-geo': 446,
#  'prev_tag:I-geo::I-geo': 447,
#  'id:Province::I-geo': 448,
#  'id:pushed::O': 449,
#  'id:law::O': 450,
#  'id:aims::O': 451,
#  'id:ensure::O': 452,
#  'id:Islamic::O': 453,
#  'id:correctness::O': 454,
#  'id:public::O': 455,
#  'id:places::O': 456,
#  'id:establishes::O': 457,
#  'id:morality::O': 458,
#  'id:enforce::O': 459,
#  'id:decent::O': 460,
#  'id:behavior::O': 461,
#  'id:six-party::O': 462,
#  'id:coalition::O': 463,
#  'id:religious::O': 464,
#  'id:based::O': 465,
#  'id:parties::O': 466,
#  'id:Mutahida::B-org': 467,
#  'id:Majlis-e-Amal::I-org': 468,
#  'id:dominates::O': 469,
#  'id:provincial::O': 470,
#  'id:assembly::O': 471,
#  'id:so::O': 472,
#  'id:bill::O': 473,
#  'id:easily::O': 474,
#  'id:passed::O': 475,
#  'id:Thursday::B-tim': 476,
#  'id:vote::O': 477,
#  'id:68-34::O': 478,
#  'id:governor::O': 479,
#  'id:must::O': 480,
#  'id:still::O': 481,
#  'id:sign::O': 482,
#  'id:before::O': 483,
#  'id:becomes::O': 484,
#  'id:seen::O': 485,
#  'id:only::O': 486,
#  'id:formality::O': 487,
#  'id:proposed::O': 488,
#  'id:calls::O': 489,
#  'id:setting::O': 490,
#  'id:up::O': 491,
#  'id:force::O': 492,
#  'id:make::O': 493,
#  'id:sure::O': 494,
#  'id:adhere::O': 495,
#  'id:values::O': 496,
#  'id:entertainment::O': 497,
#  'id:outlets::O': 498,
#  'id:close::O': 499,
#  'id:weekly::O': 500,
#  'id:prayers::O': 501,
#  'id:Violators::O': 502,
#  'id:be::O': 503,
#  'id:jailed::O': 504,
#  'id:six::O': 505,
#  'id:months::O': 506,
#  'id:denounced::O': 507,
#  'id:measure::O': 508,
#  'id:comparing::O': 509,
#  'id:draconian::O': 510,
#  'id:rule::O': 511,
#  'id:former::O': 512,
#  'id:Taleban::B-org': 513,
#  'id:neighboring::O': 514,
#  'id:Afghanistan::B-geo': 515,
#  'id:man::O': 516,
#  'id:dressed::O': 517,
#  'id:suicide::O': 518,
#  'id:bomber::O': 519,
#  'id:demonstration::O': 520,
#  'id:publication::O': 521,
#  'id:cartoons::O': 522,
#  'id:depicting::O': 523,
#  'id:Islam::B-org': 524,
#  'id:Prophet::B-per': 525,
#  'id:Muhammad::I-per': 526,
#  'id:Bedfordshire::B-gpe': 527,
#  'id:Omar::B-per': 528,
#  'id:Khayam::I-per': 529,
#  'id:Bedford::B-geo': 530,
#  'id:breaching::O': 531,
#  'id:conditions::O': 532,
#  'id:his::O': 533,
#  'id:parole::O': 534,
#  'id:British::B-org': 535,
#  'id:Home::I-org': 536,
#  'id:Office::I-org': 537,
#  'id:sought::O': 538,
#  'id:investigation::O': 539,
#  'id:Khayam::B-per': 540,
#  'id:he::O': 541,
#  'id:photographed::O': 542,
#  'id:fatigues::O': 543,
#  'id:black::O': 544,
#  'id:cap::O': 545,
#  'id:bulky::O': 546,
#  'id:belt::O': 547,
#  'id:Home::B-org': 548,
#  'id:told::O': 549,
#  'id:Associated::B-org': 550,
#  'id:Press::I-org': 551,
#  'id:paroled::O': 552,
#  'id:offender::O': 553,
#  'id:gives::O': 554,
#  'id:cause::O': 555,
#  'id:concern::O': 556,
#  'id:can::O': 557,
#  'id:sent::O': 558,
#  'id:back::O': 559,
#  'id:prison::O': 560,
#  'id:AP::B-org': 561,
#  'id:also::O': 562,
#  'id:since::O': 563,
#  'id:year::O': 564,
#  'id:serving::O': 565,
#  'id:half::O': 566,
#  'id:six-year::O': 567,
#  'id:sentence::O': 568,
#  'id:drug::O': 569,
#  'id:dealing::O': 570,
#  'id:Pakistani::B-gpe': 571,
#  'id:unidentified::O': 572,
#  'id:three::O': 573,
#  'id:minister::O': 574,
#  'id:semi-autonomous::O': 575,
#  'id:bordering::O': 576,
#  'id:prominent::O': 577,
#  'id:leader::O': 578,
#  'id:Malik::B-per': 579,
#  'id:Faridullah::I-per': 580,
#  'id:Khan::I-per': 581,
#  'id:traveling::O': 582,
#  'id:South::B-geo': 583,
#  'id:Waziristan::I-geo': 584,
#  'prev_tag:I-geo::B-tim': 585,
#  'id:vehicle::O': 586,
#  'id:ambushed::O': 587,
#  'id:Kani::B-geo': 588,
#  'id:Wam::I-geo': 589,
#  'id:area::O': 590,
#  'id:His::O': 591,
#  'id:driver::O': 592,
#  'id:elder::O': 593,
#  'id:No::O': 594,
#  'id:responsibility::O': 595,
#  'id:killings::O': 596,
#  'id:ambush::O': 597,
#  'id:commander::O': 598,
#  'id:army::O': 599,
#  'id:almost::O': 600,
#  'id:completely::O': 601,
#  'id:eliminated::O': 602,
#  'id:became::O': 603,
#  'id:refuge::O': 604,
#  'id:al-Qaida::B-org': 605,
#  'id:ousted::O': 606,
#  'id:2001::B-tim': 607,
#  'id:senior::O': 608,
#  'id:says::O': 609,
#  'id:Pakistan::B-gpe': 610,
#  'id:wants::O': 611,
#  'id:what::O': 612,
#  'id:sordid::O': 613,
#  'id:chapter::O': 614,
#  'id:proliferation::O': 615,
#  'id:top::O': 616,
#  'id:scientists::O': 617,
#  'id:behind::O': 618,
#  'id:build::O': 619,
#  'id:civilian::O': 620,
#  'id:ties::O': 621,
#  'id:United::B-gpe': 622,
#  'id:States::I-gpe': 623,
#  'prev_tag:B-gpe::I-gpe': 624,
#  'prev_tag:I-gpe::O': 625,
#  'id:But::O': 626,
#  'id:ready::O': 627,
#  'id:scientist::O': 628,
#  'id:Abdul::B-per': 629,
#  'id:Qadeer::I-per': 630,
#  'id:available::O': 631,
#  'id:direct::O': 632,
#  'id:questioning::O': 633,
#  'id:sale::O': 634,
#  'id:secrets::O': 635,
#  'id:states::O': 636,
#  'id:Libya::B-gpe': 637,
#  'id:North::B-gpe': 638,
#  'id:Korea::I-gpe': 639,
#  'id:He::O': 640,
#  'id:there::O': 641,
#  'id:reasons::O': 642,
#  'id:national::O': 643,
#  'id:sensitivities::O': 644,
#  'id:making::O': 645,
#  'id:him::O': 646,
#  'id:giving::O': 647,
#  'id:background::O': 648,
#  'id:briefing::O': 649,
#  'id:small::O': 650,
#  'id:group::O': 651,
#  'id:reporters::O': 652,
#  'id:Washington::B-geo': 653,
#  'init_tag:B-per': 654,
#  'id:Khan::B-per': 655,
#  'id:admitted::O': 656,
#  'id:2004::B-tim': 657,
#  'id:operated::O': 658,
#  'id:worldwide::O': 659,
#  'id:clandestine::O': 660,
#  'id:network::O': 661,
#  'id:sell::O': 662,
#  'id:technology::O': 663,
#  'id:market::O': 664,
#  'id:placed::O': 665,
#  'id:under::O': 666,
#  'id:house::O': 667,
#  'id:arrest::O': 668,
#  'id:Islamabad::B-geo': 669,
#  'id:because::O': 670,
#  'id:considered::O': 671,
#  'id:father::O': 672,
#  'id:bomb::O': 673,
#  'id:Army::B-org': 674,
#  'prev_tag:B-gpe::B-org': 675,
#  'id:renew::O': 676,
#  'id:controversial::O': 677,
#  'id:multi-billion::O': 678,
#  'id:dollar::O': 679,
#  'id:contract::O': 680,
#  'id:Halliburton::B-org': 681,
#  'id:company::O': 682,
#  'id:provide::O': 683,
#  'id:logistical::O': 684,
#  'id:support::O': 685,
#  'init_tag:B-org': 686,
#  'id:providing::O': 687,
#  'id:list::O': 688,
#  'id:meals::O': 689,
#  'id:communication::O': 690,
#  'id:several::O': 691,
#  'id:years::O': 692,
#  'id:Critics::O': 693,
#  'id:include::O': 694,
#  'id:auditors::O': 695,
#  'id:congressional::O': 696,
#  'id:Democrats::O': 697,
#  'id:produced::O': 698,
#  'id:some::O': 699,
#  'id:shoddy::O': 700,
#  'id:work::O': 701,
#  'id:charges::O': 702,
#  'id:too::O': 703,
#  'id:much::O': 704,
#  'id:money::O': 705,
#  'id:strongly::O': 706,
#  'id:denies::O': 707,
#  'id:allegations::O': 708,
#  'id:When::O': 709,
#  'id:re-bidding::O': 710,
#  'id:chance::O': 711,
#  'id:compete::O': 712,
#  'id:portions::O': 713,
#  'id:Representatives::O': 714,
#  'id:Asia::B-org': 715,
#  'id:Pacific::I-org': 716,
#  'id:Economic::I-org': 717,
#  'id:Cooperation::I-org': 718,
#  'id:Business::I-org': 719,
#  'id:Advisory::I-org': 720,
#  'id:holding::O': 721,
#  'id:meetings::O': 722,
#  'id:finalize::O': 723,
#  'id:report::O': 724,
#  'id:APEC::B-org': 725,
#  'id:leaders::O': 726,
#  'id:summit::O': 727,
#  'id:September::B-tim': 728,
#  'id:8::I-tim': 729,
#  'prev_tag:B-tim::I-tim': 730,
#  'prev_tag:I-tim::O': 731,
#  'id:9::B-tim': 732,
#  'id:VOA::B-org': 733,
#  'id:Nancy-Amelia::B-per': 734,
#  'id:Collins::I-per': 735,
#  'id:Sydney::B-geo': 736,
#  'id:Energy::O': 737,
#  'id:security::O': 738,
#  'id:climate::O': 739,
#  'id:change::O': 740,
#  'id:World::B-org': 741,
#  'id:Trade::I-org': 742,
#  'id:Organization::I-org': 743,
#  'id:stalled::O': 744,
#  'id:negotiations::O': 745,
#  'id:investment::O': 746,
#  'id:all::O': 747,
#  'id:expected::O': 748,
#  'id:among::O': 749,
#  'id:major::O': 750,
#  'id:topics::O': 751,
#  'id:ABAC::B-org': 752,
#  'id:Tim::B-per': 753,
#  'id:Harcourt::I-per': 754,
#  'id:chief::O': 755,
#  'id:economist::O': 756,
#  'id:Australian::B-org': 757,
#  'id:Commission::I-org': 758,
#  'id:plays::O': 759,
#  'id:important::O': 760,
#  'id:role::O': 761,
#  'id:informing::O': 762,
#  'id:governments::O': 763,
#  'id:problems::O': 764,
#  'id:most::O': 765,
#  'id:thing::O': 766,
#  'id:business::O': 767,
#  'id:do::O': 768,
#  'id:tell::O': 769,
#  'id:logjams::O': 770,
#  'id:obstacles::O': 771,
#  'id:things::O': 772,
#  'id:improve::O': 773,
#  'id:Harcourt::B-per': 774,
#  'id:I::O': 775,
#  'id:think::O': 776,
#  'id:actually::O': 777,
#  'id:played::O': 778,
#  'id:pretty::O': 779,
#  'id:good::O': 780,
#  'id:leadership::O': 781,
#  'id:talking::O': 782,
#  'id:about::O': 783,
#  'id:trade::O': 784,
#  'id:facilitation::O': 785,
#  'id:basically::O': 786,
#  'id:standards::O': 787,
#  'id:consistent::O': 788,
#  'id:harmonious::O': 789,
#  'id:across::O': 790,
#  'id:comprises::O': 791,
#  'id:private::O': 792,
#  'id:sector::O': 793,
#  'id:each::O': 794,
#  'id:21::O': 795,
#  'id:economies::O': 796,
#  'id:meets::O': 797,
#  'id:times::O': 798,
#  'id:made::O': 799,
#  'id:permanent::O': 800,
#  'id:body::O': 801,
#  'id:1995::B-tim': 802,
#  'id:perspective::O': 803,
#  'id:within::O': 804,
#  'id:Members::O': 805,
#  'id:represent::O': 806,
#  'id:range::O': 807,
#  'id:sectors::O': 808,
#  'id:medium::O': 809,
#  'id:businesses::O': 810,
#  'id:need::O': 811,
#  'id:energy::O': 812,
#  'id:efficiency::O': 813,
#  'id:encourage::O': 814,
#  'id:conservation::O': 815,
#  'id:practices::O': 816,
#  'id:discuss::O': 817,
#  'id:ways::O': 818,
#  'id:enhance::O': 819,
#  'id:regional::O': 820,
#  'id:cooperation::O': 821,
#  'id:reckon::O': 822,
#  "id:'ll::O": 823,
#  'id:talk::O': 824,
#  'id:little::O': 825,
#  'id:bit::O': 826,
#  'id:customs::O': 827,
#  'id:quarantine::O': 828,
#  'id:having::O': 829,
#  'id:arrangements::O': 830,
#  'id:around::O': 831,
#  'id:And::O': 832,
#  'id:want::O': 833,
#  'id:one-stop::O': 834,
#  'id:shop::O': 835,
#  'id:terms::O': 836,
#  'id:combining::O': 837,
#  'id:immigration::O': 838,
#  'id:together::O': 839,
#  'id:\x85::O': 840,
#  'id:just::O': 841,
#  'id:streamlined::O': 842,
#  'id:provides::O': 843,
#  'id:certainty::O': 844,
#  'id:non-governmental::O': 845,
#  'id:formal::O': 846,
#  'id:dialogue::O': 847,
#  'id:present::O': 848,
#  'id:meeting::O': 849,
#  'id:Sudan::B-gpe': 850,
#  'id:order::O': 851,
#  'id:Darfur::B-geo': 852,
#  'id:asking::O': 853,
#  'id:same::O': 854,
#  'id:Foreign::B-per': 855,
#  'id:Minister::I-per': 856,
#  'id:Mustafa::I-per': 857,
#  'id:Osman::I-per': 858,
#  'id:Ismail::I-per': 859,
#  'id:Sudanese::B-gpe': 860,
#  'id:withdraw::O': 861,
#  'id:positions::O': 862,
#  'id:held::O': 863,
#  'id:April::B-tim': 864,
#  'id:cease-fire::O': 865,
#  'id:western::O': 866,
#  'id:agree::O': 867,
#  'id:stop::O': 868,
#  'id:Mr.::B-per': 869,
#  'id:announced::O': 870,
#  'id:decision::O': 871,
#  'id:United::B-org': 872,
#  'id:Nations::I-org': 873,
#  'id:African::B-org': 874,
#  'id:Khartoum::B-geo': 875,
#  'id:weeks::O': 876,
#  'id:AU::B-org': 877,
#  'id:repeatedly::O': 878,
#  'id:truce::O': 879,
#  'init_tag:B-tim': 880,
#  'id:head::O': 881,
#  'id:accused::O': 882,
#  'id:helicopters::O': 883,
#  'id:bombing::O': 884,
#  'id:rebel::O': 885,
#  'id:sites::O': 886,
#  'id:Darfur::I-geo': 887,
#  'id:village::O': 888,
#  'id:Labado::B-geo': 889,
#  'id:Khartoum::B-gpe': 890,
#  'id:defending::O': 891,
#  'id:Aid::O': 892,
#  'id:relief::O': 893,
#  'id:efforts::O': 894,
#  'id:suspended::O': 895,
#  'id:due::O': 896,
#  'id:Indonesian::B-gpe': 897,
#  'id:men::O': 898,
#  'id:connection::O': 899,
#  'id:October::B-tim': 900,
#  'id:1::I-tim': 901,
#  'id:Bali::B-geo': 902,
#  'prev_tag:I-tim::B-geo': 903,
#  'id:left::O': 904,
#  'id:23::O': 905,
#  'id:dead::O': 906,
#  'id:flown::O': 907,
#  'id:Java::B-geo': 908,
#  'id:island::O': 909,
#  'id:headquarters::O': 910,
#  'id:Australian::B-gpe': 911,
#  'id:French::B-gpe': 912,
#  'id:agencies::O': 913,
#  'id:(::O': 914,
#  'id:Cholily::B-per': 915,
#  'id:)::O': 916,
#  'id:captured::O': 917,
#  'id:series::O': 918,
#  'id:counter-terrorism::O': 919,
#  'id:raids::O': 920,
#  'id:Indonesia::B-geo': 921,
#  'id:ended::O': 922,
#  'id:death::O': 923,
#  'id:alleged::O': 924,
#  'id:extremist::O': 925,
#  'id:bombmaker::O': 926,
#  'id:Azahari::B-per': 927,
#  'id:bin::I-per': 928,
#  'id:Husin::I-per': 929,
#  'id:authorities::O': 930,
#  'id:blame::O': 931,
#  'id:orchestrating::O': 932,
#  'id:month::O': 933,
#  'id:well::O': 934,
#  'id:2002::B-tim': 935,
#  'prev_tag:B-tim::B-geo': 936,
#  'id:Gunmen::O': 937,
#  'id:shot::O': 938,
#  'id:Roman::B-org': 939,
#  'id:Catholic::I-org': 940,
#  'id:nun::O': 941,
#  'id:her::O': 942,
#  'id:bodyguard::O': 943,
#  'id:hospital::O': 944,
#  'id:she::O': 945,
#  'id:worked::O': 946,
#  'id:Islamist-controlled::O': 947,
#  'id:Some::O': 948,
#  'id:witnesses::O': 949,
#  'id:shooting::O': 950,
#  'id:feared::O': 951,
#  'id:linked::O': 952,
#  'id:Muslim::O': 953,
#  'id:anger::O': 954,
#  'id:toward::O': 955,
#  'id:Pope::B-per': 956,
#  'id:Benedict::I-per': 957,
#  'id:pistols::O': 958,
#  'id:attacked::O': 959,
#  'id:Sister::B-per': 960,
#  'id:Leonella::I-per': 961,
#  'id:Sgorbati::I-per': 962,
#  'id:finished::O': 963,
#  'id:teaching::O': 964,
#  'id:medical::O': 965,
#  'id:school::O': 966,
#  'id:class::O': 967,
#  'id:suspect::O': 968,
#  'id:Vatican::B-org': 969,
#  'id:deplored::O': 970,
#  'id:hoped::O': 971,
#  'id:isolated::O': 972,
#  'id:event::O': 973,
#  'id:irrationality::O': 974,
#  'id:arising::O': 975,
#  'id:comments::O': 976,
#  'id:Pope::O': 977,
#  'id:angered::O': 978,
#  'id:Muslims::O': 979,
#  'id:Authorities::O': 980,
#  'id:determined::O': 981,
#  'id:motive::O': 982,
#  'id:pope::O': 983,
#  'id:meant::O': 984,
#  'id:offense::O': 985,
#  'id:quoted::O': 986,
#  'id:14::O': 987,
#  'id:century::O': 988,
#  'id:Byzantine::B-per': 989,
#  'id:emperor::O': 990,
#  'id:saying::O': 991,
#  'id:teachings::O': 992,
#  'id:Muhammed::I-per': 993,
#  'id:brought::O': 994,
#  'id:evil::O': 995,
#  'id:world::O': 996,
#  'id:targeted::O': 997,
#  'id:northwest::O': 998,
#  'id:third::O': 999,
#  ...}

# %% [markdown]
# #### Training structured perceptron

# %%
corpus = skseq.readers.pos_corpus.PostagCorpus()
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)

# %%
sp.get_num_states(), sp.get_num_observations()
# Out:
# (17, 30863)

# %%
# %%time
num_epochs = 15
sp.fit(ex_feature_mapper.dataset, num_epochs)
# Out:
# Epoch: 0 Accuracy: 0.892678
# Epoch: 1 Accuracy: 0.931972
# Epoch: 2 Accuracy: 0.941622
# Epoch: 3 Accuracy: 0.947549
# Epoch: 4 Accuracy: 0.950647
# Epoch: 5 Accuracy: 0.953512
# Epoch: 6 Accuracy: 0.955472
# Epoch: 7 Accuracy: 0.957134
# Epoch: 8 Accuracy: 0.958280
# Epoch: 9 Accuracy: 0.958821
# Epoch: 10 Accuracy: 0.959816
# Epoch: 11 Accuracy: 0.960872
# Epoch: 12 Accuracy: 0.961597
# Epoch: 13 Accuracy: 0.962109
# Epoch: 14 Accuracy: 0.962987
# Wall time: 1h 4min 12s

# %%
# sp.save_model("perceptron_ex1")

# %%
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)
sp.load_model(dir="perceptron_ex1")

# %% [markdown]
# #### Testing

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

y_pred_2 = []
y_true = [item for x in Y_ids_test for item in x]
correct_sentences = 0
n_test = len(X_test)

for i in range(n_test):
    y_pred_aux = sp.predict_tags_given_words(X_test[i])
    y_pred_2.append(y_pred_aux)
    if list(y_pred_aux) == Y_ids_test[i]:
        correct_sentences += 1
    
y_pred = [item for x in y_pred_2 for item in x]
F1_score_multi = f1_score(y_true, y_pred, average=None)
Accuracy = accuracy_score(y_true, y_pred)
print('Accuracy for test is: ' + str(Accuracy))
print('F1-Score for test is: ' + str(np.mean(F1_score_multi)))
print('Correct sentences for test (%) : ' + str(correct_sentences/n_test))
# Out:
# Accuracy for test is: 0.9497189411859115
# F1-Score for test is: 0.6325282666272773
# Correct sentences for test (%) : 0.4780613947280614

# %%
ax = plot_confusion_matrix(y_true, y_pred, classes=list(sp.state_labels),
                      title='Confusion matrix')

# %% [markdown]
# #### SENTENCES TO TEST THE MODEL

# %% [markdown]
# We think that these are the tags that the model should obtain:
#
# 1. The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 2. The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 3. Jack/B-per London/I-per went/O to/O Parris./O
#
# 4. Jack/B-per London/I-per went/O to/O/O Paris./B-geo
#
# 5. We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
#
# 6. We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
#
# 7. The/O president/O of/O U.S.A/B-geo though/O they/O could/O win/O the/O war/O
#
# 8. The/O president/O of/O the/O United/B-geo States/B-geo of/B-geo America/B-geo though/O they/O could/O win/O the/O war/O
#
# 9. The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
#
# 10. Robin/B-per does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
print_all_test_sentences(test_sentences, sp)
# Out:
# The/O programmers/O from/O Barcelona/B-org might/O write/O a/O sentence/O without/O a/O spell/B-per checker./I-per
# The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/B-per checker./I-per
# Jack/B-per London/B-geo went/O to/O Parris./O
# Jack/B-per London/B-geo went/O to/O Paris./O
# We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
# We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
# The/O president/O of/O U.S.A/B-org though/O they/O could/O win/O the/O war/O
# The/O president/O of/O the/O United/B-geo States/I-geo of/I-geo America/I-geo though/O they/O could/O win/O the/O war/O
# The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
# Robin/B-org does/O not/O want/O to/O go/O to/O Saudi/O Arabia./O

# %%
# Here we can select the sentence in which we want to compare the true and the predicted tags
# Select a sentence between 1 and 10
i=1
compare_one_test_sentence(test_sentences, test_tags, sp, pos_to_tag, i)
# Out:
# Word            (True ): Pred
# The             (O    ): O
# programmers     (O    ): O
# from            (O    ): O
# Barcelona       (B-geo): B-org
# might           (O    ): O
# write           (O    ): O
# a               (O    ): O
# sentence        (O    ): O
# without         (O    ): O
# a               (O    ): O
# spell           (O    ): B-per
# checker.        (O    ): I-per

# %% [markdown]
# #### Checking the first sentence of the corpus

# %%
new_seq = Sequence(x=X_test[0], y=[int(0) for w in X_test[0]])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(X_test[0], Y_test[0], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# Officials       (O    ): O
# said            (O    ): O
# Sunday          (B-tim): B-tim
# Jean            (B-per): B-per
# Rene            (I-per): I-per
# Anthony         (I-per): I-per
# was             (O    ): O
# killed          (O    ): O
# in              (O    ): O
# a               (O    ): O
# shootout        (O    ): O
# with            (O    ): O
# police          (O    ): O
# near            (O    ): O
# the             (O    ): O
# capital         (O    ): O
# city            (O    ): O
# of              (O    ): O
# Port-au-Prince  (B-geo): O
# .               (O    ): O

# %% [markdown]
# ##### Post-comments:
#
# In the next experiment we are going to add a hyphen feature, because as we can see in the first sentence of the Test corpus (Port-au-Prince) we are failing.

# %% [markdown]
# # EXPERIMENT 2: Adding a hyphen

# %% [markdown]
# ##### Comments:
# In the second experiment we are going to introduce the **hyphen features** to check if this information is useful or not and if it helps with the previous error.

# %% [markdown]
# ### Extended features

# %%
ex_feature_mapper = skseq.sequences.extended_feature.ExtendedFeatures(sequence_list_train) 
ex_feature_mapper.build_features()
pprint.pprint(list(ex_feature_mapper.__dict__.keys()))
# Out:
# ['feature_dict',
#  'feature_list',
#  'add_features',
#  'dataset',
#  'node_feature_cache',
#  'initial_state_feature_cache',
#  'final_state_feature_cache',
#  'edge_feature_cache']

# %%
len(ex_feature_mapper.feature_dict)
# Out:
# 38313

# %%
ex_feature_mapper.feature_dict
# Out:
# {'init_tag:O': 0,
#  'id:Thousands::O': 1,
#  'id:of::O': 2,
#  'prev_tag:O::O': 3,
#  'id:demonstrators::O': 4,
#  'id:have::O': 5,
#  'id:marched::O': 6,
#  'id:through::O': 7,
#  'id:London::B-geo': 8,
#  'prev_tag:O::B-geo': 9,
#  'id:to::O': 10,
#  'prev_tag:B-geo::O': 11,
#  'id:protest::O': 12,
#  'id:the::O': 13,
#  'id:war::O': 14,
#  'id:in::O': 15,
#  'id:Iraq::B-geo': 16,
#  'id:and::O': 17,
#  'id:demand::O': 18,
#  'id:withdrawal::O': 19,
#  'id:British::B-gpe': 20,
#  'prev_tag:O::B-gpe': 21,
#  'id:troops::O': 22,
#  'prev_tag:B-gpe::O': 23,
#  'id:from::O': 24,
#  'id:that::O': 25,
#  'id:country::O': 26,
#  'id:.::O': 27,
#  'final_prev_tag:O': 28,
#  'id:Families::O': 29,
#  'id:soldiers::O': 30,
#  'id:killed::O': 31,
#  'id:conflict::O': 32,
#  'id:joined::O': 33,
#  'id:protesters::O': 34,
#  'id:who::O': 35,
#  'id:carried::O': 36,
#  'id:banners::O': 37,
#  'id:with::O': 38,
#  'id:such::O': 39,
#  'id:slogans::O': 40,
#  'id:as::O': 41,
#  'id:"::O': 42,
#  'id:Bush::B-per': 43,
#  'prev_tag:O::B-per': 44,
#  'id:Number::O': 45,
#  'prev_tag:B-per::O': 46,
#  'id:One::O': 47,
#  'id:Terrorist::O': 48,
#  'id:Stop::O': 49,
#  'id:Bombings::O': 50,
#  'id:They::O': 51,
#  'id:Houses::O': 52,
#  'id:Parliament::O': 53,
#  'id:a::O': 54,
#  'id:rally::O': 55,
#  'id:Hyde::B-geo': 56,
#  'id:Park::I-geo': 57,
#  'prev_tag:B-geo::I-geo': 58,
#  'prev_tag:I-geo::O': 59,
#  'id:Police::O': 60,
#  'id:put::O': 61,
#  'id:number::O': 62,
#  'id:marchers::O': 63,
#  'id:at::O': 64,
#  'id:10,000::O': 65,
#  'id:while::O': 66,
#  'id:organizers::O': 67,
#  'id:claimed::O': 68,
#  'id:it::O': 69,
#  'id:was::O': 70,
#  'id:1,00,000::O': 71,
#  'id:The::O': 72,
#  'id:comes::O': 73,
#  'id:on::O': 74,
#  'id:eve::O': 75,
#  'id:annual::O': 76,
#  'id:conference::O': 77,
#  'id:Britain::B-geo': 78,
#  "id:'s::O": 79,
#  'id:ruling::O': 80,
#  'id:Labor::B-org': 81,
#  'prev_tag:O::B-org': 82,
#  'id:Party::I-org': 83,
#  'prev_tag:B-org::I-org': 84,
#  'prev_tag:I-org::O': 85,
#  'id:southern::O': 86,
#  'id:English::B-gpe': 87,
#  'id:seaside::O': 88,
#  'id:resort::O': 89,
#  'id:Brighton::B-geo': 90,
#  'id:party::O': 91,
#  'id:is::O': 92,
#  'id:divided::O': 93,
#  'id:over::O': 94,
#  'id:Britain::B-gpe': 95,
#  'id:participation::O': 96,
#  'id:continued::O': 97,
#  'id:deployment::O': 98,
#  'id:8,500::O': 99,
#  'id:march::O': 100,
#  'id:came::O': 101,
#  'id:ahead::O': 102,
#  'id:anti-war::O': 103,
#  'hyphen::O': 104,
#  'id:protests::O': 105,
#  'id:today::O': 106,
#  'id:other::O': 107,
#  'id:cities::O': 108,
#  'id:,::O': 109,
#  'id:including::O': 110,
#  'id:Rome::B-geo': 111,
#  'id:Paris::B-geo': 112,
#  'id:Madrid::B-geo': 113,
#  'id:International::B-org': 114,
#  'id:Atomic::I-org': 115,
#  'id:Energy::I-org': 116,
#  'prev_tag:I-org::I-org': 117,
#  'id:Agency::I-org': 118,
#  'id:hold::O': 119,
#  'id:second::O': 120,
#  'id:day::O': 121,
#  'id:talks::O': 122,
#  'id:Vienna::B-geo': 123,
#  'id:Wednesday::B-tim': 124,
#  'prev_tag:B-geo::B-tim': 125,
#  'prev_tag:B-tim::O': 126,
#  'id:how::O': 127,
#  'id:respond::O': 128,
#  'id:Iran::B-gpe': 129,
#  'id:resumption::O': 130,
#  'id:low-level::O': 131,
#  'id:uranium::O': 132,
#  'id:conversion::O': 133,
#  'init_tag:B-gpe': 134,
#  'id:this::O': 135,
#  'id:week::O': 136,
#  'id:restarted::O': 137,
#  'id:parts::O': 138,
#  'id:process::O': 139,
#  'id:its::O': 140,
#  'id:Isfahan::B-geo': 141,
#  'id:nuclear::O': 142,
#  'id:plant::O': 143,
#  'id:Iranian::B-gpe': 144,
#  'id:officials::O': 145,
#  'id:say::O': 146,
#  'id:they::O': 147,
#  'id:expect::O': 148,
#  'id:get::O': 149,
#  'id:access::O': 150,
#  'id:sealed::O': 151,
#  'id:sensitive::O': 152,
#  'prev_tag:O::B-tim': 153,
#  'id:after::O': 154,
#  'id:an::O': 155,
#  'id:IAEA::B-org': 156,
#  'id:surveillance::O': 157,
#  'prev_tag:B-org::O': 158,
#  'id:system::O': 159,
#  'id:begins::O': 160,
#  'id:functioning::O': 161,
#  'id:step::O': 162,
#  'id:will::O': 163,
#  'id:allow::O': 164,
#  'id:facility::O': 165,
#  'id:operate::O': 166,
#  'id:full::O': 167,
#  'id:capacity::O': 168,
#  'id:European::B-org': 169,
#  'id:Union::I-org': 170,
#  'id:U.S.::B-gpe': 171,
#  'id:backing::O': 172,
#  'id:has::O': 173,
#  'id:threatened::O': 174,
#  'id:refer::O': 175,
#  'id:U.N.::B-org': 176,
#  'id:Security::I-org': 177,
#  'id:Council::I-org': 178,
#  'id:which::O': 179,
#  'id:could::O': 180,
#  'id:impose::O': 181,
#  'id:sanctions::O': 182,
#  'id:if::O': 183,
#  'id:finds::O': 184,
#  'id:Tehran::B-gpe': 185,
#  'id:violated::O': 186,
#  'id:Nuclear::B-art': 187,
#  'prev_tag:O::B-art': 188,
#  'id:Non-Proliferation::I-art': 189,
#  'hyphen::I-art': 190,
#  'prev_tag:B-art::I-art': 191,
#  'id:treaty::O': 192,
#  'prev_tag:I-art::O': 193,
#  'id:new::O': 194,
#  'id:President::B-per': 195,
#  'id:Mahmoud::I-per': 196,
#  'prev_tag:B-per::I-per': 197,
#  'id:Ahmadinejad::I-per': 198,
#  'prev_tag:I-per::I-per': 199,
#  'id:said::O': 200,
#  'prev_tag:I-per::O': 201,
#  'id:Tuesday::B-tim': 202,
#  'id:European::B-gpe': 203,
#  'id:incentives::O': 204,
#  'id:aimed::O': 205,
#  'id:persuading::O': 206,
#  'id:end::O': 207,
#  'id:fuel::O': 208,
#  'id:program::O': 209,
#  'id:are::O': 210,
#  'id:insult::O': 211,
#  'id:nation::O': 212,
#  'id:Two::O': 213,
#  'id:Germans::B-gpe': 214,
#  'id:four::O': 215,
#  'id:Nigerian::B-gpe': 216,
#  'id:oil::O': 217,
#  'id:workers::O': 218,
#  'id:were::O': 219,
#  'id:kidnapped::O': 220,
#  'id:by::O': 221,
#  'id:armed::O': 222,
#  'id:militants::O': 223,
#  'id:during::O': 224,
#  'id:raid::O': 225,
#  'id:boat::O': 226,
#  'id:Nigeria::B-geo': 227,
#  'id:oil-rich::O': 228,
#  'id:Delta::B-geo': 229,
#  'id:region::O': 230,
#  'id:An::O': 231,
#  'id:official::O': 232,
#  'id:German::B-gpe': 233,
#  'id:firm::O': 234,
#  'id:Bilfinger::B-org': 235,
#  'id:Berger::I-org': 236,
#  'id:Thomas::B-per': 237,
#  'id:Horbach::I-per': 238,
#  'id:gunmen::O': 239,
#  'id:stopped::O': 240,
#  'id:supply::O': 241,
#  'id:sailed::O': 242,
#  'id:State::I-geo': 243,
#  'id:Bayelsa::B-geo': 244,
#  'id:inspect::O': 245,
#  'id:offshore::O': 246,
#  'id:field::O': 247,
#  'id:owned::O': 248,
#  'id:Royal-Dutch::B-org': 249,
#  'hyphen::B-org': 250,
#  'id:Shell::I-org': 251,
#  'id:works::O': 252,
#  'id:sub-contractor::O': 253,
#  'id:for::O': 254,
#  'id:Shell::B-org': 255,
#  'id:Militant::O': 256,
#  'id:groups::O': 257,
#  'id:frequently::O': 258,
#  'id:attack::O': 259,
#  'id:operations::O': 260,
#  'id:Niger::B-geo': 261,
#  'id:Delta::I-geo': 262,
#  'id:social::O': 263,
#  'id:services::O': 264,
#  'id:better::O': 265,
#  'id:job::O': 266,
#  'id:opportunities::O': 267,
#  'id:multinational::O': 268,
#  'id:companies::O': 269,
#  'id:Poor::O': 270,
#  'id:residents::O': 271,
#  'id:often::O': 272,
#  'id:complain::O': 273,
#  'id:been::O': 274,
#  'id:cheated::O': 275,
#  'id:out::O': 276,
#  'id:huge::O': 277,
#  'id:riches::O': 278,
#  'id:extracted::O': 279,
#  'id:their::O': 280,
#  'id:tribal::O': 281,
#  'id:lands::O': 282,
#  'id:-::O': 283,
#  'id:where::O': 284,
#  'id:bulk::O': 285,
#  'id:Nigeria::B-gpe': 286,
#  'id:2.3::O': 287,
#  'id:million::O': 288,
#  'id:barrels::O': 289,
#  'id:petroleum::O': 290,
#  'id:pumped::O': 291,
#  'id:daily::O': 292,
#  'id:Suspected::O': 293,
#  'id:Islamist::O': 294,
#  'id:rebels::O': 295,
#  'id:fired::O': 296,
#  'id:mortar::O': 297,
#  'id:shells::O': 298,
#  'id:palace::O': 299,
#  'id:used::O': 300,
#  'id:Somalia::B-geo': 301,
#  'id:interim::O': 302,
#  'id:Abdullahi::I-per': 303,
#  'id:Yusuf::I-per': 304,
#  'id:Ahmad::I-per': 305,
#  'id:It::O': 306,
#  'id:not::O': 307,
#  'id:immediately::O': 308,
#  'id:clear::O': 309,
#  'id:president::O': 310,
#  'id:Mogadishu::B-geo': 311,
#  'id:when::O': 312,
#  'id:occurred::O': 313,
#  'id:or::O': 314,
#  'id:anyone::O': 315,
#  'id:hurt::O': 316,
#  'id:Local::O': 317,
#  'id:news::O': 318,
#  'id:reports::O': 319,
#  'id:least::O': 320,
#  'id:five::O': 321,
#  'id:hit::O': 322,
#  'id:compound::O': 323,
#  'id:mortars::O': 324,
#  'id:elsewhere::O': 325,
#  'id:attacks::O': 326,
#  'id:government::O': 327,
#  'id:go::O': 328,
#  'id:reconciliation::O': 329,
#  'id:more::O': 330,
#  'id:than::O': 331,
#  'id:1,300::O': 332,
#  'id:Somali::B-gpe': 333,
#  'id:elders::O': 334,
#  'id:warlords::O': 335,
#  'id:politicians::O': 336,
#  'id:invited::O': 337,
#  'id:Iraqi::B-gpe': 338,
#  'id:military::O': 339,
#  'id:tanks::O': 340,
#  'id:arrived::O': 341,
#  'id:northern::O': 342,
#  'id:city::O': 343,
#  'id:Mosul::B-geo': 344,
#  'id:offensive::O': 345,
#  'id:against::O': 346,
#  'id:al::B-org': 347,
#  'id:Qaida::I-org': 348,
#  'id:in::I-org': 349,
#  'id:Iraq::I-org': 350,
#  'id:fighters::O': 351,
#  'id:Officials::O': 352,
#  'id:many::O': 353,
#  'id:Sunni::B-geo': 354,
#  'id:Arab::I-geo': 355,
#  'id:Kurdish::B-geo': 356,
#  'id:bombings::O': 357,
#  'id:last::O': 358,
#  'id:34::O': 359,
#  'id:people::O': 360,
#  'id:wounded::O': 361,
#  'id:200::O': 362,
#  'id:commanders::O': 363,
#  'id:explained::O': 364,
#  'id:American::B-gpe': 365,
#  'id:forces::O': 366,
#  'id:participate::O': 367,
#  'id:fled::O': 368,
#  'id:successful::O': 369,
#  'id:campaigns::O': 370,
#  'id:them::O': 371,
#  'id:Anbar::B-geo': 372,
#  'id:province::O': 373,
#  'id:Baghdad::B-geo': 374,
#  'id:provinces::O': 375,
#  'init_tag:B-geo': 376,
#  'id:largest::O': 377,
#  'id:north::O': 378,
#  'id:long::O': 379,
#  'id:stronghold::O': 380,
#  'id:Sunni::B-org': 381,
#  'id:militant::O': 382,
#  'id:In::O': 383,
#  'id:violence::O': 384,
#  'id:one::O': 385,
#  'id:soldier::O': 386,
#  'id:patrol::O': 387,
#  'id:Sunday::B-tim': 388,
#  'id:Egyptian::B-gpe': 389,
#  'id:police::O': 390,
#  'id:arrested::O': 391,
#  'id:16::O': 392,
#  'id:members::O': 393,
#  'id:opposition::O': 394,
#  'id:Muslim::B-org': 395,
#  'id:Brotherhood::I-org': 396,
#  'id:prepare::O': 397,
#  'id:parliamentary::O': 398,
#  'id:runoff::O': 399,
#  'id:elections::O': 400,
#  'id:Saturday::B-tim': 401,
#  'id:arrests::O': 402,
#  'id:Friday::B-tim': 403,
#  'id:Alexandria::B-geo': 404,
#  'id:A::O': 405,
#  'id:spokesman::O': 406,
#  'id:Brotherhood::B-org': 407,
#  'id:attempt::O': 408,
#  'id:cut::O': 409,
#  'id:off::O': 410,
#  'id:supporters::O': 411,
#  'id:punishment::O': 412,
#  'id:winning::O': 413,
#  'id:seats::O': 414,
#  'id:earlier::O': 415,
#  'id:tripled::O': 416,
#  'id:strength::O': 417,
#  'id:parliament::O': 418,
#  'id:recent::O': 419,
#  'id:raising::O': 420,
#  'id:total::O': 421,
#  'id:47::O': 422,
#  'id:voters::O': 423,
#  'id:cast::O': 424,
#  'id:ballots::O': 425,
#  'id:nine::O': 426,
#  'id:no::O': 427,
#  'id:candidate::O': 428,
#  'id:won::O': 429,
#  'id:majority::O': 430,
#  'id:previous::O': 431,
#  'id:round::O': 432,
#  'id:voting::O': 433,
#  'id:banned::O': 434,
#  'id:political::O': 435,
#  'id:but::O': 436,
#  'id:endorses::O': 437,
#  'id:so-called::O': 438,
#  'id:independent::O': 439,
#  'id:candidates::O': 440,
#  'id:whose::O': 441,
#  'id:allegiance::O': 442,
#  'id:known::O': 443,
#  'id:Hardline::O': 444,
#  'id:lawmakers::O': 445,
#  'id:Pakistan::B-geo': 446,
#  'id:North::B-geo': 447,
#  'id:West::I-geo': 448,
#  'id:Frontier::I-geo': 449,
#  'prev_tag:I-geo::I-geo': 450,
#  'id:Province::I-geo': 451,
#  'id:pushed::O': 452,
#  'id:law::O': 453,
#  'id:aims::O': 454,
#  'id:ensure::O': 455,
#  'id:Islamic::O': 456,
#  'id:correctness::O': 457,
#  'id:public::O': 458,
#  'id:places::O': 459,
#  'id:establishes::O': 460,
#  'id:morality::O': 461,
#  'id:enforce::O': 462,
#  'id:decent::O': 463,
#  'id:behavior::O': 464,
#  'id:six-party::O': 465,
#  'id:coalition::O': 466,
#  'id:religious::O': 467,
#  'id:based::O': 468,
#  'id:parties::O': 469,
#  'id:Mutahida::B-org': 470,
#  'id:Majlis-e-Amal::I-org': 471,
#  'hyphen::I-org': 472,
#  'id:dominates::O': 473,
#  'id:provincial::O': 474,
#  'id:assembly::O': 475,
#  'id:so::O': 476,
#  'id:bill::O': 477,
#  'id:easily::O': 478,
#  'id:passed::O': 479,
#  'id:Thursday::B-tim': 480,
#  'id:vote::O': 481,
#  'id:68-34::O': 482,
#  'id:governor::O': 483,
#  'id:must::O': 484,
#  'id:still::O': 485,
#  'id:sign::O': 486,
#  'id:before::O': 487,
#  'id:becomes::O': 488,
#  'id:seen::O': 489,
#  'id:only::O': 490,
#  'id:formality::O': 491,
#  'id:proposed::O': 492,
#  'id:calls::O': 493,
#  'id:setting::O': 494,
#  'id:up::O': 495,
#  'id:force::O': 496,
#  'id:make::O': 497,
#  'id:sure::O': 498,
#  'id:adhere::O': 499,
#  'id:values::O': 500,
#  'id:entertainment::O': 501,
#  'id:outlets::O': 502,
#  'id:close::O': 503,
#  'id:weekly::O': 504,
#  'id:prayers::O': 505,
#  'id:Violators::O': 506,
#  'id:be::O': 507,
#  'id:jailed::O': 508,
#  'id:six::O': 509,
#  'id:months::O': 510,
#  'id:denounced::O': 511,
#  'id:measure::O': 512,
#  'id:comparing::O': 513,
#  'id:draconian::O': 514,
#  'id:rule::O': 515,
#  'id:former::O': 516,
#  'id:Taleban::B-org': 517,
#  'id:neighboring::O': 518,
#  'id:Afghanistan::B-geo': 519,
#  'id:man::O': 520,
#  'id:dressed::O': 521,
#  'id:suicide::O': 522,
#  'id:bomber::O': 523,
#  'id:demonstration::O': 524,
#  'id:publication::O': 525,
#  'id:cartoons::O': 526,
#  'id:depicting::O': 527,
#  'id:Islam::B-org': 528,
#  'id:Prophet::B-per': 529,
#  'id:Muhammad::I-per': 530,
#  'id:Bedfordshire::B-gpe': 531,
#  'id:Omar::B-per': 532,
#  'id:Khayam::I-per': 533,
#  'id:Bedford::B-geo': 534,
#  'id:breaching::O': 535,
#  'id:conditions::O': 536,
#  'id:his::O': 537,
#  'id:parole::O': 538,
#  'id:British::B-org': 539,
#  'id:Home::I-org': 540,
#  'id:Office::I-org': 541,
#  'id:sought::O': 542,
#  'id:investigation::O': 543,
#  'id:Khayam::B-per': 544,
#  'id:he::O': 545,
#  'id:photographed::O': 546,
#  'id:fatigues::O': 547,
#  'id:black::O': 548,
#  'id:cap::O': 549,
#  'id:bulky::O': 550,
#  'id:belt::O': 551,
#  'id:Home::B-org': 552,
#  'id:told::O': 553,
#  'id:Associated::B-org': 554,
#  'id:Press::I-org': 555,
#  'id:paroled::O': 556,
#  'id:offender::O': 557,
#  'id:gives::O': 558,
#  'id:cause::O': 559,
#  'id:concern::O': 560,
#  'id:can::O': 561,
#  'id:sent::O': 562,
#  'id:back::O': 563,
#  'id:prison::O': 564,
#  'id:AP::B-org': 565,
#  'id:also::O': 566,
#  'id:since::O': 567,
#  'id:year::O': 568,
#  'id:serving::O': 569,
#  'id:half::O': 570,
#  'id:six-year::O': 571,
#  'id:sentence::O': 572,
#  'id:drug::O': 573,
#  'id:dealing::O': 574,
#  'id:Pakistani::B-gpe': 575,
#  'id:unidentified::O': 576,
#  'id:three::O': 577,
#  'id:minister::O': 578,
#  'id:semi-autonomous::O': 579,
#  'id:bordering::O': 580,
#  'id:prominent::O': 581,
#  'id:leader::O': 582,
#  'id:Malik::B-per': 583,
#  'id:Faridullah::I-per': 584,
#  'id:Khan::I-per': 585,
#  'id:traveling::O': 586,
#  'id:South::B-geo': 587,
#  'id:Waziristan::I-geo': 588,
#  'prev_tag:I-geo::B-tim': 589,
#  'id:vehicle::O': 590,
#  'id:ambushed::O': 591,
#  'id:Kani::B-geo': 592,
#  'id:Wam::I-geo': 593,
#  'id:area::O': 594,
#  'id:His::O': 595,
#  'id:driver::O': 596,
#  'id:elder::O': 597,
#  'id:No::O': 598,
#  'id:responsibility::O': 599,
#  'id:killings::O': 600,
#  'id:ambush::O': 601,
#  'id:commander::O': 602,
#  'id:army::O': 603,
#  'id:almost::O': 604,
#  'id:completely::O': 605,
#  'id:eliminated::O': 606,
#  'id:became::O': 607,
#  'id:refuge::O': 608,
#  'id:al-Qaida::B-org': 609,
#  'id:ousted::O': 610,
#  'id:2001::B-tim': 611,
#  'id:senior::O': 612,
#  'id:says::O': 613,
#  'id:Pakistan::B-gpe': 614,
#  'id:wants::O': 615,
#  'id:what::O': 616,
#  'id:sordid::O': 617,
#  'id:chapter::O': 618,
#  'id:proliferation::O': 619,
#  'id:top::O': 620,
#  'id:scientists::O': 621,
#  'id:behind::O': 622,
#  'id:build::O': 623,
#  'id:civilian::O': 624,
#  'id:ties::O': 625,
#  'id:United::B-gpe': 626,
#  'id:States::I-gpe': 627,
#  'prev_tag:B-gpe::I-gpe': 628,
#  'prev_tag:I-gpe::O': 629,
#  'id:But::O': 630,
#  'id:ready::O': 631,
#  'id:scientist::O': 632,
#  'id:Abdul::B-per': 633,
#  'id:Qadeer::I-per': 634,
#  'id:available::O': 635,
#  'id:direct::O': 636,
#  'id:questioning::O': 637,
#  'id:sale::O': 638,
#  'id:secrets::O': 639,
#  'id:states::O': 640,
#  'id:Libya::B-gpe': 641,
#  'id:North::B-gpe': 642,
#  'id:Korea::I-gpe': 643,
#  'id:He::O': 644,
#  'id:there::O': 645,
#  'id:reasons::O': 646,
#  'id:national::O': 647,
#  'id:sensitivities::O': 648,
#  'id:making::O': 649,
#  'id:him::O': 650,
#  'id:giving::O': 651,
#  'id:background::O': 652,
#  'id:briefing::O': 653,
#  'id:small::O': 654,
#  'id:group::O': 655,
#  'id:reporters::O': 656,
#  'id:Washington::B-geo': 657,
#  'init_tag:B-per': 658,
#  'id:Khan::B-per': 659,
#  'id:admitted::O': 660,
#  'id:2004::B-tim': 661,
#  'id:operated::O': 662,
#  'id:worldwide::O': 663,
#  'id:clandestine::O': 664,
#  'id:network::O': 665,
#  'id:sell::O': 666,
#  'id:technology::O': 667,
#  'id:market::O': 668,
#  'id:placed::O': 669,
#  'id:under::O': 670,
#  'id:house::O': 671,
#  'id:arrest::O': 672,
#  'id:Islamabad::B-geo': 673,
#  'id:because::O': 674,
#  'id:considered::O': 675,
#  'id:father::O': 676,
#  'id:bomb::O': 677,
#  'id:Army::B-org': 678,
#  'prev_tag:B-gpe::B-org': 679,
#  'id:renew::O': 680,
#  'id:controversial::O': 681,
#  'id:multi-billion::O': 682,
#  'id:dollar::O': 683,
#  'id:contract::O': 684,
#  'id:Halliburton::B-org': 685,
#  'id:company::O': 686,
#  'id:provide::O': 687,
#  'id:logistical::O': 688,
#  'id:support::O': 689,
#  'init_tag:B-org': 690,
#  'id:providing::O': 691,
#  'id:list::O': 692,
#  'id:meals::O': 693,
#  'id:communication::O': 694,
#  'id:several::O': 695,
#  'id:years::O': 696,
#  'id:Critics::O': 697,
#  'id:include::O': 698,
#  'id:auditors::O': 699,
#  'id:congressional::O': 700,
#  'id:Democrats::O': 701,
#  'id:produced::O': 702,
#  'id:some::O': 703,
#  'id:shoddy::O': 704,
#  'id:work::O': 705,
#  'id:charges::O': 706,
#  'id:too::O': 707,
#  'id:much::O': 708,
#  'id:money::O': 709,
#  'id:strongly::O': 710,
#  'id:denies::O': 711,
#  'id:allegations::O': 712,
#  'id:When::O': 713,
#  'id:re-bidding::O': 714,
#  'id:chance::O': 715,
#  'id:compete::O': 716,
#  'id:portions::O': 717,
#  'id:Representatives::O': 718,
#  'id:Asia::B-org': 719,
#  'id:Pacific::I-org': 720,
#  'id:Economic::I-org': 721,
#  'id:Cooperation::I-org': 722,
#  'id:Business::I-org': 723,
#  'id:Advisory::I-org': 724,
#  'id:holding::O': 725,
#  'id:meetings::O': 726,
#  'id:finalize::O': 727,
#  'id:report::O': 728,
#  'id:APEC::B-org': 729,
#  'id:leaders::O': 730,
#  'id:summit::O': 731,
#  'id:September::B-tim': 732,
#  'id:8::I-tim': 733,
#  'prev_tag:B-tim::I-tim': 734,
#  'prev_tag:I-tim::O': 735,
#  'id:9::B-tim': 736,
#  'id:VOA::B-org': 737,
#  'id:Nancy-Amelia::B-per': 738,
#  'hyphen::B-per': 739,
#  'id:Collins::I-per': 740,
#  'id:Sydney::B-geo': 741,
#  'id:Energy::O': 742,
#  'id:security::O': 743,
#  'id:climate::O': 744,
#  'id:change::O': 745,
#  'id:World::B-org': 746,
#  'id:Trade::I-org': 747,
#  'id:Organization::I-org': 748,
#  'id:stalled::O': 749,
#  'id:negotiations::O': 750,
#  'id:investment::O': 751,
#  'id:all::O': 752,
#  'id:expected::O': 753,
#  'id:among::O': 754,
#  'id:major::O': 755,
#  'id:topics::O': 756,
#  'id:ABAC::B-org': 757,
#  'id:Tim::B-per': 758,
#  'id:Harcourt::I-per': 759,
#  'id:chief::O': 760,
#  'id:economist::O': 761,
#  'id:Australian::B-org': 762,
#  'id:Commission::I-org': 763,
#  'id:plays::O': 764,
#  'id:important::O': 765,
#  'id:role::O': 766,
#  'id:informing::O': 767,
#  'id:governments::O': 768,
#  'id:problems::O': 769,
#  'id:most::O': 770,
#  'id:thing::O': 771,
#  'id:business::O': 772,
#  'id:do::O': 773,
#  'id:tell::O': 774,
#  'id:logjams::O': 775,
#  'id:obstacles::O': 776,
#  'id:things::O': 777,
#  'id:improve::O': 778,
#  'id:Harcourt::B-per': 779,
#  'id:I::O': 780,
#  'id:think::O': 781,
#  'id:actually::O': 782,
#  'id:played::O': 783,
#  'id:pretty::O': 784,
#  'id:good::O': 785,
#  'id:leadership::O': 786,
#  'id:talking::O': 787,
#  'id:about::O': 788,
#  'id:trade::O': 789,
#  'id:facilitation::O': 790,
#  'id:basically::O': 791,
#  'id:standards::O': 792,
#  'id:consistent::O': 793,
#  'id:harmonious::O': 794,
#  'id:across::O': 795,
#  'id:comprises::O': 796,
#  'id:private::O': 797,
#  'id:sector::O': 798,
#  'id:each::O': 799,
#  'id:21::O': 800,
#  'id:economies::O': 801,
#  'id:meets::O': 802,
#  'id:times::O': 803,
#  'id:made::O': 804,
#  'id:permanent::O': 805,
#  'id:body::O': 806,
#  'id:1995::B-tim': 807,
#  'id:perspective::O': 808,
#  'id:within::O': 809,
#  'id:Members::O': 810,
#  'id:represent::O': 811,
#  'id:range::O': 812,
#  'id:sectors::O': 813,
#  'id:medium::O': 814,
#  'id:businesses::O': 815,
#  'id:need::O': 816,
#  'id:energy::O': 817,
#  'id:efficiency::O': 818,
#  'id:encourage::O': 819,
#  'id:conservation::O': 820,
#  'id:practices::O': 821,
#  'id:discuss::O': 822,
#  'id:ways::O': 823,
#  'id:enhance::O': 824,
#  'id:regional::O': 825,
#  'id:cooperation::O': 826,
#  'id:reckon::O': 827,
#  "id:'ll::O": 828,
#  'id:talk::O': 829,
#  'id:little::O': 830,
#  'id:bit::O': 831,
#  'id:customs::O': 832,
#  'id:quarantine::O': 833,
#  'id:having::O': 834,
#  'id:arrangements::O': 835,
#  'id:around::O': 836,
#  'id:And::O': 837,
#  'id:want::O': 838,
#  'id:one-stop::O': 839,
#  'id:shop::O': 840,
#  'id:terms::O': 841,
#  'id:combining::O': 842,
#  'id:immigration::O': 843,
#  'id:together::O': 844,
#  'id:\x85::O': 845,
#  'id:just::O': 846,
#  'id:streamlined::O': 847,
#  'id:provides::O': 848,
#  'id:certainty::O': 849,
#  'id:non-governmental::O': 850,
#  'id:formal::O': 851,
#  'id:dialogue::O': 852,
#  'id:present::O': 853,
#  'id:meeting::O': 854,
#  'id:Sudan::B-gpe': 855,
#  'id:order::O': 856,
#  'id:Darfur::B-geo': 857,
#  'id:asking::O': 858,
#  'id:same::O': 859,
#  'id:Foreign::B-per': 860,
#  'id:Minister::I-per': 861,
#  'id:Mustafa::I-per': 862,
#  'id:Osman::I-per': 863,
#  'id:Ismail::I-per': 864,
#  'id:Sudanese::B-gpe': 865,
#  'id:withdraw::O': 866,
#  'id:positions::O': 867,
#  'id:held::O': 868,
#  'id:April::B-tim': 869,
#  'id:cease-fire::O': 870,
#  'id:western::O': 871,
#  'id:agree::O': 872,
#  'id:stop::O': 873,
#  'id:Mr.::B-per': 874,
#  'id:announced::O': 875,
#  'id:decision::O': 876,
#  'id:United::B-org': 877,
#  'id:Nations::I-org': 878,
#  'id:African::B-org': 879,
#  'id:Khartoum::B-geo': 880,
#  'id:weeks::O': 881,
#  'id:AU::B-org': 882,
#  'id:repeatedly::O': 883,
#  'id:truce::O': 884,
#  'init_tag:B-tim': 885,
#  'id:head::O': 886,
#  'id:accused::O': 887,
#  'id:helicopters::O': 888,
#  'id:bombing::O': 889,
#  'id:rebel::O': 890,
#  'id:sites::O': 891,
#  'id:Darfur::I-geo': 892,
#  'id:village::O': 893,
#  'id:Labado::B-geo': 894,
#  'id:Khartoum::B-gpe': 895,
#  'id:defending::O': 896,
#  'id:Aid::O': 897,
#  'id:relief::O': 898,
#  'id:efforts::O': 899,
#  'id:suspended::O': 900,
#  'id:due::O': 901,
#  'id:Indonesian::B-gpe': 902,
#  'id:men::O': 903,
#  'id:connection::O': 904,
#  'id:October::B-tim': 905,
#  'id:1::I-tim': 906,
#  'id:Bali::B-geo': 907,
#  'prev_tag:I-tim::B-geo': 908,
#  'id:left::O': 909,
#  'id:23::O': 910,
#  'id:dead::O': 911,
#  'id:flown::O': 912,
#  'id:Java::B-geo': 913,
#  'id:island::O': 914,
#  'id:headquarters::O': 915,
#  'id:Australian::B-gpe': 916,
#  'id:French::B-gpe': 917,
#  'id:agencies::O': 918,
#  'id:(::O': 919,
#  'id:Cholily::B-per': 920,
#  'id:)::O': 921,
#  'id:captured::O': 922,
#  'id:series::O': 923,
#  'id:counter-terrorism::O': 924,
#  'id:raids::O': 925,
#  'id:Indonesia::B-geo': 926,
#  'id:ended::O': 927,
#  'id:death::O': 928,
#  'id:alleged::O': 929,
#  'id:extremist::O': 930,
#  'id:bombmaker::O': 931,
#  'id:Azahari::B-per': 932,
#  'id:bin::I-per': 933,
#  'id:Husin::I-per': 934,
#  'id:authorities::O': 935,
#  'id:blame::O': 936,
#  'id:orchestrating::O': 937,
#  'id:month::O': 938,
#  'id:well::O': 939,
#  'id:2002::B-tim': 940,
#  'prev_tag:B-tim::B-geo': 941,
#  'id:Gunmen::O': 942,
#  'id:shot::O': 943,
#  'id:Roman::B-org': 944,
#  'id:Catholic::I-org': 945,
#  'id:nun::O': 946,
#  'id:her::O': 947,
#  'id:bodyguard::O': 948,
#  'id:hospital::O': 949,
#  'id:she::O': 950,
#  'id:worked::O': 951,
#  'id:Islamist-controlled::O': 952,
#  'id:Some::O': 953,
#  'id:witnesses::O': 954,
#  'id:shooting::O': 955,
#  'id:feared::O': 956,
#  'id:linked::O': 957,
#  'id:Muslim::O': 958,
#  'id:anger::O': 959,
#  'id:toward::O': 960,
#  'id:Pope::B-per': 961,
#  'id:Benedict::I-per': 962,
#  'id:pistols::O': 963,
#  'id:attacked::O': 964,
#  'id:Sister::B-per': 965,
#  'id:Leonella::I-per': 966,
#  'id:Sgorbati::I-per': 967,
#  'id:finished::O': 968,
#  'id:teaching::O': 969,
#  'id:medical::O': 970,
#  'id:school::O': 971,
#  'id:class::O': 972,
#  'id:suspect::O': 973,
#  'id:Vatican::B-org': 974,
#  'id:deplored::O': 975,
#  'id:hoped::O': 976,
#  'id:isolated::O': 977,
#  'id:event::O': 978,
#  'id:irrationality::O': 979,
#  'id:arising::O': 980,
#  'id:comments::O': 981,
#  'id:Pope::O': 982,
#  'id:angered::O': 983,
#  'id:Muslims::O': 984,
#  'id:Authorities::O': 985,
#  'id:determined::O': 986,
#  'id:motive::O': 987,
#  'id:pope::O': 988,
#  'id:meant::O': 989,
#  'id:offense::O': 990,
#  'id:quoted::O': 991,
#  'id:14::O': 992,
#  'id:century::O': 993,
#  'id:Byzantine::B-per': 994,
#  'id:emperor::O': 995,
#  'id:saying::O': 996,
#  'id:teachings::O': 997,
#  'id:Muhammed::I-per': 998,
#  'id:brought::O': 999,
#  ...}

# %%
[x for x in list(ex_feature_mapper.feature_dict.keys()) if 'hyphen' in x]
# Out:
# ['hyphen::O',
#  'hyphen::I-art',
#  'hyphen::B-org',
#  'hyphen::I-org',
#  'hyphen::B-per',
#  'hyphen::B-geo',
#  'hyphen::I-per',
#  'hyphen::B-gpe',
#  'hyphen::I-tim',
#  'hyphen::B-art',
#  'hyphen::B-tim',
#  'hyphen::I-geo',
#  'hyphen::B-nat',
#  'hyphen::B-eve',
#  'hyphen::I-eve']

# %% [markdown]
# #### Training structured perceptron

# %%
corpus = skseq.readers.pos_corpus.PostagCorpus()
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)

# %%
sp.get_num_states(), sp.get_num_observations()
# Out:
# (17, 30863)

# %%
# %%time
num_epochs = 15
sp.fit(ex_feature_mapper.dataset, num_epochs)
# Out:
# Epoch: 0 Accuracy: 0.893649
# Epoch: 1 Accuracy: 0.932477
# Epoch: 2 Accuracy: 0.941703
# Epoch: 3 Accuracy: 0.947204
# Epoch: 4 Accuracy: 0.950647
# Epoch: 5 Accuracy: 0.953267
# Epoch: 6 Accuracy: 0.955126
# Epoch: 7 Accuracy: 0.956926
# Epoch: 8 Accuracy: 0.957718
# Epoch: 9 Accuracy: 0.959740
# Epoch: 10 Accuracy: 0.960284
# Epoch: 11 Accuracy: 0.960919
# Epoch: 12 Accuracy: 0.961542
# Epoch: 13 Accuracy: 0.962344
# Epoch: 14 Accuracy: 0.962593
# Wall time: 1h 5min 56s

# %%
sp.save_model("perceptron_ex2")

# %%
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)
sp.load_model(dir="perceptron_ex2")

# %% [markdown]
# #### Testing

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

y_pred_2 = []
y_true = [item for x in Y_ids_test for item in x]
correct_sentences = 0
n_test = len(X_test)

for i in range(n_test):
    y_pred_aux = sp.predict_tags_given_words(X_test[i])
    y_pred_2.append(y_pred_aux)
    if list(y_pred_aux) == Y_ids_test[i]:
        correct_sentences += 1
    
y_pred = [item for x in y_pred_2 for item in x]
F1_score_multi = f1_score(y_true, y_pred, average=None)
Accuracy = accuracy_score(y_true, y_pred)
print('Accuracy for test is: ' + str(Accuracy))
print('F1-Score for test is: ' + str(np.mean(F1_score_multi)))
print('Correct sentences for test (%) : ' + str(correct_sentences/n_test))
# Out:
# Accuracy for test is: 0.950487028495657
# F1-Score for test is: 0.6293839019546097
# Correct sentences for test (%) : 0.48373373373373374

# %%
ax = plot_confusion_matrix(y_true, y_pred, classes=list(sp.state_labels),
                      title='Confusion matrix')

# %% [markdown]
# #### SENTENCES TO TEST THE MODEL

# %% [markdown]
# We think that these are the tags that the model should obtain:
#
# 1. The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 2. The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 3. Jack/B-per London/I-per went/O to/O Parris./O
#
# 4. Jack/B-per London/I-per went/O to/O/O Paris./B-geo
#
# 5. We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
#
# 6. We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
#
# 7. The/O president/O of/O U.S.A/B-geo though/O they/O could/O win/O the/O war/O
#
# 8. The/O president/O of/O the/O United/B-geo States/B-geo of/B-geo America/B-geo though/O they/O could/O win/O the/O war/O
#
# 9. The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
#
# 10. Robin/B-per does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
for sentence in test_sentences:
    new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
    print(sp.viterbi_decode(new_seq)[0].to_words(sequence_list_train, only_tag_translation=True))
# Out:
# The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/B-per checker./I-per
# The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/B-per checker./I-per
# Jack/B-per London/B-geo went/O to/O Parris./O
# Jack/B-per London/B-geo went/O to/O Paris./O
# We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
# We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
# The/O president/O of/O U.S.A/B-org though/O they/O could/O win/O the/O war/O
# The/O president/O of/O the/O United/B-geo States/I-geo of/I-geo America/I-geo though/O they/O could/O win/O the/O war/O
# The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
# Robin/B-org does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
# Here we can select the sentence in which we want to compare the true and the predicted tags
# Select a sentence between 1 and 10
i=1
sentence = test_sentences[i-1]
new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(sentence.split(), test_tags[i-1], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# The             (O    ): O
# programmers     (O    ): O
# from            (O    ): O
# Barcelona       (B-geo): B-geo
# might           (O    ): O
# write           (O    ): O
# a               (O    ): O
# sentence        (O    ): O
# without         (O    ): O
# a               (O    ): O
# spell           (O    ): B-per
# checker.        (O    ): I-per

# %% [markdown]
# #### Hyphen checking

# %%
new_seq = Sequence(x=X_test[0], y=[int(0) for w in X_test[0]])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(X_test[0], Y_test[0], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# Officials       (O    ): O
# said            (O    ): O
# Sunday          (B-tim): B-tim
# Jean            (B-per): B-per
# Rene            (I-per): I-per
# Anthony         (I-per): I-per
# was             (O    ): O
# killed          (O    ): O
# in              (O    ): O
# a               (O    ): O
# shootout        (O    ): O
# with            (O    ): O
# police          (O    ): O
# near            (O    ): O
# the             (O    ): O
# capital         (O    ): O
# city            (O    ): O
# of              (O    ): O
# Port-au-Prince  (B-geo): O
# .               (O    ): O

# %% [markdown]
# ##### Post-comments:
#
# As we can see we have fixed the error with the word Port-au-Prince. Now, we are going to fix the problem with capital letter at the begging. For example, when we have Jean Rene Anthony it does not recognize it as person. We are going to add in the next experiment a new feature with a capital letter at the beggining.

# %% [markdown]
# # EXPERIMENT 3: Adding a capital letter at the beggining

# %% [markdown]
# ##### Comments:
#
# Adding a **capital letter at the beggining** feature (without the point at the end) + Hyphen feature

# %% [markdown]
# ### Extended features

# %%
ex_feature_mapper = skseq.sequences.extended_feature.ExtendedFeatures(sequence_list_train) 
ex_feature_mapper.build_features()
pprint.pprint(list(ex_feature_mapper.__dict__.keys()))
# Out:
# ['feature_dict',
#  'feature_list',
#  'add_features',
#  'dataset',
#  'node_feature_cache',
#  'initial_state_feature_cache',
#  'final_state_feature_cache',
#  'edge_feature_cache']

# %%
len(ex_feature_mapper.feature_dict)
# Out:
# 38330

# %%
ex_feature_mapper.feature_dict
# Out:
# {'init_tag:O': 0,
#  'id:Thousands::O': 1,
#  'upper_ini::O': 2,
#  'id:of::O': 3,
#  'prev_tag:O::O': 4,
#  'id:demonstrators::O': 5,
#  'id:have::O': 6,
#  'id:marched::O': 7,
#  'id:through::O': 8,
#  'id:London::B-geo': 9,
#  'upper_ini::B-geo': 10,
#  'prev_tag:O::B-geo': 11,
#  'id:to::O': 12,
#  'prev_tag:B-geo::O': 13,
#  'id:protest::O': 14,
#  'id:the::O': 15,
#  'id:war::O': 16,
#  'id:in::O': 17,
#  'id:Iraq::B-geo': 18,
#  'id:and::O': 19,
#  'id:demand::O': 20,
#  'id:withdrawal::O': 21,
#  'id:British::B-gpe': 22,
#  'upper_ini::B-gpe': 23,
#  'prev_tag:O::B-gpe': 24,
#  'id:troops::O': 25,
#  'prev_tag:B-gpe::O': 26,
#  'id:from::O': 27,
#  'id:that::O': 28,
#  'id:country::O': 29,
#  'id:.::O': 30,
#  'final_prev_tag:O': 31,
#  'id:Families::O': 32,
#  'id:soldiers::O': 33,
#  'id:killed::O': 34,
#  'id:conflict::O': 35,
#  'id:joined::O': 36,
#  'id:protesters::O': 37,
#  'id:who::O': 38,
#  'id:carried::O': 39,
#  'id:banners::O': 40,
#  'id:with::O': 41,
#  'id:such::O': 42,
#  'id:slogans::O': 43,
#  'id:as::O': 44,
#  'id:"::O': 45,
#  'id:Bush::B-per': 46,
#  'upper_ini::B-per': 47,
#  'prev_tag:O::B-per': 48,
#  'id:Number::O': 49,
#  'prev_tag:B-per::O': 50,
#  'id:One::O': 51,
#  'id:Terrorist::O': 52,
#  'id:Stop::O': 53,
#  'id:Bombings::O': 54,
#  'id:They::O': 55,
#  'id:Houses::O': 56,
#  'id:Parliament::O': 57,
#  'id:a::O': 58,
#  'id:rally::O': 59,
#  'id:Hyde::B-geo': 60,
#  'id:Park::I-geo': 61,
#  'upper_ini::I-geo': 62,
#  'prev_tag:B-geo::I-geo': 63,
#  'prev_tag:I-geo::O': 64,
#  'id:Police::O': 65,
#  'id:put::O': 66,
#  'id:number::O': 67,
#  'id:marchers::O': 68,
#  'id:at::O': 69,
#  'id:10,000::O': 70,
#  'id:while::O': 71,
#  'id:organizers::O': 72,
#  'id:claimed::O': 73,
#  'id:it::O': 74,
#  'id:was::O': 75,
#  'id:1,00,000::O': 76,
#  'id:The::O': 77,
#  'id:comes::O': 78,
#  'id:on::O': 79,
#  'id:eve::O': 80,
#  'id:annual::O': 81,
#  'id:conference::O': 82,
#  'id:Britain::B-geo': 83,
#  "id:'s::O": 84,
#  'id:ruling::O': 85,
#  'id:Labor::B-org': 86,
#  'upper_ini::B-org': 87,
#  'prev_tag:O::B-org': 88,
#  'id:Party::I-org': 89,
#  'upper_ini::I-org': 90,
#  'prev_tag:B-org::I-org': 91,
#  'prev_tag:I-org::O': 92,
#  'id:southern::O': 93,
#  'id:English::B-gpe': 94,
#  'id:seaside::O': 95,
#  'id:resort::O': 96,
#  'id:Brighton::B-geo': 97,
#  'id:party::O': 98,
#  'id:is::O': 99,
#  'id:divided::O': 100,
#  'id:over::O': 101,
#  'id:Britain::B-gpe': 102,
#  'id:participation::O': 103,
#  'id:continued::O': 104,
#  'id:deployment::O': 105,
#  'id:8,500::O': 106,
#  'id:march::O': 107,
#  'id:came::O': 108,
#  'id:ahead::O': 109,
#  'id:anti-war::O': 110,
#  'hyphen::O': 111,
#  'id:protests::O': 112,
#  'id:today::O': 113,
#  'id:other::O': 114,
#  'id:cities::O': 115,
#  'id:,::O': 116,
#  'id:including::O': 117,
#  'id:Rome::B-geo': 118,
#  'id:Paris::B-geo': 119,
#  'id:Madrid::B-geo': 120,
#  'id:International::B-org': 121,
#  'id:Atomic::I-org': 122,
#  'id:Energy::I-org': 123,
#  'prev_tag:I-org::I-org': 124,
#  'id:Agency::I-org': 125,
#  'id:hold::O': 126,
#  'id:second::O': 127,
#  'id:day::O': 128,
#  'id:talks::O': 129,
#  'id:Vienna::B-geo': 130,
#  'id:Wednesday::B-tim': 131,
#  'upper_ini::B-tim': 132,
#  'prev_tag:B-geo::B-tim': 133,
#  'prev_tag:B-tim::O': 134,
#  'id:how::O': 135,
#  'id:respond::O': 136,
#  'id:Iran::B-gpe': 137,
#  'id:resumption::O': 138,
#  'id:low-level::O': 139,
#  'id:uranium::O': 140,
#  'id:conversion::O': 141,
#  'init_tag:B-gpe': 142,
#  'id:this::O': 143,
#  'id:week::O': 144,
#  'id:restarted::O': 145,
#  'id:parts::O': 146,
#  'id:process::O': 147,
#  'id:its::O': 148,
#  'id:Isfahan::B-geo': 149,
#  'id:nuclear::O': 150,
#  'id:plant::O': 151,
#  'id:Iranian::B-gpe': 152,
#  'id:officials::O': 153,
#  'id:say::O': 154,
#  'id:they::O': 155,
#  'id:expect::O': 156,
#  'id:get::O': 157,
#  'id:access::O': 158,
#  'id:sealed::O': 159,
#  'id:sensitive::O': 160,
#  'prev_tag:O::B-tim': 161,
#  'id:after::O': 162,
#  'id:an::O': 163,
#  'id:IAEA::B-org': 164,
#  'id:surveillance::O': 165,
#  'prev_tag:B-org::O': 166,
#  'id:system::O': 167,
#  'id:begins::O': 168,
#  'id:functioning::O': 169,
#  'id:step::O': 170,
#  'id:will::O': 171,
#  'id:allow::O': 172,
#  'id:facility::O': 173,
#  'id:operate::O': 174,
#  'id:full::O': 175,
#  'id:capacity::O': 176,
#  'id:European::B-org': 177,
#  'id:Union::I-org': 178,
#  'id:U.S.::B-gpe': 179,
#  'id:backing::O': 180,
#  'id:has::O': 181,
#  'id:threatened::O': 182,
#  'id:refer::O': 183,
#  'id:U.N.::B-org': 184,
#  'id:Security::I-org': 185,
#  'id:Council::I-org': 186,
#  'id:which::O': 187,
#  'id:could::O': 188,
#  'id:impose::O': 189,
#  'id:sanctions::O': 190,
#  'id:if::O': 191,
#  'id:finds::O': 192,
#  'id:Tehran::B-gpe': 193,
#  'id:violated::O': 194,
#  'id:Nuclear::B-art': 195,
#  'upper_ini::B-art': 196,
#  'prev_tag:O::B-art': 197,
#  'id:Non-Proliferation::I-art': 198,
#  'hyphen::I-art': 199,
#  'upper_ini::I-art': 200,
#  'prev_tag:B-art::I-art': 201,
#  'id:treaty::O': 202,
#  'prev_tag:I-art::O': 203,
#  'id:new::O': 204,
#  'id:President::B-per': 205,
#  'id:Mahmoud::I-per': 206,
#  'upper_ini::I-per': 207,
#  'prev_tag:B-per::I-per': 208,
#  'id:Ahmadinejad::I-per': 209,
#  'prev_tag:I-per::I-per': 210,
#  'id:said::O': 211,
#  'prev_tag:I-per::O': 212,
#  'id:Tuesday::B-tim': 213,
#  'id:European::B-gpe': 214,
#  'id:incentives::O': 215,
#  'id:aimed::O': 216,
#  'id:persuading::O': 217,
#  'id:end::O': 218,
#  'id:fuel::O': 219,
#  'id:program::O': 220,
#  'id:are::O': 221,
#  'id:insult::O': 222,
#  'id:nation::O': 223,
#  'id:Two::O': 224,
#  'id:Germans::B-gpe': 225,
#  'id:four::O': 226,
#  'id:Nigerian::B-gpe': 227,
#  'id:oil::O': 228,
#  'id:workers::O': 229,
#  'id:were::O': 230,
#  'id:kidnapped::O': 231,
#  'id:by::O': 232,
#  'id:armed::O': 233,
#  'id:militants::O': 234,
#  'id:during::O': 235,
#  'id:raid::O': 236,
#  'id:boat::O': 237,
#  'id:Nigeria::B-geo': 238,
#  'id:oil-rich::O': 239,
#  'id:Delta::B-geo': 240,
#  'id:region::O': 241,
#  'id:An::O': 242,
#  'id:official::O': 243,
#  'id:German::B-gpe': 244,
#  'id:firm::O': 245,
#  'id:Bilfinger::B-org': 246,
#  'id:Berger::I-org': 247,
#  'id:Thomas::B-per': 248,
#  'id:Horbach::I-per': 249,
#  'id:gunmen::O': 250,
#  'id:stopped::O': 251,
#  'id:supply::O': 252,
#  'id:sailed::O': 253,
#  'id:State::I-geo': 254,
#  'id:Bayelsa::B-geo': 255,
#  'id:inspect::O': 256,
#  'id:offshore::O': 257,
#  'id:field::O': 258,
#  'id:owned::O': 259,
#  'id:Royal-Dutch::B-org': 260,
#  'hyphen::B-org': 261,
#  'id:Shell::I-org': 262,
#  'id:works::O': 263,
#  'id:sub-contractor::O': 264,
#  'id:for::O': 265,
#  'id:Shell::B-org': 266,
#  'id:Militant::O': 267,
#  'id:groups::O': 268,
#  'id:frequently::O': 269,
#  'id:attack::O': 270,
#  'id:operations::O': 271,
#  'id:Niger::B-geo': 272,
#  'id:Delta::I-geo': 273,
#  'id:social::O': 274,
#  'id:services::O': 275,
#  'id:better::O': 276,
#  'id:job::O': 277,
#  'id:opportunities::O': 278,
#  'id:multinational::O': 279,
#  'id:companies::O': 280,
#  'id:Poor::O': 281,
#  'id:residents::O': 282,
#  'id:often::O': 283,
#  'id:complain::O': 284,
#  'id:been::O': 285,
#  'id:cheated::O': 286,
#  'id:out::O': 287,
#  'id:huge::O': 288,
#  'id:riches::O': 289,
#  'id:extracted::O': 290,
#  'id:their::O': 291,
#  'id:tribal::O': 292,
#  'id:lands::O': 293,
#  'id:-::O': 294,
#  'id:where::O': 295,
#  'id:bulk::O': 296,
#  'id:Nigeria::B-gpe': 297,
#  'id:2.3::O': 298,
#  'id:million::O': 299,
#  'id:barrels::O': 300,
#  'id:petroleum::O': 301,
#  'id:pumped::O': 302,
#  'id:daily::O': 303,
#  'id:Suspected::O': 304,
#  'id:Islamist::O': 305,
#  'id:rebels::O': 306,
#  'id:fired::O': 307,
#  'id:mortar::O': 308,
#  'id:shells::O': 309,
#  'id:palace::O': 310,
#  'id:used::O': 311,
#  'id:Somalia::B-geo': 312,
#  'id:interim::O': 313,
#  'id:Abdullahi::I-per': 314,
#  'id:Yusuf::I-per': 315,
#  'id:Ahmad::I-per': 316,
#  'id:It::O': 317,
#  'id:not::O': 318,
#  'id:immediately::O': 319,
#  'id:clear::O': 320,
#  'id:president::O': 321,
#  'id:Mogadishu::B-geo': 322,
#  'id:when::O': 323,
#  'id:occurred::O': 324,
#  'id:or::O': 325,
#  'id:anyone::O': 326,
#  'id:hurt::O': 327,
#  'id:Local::O': 328,
#  'id:news::O': 329,
#  'id:reports::O': 330,
#  'id:least::O': 331,
#  'id:five::O': 332,
#  'id:hit::O': 333,
#  'id:compound::O': 334,
#  'id:mortars::O': 335,
#  'id:elsewhere::O': 336,
#  'id:attacks::O': 337,
#  'id:government::O': 338,
#  'id:go::O': 339,
#  'id:reconciliation::O': 340,
#  'id:more::O': 341,
#  'id:than::O': 342,
#  'id:1,300::O': 343,
#  'id:Somali::B-gpe': 344,
#  'id:elders::O': 345,
#  'id:warlords::O': 346,
#  'id:politicians::O': 347,
#  'id:invited::O': 348,
#  'id:Iraqi::B-gpe': 349,
#  'id:military::O': 350,
#  'id:tanks::O': 351,
#  'id:arrived::O': 352,
#  'id:northern::O': 353,
#  'id:city::O': 354,
#  'id:Mosul::B-geo': 355,
#  'id:offensive::O': 356,
#  'id:against::O': 357,
#  'id:al::B-org': 358,
#  'id:Qaida::I-org': 359,
#  'id:in::I-org': 360,
#  'id:Iraq::I-org': 361,
#  'id:fighters::O': 362,
#  'id:Officials::O': 363,
#  'id:many::O': 364,
#  'id:Sunni::B-geo': 365,
#  'id:Arab::I-geo': 366,
#  'id:Kurdish::B-geo': 367,
#  'id:bombings::O': 368,
#  'id:last::O': 369,
#  'id:34::O': 370,
#  'id:people::O': 371,
#  'id:wounded::O': 372,
#  'id:200::O': 373,
#  'id:commanders::O': 374,
#  'id:explained::O': 375,
#  'id:American::B-gpe': 376,
#  'id:forces::O': 377,
#  'id:participate::O': 378,
#  'id:fled::O': 379,
#  'id:successful::O': 380,
#  'id:campaigns::O': 381,
#  'id:them::O': 382,
#  'id:Anbar::B-geo': 383,
#  'id:province::O': 384,
#  'id:Baghdad::B-geo': 385,
#  'id:provinces::O': 386,
#  'init_tag:B-geo': 387,
#  'id:largest::O': 388,
#  'id:north::O': 389,
#  'id:long::O': 390,
#  'id:stronghold::O': 391,
#  'id:Sunni::B-org': 392,
#  'id:militant::O': 393,
#  'id:In::O': 394,
#  'id:violence::O': 395,
#  'id:one::O': 396,
#  'id:soldier::O': 397,
#  'id:patrol::O': 398,
#  'id:Sunday::B-tim': 399,
#  'id:Egyptian::B-gpe': 400,
#  'id:police::O': 401,
#  'id:arrested::O': 402,
#  'id:16::O': 403,
#  'id:members::O': 404,
#  'id:opposition::O': 405,
#  'id:Muslim::B-org': 406,
#  'id:Brotherhood::I-org': 407,
#  'id:prepare::O': 408,
#  'id:parliamentary::O': 409,
#  'id:runoff::O': 410,
#  'id:elections::O': 411,
#  'id:Saturday::B-tim': 412,
#  'id:arrests::O': 413,
#  'id:Friday::B-tim': 414,
#  'id:Alexandria::B-geo': 415,
#  'id:A::O': 416,
#  'id:spokesman::O': 417,
#  'id:Brotherhood::B-org': 418,
#  'id:attempt::O': 419,
#  'id:cut::O': 420,
#  'id:off::O': 421,
#  'id:supporters::O': 422,
#  'id:punishment::O': 423,
#  'id:winning::O': 424,
#  'id:seats::O': 425,
#  'id:earlier::O': 426,
#  'id:tripled::O': 427,
#  'id:strength::O': 428,
#  'id:parliament::O': 429,
#  'id:recent::O': 430,
#  'id:raising::O': 431,
#  'id:total::O': 432,
#  'id:47::O': 433,
#  'id:voters::O': 434,
#  'id:cast::O': 435,
#  'id:ballots::O': 436,
#  'id:nine::O': 437,
#  'id:no::O': 438,
#  'id:candidate::O': 439,
#  'id:won::O': 440,
#  'id:majority::O': 441,
#  'id:previous::O': 442,
#  'id:round::O': 443,
#  'id:voting::O': 444,
#  'id:banned::O': 445,
#  'id:political::O': 446,
#  'id:but::O': 447,
#  'id:endorses::O': 448,
#  'id:so-called::O': 449,
#  'id:independent::O': 450,
#  'id:candidates::O': 451,
#  'id:whose::O': 452,
#  'id:allegiance::O': 453,
#  'id:known::O': 454,
#  'id:Hardline::O': 455,
#  'id:lawmakers::O': 456,
#  'id:Pakistan::B-geo': 457,
#  'id:North::B-geo': 458,
#  'id:West::I-geo': 459,
#  'id:Frontier::I-geo': 460,
#  'prev_tag:I-geo::I-geo': 461,
#  'id:Province::I-geo': 462,
#  'id:pushed::O': 463,
#  'id:law::O': 464,
#  'id:aims::O': 465,
#  'id:ensure::O': 466,
#  'id:Islamic::O': 467,
#  'id:correctness::O': 468,
#  'id:public::O': 469,
#  'id:places::O': 470,
#  'id:establishes::O': 471,
#  'id:morality::O': 472,
#  'id:enforce::O': 473,
#  'id:decent::O': 474,
#  'id:behavior::O': 475,
#  'id:six-party::O': 476,
#  'id:coalition::O': 477,
#  'id:religious::O': 478,
#  'id:based::O': 479,
#  'id:parties::O': 480,
#  'id:Mutahida::B-org': 481,
#  'id:Majlis-e-Amal::I-org': 482,
#  'hyphen::I-org': 483,
#  'id:dominates::O': 484,
#  'id:provincial::O': 485,
#  'id:assembly::O': 486,
#  'id:so::O': 487,
#  'id:bill::O': 488,
#  'id:easily::O': 489,
#  'id:passed::O': 490,
#  'id:Thursday::B-tim': 491,
#  'id:vote::O': 492,
#  'id:68-34::O': 493,
#  'id:governor::O': 494,
#  'id:must::O': 495,
#  'id:still::O': 496,
#  'id:sign::O': 497,
#  'id:before::O': 498,
#  'id:becomes::O': 499,
#  'id:seen::O': 500,
#  'id:only::O': 501,
#  'id:formality::O': 502,
#  'id:proposed::O': 503,
#  'id:calls::O': 504,
#  'id:setting::O': 505,
#  'id:up::O': 506,
#  'id:force::O': 507,
#  'id:make::O': 508,
#  'id:sure::O': 509,
#  'id:adhere::O': 510,
#  'id:values::O': 511,
#  'id:entertainment::O': 512,
#  'id:outlets::O': 513,
#  'id:close::O': 514,
#  'id:weekly::O': 515,
#  'id:prayers::O': 516,
#  'id:Violators::O': 517,
#  'id:be::O': 518,
#  'id:jailed::O': 519,
#  'id:six::O': 520,
#  'id:months::O': 521,
#  'id:denounced::O': 522,
#  'id:measure::O': 523,
#  'id:comparing::O': 524,
#  'id:draconian::O': 525,
#  'id:rule::O': 526,
#  'id:former::O': 527,
#  'id:Taleban::B-org': 528,
#  'id:neighboring::O': 529,
#  'id:Afghanistan::B-geo': 530,
#  'id:man::O': 531,
#  'id:dressed::O': 532,
#  'id:suicide::O': 533,
#  'id:bomber::O': 534,
#  'id:demonstration::O': 535,
#  'id:publication::O': 536,
#  'id:cartoons::O': 537,
#  'id:depicting::O': 538,
#  'id:Islam::B-org': 539,
#  'id:Prophet::B-per': 540,
#  'id:Muhammad::I-per': 541,
#  'id:Bedfordshire::B-gpe': 542,
#  'id:Omar::B-per': 543,
#  'id:Khayam::I-per': 544,
#  'id:Bedford::B-geo': 545,
#  'id:breaching::O': 546,
#  'id:conditions::O': 547,
#  'id:his::O': 548,
#  'id:parole::O': 549,
#  'id:British::B-org': 550,
#  'id:Home::I-org': 551,
#  'id:Office::I-org': 552,
#  'id:sought::O': 553,
#  'id:investigation::O': 554,
#  'id:Khayam::B-per': 555,
#  'id:he::O': 556,
#  'id:photographed::O': 557,
#  'id:fatigues::O': 558,
#  'id:black::O': 559,
#  'id:cap::O': 560,
#  'id:bulky::O': 561,
#  'id:belt::O': 562,
#  'id:Home::B-org': 563,
#  'id:told::O': 564,
#  'id:Associated::B-org': 565,
#  'id:Press::I-org': 566,
#  'id:paroled::O': 567,
#  'id:offender::O': 568,
#  'id:gives::O': 569,
#  'id:cause::O': 570,
#  'id:concern::O': 571,
#  'id:can::O': 572,
#  'id:sent::O': 573,
#  'id:back::O': 574,
#  'id:prison::O': 575,
#  'id:AP::B-org': 576,
#  'id:also::O': 577,
#  'id:since::O': 578,
#  'id:year::O': 579,
#  'id:serving::O': 580,
#  'id:half::O': 581,
#  'id:six-year::O': 582,
#  'id:sentence::O': 583,
#  'id:drug::O': 584,
#  'id:dealing::O': 585,
#  'id:Pakistani::B-gpe': 586,
#  'id:unidentified::O': 587,
#  'id:three::O': 588,
#  'id:minister::O': 589,
#  'id:semi-autonomous::O': 590,
#  'id:bordering::O': 591,
#  'id:prominent::O': 592,
#  'id:leader::O': 593,
#  'id:Malik::B-per': 594,
#  'id:Faridullah::I-per': 595,
#  'id:Khan::I-per': 596,
#  'id:traveling::O': 597,
#  'id:South::B-geo': 598,
#  'id:Waziristan::I-geo': 599,
#  'prev_tag:I-geo::B-tim': 600,
#  'id:vehicle::O': 601,
#  'id:ambushed::O': 602,
#  'id:Kani::B-geo': 603,
#  'id:Wam::I-geo': 604,
#  'id:area::O': 605,
#  'id:His::O': 606,
#  'id:driver::O': 607,
#  'id:elder::O': 608,
#  'id:No::O': 609,
#  'id:responsibility::O': 610,
#  'id:killings::O': 611,
#  'id:ambush::O': 612,
#  'id:commander::O': 613,
#  'id:army::O': 614,
#  'id:almost::O': 615,
#  'id:completely::O': 616,
#  'id:eliminated::O': 617,
#  'id:became::O': 618,
#  'id:refuge::O': 619,
#  'id:al-Qaida::B-org': 620,
#  'id:ousted::O': 621,
#  'id:2001::B-tim': 622,
#  'id:senior::O': 623,
#  'id:says::O': 624,
#  'id:Pakistan::B-gpe': 625,
#  'id:wants::O': 626,
#  'id:what::O': 627,
#  'id:sordid::O': 628,
#  'id:chapter::O': 629,
#  'id:proliferation::O': 630,
#  'id:top::O': 631,
#  'id:scientists::O': 632,
#  'id:behind::O': 633,
#  'id:build::O': 634,
#  'id:civilian::O': 635,
#  'id:ties::O': 636,
#  'id:United::B-gpe': 637,
#  'id:States::I-gpe': 638,
#  'upper_ini::I-gpe': 639,
#  'prev_tag:B-gpe::I-gpe': 640,
#  'prev_tag:I-gpe::O': 641,
#  'id:But::O': 642,
#  'id:ready::O': 643,
#  'id:scientist::O': 644,
#  'id:Abdul::B-per': 645,
#  'id:Qadeer::I-per': 646,
#  'id:available::O': 647,
#  'id:direct::O': 648,
#  'id:questioning::O': 649,
#  'id:sale::O': 650,
#  'id:secrets::O': 651,
#  'id:states::O': 652,
#  'id:Libya::B-gpe': 653,
#  'id:North::B-gpe': 654,
#  'id:Korea::I-gpe': 655,
#  'id:He::O': 656,
#  'id:there::O': 657,
#  'id:reasons::O': 658,
#  'id:national::O': 659,
#  'id:sensitivities::O': 660,
#  'id:making::O': 661,
#  'id:him::O': 662,
#  'id:giving::O': 663,
#  'id:background::O': 664,
#  'id:briefing::O': 665,
#  'id:small::O': 666,
#  'id:group::O': 667,
#  'id:reporters::O': 668,
#  'id:Washington::B-geo': 669,
#  'init_tag:B-per': 670,
#  'id:Khan::B-per': 671,
#  'id:admitted::O': 672,
#  'id:2004::B-tim': 673,
#  'id:operated::O': 674,
#  'id:worldwide::O': 675,
#  'id:clandestine::O': 676,
#  'id:network::O': 677,
#  'id:sell::O': 678,
#  'id:technology::O': 679,
#  'id:market::O': 680,
#  'id:placed::O': 681,
#  'id:under::O': 682,
#  'id:house::O': 683,
#  'id:arrest::O': 684,
#  'id:Islamabad::B-geo': 685,
#  'id:because::O': 686,
#  'id:considered::O': 687,
#  'id:father::O': 688,
#  'id:bomb::O': 689,
#  'id:Army::B-org': 690,
#  'prev_tag:B-gpe::B-org': 691,
#  'id:renew::O': 692,
#  'id:controversial::O': 693,
#  'id:multi-billion::O': 694,
#  'id:dollar::O': 695,
#  'id:contract::O': 696,
#  'id:Halliburton::B-org': 697,
#  'id:company::O': 698,
#  'id:provide::O': 699,
#  'id:logistical::O': 700,
#  'id:support::O': 701,
#  'init_tag:B-org': 702,
#  'id:providing::O': 703,
#  'id:list::O': 704,
#  'id:meals::O': 705,
#  'id:communication::O': 706,
#  'id:several::O': 707,
#  'id:years::O': 708,
#  'id:Critics::O': 709,
#  'id:include::O': 710,
#  'id:auditors::O': 711,
#  'id:congressional::O': 712,
#  'id:Democrats::O': 713,
#  'id:produced::O': 714,
#  'id:some::O': 715,
#  'id:shoddy::O': 716,
#  'id:work::O': 717,
#  'id:charges::O': 718,
#  'id:too::O': 719,
#  'id:much::O': 720,
#  'id:money::O': 721,
#  'id:strongly::O': 722,
#  'id:denies::O': 723,
#  'id:allegations::O': 724,
#  'id:When::O': 725,
#  'id:re-bidding::O': 726,
#  'id:chance::O': 727,
#  'id:compete::O': 728,
#  'id:portions::O': 729,
#  'id:Representatives::O': 730,
#  'id:Asia::B-org': 731,
#  'id:Pacific::I-org': 732,
#  'id:Economic::I-org': 733,
#  'id:Cooperation::I-org': 734,
#  'id:Business::I-org': 735,
#  'id:Advisory::I-org': 736,
#  'id:holding::O': 737,
#  'id:meetings::O': 738,
#  'id:finalize::O': 739,
#  'id:report::O': 740,
#  'id:APEC::B-org': 741,
#  'id:leaders::O': 742,
#  'id:summit::O': 743,
#  'id:September::B-tim': 744,
#  'id:8::I-tim': 745,
#  'prev_tag:B-tim::I-tim': 746,
#  'prev_tag:I-tim::O': 747,
#  'id:9::B-tim': 748,
#  'id:VOA::B-org': 749,
#  'id:Nancy-Amelia::B-per': 750,
#  'hyphen::B-per': 751,
#  'id:Collins::I-per': 752,
#  'id:Sydney::B-geo': 753,
#  'id:Energy::O': 754,
#  'id:security::O': 755,
#  'id:climate::O': 756,
#  'id:change::O': 757,
#  'id:World::B-org': 758,
#  'id:Trade::I-org': 759,
#  'id:Organization::I-org': 760,
#  'id:stalled::O': 761,
#  'id:negotiations::O': 762,
#  'id:investment::O': 763,
#  'id:all::O': 764,
#  'id:expected::O': 765,
#  'id:among::O': 766,
#  'id:major::O': 767,
#  'id:topics::O': 768,
#  'id:ABAC::B-org': 769,
#  'id:Tim::B-per': 770,
#  'id:Harcourt::I-per': 771,
#  'id:chief::O': 772,
#  'id:economist::O': 773,
#  'id:Australian::B-org': 774,
#  'id:Commission::I-org': 775,
#  'id:plays::O': 776,
#  'id:important::O': 777,
#  'id:role::O': 778,
#  'id:informing::O': 779,
#  'id:governments::O': 780,
#  'id:problems::O': 781,
#  'id:most::O': 782,
#  'id:thing::O': 783,
#  'id:business::O': 784,
#  'id:do::O': 785,
#  'id:tell::O': 786,
#  'id:logjams::O': 787,
#  'id:obstacles::O': 788,
#  'id:things::O': 789,
#  'id:improve::O': 790,
#  'id:Harcourt::B-per': 791,
#  'id:I::O': 792,
#  'id:think::O': 793,
#  'id:actually::O': 794,
#  'id:played::O': 795,
#  'id:pretty::O': 796,
#  'id:good::O': 797,
#  'id:leadership::O': 798,
#  'id:talking::O': 799,
#  'id:about::O': 800,
#  'id:trade::O': 801,
#  'id:facilitation::O': 802,
#  'id:basically::O': 803,
#  'id:standards::O': 804,
#  'id:consistent::O': 805,
#  'id:harmonious::O': 806,
#  'id:across::O': 807,
#  'id:comprises::O': 808,
#  'id:private::O': 809,
#  'id:sector::O': 810,
#  'id:each::O': 811,
#  'id:21::O': 812,
#  'id:economies::O': 813,
#  'id:meets::O': 814,
#  'id:times::O': 815,
#  'id:made::O': 816,
#  'id:permanent::O': 817,
#  'id:body::O': 818,
#  'id:1995::B-tim': 819,
#  'id:perspective::O': 820,
#  'id:within::O': 821,
#  'id:Members::O': 822,
#  'id:represent::O': 823,
#  'id:range::O': 824,
#  'id:sectors::O': 825,
#  'id:medium::O': 826,
#  'id:businesses::O': 827,
#  'id:need::O': 828,
#  'id:energy::O': 829,
#  'id:efficiency::O': 830,
#  'id:encourage::O': 831,
#  'id:conservation::O': 832,
#  'id:practices::O': 833,
#  'id:discuss::O': 834,
#  'id:ways::O': 835,
#  'id:enhance::O': 836,
#  'id:regional::O': 837,
#  'id:cooperation::O': 838,
#  'id:reckon::O': 839,
#  "id:'ll::O": 840,
#  'id:talk::O': 841,
#  'id:little::O': 842,
#  'id:bit::O': 843,
#  'id:customs::O': 844,
#  'id:quarantine::O': 845,
#  'id:having::O': 846,
#  'id:arrangements::O': 847,
#  'id:around::O': 848,
#  'id:And::O': 849,
#  'id:want::O': 850,
#  'id:one-stop::O': 851,
#  'id:shop::O': 852,
#  'id:terms::O': 853,
#  'id:combining::O': 854,
#  'id:immigration::O': 855,
#  'id:together::O': 856,
#  'id:\x85::O': 857,
#  'id:just::O': 858,
#  'id:streamlined::O': 859,
#  'id:provides::O': 860,
#  'id:certainty::O': 861,
#  'id:non-governmental::O': 862,
#  'id:formal::O': 863,
#  'id:dialogue::O': 864,
#  'id:present::O': 865,
#  'id:meeting::O': 866,
#  'id:Sudan::B-gpe': 867,
#  'id:order::O': 868,
#  'id:Darfur::B-geo': 869,
#  'id:asking::O': 870,
#  'id:same::O': 871,
#  'id:Foreign::B-per': 872,
#  'id:Minister::I-per': 873,
#  'id:Mustafa::I-per': 874,
#  'id:Osman::I-per': 875,
#  'id:Ismail::I-per': 876,
#  'id:Sudanese::B-gpe': 877,
#  'id:withdraw::O': 878,
#  'id:positions::O': 879,
#  'id:held::O': 880,
#  'id:April::B-tim': 881,
#  'id:cease-fire::O': 882,
#  'id:western::O': 883,
#  'id:agree::O': 884,
#  'id:stop::O': 885,
#  'id:Mr.::B-per': 886,
#  'id:announced::O': 887,
#  'id:decision::O': 888,
#  'id:United::B-org': 889,
#  'id:Nations::I-org': 890,
#  'id:African::B-org': 891,
#  'id:Khartoum::B-geo': 892,
#  'id:weeks::O': 893,
#  'id:AU::B-org': 894,
#  'id:repeatedly::O': 895,
#  'id:truce::O': 896,
#  'init_tag:B-tim': 897,
#  'id:head::O': 898,
#  'id:accused::O': 899,
#  'id:helicopters::O': 900,
#  'id:bombing::O': 901,
#  'id:rebel::O': 902,
#  'id:sites::O': 903,
#  'id:Darfur::I-geo': 904,
#  'id:village::O': 905,
#  'id:Labado::B-geo': 906,
#  'id:Khartoum::B-gpe': 907,
#  'id:defending::O': 908,
#  'id:Aid::O': 909,
#  'id:relief::O': 910,
#  'id:efforts::O': 911,
#  'id:suspended::O': 912,
#  'id:due::O': 913,
#  'id:Indonesian::B-gpe': 914,
#  'id:men::O': 915,
#  'id:connection::O': 916,
#  'id:October::B-tim': 917,
#  'id:1::I-tim': 918,
#  'id:Bali::B-geo': 919,
#  'prev_tag:I-tim::B-geo': 920,
#  'id:left::O': 921,
#  'id:23::O': 922,
#  'id:dead::O': 923,
#  'id:flown::O': 924,
#  'id:Java::B-geo': 925,
#  'id:island::O': 926,
#  'id:headquarters::O': 927,
#  'id:Australian::B-gpe': 928,
#  'id:French::B-gpe': 929,
#  'id:agencies::O': 930,
#  'id:(::O': 931,
#  'id:Cholily::B-per': 932,
#  'id:)::O': 933,
#  'id:captured::O': 934,
#  'id:series::O': 935,
#  'id:counter-terrorism::O': 936,
#  'id:raids::O': 937,
#  'id:Indonesia::B-geo': 938,
#  'id:ended::O': 939,
#  'id:death::O': 940,
#  'id:alleged::O': 941,
#  'id:extremist::O': 942,
#  'id:bombmaker::O': 943,
#  'id:Azahari::B-per': 944,
#  'id:bin::I-per': 945,
#  'id:Husin::I-per': 946,
#  'id:authorities::O': 947,
#  'id:blame::O': 948,
#  'id:orchestrating::O': 949,
#  'id:month::O': 950,
#  'id:well::O': 951,
#  'id:2002::B-tim': 952,
#  'prev_tag:B-tim::B-geo': 953,
#  'id:Gunmen::O': 954,
#  'id:shot::O': 955,
#  'id:Roman::B-org': 956,
#  'id:Catholic::I-org': 957,
#  'id:nun::O': 958,
#  'id:her::O': 959,
#  'id:bodyguard::O': 960,
#  'id:hospital::O': 961,
#  'id:she::O': 962,
#  'id:worked::O': 963,
#  'id:Islamist-controlled::O': 964,
#  'id:Some::O': 965,
#  'id:witnesses::O': 966,
#  'id:shooting::O': 967,
#  'id:feared::O': 968,
#  'id:linked::O': 969,
#  'id:Muslim::O': 970,
#  'id:anger::O': 971,
#  'id:toward::O': 972,
#  'id:Pope::B-per': 973,
#  'id:Benedict::I-per': 974,
#  'id:pistols::O': 975,
#  'id:attacked::O': 976,
#  'id:Sister::B-per': 977,
#  'id:Leonella::I-per': 978,
#  'id:Sgorbati::I-per': 979,
#  'id:finished::O': 980,
#  'id:teaching::O': 981,
#  'id:medical::O': 982,
#  'id:school::O': 983,
#  'id:class::O': 984,
#  'id:suspect::O': 985,
#  'id:Vatican::B-org': 986,
#  'id:deplored::O': 987,
#  'id:hoped::O': 988,
#  'id:isolated::O': 989,
#  'id:event::O': 990,
#  'id:irrationality::O': 991,
#  'id:arising::O': 992,
#  'id:comments::O': 993,
#  'id:Pope::O': 994,
#  'id:angered::O': 995,
#  'id:Muslims::O': 996,
#  'id:Authorities::O': 997,
#  'id:determined::O': 998,
#  'id:motive::O': 999,
#  ...}

# %%
[x for x in list(ex_feature_mapper.feature_dict.keys()) if 'upper_ini' in x]
# Out:
# ['upper_ini::O',
#  'upper_ini::B-geo',
#  'upper_ini::B-gpe',
#  'upper_ini::B-per',
#  'upper_ini::I-geo',
#  'upper_ini::B-org',
#  'upper_ini::I-org',
#  'upper_ini::B-tim',
#  'upper_ini::B-art',
#  'upper_ini::I-art',
#  'upper_ini::I-per',
#  'upper_ini::I-gpe',
#  'upper_ini::B-nat',
#  'upper_ini::I-eve',
#  'upper_ini::B-eve',
#  'upper_ini::I-nat',
#  'upper_ini::I-tim']

# %% [markdown]
# #### Training structured perceptron

# %%
corpus = skseq.readers.pos_corpus.PostagCorpus()
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)

# %%
sp.get_num_states(), sp.get_num_observations()
# Out:
# (17, 30863)

# %%
# %%time
num_epochs = 15
sp.fit(ex_feature_mapper.dataset, num_epochs)
# Out:
# Epoch: 0 Accuracy: 0.929550
# Epoch: 1 Accuracy: 0.945799
# Epoch: 2 Accuracy: 0.950572
# Epoch: 3 Accuracy: 0.953116
# Epoch: 4 Accuracy: 0.955269
# Epoch: 5 Accuracy: 0.956869
# Epoch: 6 Accuracy: 0.957414
# Epoch: 7 Accuracy: 0.958818
# Epoch: 8 Accuracy: 0.959953
# Epoch: 9 Accuracy: 0.961050
# Epoch: 10 Accuracy: 0.960701
# Epoch: 11 Accuracy: 0.962092
# Epoch: 12 Accuracy: 0.962691
# Epoch: 13 Accuracy: 0.962930
# Epoch: 14 Accuracy: 0.963378
# Wall time: 1h 6min 37s

# %%
sp.save_model("perceptron_ex3")

# %%
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)
sp.load_model(dir="perceptron_ex3")

# %% [markdown]
# #### Testing

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

y_pred_2 = []
y_true = [item for x in Y_ids_test for item in x]
correct_sentences = 0
n_test = len(X_test)

for i in range(n_test):
    y_pred_aux = sp.predict_tags_given_words(X_test[i])
    y_pred_2.append(y_pred_aux)
    if list(y_pred_aux) == Y_ids_test[i]:
        correct_sentences += 1
    
y_pred = [item for x in y_pred_2 for item in x]
F1_score_multi = f1_score(y_true, y_pred, average=None)
Accuracy = accuracy_score(y_true, y_pred)
print('Accuracy for test is: ' + str(Accuracy))
print('F1-Score for test is: ' + str(np.mean(F1_score_multi)))
print('Correct sentences for test (%) : ' + str(correct_sentences/n_test))
# Out:
# Accuracy for test is: 0.9475751751124426
# F1-Score for test is: 0.6106155869704232
# Correct sentences for test (%) : 0.45979312645979314

# %%
ax = plot_confusion_matrix(y_true, y_pred, classes=list(sp.state_labels),
                      title='Confusion matrix')

# %% [markdown]
# #### SENTENCES TO TEST THE MODEL

# %% [markdown]
# We think that these are the tags that the model should obtain:
#
# 1. The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 2. The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 3. Jack/B-per London/I-per went/O to/O Parris./O
#
# 4. Jack/B-per London/I-per went/O to/O/O Paris./B-geo
#
# 5. We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
#
# 6. We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
#
# 7. The/O president/O of/O U.S.A/B-geo though/O they/O could/O win/O the/O war/O
#
# 8. The/O president/O of/O the/O United/B-geo States/B-geo of/B-geo America/B-geo though/O they/O could/O win/O the/O war/O
#
# 9. The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
#
# 10. Robin/B-per does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
for sentence in test_sentences:
    new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
    print(sp.viterbi_decode(new_seq)[0].to_words(sequence_list_train, only_tag_translation=True))
# Out:
# The/O programmers/O from/O Barcelona/B-org might/O write/O a/O sentence/O without/O a/O spell/O checker./O
# The/O programmers/O from/O Barchelona/B-org cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
# Jack/B-per London/B-geo went/O to/O Parris./B-eve
# Jack/B-per London/B-geo went/O to/O Paris./B-eve
# We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
# We/O never/O though/O Microsof/B-org would/O become/O such/O a/O big/O company./O
# The/O president/O of/O U.S.A/B-org though/O they/O could/O win/O the/O war/O
# The/O president/O of/O the/O United/B-geo States/I-geo of/I-geo America/I-geo though/O they/O could/O win/O the/O war/O
# The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
# Robin/B-org does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
# Here we can select the sentence in which we want to compare the true and the predicted tags
# Select a sentence between 1 and 10
i=1
sentence = test_sentences[i-1]
new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(sentence.split(), test_tags[i-1], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# The             (O    ): O
# programmers     (O    ): O
# from            (O    ): O
# Barcelona       (B-geo): B-org
# might           (O    ): O
# write           (O    ): O
# a               (O    ): O
# sentence        (O    ): O
# without         (O    ): O
# a               (O    ): O
# spell           (O    ): O
# checker.        (O    ): O

# %% [markdown]
# #### Capital checking

# %%
new_seq = Sequence(x=X_test[0], y=[int(0) for w in X_test[0]])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(X_test[0], Y_test[0], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# Officials       (O    ): O
# said            (O    ): O
# Sunday          (B-tim): B-tim
# Jean            (B-per): B-per
# Rene            (I-per): I-per
# Anthony         (I-per): I-per
# was             (O    ): O
# killed          (O    ): O
# in              (O    ): O
# a               (O    ): O
# shootout        (O    ): O
# with            (O    ): O
# police          (O    ): O
# near            (O    ): O
# the             (O    ): O
# capital         (O    ): O
# city            (O    ): O
# of              (O    ): O
# Port-au-Prince  (B-geo): O
# .               (O    ): O

# %% [markdown]
# ##### Comments:
#
# We have solved the problem with Jean Rene Anthony but now we have again problems with Port-au-Prince. As well, we have changed the output of Barcelona and now we have it wrong. In the next experiments we are going to fix this problem.

# %% [markdown]
# # EXPERIMENT 4: Adding -ED at the end

# %% [markdown]
# ##### Comments:

# %% [markdown]
# ### Extended features

# %%
ex_feature_mapper = skseq.sequences.extended_feature.ExtendedFeatures(sequence_list_train) 
ex_feature_mapper.build_features()
pprint.pprint(list(ex_feature_mapper.__dict__.keys()))
# Out:
# ['feature_dict',
#  'feature_list',
#  'add_features',
#  'dataset',
#  'node_feature_cache',
#  'initial_state_feature_cache',
#  'final_state_feature_cache',
#  'edge_feature_cache']

# %%
len(ex_feature_mapper.feature_dict)
# Out:
# 38342

# %%
ex_feature_mapper.feature_dict
# Out:
# {'init_tag:O': 0,
#  'id:Thousands::O': 1,
#  'upper_ini::O': 2,
#  'id:of::O': 3,
#  'prev_tag:O::O': 4,
#  'id:demonstrators::O': 5,
#  'id:have::O': 6,
#  'id:marched::O': 7,
#  'verb_ed::O': 8,
#  'id:through::O': 9,
#  'id:London::B-geo': 10,
#  'upper_ini::B-geo': 11,
#  'prev_tag:O::B-geo': 12,
#  'id:to::O': 13,
#  'prev_tag:B-geo::O': 14,
#  'id:protest::O': 15,
#  'id:the::O': 16,
#  'id:war::O': 17,
#  'id:in::O': 18,
#  'id:Iraq::B-geo': 19,
#  'id:and::O': 20,
#  'id:demand::O': 21,
#  'id:withdrawal::O': 22,
#  'id:British::B-gpe': 23,
#  'upper_ini::B-gpe': 24,
#  'prev_tag:O::B-gpe': 25,
#  'id:troops::O': 26,
#  'prev_tag:B-gpe::O': 27,
#  'id:from::O': 28,
#  'id:that::O': 29,
#  'id:country::O': 30,
#  'id:.::O': 31,
#  'final_prev_tag:O': 32,
#  'id:Families::O': 33,
#  'id:soldiers::O': 34,
#  'id:killed::O': 35,
#  'id:conflict::O': 36,
#  'id:joined::O': 37,
#  'id:protesters::O': 38,
#  'id:who::O': 39,
#  'id:carried::O': 40,
#  'id:banners::O': 41,
#  'id:with::O': 42,
#  'id:such::O': 43,
#  'id:slogans::O': 44,
#  'id:as::O': 45,
#  'id:"::O': 46,
#  'id:Bush::B-per': 47,
#  'upper_ini::B-per': 48,
#  'prev_tag:O::B-per': 49,
#  'id:Number::O': 50,
#  'prev_tag:B-per::O': 51,
#  'id:One::O': 52,
#  'id:Terrorist::O': 53,
#  'id:Stop::O': 54,
#  'id:Bombings::O': 55,
#  'id:They::O': 56,
#  'id:Houses::O': 57,
#  'id:Parliament::O': 58,
#  'id:a::O': 59,
#  'id:rally::O': 60,
#  'id:Hyde::B-geo': 61,
#  'id:Park::I-geo': 62,
#  'upper_ini::I-geo': 63,
#  'prev_tag:B-geo::I-geo': 64,
#  'prev_tag:I-geo::O': 65,
#  'id:Police::O': 66,
#  'id:put::O': 67,
#  'id:number::O': 68,
#  'id:marchers::O': 69,
#  'id:at::O': 70,
#  'id:10,000::O': 71,
#  'id:while::O': 72,
#  'id:organizers::O': 73,
#  'id:claimed::O': 74,
#  'id:it::O': 75,
#  'id:was::O': 76,
#  'id:1,00,000::O': 77,
#  'id:The::O': 78,
#  'id:comes::O': 79,
#  'id:on::O': 80,
#  'id:eve::O': 81,
#  'id:annual::O': 82,
#  'id:conference::O': 83,
#  'id:Britain::B-geo': 84,
#  "id:'s::O": 85,
#  'id:ruling::O': 86,
#  'id:Labor::B-org': 87,
#  'upper_ini::B-org': 88,
#  'prev_tag:O::B-org': 89,
#  'id:Party::I-org': 90,
#  'upper_ini::I-org': 91,
#  'prev_tag:B-org::I-org': 92,
#  'prev_tag:I-org::O': 93,
#  'id:southern::O': 94,
#  'id:English::B-gpe': 95,
#  'id:seaside::O': 96,
#  'id:resort::O': 97,
#  'id:Brighton::B-geo': 98,
#  'id:party::O': 99,
#  'id:is::O': 100,
#  'id:divided::O': 101,
#  'id:over::O': 102,
#  'id:Britain::B-gpe': 103,
#  'id:participation::O': 104,
#  'id:continued::O': 105,
#  'id:deployment::O': 106,
#  'id:8,500::O': 107,
#  'id:march::O': 108,
#  'id:came::O': 109,
#  'id:ahead::O': 110,
#  'id:anti-war::O': 111,
#  'hyphen::O': 112,
#  'id:protests::O': 113,
#  'id:today::O': 114,
#  'id:other::O': 115,
#  'id:cities::O': 116,
#  'id:,::O': 117,
#  'id:including::O': 118,
#  'id:Rome::B-geo': 119,
#  'id:Paris::B-geo': 120,
#  'id:Madrid::B-geo': 121,
#  'id:International::B-org': 122,
#  'id:Atomic::I-org': 123,
#  'id:Energy::I-org': 124,
#  'prev_tag:I-org::I-org': 125,
#  'id:Agency::I-org': 126,
#  'id:hold::O': 127,
#  'id:second::O': 128,
#  'id:day::O': 129,
#  'id:talks::O': 130,
#  'id:Vienna::B-geo': 131,
#  'id:Wednesday::B-tim': 132,
#  'upper_ini::B-tim': 133,
#  'prev_tag:B-geo::B-tim': 134,
#  'prev_tag:B-tim::O': 135,
#  'id:how::O': 136,
#  'id:respond::O': 137,
#  'id:Iran::B-gpe': 138,
#  'id:resumption::O': 139,
#  'id:low-level::O': 140,
#  'id:uranium::O': 141,
#  'id:conversion::O': 142,
#  'init_tag:B-gpe': 143,
#  'id:this::O': 144,
#  'id:week::O': 145,
#  'id:restarted::O': 146,
#  'id:parts::O': 147,
#  'id:process::O': 148,
#  'id:its::O': 149,
#  'id:Isfahan::B-geo': 150,
#  'id:nuclear::O': 151,
#  'id:plant::O': 152,
#  'id:Iranian::B-gpe': 153,
#  'id:officials::O': 154,
#  'id:say::O': 155,
#  'id:they::O': 156,
#  'id:expect::O': 157,
#  'id:get::O': 158,
#  'id:access::O': 159,
#  'id:sealed::O': 160,
#  'id:sensitive::O': 161,
#  'prev_tag:O::B-tim': 162,
#  'id:after::O': 163,
#  'id:an::O': 164,
#  'id:IAEA::B-org': 165,
#  'id:surveillance::O': 166,
#  'prev_tag:B-org::O': 167,
#  'id:system::O': 168,
#  'id:begins::O': 169,
#  'id:functioning::O': 170,
#  'id:step::O': 171,
#  'id:will::O': 172,
#  'id:allow::O': 173,
#  'id:facility::O': 174,
#  'id:operate::O': 175,
#  'id:full::O': 176,
#  'id:capacity::O': 177,
#  'id:European::B-org': 178,
#  'id:Union::I-org': 179,
#  'id:U.S.::B-gpe': 180,
#  'id:backing::O': 181,
#  'id:has::O': 182,
#  'id:threatened::O': 183,
#  'id:refer::O': 184,
#  'id:U.N.::B-org': 185,
#  'id:Security::I-org': 186,
#  'id:Council::I-org': 187,
#  'id:which::O': 188,
#  'id:could::O': 189,
#  'id:impose::O': 190,
#  'id:sanctions::O': 191,
#  'id:if::O': 192,
#  'id:finds::O': 193,
#  'id:Tehran::B-gpe': 194,
#  'id:violated::O': 195,
#  'id:Nuclear::B-art': 196,
#  'upper_ini::B-art': 197,
#  'prev_tag:O::B-art': 198,
#  'id:Non-Proliferation::I-art': 199,
#  'hyphen::I-art': 200,
#  'upper_ini::I-art': 201,
#  'prev_tag:B-art::I-art': 202,
#  'id:treaty::O': 203,
#  'prev_tag:I-art::O': 204,
#  'id:new::O': 205,
#  'id:President::B-per': 206,
#  'id:Mahmoud::I-per': 207,
#  'upper_ini::I-per': 208,
#  'prev_tag:B-per::I-per': 209,
#  'id:Ahmadinejad::I-per': 210,
#  'prev_tag:I-per::I-per': 211,
#  'id:said::O': 212,
#  'prev_tag:I-per::O': 213,
#  'id:Tuesday::B-tim': 214,
#  'id:European::B-gpe': 215,
#  'id:incentives::O': 216,
#  'id:aimed::O': 217,
#  'id:persuading::O': 218,
#  'id:end::O': 219,
#  'id:fuel::O': 220,
#  'id:program::O': 221,
#  'id:are::O': 222,
#  'id:insult::O': 223,
#  'id:nation::O': 224,
#  'id:Two::O': 225,
#  'id:Germans::B-gpe': 226,
#  'id:four::O': 227,
#  'id:Nigerian::B-gpe': 228,
#  'id:oil::O': 229,
#  'id:workers::O': 230,
#  'id:were::O': 231,
#  'id:kidnapped::O': 232,
#  'id:by::O': 233,
#  'id:armed::O': 234,
#  'id:militants::O': 235,
#  'id:during::O': 236,
#  'id:raid::O': 237,
#  'id:boat::O': 238,
#  'id:Nigeria::B-geo': 239,
#  'id:oil-rich::O': 240,
#  'id:Delta::B-geo': 241,
#  'id:region::O': 242,
#  'id:An::O': 243,
#  'id:official::O': 244,
#  'id:German::B-gpe': 245,
#  'id:firm::O': 246,
#  'id:Bilfinger::B-org': 247,
#  'id:Berger::I-org': 248,
#  'id:Thomas::B-per': 249,
#  'id:Horbach::I-per': 250,
#  'id:gunmen::O': 251,
#  'id:stopped::O': 252,
#  'id:supply::O': 253,
#  'id:sailed::O': 254,
#  'id:State::I-geo': 255,
#  'id:Bayelsa::B-geo': 256,
#  'id:inspect::O': 257,
#  'id:offshore::O': 258,
#  'id:field::O': 259,
#  'id:owned::O': 260,
#  'id:Royal-Dutch::B-org': 261,
#  'hyphen::B-org': 262,
#  'id:Shell::I-org': 263,
#  'id:works::O': 264,
#  'id:sub-contractor::O': 265,
#  'id:for::O': 266,
#  'id:Shell::B-org': 267,
#  'id:Militant::O': 268,
#  'id:groups::O': 269,
#  'id:frequently::O': 270,
#  'id:attack::O': 271,
#  'id:operations::O': 272,
#  'id:Niger::B-geo': 273,
#  'id:Delta::I-geo': 274,
#  'id:social::O': 275,
#  'id:services::O': 276,
#  'id:better::O': 277,
#  'id:job::O': 278,
#  'id:opportunities::O': 279,
#  'id:multinational::O': 280,
#  'id:companies::O': 281,
#  'id:Poor::O': 282,
#  'id:residents::O': 283,
#  'id:often::O': 284,
#  'id:complain::O': 285,
#  'id:been::O': 286,
#  'id:cheated::O': 287,
#  'id:out::O': 288,
#  'id:huge::O': 289,
#  'id:riches::O': 290,
#  'id:extracted::O': 291,
#  'id:their::O': 292,
#  'id:tribal::O': 293,
#  'id:lands::O': 294,
#  'id:-::O': 295,
#  'id:where::O': 296,
#  'id:bulk::O': 297,
#  'id:Nigeria::B-gpe': 298,
#  'id:2.3::O': 299,
#  'id:million::O': 300,
#  'id:barrels::O': 301,
#  'id:petroleum::O': 302,
#  'id:pumped::O': 303,
#  'id:daily::O': 304,
#  'id:Suspected::O': 305,
#  'id:Islamist::O': 306,
#  'id:rebels::O': 307,
#  'id:fired::O': 308,
#  'id:mortar::O': 309,
#  'id:shells::O': 310,
#  'id:palace::O': 311,
#  'id:used::O': 312,
#  'id:Somalia::B-geo': 313,
#  'id:interim::O': 314,
#  'id:Abdullahi::I-per': 315,
#  'id:Yusuf::I-per': 316,
#  'id:Ahmad::I-per': 317,
#  'id:It::O': 318,
#  'id:not::O': 319,
#  'id:immediately::O': 320,
#  'id:clear::O': 321,
#  'id:president::O': 322,
#  'id:Mogadishu::B-geo': 323,
#  'id:when::O': 324,
#  'id:occurred::O': 325,
#  'id:or::O': 326,
#  'id:anyone::O': 327,
#  'id:hurt::O': 328,
#  'id:Local::O': 329,
#  'id:news::O': 330,
#  'id:reports::O': 331,
#  'id:least::O': 332,
#  'id:five::O': 333,
#  'id:hit::O': 334,
#  'id:compound::O': 335,
#  'id:mortars::O': 336,
#  'id:elsewhere::O': 337,
#  'id:attacks::O': 338,
#  'id:government::O': 339,
#  'id:go::O': 340,
#  'id:reconciliation::O': 341,
#  'id:more::O': 342,
#  'id:than::O': 343,
#  'id:1,300::O': 344,
#  'id:Somali::B-gpe': 345,
#  'id:elders::O': 346,
#  'id:warlords::O': 347,
#  'id:politicians::O': 348,
#  'id:invited::O': 349,
#  'id:Iraqi::B-gpe': 350,
#  'id:military::O': 351,
#  'id:tanks::O': 352,
#  'id:arrived::O': 353,
#  'id:northern::O': 354,
#  'id:city::O': 355,
#  'id:Mosul::B-geo': 356,
#  'id:offensive::O': 357,
#  'id:against::O': 358,
#  'id:al::B-org': 359,
#  'id:Qaida::I-org': 360,
#  'id:in::I-org': 361,
#  'id:Iraq::I-org': 362,
#  'id:fighters::O': 363,
#  'id:Officials::O': 364,
#  'id:many::O': 365,
#  'id:Sunni::B-geo': 366,
#  'id:Arab::I-geo': 367,
#  'id:Kurdish::B-geo': 368,
#  'id:bombings::O': 369,
#  'id:last::O': 370,
#  'id:34::O': 371,
#  'id:people::O': 372,
#  'id:wounded::O': 373,
#  'id:200::O': 374,
#  'id:commanders::O': 375,
#  'id:explained::O': 376,
#  'id:American::B-gpe': 377,
#  'id:forces::O': 378,
#  'id:participate::O': 379,
#  'id:fled::O': 380,
#  'id:successful::O': 381,
#  'id:campaigns::O': 382,
#  'id:them::O': 383,
#  'id:Anbar::B-geo': 384,
#  'id:province::O': 385,
#  'id:Baghdad::B-geo': 386,
#  'id:provinces::O': 387,
#  'init_tag:B-geo': 388,
#  'id:largest::O': 389,
#  'id:north::O': 390,
#  'id:long::O': 391,
#  'id:stronghold::O': 392,
#  'id:Sunni::B-org': 393,
#  'id:militant::O': 394,
#  'id:In::O': 395,
#  'id:violence::O': 396,
#  'id:one::O': 397,
#  'id:soldier::O': 398,
#  'id:patrol::O': 399,
#  'id:Sunday::B-tim': 400,
#  'id:Egyptian::B-gpe': 401,
#  'id:police::O': 402,
#  'id:arrested::O': 403,
#  'id:16::O': 404,
#  'id:members::O': 405,
#  'id:opposition::O': 406,
#  'id:Muslim::B-org': 407,
#  'id:Brotherhood::I-org': 408,
#  'id:prepare::O': 409,
#  'id:parliamentary::O': 410,
#  'id:runoff::O': 411,
#  'id:elections::O': 412,
#  'id:Saturday::B-tim': 413,
#  'id:arrests::O': 414,
#  'id:Friday::B-tim': 415,
#  'id:Alexandria::B-geo': 416,
#  'id:A::O': 417,
#  'id:spokesman::O': 418,
#  'id:Brotherhood::B-org': 419,
#  'id:attempt::O': 420,
#  'id:cut::O': 421,
#  'id:off::O': 422,
#  'id:supporters::O': 423,
#  'id:punishment::O': 424,
#  'id:winning::O': 425,
#  'id:seats::O': 426,
#  'id:earlier::O': 427,
#  'id:tripled::O': 428,
#  'id:strength::O': 429,
#  'id:parliament::O': 430,
#  'id:recent::O': 431,
#  'id:raising::O': 432,
#  'id:total::O': 433,
#  'id:47::O': 434,
#  'id:voters::O': 435,
#  'id:cast::O': 436,
#  'id:ballots::O': 437,
#  'id:nine::O': 438,
#  'id:no::O': 439,
#  'id:candidate::O': 440,
#  'id:won::O': 441,
#  'id:majority::O': 442,
#  'id:previous::O': 443,
#  'id:round::O': 444,
#  'id:voting::O': 445,
#  'id:banned::O': 446,
#  'id:political::O': 447,
#  'id:but::O': 448,
#  'id:endorses::O': 449,
#  'id:so-called::O': 450,
#  'id:independent::O': 451,
#  'id:candidates::O': 452,
#  'id:whose::O': 453,
#  'id:allegiance::O': 454,
#  'id:known::O': 455,
#  'id:Hardline::O': 456,
#  'id:lawmakers::O': 457,
#  'id:Pakistan::B-geo': 458,
#  'id:North::B-geo': 459,
#  'id:West::I-geo': 460,
#  'id:Frontier::I-geo': 461,
#  'prev_tag:I-geo::I-geo': 462,
#  'id:Province::I-geo': 463,
#  'id:pushed::O': 464,
#  'id:law::O': 465,
#  'id:aims::O': 466,
#  'id:ensure::O': 467,
#  'id:Islamic::O': 468,
#  'id:correctness::O': 469,
#  'id:public::O': 470,
#  'id:places::O': 471,
#  'id:establishes::O': 472,
#  'id:morality::O': 473,
#  'id:enforce::O': 474,
#  'id:decent::O': 475,
#  'id:behavior::O': 476,
#  'id:six-party::O': 477,
#  'id:coalition::O': 478,
#  'id:religious::O': 479,
#  'id:based::O': 480,
#  'id:parties::O': 481,
#  'id:Mutahida::B-org': 482,
#  'id:Majlis-e-Amal::I-org': 483,
#  'hyphen::I-org': 484,
#  'id:dominates::O': 485,
#  'id:provincial::O': 486,
#  'id:assembly::O': 487,
#  'id:so::O': 488,
#  'id:bill::O': 489,
#  'id:easily::O': 490,
#  'id:passed::O': 491,
#  'id:Thursday::B-tim': 492,
#  'id:vote::O': 493,
#  'id:68-34::O': 494,
#  'id:governor::O': 495,
#  'id:must::O': 496,
#  'id:still::O': 497,
#  'id:sign::O': 498,
#  'id:before::O': 499,
#  'id:becomes::O': 500,
#  'id:seen::O': 501,
#  'id:only::O': 502,
#  'id:formality::O': 503,
#  'id:proposed::O': 504,
#  'id:calls::O': 505,
#  'id:setting::O': 506,
#  'id:up::O': 507,
#  'id:force::O': 508,
#  'id:make::O': 509,
#  'id:sure::O': 510,
#  'id:adhere::O': 511,
#  'id:values::O': 512,
#  'id:entertainment::O': 513,
#  'id:outlets::O': 514,
#  'id:close::O': 515,
#  'id:weekly::O': 516,
#  'id:prayers::O': 517,
#  'id:Violators::O': 518,
#  'id:be::O': 519,
#  'id:jailed::O': 520,
#  'id:six::O': 521,
#  'id:months::O': 522,
#  'id:denounced::O': 523,
#  'id:measure::O': 524,
#  'id:comparing::O': 525,
#  'id:draconian::O': 526,
#  'id:rule::O': 527,
#  'id:former::O': 528,
#  'id:Taleban::B-org': 529,
#  'id:neighboring::O': 530,
#  'id:Afghanistan::B-geo': 531,
#  'id:man::O': 532,
#  'id:dressed::O': 533,
#  'id:suicide::O': 534,
#  'id:bomber::O': 535,
#  'id:demonstration::O': 536,
#  'id:publication::O': 537,
#  'id:cartoons::O': 538,
#  'id:depicting::O': 539,
#  'id:Islam::B-org': 540,
#  'id:Prophet::B-per': 541,
#  'id:Muhammad::I-per': 542,
#  'id:Bedfordshire::B-gpe': 543,
#  'id:Omar::B-per': 544,
#  'id:Khayam::I-per': 545,
#  'id:Bedford::B-geo': 546,
#  'id:breaching::O': 547,
#  'id:conditions::O': 548,
#  'id:his::O': 549,
#  'id:parole::O': 550,
#  'id:British::B-org': 551,
#  'id:Home::I-org': 552,
#  'id:Office::I-org': 553,
#  'id:sought::O': 554,
#  'id:investigation::O': 555,
#  'id:Khayam::B-per': 556,
#  'id:he::O': 557,
#  'id:photographed::O': 558,
#  'id:fatigues::O': 559,
#  'id:black::O': 560,
#  'id:cap::O': 561,
#  'id:bulky::O': 562,
#  'id:belt::O': 563,
#  'id:Home::B-org': 564,
#  'id:told::O': 565,
#  'id:Associated::B-org': 566,
#  'verb_ed::B-org': 567,
#  'id:Press::I-org': 568,
#  'id:paroled::O': 569,
#  'id:offender::O': 570,
#  'id:gives::O': 571,
#  'id:cause::O': 572,
#  'id:concern::O': 573,
#  'id:can::O': 574,
#  'id:sent::O': 575,
#  'id:back::O': 576,
#  'id:prison::O': 577,
#  'id:AP::B-org': 578,
#  'id:also::O': 579,
#  'id:since::O': 580,
#  'id:year::O': 581,
#  'id:serving::O': 582,
#  'id:half::O': 583,
#  'id:six-year::O': 584,
#  'id:sentence::O': 585,
#  'id:drug::O': 586,
#  'id:dealing::O': 587,
#  'id:Pakistani::B-gpe': 588,
#  'id:unidentified::O': 589,
#  'id:three::O': 590,
#  'id:minister::O': 591,
#  'id:semi-autonomous::O': 592,
#  'id:bordering::O': 593,
#  'id:prominent::O': 594,
#  'id:leader::O': 595,
#  'id:Malik::B-per': 596,
#  'id:Faridullah::I-per': 597,
#  'id:Khan::I-per': 598,
#  'id:traveling::O': 599,
#  'id:South::B-geo': 600,
#  'id:Waziristan::I-geo': 601,
#  'prev_tag:I-geo::B-tim': 602,
#  'id:vehicle::O': 603,
#  'id:ambushed::O': 604,
#  'id:Kani::B-geo': 605,
#  'id:Wam::I-geo': 606,
#  'id:area::O': 607,
#  'id:His::O': 608,
#  'id:driver::O': 609,
#  'id:elder::O': 610,
#  'id:No::O': 611,
#  'id:responsibility::O': 612,
#  'id:killings::O': 613,
#  'id:ambush::O': 614,
#  'id:commander::O': 615,
#  'id:army::O': 616,
#  'id:almost::O': 617,
#  'id:completely::O': 618,
#  'id:eliminated::O': 619,
#  'id:became::O': 620,
#  'id:refuge::O': 621,
#  'id:al-Qaida::B-org': 622,
#  'id:ousted::O': 623,
#  'id:2001::B-tim': 624,
#  'id:senior::O': 625,
#  'id:says::O': 626,
#  'id:Pakistan::B-gpe': 627,
#  'id:wants::O': 628,
#  'id:what::O': 629,
#  'id:sordid::O': 630,
#  'id:chapter::O': 631,
#  'id:proliferation::O': 632,
#  'id:top::O': 633,
#  'id:scientists::O': 634,
#  'id:behind::O': 635,
#  'id:build::O': 636,
#  'id:civilian::O': 637,
#  'id:ties::O': 638,
#  'id:United::B-gpe': 639,
#  'verb_ed::B-gpe': 640,
#  'id:States::I-gpe': 641,
#  'upper_ini::I-gpe': 642,
#  'prev_tag:B-gpe::I-gpe': 643,
#  'prev_tag:I-gpe::O': 644,
#  'id:But::O': 645,
#  'id:ready::O': 646,
#  'id:scientist::O': 647,
#  'id:Abdul::B-per': 648,
#  'id:Qadeer::I-per': 649,
#  'id:available::O': 650,
#  'id:direct::O': 651,
#  'id:questioning::O': 652,
#  'id:sale::O': 653,
#  'id:secrets::O': 654,
#  'id:states::O': 655,
#  'id:Libya::B-gpe': 656,
#  'id:North::B-gpe': 657,
#  'id:Korea::I-gpe': 658,
#  'id:He::O': 659,
#  'id:there::O': 660,
#  'id:reasons::O': 661,
#  'id:national::O': 662,
#  'id:sensitivities::O': 663,
#  'id:making::O': 664,
#  'id:him::O': 665,
#  'id:giving::O': 666,
#  'id:background::O': 667,
#  'id:briefing::O': 668,
#  'id:small::O': 669,
#  'id:group::O': 670,
#  'id:reporters::O': 671,
#  'id:Washington::B-geo': 672,
#  'init_tag:B-per': 673,
#  'id:Khan::B-per': 674,
#  'id:admitted::O': 675,
#  'id:2004::B-tim': 676,
#  'id:operated::O': 677,
#  'id:worldwide::O': 678,
#  'id:clandestine::O': 679,
#  'id:network::O': 680,
#  'id:sell::O': 681,
#  'id:technology::O': 682,
#  'id:market::O': 683,
#  'id:placed::O': 684,
#  'id:under::O': 685,
#  'id:house::O': 686,
#  'id:arrest::O': 687,
#  'id:Islamabad::B-geo': 688,
#  'id:because::O': 689,
#  'id:considered::O': 690,
#  'id:father::O': 691,
#  'id:bomb::O': 692,
#  'id:Army::B-org': 693,
#  'prev_tag:B-gpe::B-org': 694,
#  'id:renew::O': 695,
#  'id:controversial::O': 696,
#  'id:multi-billion::O': 697,
#  'id:dollar::O': 698,
#  'id:contract::O': 699,
#  'id:Halliburton::B-org': 700,
#  'id:company::O': 701,
#  'id:provide::O': 702,
#  'id:logistical::O': 703,
#  'id:support::O': 704,
#  'init_tag:B-org': 705,
#  'id:providing::O': 706,
#  'id:list::O': 707,
#  'id:meals::O': 708,
#  'id:communication::O': 709,
#  'id:several::O': 710,
#  'id:years::O': 711,
#  'id:Critics::O': 712,
#  'id:include::O': 713,
#  'id:auditors::O': 714,
#  'id:congressional::O': 715,
#  'id:Democrats::O': 716,
#  'id:produced::O': 717,
#  'id:some::O': 718,
#  'id:shoddy::O': 719,
#  'id:work::O': 720,
#  'id:charges::O': 721,
#  'id:too::O': 722,
#  'id:much::O': 723,
#  'id:money::O': 724,
#  'id:strongly::O': 725,
#  'id:denies::O': 726,
#  'id:allegations::O': 727,
#  'id:When::O': 728,
#  'id:re-bidding::O': 729,
#  'id:chance::O': 730,
#  'id:compete::O': 731,
#  'id:portions::O': 732,
#  'id:Representatives::O': 733,
#  'id:Asia::B-org': 734,
#  'id:Pacific::I-org': 735,
#  'id:Economic::I-org': 736,
#  'id:Cooperation::I-org': 737,
#  'id:Business::I-org': 738,
#  'id:Advisory::I-org': 739,
#  'id:holding::O': 740,
#  'id:meetings::O': 741,
#  'id:finalize::O': 742,
#  'id:report::O': 743,
#  'id:APEC::B-org': 744,
#  'id:leaders::O': 745,
#  'id:summit::O': 746,
#  'id:September::B-tim': 747,
#  'id:8::I-tim': 748,
#  'prev_tag:B-tim::I-tim': 749,
#  'prev_tag:I-tim::O': 750,
#  'id:9::B-tim': 751,
#  'id:VOA::B-org': 752,
#  'id:Nancy-Amelia::B-per': 753,
#  'hyphen::B-per': 754,
#  'id:Collins::I-per': 755,
#  'id:Sydney::B-geo': 756,
#  'id:Energy::O': 757,
#  'id:security::O': 758,
#  'id:climate::O': 759,
#  'id:change::O': 760,
#  'id:World::B-org': 761,
#  'id:Trade::I-org': 762,
#  'id:Organization::I-org': 763,
#  'id:stalled::O': 764,
#  'id:negotiations::O': 765,
#  'id:investment::O': 766,
#  'id:all::O': 767,
#  'id:expected::O': 768,
#  'id:among::O': 769,
#  'id:major::O': 770,
#  'id:topics::O': 771,
#  'id:ABAC::B-org': 772,
#  'id:Tim::B-per': 773,
#  'id:Harcourt::I-per': 774,
#  'id:chief::O': 775,
#  'id:economist::O': 776,
#  'id:Australian::B-org': 777,
#  'id:Commission::I-org': 778,
#  'id:plays::O': 779,
#  'id:important::O': 780,
#  'id:role::O': 781,
#  'id:informing::O': 782,
#  'id:governments::O': 783,
#  'id:problems::O': 784,
#  'id:most::O': 785,
#  'id:thing::O': 786,
#  'id:business::O': 787,
#  'id:do::O': 788,
#  'id:tell::O': 789,
#  'id:logjams::O': 790,
#  'id:obstacles::O': 791,
#  'id:things::O': 792,
#  'id:improve::O': 793,
#  'id:Harcourt::B-per': 794,
#  'id:I::O': 795,
#  'id:think::O': 796,
#  'id:actually::O': 797,
#  'id:played::O': 798,
#  'id:pretty::O': 799,
#  'id:good::O': 800,
#  'id:leadership::O': 801,
#  'id:talking::O': 802,
#  'id:about::O': 803,
#  'id:trade::O': 804,
#  'id:facilitation::O': 805,
#  'id:basically::O': 806,
#  'id:standards::O': 807,
#  'id:consistent::O': 808,
#  'id:harmonious::O': 809,
#  'id:across::O': 810,
#  'id:comprises::O': 811,
#  'id:private::O': 812,
#  'id:sector::O': 813,
#  'id:each::O': 814,
#  'id:21::O': 815,
#  'id:economies::O': 816,
#  'id:meets::O': 817,
#  'id:times::O': 818,
#  'id:made::O': 819,
#  'id:permanent::O': 820,
#  'id:body::O': 821,
#  'id:1995::B-tim': 822,
#  'id:perspective::O': 823,
#  'id:within::O': 824,
#  'id:Members::O': 825,
#  'id:represent::O': 826,
#  'id:range::O': 827,
#  'id:sectors::O': 828,
#  'id:medium::O': 829,
#  'id:businesses::O': 830,
#  'id:need::O': 831,
#  'id:energy::O': 832,
#  'id:efficiency::O': 833,
#  'id:encourage::O': 834,
#  'id:conservation::O': 835,
#  'id:practices::O': 836,
#  'id:discuss::O': 837,
#  'id:ways::O': 838,
#  'id:enhance::O': 839,
#  'id:regional::O': 840,
#  'id:cooperation::O': 841,
#  'id:reckon::O': 842,
#  "id:'ll::O": 843,
#  'id:talk::O': 844,
#  'id:little::O': 845,
#  'id:bit::O': 846,
#  'id:customs::O': 847,
#  'id:quarantine::O': 848,
#  'id:having::O': 849,
#  'id:arrangements::O': 850,
#  'id:around::O': 851,
#  'id:And::O': 852,
#  'id:want::O': 853,
#  'id:one-stop::O': 854,
#  'id:shop::O': 855,
#  'id:terms::O': 856,
#  'id:combining::O': 857,
#  'id:immigration::O': 858,
#  'id:together::O': 859,
#  'id:\x85::O': 860,
#  'id:just::O': 861,
#  'id:streamlined::O': 862,
#  'id:provides::O': 863,
#  'id:certainty::O': 864,
#  'id:non-governmental::O': 865,
#  'id:formal::O': 866,
#  'id:dialogue::O': 867,
#  'id:present::O': 868,
#  'id:meeting::O': 869,
#  'id:Sudan::B-gpe': 870,
#  'id:order::O': 871,
#  'id:Darfur::B-geo': 872,
#  'id:asking::O': 873,
#  'id:same::O': 874,
#  'id:Foreign::B-per': 875,
#  'id:Minister::I-per': 876,
#  'id:Mustafa::I-per': 877,
#  'id:Osman::I-per': 878,
#  'id:Ismail::I-per': 879,
#  'id:Sudanese::B-gpe': 880,
#  'id:withdraw::O': 881,
#  'id:positions::O': 882,
#  'id:held::O': 883,
#  'id:April::B-tim': 884,
#  'id:cease-fire::O': 885,
#  'id:western::O': 886,
#  'id:agree::O': 887,
#  'id:stop::O': 888,
#  'id:Mr.::B-per': 889,
#  'id:announced::O': 890,
#  'id:decision::O': 891,
#  'id:United::B-org': 892,
#  'id:Nations::I-org': 893,
#  'id:African::B-org': 894,
#  'id:Khartoum::B-geo': 895,
#  'id:weeks::O': 896,
#  'id:AU::B-org': 897,
#  'id:repeatedly::O': 898,
#  'id:truce::O': 899,
#  'init_tag:B-tim': 900,
#  'id:head::O': 901,
#  'id:accused::O': 902,
#  'id:helicopters::O': 903,
#  'id:bombing::O': 904,
#  'id:rebel::O': 905,
#  'id:sites::O': 906,
#  'id:Darfur::I-geo': 907,
#  'id:village::O': 908,
#  'id:Labado::B-geo': 909,
#  'id:Khartoum::B-gpe': 910,
#  'id:defending::O': 911,
#  'id:Aid::O': 912,
#  'id:relief::O': 913,
#  'id:efforts::O': 914,
#  'id:suspended::O': 915,
#  'id:due::O': 916,
#  'id:Indonesian::B-gpe': 917,
#  'id:men::O': 918,
#  'id:connection::O': 919,
#  'id:October::B-tim': 920,
#  'id:1::I-tim': 921,
#  'id:Bali::B-geo': 922,
#  'prev_tag:I-tim::B-geo': 923,
#  'id:left::O': 924,
#  'id:23::O': 925,
#  'id:dead::O': 926,
#  'id:flown::O': 927,
#  'id:Java::B-geo': 928,
#  'id:island::O': 929,
#  'id:headquarters::O': 930,
#  'id:Australian::B-gpe': 931,
#  'id:French::B-gpe': 932,
#  'id:agencies::O': 933,
#  'id:(::O': 934,
#  'id:Cholily::B-per': 935,
#  'id:)::O': 936,
#  'id:captured::O': 937,
#  'id:series::O': 938,
#  'id:counter-terrorism::O': 939,
#  'id:raids::O': 940,
#  'id:Indonesia::B-geo': 941,
#  'id:ended::O': 942,
#  'id:death::O': 943,
#  'id:alleged::O': 944,
#  'id:extremist::O': 945,
#  'id:bombmaker::O': 946,
#  'id:Azahari::B-per': 947,
#  'id:bin::I-per': 948,
#  'id:Husin::I-per': 949,
#  'id:authorities::O': 950,
#  'id:blame::O': 951,
#  'id:orchestrating::O': 952,
#  'id:month::O': 953,
#  'id:well::O': 954,
#  'id:2002::B-tim': 955,
#  'prev_tag:B-tim::B-geo': 956,
#  'id:Gunmen::O': 957,
#  'id:shot::O': 958,
#  'id:Roman::B-org': 959,
#  'id:Catholic::I-org': 960,
#  'id:nun::O': 961,
#  'id:her::O': 962,
#  'id:bodyguard::O': 963,
#  'id:hospital::O': 964,
#  'id:she::O': 965,
#  'id:worked::O': 966,
#  'id:Islamist-controlled::O': 967,
#  'id:Some::O': 968,
#  'id:witnesses::O': 969,
#  'id:shooting::O': 970,
#  'id:feared::O': 971,
#  'id:linked::O': 972,
#  'id:Muslim::O': 973,
#  'id:anger::O': 974,
#  'id:toward::O': 975,
#  'id:Pope::B-per': 976,
#  'id:Benedict::I-per': 977,
#  'id:pistols::O': 978,
#  'id:attacked::O': 979,
#  'id:Sister::B-per': 980,
#  'id:Leonella::I-per': 981,
#  'id:Sgorbati::I-per': 982,
#  'id:finished::O': 983,
#  'id:teaching::O': 984,
#  'id:medical::O': 985,
#  'id:school::O': 986,
#  'id:class::O': 987,
#  'id:suspect::O': 988,
#  'id:Vatican::B-org': 989,
#  'id:deplored::O': 990,
#  'id:hoped::O': 991,
#  'id:isolated::O': 992,
#  'id:event::O': 993,
#  'id:irrationality::O': 994,
#  'id:arising::O': 995,
#  'id:comments::O': 996,
#  'id:Pope::O': 997,
#  'id:angered::O': 998,
#  'id:Muslims::O': 999,
#  ...}

# %%
[x for x in list(ex_feature_mapper.feature_dict.keys()) if 'verb_ed' in x]
# Out:
# ['verb_ed::O',
#  'verb_ed::B-org',
#  'verb_ed::B-gpe',
#  'verb_ed::I-per',
#  'verb_ed::B-per',
#  'verb_ed::I-org',
#  'verb_ed::B-geo',
#  'verb_ed::B-art',
#  'verb_ed::B-tim',
#  'verb_ed::I-tim',
#  'verb_ed::I-geo',
#  'verb_ed::B-eve']

# %% [markdown]
# #### Training structured perceptron

# %%
corpus = skseq.readers.pos_corpus.PostagCorpus()
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)

# %%
sp.get_num_states(), sp.get_num_observations()
# Out:
# (17, 30863)

# %%
# %%time
num_epochs = 15
sp.fit(ex_feature_mapper.dataset, num_epochs)
# Out:
# Epoch: 0 Accuracy: 0.929893
# Epoch: 1 Accuracy: 0.945859
# Epoch: 2 Accuracy: 0.950447
# Epoch: 3 Accuracy: 0.953116
# Epoch: 4 Accuracy: 0.955520
# Epoch: 5 Accuracy: 0.956555
# Epoch: 6 Accuracy: 0.958235
# Epoch: 7 Accuracy: 0.959212
# Epoch: 8 Accuracy: 0.959951
# Epoch: 9 Accuracy: 0.960900
# Epoch: 10 Accuracy: 0.961482
# Epoch: 11 Accuracy: 0.961900
# Epoch: 12 Accuracy: 0.962931
# Epoch: 13 Accuracy: 0.963072
# Epoch: 14 Accuracy: 0.963401
# Wall time: 1h 10min 54s

# %%
sp.save_model("perceptron_ex4")

# %%
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)
sp.load_model(dir="perceptron_ex4")

# %% [markdown]
# #### Testing

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

y_pred_2 = []
y_true = [item for x in Y_ids_test for item in x]
correct_sentences = 0
n_test = len(X_test)

for i in range(n_test):
    y_pred_aux = sp.predict_tags_given_words(X_test[i])
    y_pred_2.append(y_pred_aux)
    if list(y_pred_aux) == Y_ids_test[i]:
        correct_sentences += 1
    
y_pred = [item for x in y_pred_2 for item in x]
F1_score_multi = f1_score(y_true, y_pred, average=None)
Accuracy = accuracy_score(y_true, y_pred)
print('Accuracy for test is: ' + str(Accuracy))
print('F1-Score for test is: ' + str(np.mean(F1_score_multi)))
print('Correct sentences for test (%) : ' + str(correct_sentences/n_test))
# Out:
# Accuracy for test is: 0.9489546752060652
# F1-Score for test is: 0.6005716000744572
# Correct sentences for test (%) : 0.46838505171838507

# %%
ax = plot_confusion_matrix(y_true, y_pred, classes=list(sp.state_labels),
                      title='Confusion matrix')

# %% [markdown]
# #### SENTENCES TO TEST THE MODEL

# %% [markdown]
# We think that these are the tags that the model should obtain:
#
# 1. The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 2. The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 3. Jack/B-per London/I-per went/O to/O Parris./O
#
# 4. Jack/B-per London/I-per went/O to/O/O Paris./B-geo
#
# 5. We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
#
# 6. We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
#
# 7. The/O president/O of/O U.S.A/B-geo though/O they/O could/O win/O the/O war/O
#
# 8. The/O president/O of/O the/O United/B-geo States/B-geo of/B-geo America/B-geo though/O they/O could/O win/O the/O war/O
#
# 9. The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
#
# 10. Robin/B-per does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
for sentence in test_sentences:
    new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
    print(sp.viterbi_decode(new_seq)[0].to_words(sequence_list_train, only_tag_translation=True))
# Out:
# The/O programmers/O from/O Barcelona/B-org might/O write/O a/O sentence/O without/O a/O spell/O checker./O
# The/O programmers/O from/O Barchelona/B-org cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
# Jack/B-per London/B-geo went/O to/O Parris./B-eve
# Jack/B-per London/B-geo went/O to/O Paris./B-eve
# We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
# We/O never/O though/O Microsof/B-org would/O become/O such/O a/O big/O company./O
# The/O president/O of/O U.S.A/B-org though/O they/O could/O win/O the/O war/O
# The/O president/O of/O the/O United/B-geo States/I-geo of/I-geo America/I-geo though/O they/O could/O win/O the/O war/O
# The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
# Robin/B-org does/O not/O want/O to/O go/O to/O Saudi/B-per Arabia./I-per

# %%
# Here we can select the sentence in which we want to compare the true and the predicted tags
# Select a sentence between 1 and 10
i=1
sentence = test_sentences[i-1]
new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(sentence.split(), test_tags[i-1], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# The             (O    ): O
# programmers     (O    ): O
# from            (O    ): O
# Barcelona       (B-geo): B-org
# might           (O    ): O
# write           (O    ): O
# a               (O    ): O
# sentence        (O    ): O
# without         (O    ): O
# a               (O    ): O
# spell           (O    ): O
# checker.        (O    ): O

# %% [markdown]
# #### Capital checking

# %%
new_seq = Sequence(x=X_test[0], y=[int(0) for w in X_test[0]])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(X_test[0], Y_test[0], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# Officials       (O    ): O
# said            (O    ): O
# Sunday          (B-tim): B-tim
# Jean            (B-per): B-per
# Rene            (I-per): I-per
# Anthony         (I-per): I-per
# was             (O    ): O
# killed          (O    ): O
# in              (O    ): O
# a               (O    ): O
# shootout        (O    ): O
# with            (O    ): O
# police          (O    ): O
# near            (O    ): O
# the             (O    ): O
# capital         (O    ): O
# city            (O    ): O
# of              (O    ): O
# Port-au-Prince  (B-geo): O
# .               (O    ): O

# %% [markdown]
# # EXPERIMENT 5: Adding -LY at the end

# %% [markdown]
# ##### Comments:

# %% [markdown]
# ### Extended features

# %%
ex_feature_mapper = skseq.sequences.extended_feature.ExtendedFeatures(sequence_list_train) 
ex_feature_mapper.build_features()
pprint.pprint(list(ex_feature_mapper.__dict__.keys()))
# Out:
# ['feature_dict',
#  'feature_list',
#  'add_features',
#  'dataset',
#  'node_feature_cache',
#  'initial_state_feature_cache',
#  'final_state_feature_cache',
#  'edge_feature_cache']

# %%
len(ex_feature_mapper.feature_dict)
# Out:
# 38353

# %%
ex_feature_mapper.feature_dict
# Out:
# {'init_tag:O': 0,
#  'id:Thousands::O': 1,
#  'upper_ini::O': 2,
#  'id:of::O': 3,
#  'prev_tag:O::O': 4,
#  'id:demonstrators::O': 5,
#  'id:have::O': 6,
#  'id:marched::O': 7,
#  'verb_ed::O': 8,
#  'id:through::O': 9,
#  'id:London::B-geo': 10,
#  'upper_ini::B-geo': 11,
#  'prev_tag:O::B-geo': 12,
#  'id:to::O': 13,
#  'prev_tag:B-geo::O': 14,
#  'id:protest::O': 15,
#  'id:the::O': 16,
#  'id:war::O': 17,
#  'id:in::O': 18,
#  'id:Iraq::B-geo': 19,
#  'id:and::O': 20,
#  'id:demand::O': 21,
#  'id:withdrawal::O': 22,
#  'id:British::B-gpe': 23,
#  'upper_ini::B-gpe': 24,
#  'prev_tag:O::B-gpe': 25,
#  'id:troops::O': 26,
#  'prev_tag:B-gpe::O': 27,
#  'id:from::O': 28,
#  'id:that::O': 29,
#  'id:country::O': 30,
#  'id:.::O': 31,
#  'final_prev_tag:O': 32,
#  'id:Families::O': 33,
#  'id:soldiers::O': 34,
#  'id:killed::O': 35,
#  'id:conflict::O': 36,
#  'id:joined::O': 37,
#  'id:protesters::O': 38,
#  'id:who::O': 39,
#  'id:carried::O': 40,
#  'id:banners::O': 41,
#  'id:with::O': 42,
#  'id:such::O': 43,
#  'id:slogans::O': 44,
#  'id:as::O': 45,
#  'id:"::O': 46,
#  'id:Bush::B-per': 47,
#  'upper_ini::B-per': 48,
#  'prev_tag:O::B-per': 49,
#  'id:Number::O': 50,
#  'prev_tag:B-per::O': 51,
#  'id:One::O': 52,
#  'id:Terrorist::O': 53,
#  'id:Stop::O': 54,
#  'id:Bombings::O': 55,
#  'id:They::O': 56,
#  'id:Houses::O': 57,
#  'id:Parliament::O': 58,
#  'id:a::O': 59,
#  'id:rally::O': 60,
#  'adverb_ly::O': 61,
#  'id:Hyde::B-geo': 62,
#  'id:Park::I-geo': 63,
#  'upper_ini::I-geo': 64,
#  'prev_tag:B-geo::I-geo': 65,
#  'prev_tag:I-geo::O': 66,
#  'id:Police::O': 67,
#  'id:put::O': 68,
#  'id:number::O': 69,
#  'id:marchers::O': 70,
#  'id:at::O': 71,
#  'id:10,000::O': 72,
#  'id:while::O': 73,
#  'id:organizers::O': 74,
#  'id:claimed::O': 75,
#  'id:it::O': 76,
#  'id:was::O': 77,
#  'id:1,00,000::O': 78,
#  'id:The::O': 79,
#  'id:comes::O': 80,
#  'id:on::O': 81,
#  'id:eve::O': 82,
#  'id:annual::O': 83,
#  'id:conference::O': 84,
#  'id:Britain::B-geo': 85,
#  "id:'s::O": 86,
#  'id:ruling::O': 87,
#  'id:Labor::B-org': 88,
#  'upper_ini::B-org': 89,
#  'prev_tag:O::B-org': 90,
#  'id:Party::I-org': 91,
#  'upper_ini::I-org': 92,
#  'prev_tag:B-org::I-org': 93,
#  'prev_tag:I-org::O': 94,
#  'id:southern::O': 95,
#  'id:English::B-gpe': 96,
#  'id:seaside::O': 97,
#  'id:resort::O': 98,
#  'id:Brighton::B-geo': 99,
#  'id:party::O': 100,
#  'id:is::O': 101,
#  'id:divided::O': 102,
#  'id:over::O': 103,
#  'id:Britain::B-gpe': 104,
#  'id:participation::O': 105,
#  'id:continued::O': 106,
#  'id:deployment::O': 107,
#  'id:8,500::O': 108,
#  'id:march::O': 109,
#  'id:came::O': 110,
#  'id:ahead::O': 111,
#  'id:anti-war::O': 112,
#  'hyphen::O': 113,
#  'id:protests::O': 114,
#  'id:today::O': 115,
#  'id:other::O': 116,
#  'id:cities::O': 117,
#  'id:,::O': 118,
#  'id:including::O': 119,
#  'id:Rome::B-geo': 120,
#  'id:Paris::B-geo': 121,
#  'id:Madrid::B-geo': 122,
#  'id:International::B-org': 123,
#  'id:Atomic::I-org': 124,
#  'id:Energy::I-org': 125,
#  'prev_tag:I-org::I-org': 126,
#  'id:Agency::I-org': 127,
#  'id:hold::O': 128,
#  'id:second::O': 129,
#  'id:day::O': 130,
#  'id:talks::O': 131,
#  'id:Vienna::B-geo': 132,
#  'id:Wednesday::B-tim': 133,
#  'upper_ini::B-tim': 134,
#  'prev_tag:B-geo::B-tim': 135,
#  'prev_tag:B-tim::O': 136,
#  'id:how::O': 137,
#  'id:respond::O': 138,
#  'id:Iran::B-gpe': 139,
#  'id:resumption::O': 140,
#  'id:low-level::O': 141,
#  'id:uranium::O': 142,
#  'id:conversion::O': 143,
#  'init_tag:B-gpe': 144,
#  'id:this::O': 145,
#  'id:week::O': 146,
#  'id:restarted::O': 147,
#  'id:parts::O': 148,
#  'id:process::O': 149,
#  'id:its::O': 150,
#  'id:Isfahan::B-geo': 151,
#  'id:nuclear::O': 152,
#  'id:plant::O': 153,
#  'id:Iranian::B-gpe': 154,
#  'id:officials::O': 155,
#  'id:say::O': 156,
#  'id:they::O': 157,
#  'id:expect::O': 158,
#  'id:get::O': 159,
#  'id:access::O': 160,
#  'id:sealed::O': 161,
#  'id:sensitive::O': 162,
#  'prev_tag:O::B-tim': 163,
#  'id:after::O': 164,
#  'id:an::O': 165,
#  'id:IAEA::B-org': 166,
#  'id:surveillance::O': 167,
#  'prev_tag:B-org::O': 168,
#  'id:system::O': 169,
#  'id:begins::O': 170,
#  'id:functioning::O': 171,
#  'id:step::O': 172,
#  'id:will::O': 173,
#  'id:allow::O': 174,
#  'id:facility::O': 175,
#  'id:operate::O': 176,
#  'id:full::O': 177,
#  'id:capacity::O': 178,
#  'id:European::B-org': 179,
#  'id:Union::I-org': 180,
#  'id:U.S.::B-gpe': 181,
#  'id:backing::O': 182,
#  'id:has::O': 183,
#  'id:threatened::O': 184,
#  'id:refer::O': 185,
#  'id:U.N.::B-org': 186,
#  'id:Security::I-org': 187,
#  'id:Council::I-org': 188,
#  'id:which::O': 189,
#  'id:could::O': 190,
#  'id:impose::O': 191,
#  'id:sanctions::O': 192,
#  'id:if::O': 193,
#  'id:finds::O': 194,
#  'id:Tehran::B-gpe': 195,
#  'id:violated::O': 196,
#  'id:Nuclear::B-art': 197,
#  'upper_ini::B-art': 198,
#  'prev_tag:O::B-art': 199,
#  'id:Non-Proliferation::I-art': 200,
#  'hyphen::I-art': 201,
#  'upper_ini::I-art': 202,
#  'prev_tag:B-art::I-art': 203,
#  'id:treaty::O': 204,
#  'prev_tag:I-art::O': 205,
#  'id:new::O': 206,
#  'id:President::B-per': 207,
#  'id:Mahmoud::I-per': 208,
#  'upper_ini::I-per': 209,
#  'prev_tag:B-per::I-per': 210,
#  'id:Ahmadinejad::I-per': 211,
#  'prev_tag:I-per::I-per': 212,
#  'id:said::O': 213,
#  'prev_tag:I-per::O': 214,
#  'id:Tuesday::B-tim': 215,
#  'id:European::B-gpe': 216,
#  'id:incentives::O': 217,
#  'id:aimed::O': 218,
#  'id:persuading::O': 219,
#  'id:end::O': 220,
#  'id:fuel::O': 221,
#  'id:program::O': 222,
#  'id:are::O': 223,
#  'id:insult::O': 224,
#  'id:nation::O': 225,
#  'id:Two::O': 226,
#  'id:Germans::B-gpe': 227,
#  'id:four::O': 228,
#  'id:Nigerian::B-gpe': 229,
#  'id:oil::O': 230,
#  'id:workers::O': 231,
#  'id:were::O': 232,
#  'id:kidnapped::O': 233,
#  'id:by::O': 234,
#  'id:armed::O': 235,
#  'id:militants::O': 236,
#  'id:during::O': 237,
#  'id:raid::O': 238,
#  'id:boat::O': 239,
#  'id:Nigeria::B-geo': 240,
#  'id:oil-rich::O': 241,
#  'id:Delta::B-geo': 242,
#  'id:region::O': 243,
#  'id:An::O': 244,
#  'id:official::O': 245,
#  'id:German::B-gpe': 246,
#  'id:firm::O': 247,
#  'id:Bilfinger::B-org': 248,
#  'id:Berger::I-org': 249,
#  'id:Thomas::B-per': 250,
#  'id:Horbach::I-per': 251,
#  'id:gunmen::O': 252,
#  'id:stopped::O': 253,
#  'id:supply::O': 254,
#  'id:sailed::O': 255,
#  'id:State::I-geo': 256,
#  'id:Bayelsa::B-geo': 257,
#  'id:inspect::O': 258,
#  'id:offshore::O': 259,
#  'id:field::O': 260,
#  'id:owned::O': 261,
#  'id:Royal-Dutch::B-org': 262,
#  'hyphen::B-org': 263,
#  'id:Shell::I-org': 264,
#  'id:works::O': 265,
#  'id:sub-contractor::O': 266,
#  'id:for::O': 267,
#  'id:Shell::B-org': 268,
#  'id:Militant::O': 269,
#  'id:groups::O': 270,
#  'id:frequently::O': 271,
#  'id:attack::O': 272,
#  'id:operations::O': 273,
#  'id:Niger::B-geo': 274,
#  'id:Delta::I-geo': 275,
#  'id:social::O': 276,
#  'id:services::O': 277,
#  'id:better::O': 278,
#  'id:job::O': 279,
#  'id:opportunities::O': 280,
#  'id:multinational::O': 281,
#  'id:companies::O': 282,
#  'id:Poor::O': 283,
#  'id:residents::O': 284,
#  'id:often::O': 285,
#  'id:complain::O': 286,
#  'id:been::O': 287,
#  'id:cheated::O': 288,
#  'id:out::O': 289,
#  'id:huge::O': 290,
#  'id:riches::O': 291,
#  'id:extracted::O': 292,
#  'id:their::O': 293,
#  'id:tribal::O': 294,
#  'id:lands::O': 295,
#  'id:-::O': 296,
#  'id:where::O': 297,
#  'id:bulk::O': 298,
#  'id:Nigeria::B-gpe': 299,
#  'id:2.3::O': 300,
#  'id:million::O': 301,
#  'id:barrels::O': 302,
#  'id:petroleum::O': 303,
#  'id:pumped::O': 304,
#  'id:daily::O': 305,
#  'id:Suspected::O': 306,
#  'id:Islamist::O': 307,
#  'id:rebels::O': 308,
#  'id:fired::O': 309,
#  'id:mortar::O': 310,
#  'id:shells::O': 311,
#  'id:palace::O': 312,
#  'id:used::O': 313,
#  'id:Somalia::B-geo': 314,
#  'id:interim::O': 315,
#  'id:Abdullahi::I-per': 316,
#  'id:Yusuf::I-per': 317,
#  'id:Ahmad::I-per': 318,
#  'id:It::O': 319,
#  'id:not::O': 320,
#  'id:immediately::O': 321,
#  'id:clear::O': 322,
#  'id:president::O': 323,
#  'id:Mogadishu::B-geo': 324,
#  'id:when::O': 325,
#  'id:occurred::O': 326,
#  'id:or::O': 327,
#  'id:anyone::O': 328,
#  'id:hurt::O': 329,
#  'id:Local::O': 330,
#  'id:news::O': 331,
#  'id:reports::O': 332,
#  'id:least::O': 333,
#  'id:five::O': 334,
#  'id:hit::O': 335,
#  'id:compound::O': 336,
#  'id:mortars::O': 337,
#  'id:elsewhere::O': 338,
#  'id:attacks::O': 339,
#  'id:government::O': 340,
#  'id:go::O': 341,
#  'id:reconciliation::O': 342,
#  'id:more::O': 343,
#  'id:than::O': 344,
#  'id:1,300::O': 345,
#  'id:Somali::B-gpe': 346,
#  'id:elders::O': 347,
#  'id:warlords::O': 348,
#  'id:politicians::O': 349,
#  'id:invited::O': 350,
#  'id:Iraqi::B-gpe': 351,
#  'id:military::O': 352,
#  'id:tanks::O': 353,
#  'id:arrived::O': 354,
#  'id:northern::O': 355,
#  'id:city::O': 356,
#  'id:Mosul::B-geo': 357,
#  'id:offensive::O': 358,
#  'id:against::O': 359,
#  'id:al::B-org': 360,
#  'id:Qaida::I-org': 361,
#  'id:in::I-org': 362,
#  'id:Iraq::I-org': 363,
#  'id:fighters::O': 364,
#  'id:Officials::O': 365,
#  'id:many::O': 366,
#  'id:Sunni::B-geo': 367,
#  'id:Arab::I-geo': 368,
#  'id:Kurdish::B-geo': 369,
#  'id:bombings::O': 370,
#  'id:last::O': 371,
#  'id:34::O': 372,
#  'id:people::O': 373,
#  'id:wounded::O': 374,
#  'id:200::O': 375,
#  'id:commanders::O': 376,
#  'id:explained::O': 377,
#  'id:American::B-gpe': 378,
#  'id:forces::O': 379,
#  'id:participate::O': 380,
#  'id:fled::O': 381,
#  'id:successful::O': 382,
#  'id:campaigns::O': 383,
#  'id:them::O': 384,
#  'id:Anbar::B-geo': 385,
#  'id:province::O': 386,
#  'id:Baghdad::B-geo': 387,
#  'id:provinces::O': 388,
#  'init_tag:B-geo': 389,
#  'id:largest::O': 390,
#  'id:north::O': 391,
#  'id:long::O': 392,
#  'id:stronghold::O': 393,
#  'id:Sunni::B-org': 394,
#  'id:militant::O': 395,
#  'id:In::O': 396,
#  'id:violence::O': 397,
#  'id:one::O': 398,
#  'id:soldier::O': 399,
#  'id:patrol::O': 400,
#  'id:Sunday::B-tim': 401,
#  'id:Egyptian::B-gpe': 402,
#  'id:police::O': 403,
#  'id:arrested::O': 404,
#  'id:16::O': 405,
#  'id:members::O': 406,
#  'id:opposition::O': 407,
#  'id:Muslim::B-org': 408,
#  'id:Brotherhood::I-org': 409,
#  'id:prepare::O': 410,
#  'id:parliamentary::O': 411,
#  'id:runoff::O': 412,
#  'id:elections::O': 413,
#  'id:Saturday::B-tim': 414,
#  'id:arrests::O': 415,
#  'id:Friday::B-tim': 416,
#  'id:Alexandria::B-geo': 417,
#  'id:A::O': 418,
#  'id:spokesman::O': 419,
#  'id:Brotherhood::B-org': 420,
#  'id:attempt::O': 421,
#  'id:cut::O': 422,
#  'id:off::O': 423,
#  'id:supporters::O': 424,
#  'id:punishment::O': 425,
#  'id:winning::O': 426,
#  'id:seats::O': 427,
#  'id:earlier::O': 428,
#  'id:tripled::O': 429,
#  'id:strength::O': 430,
#  'id:parliament::O': 431,
#  'id:recent::O': 432,
#  'id:raising::O': 433,
#  'id:total::O': 434,
#  'id:47::O': 435,
#  'id:voters::O': 436,
#  'id:cast::O': 437,
#  'id:ballots::O': 438,
#  'id:nine::O': 439,
#  'id:no::O': 440,
#  'id:candidate::O': 441,
#  'id:won::O': 442,
#  'id:majority::O': 443,
#  'id:previous::O': 444,
#  'id:round::O': 445,
#  'id:voting::O': 446,
#  'id:banned::O': 447,
#  'id:political::O': 448,
#  'id:but::O': 449,
#  'id:endorses::O': 450,
#  'id:so-called::O': 451,
#  'id:independent::O': 452,
#  'id:candidates::O': 453,
#  'id:whose::O': 454,
#  'id:allegiance::O': 455,
#  'id:known::O': 456,
#  'id:Hardline::O': 457,
#  'id:lawmakers::O': 458,
#  'id:Pakistan::B-geo': 459,
#  'id:North::B-geo': 460,
#  'id:West::I-geo': 461,
#  'id:Frontier::I-geo': 462,
#  'prev_tag:I-geo::I-geo': 463,
#  'id:Province::I-geo': 464,
#  'id:pushed::O': 465,
#  'id:law::O': 466,
#  'id:aims::O': 467,
#  'id:ensure::O': 468,
#  'id:Islamic::O': 469,
#  'id:correctness::O': 470,
#  'id:public::O': 471,
#  'id:places::O': 472,
#  'id:establishes::O': 473,
#  'id:morality::O': 474,
#  'id:enforce::O': 475,
#  'id:decent::O': 476,
#  'id:behavior::O': 477,
#  'id:six-party::O': 478,
#  'id:coalition::O': 479,
#  'id:religious::O': 480,
#  'id:based::O': 481,
#  'id:parties::O': 482,
#  'id:Mutahida::B-org': 483,
#  'id:Majlis-e-Amal::I-org': 484,
#  'hyphen::I-org': 485,
#  'id:dominates::O': 486,
#  'id:provincial::O': 487,
#  'id:assembly::O': 488,
#  'id:so::O': 489,
#  'id:bill::O': 490,
#  'id:easily::O': 491,
#  'id:passed::O': 492,
#  'id:Thursday::B-tim': 493,
#  'id:vote::O': 494,
#  'id:68-34::O': 495,
#  'id:governor::O': 496,
#  'id:must::O': 497,
#  'id:still::O': 498,
#  'id:sign::O': 499,
#  'id:before::O': 500,
#  'id:becomes::O': 501,
#  'id:seen::O': 502,
#  'id:only::O': 503,
#  'id:formality::O': 504,
#  'id:proposed::O': 505,
#  'id:calls::O': 506,
#  'id:setting::O': 507,
#  'id:up::O': 508,
#  'id:force::O': 509,
#  'id:make::O': 510,
#  'id:sure::O': 511,
#  'id:adhere::O': 512,
#  'id:values::O': 513,
#  'id:entertainment::O': 514,
#  'id:outlets::O': 515,
#  'id:close::O': 516,
#  'id:weekly::O': 517,
#  'id:prayers::O': 518,
#  'id:Violators::O': 519,
#  'id:be::O': 520,
#  'id:jailed::O': 521,
#  'id:six::O': 522,
#  'id:months::O': 523,
#  'id:denounced::O': 524,
#  'id:measure::O': 525,
#  'id:comparing::O': 526,
#  'id:draconian::O': 527,
#  'id:rule::O': 528,
#  'id:former::O': 529,
#  'id:Taleban::B-org': 530,
#  'id:neighboring::O': 531,
#  'id:Afghanistan::B-geo': 532,
#  'id:man::O': 533,
#  'id:dressed::O': 534,
#  'id:suicide::O': 535,
#  'id:bomber::O': 536,
#  'id:demonstration::O': 537,
#  'id:publication::O': 538,
#  'id:cartoons::O': 539,
#  'id:depicting::O': 540,
#  'id:Islam::B-org': 541,
#  'id:Prophet::B-per': 542,
#  'id:Muhammad::I-per': 543,
#  'id:Bedfordshire::B-gpe': 544,
#  'id:Omar::B-per': 545,
#  'id:Khayam::I-per': 546,
#  'id:Bedford::B-geo': 547,
#  'id:breaching::O': 548,
#  'id:conditions::O': 549,
#  'id:his::O': 550,
#  'id:parole::O': 551,
#  'id:British::B-org': 552,
#  'id:Home::I-org': 553,
#  'id:Office::I-org': 554,
#  'id:sought::O': 555,
#  'id:investigation::O': 556,
#  'id:Khayam::B-per': 557,
#  'id:he::O': 558,
#  'id:photographed::O': 559,
#  'id:fatigues::O': 560,
#  'id:black::O': 561,
#  'id:cap::O': 562,
#  'id:bulky::O': 563,
#  'id:belt::O': 564,
#  'id:Home::B-org': 565,
#  'id:told::O': 566,
#  'id:Associated::B-org': 567,
#  'verb_ed::B-org': 568,
#  'id:Press::I-org': 569,
#  'id:paroled::O': 570,
#  'id:offender::O': 571,
#  'id:gives::O': 572,
#  'id:cause::O': 573,
#  'id:concern::O': 574,
#  'id:can::O': 575,
#  'id:sent::O': 576,
#  'id:back::O': 577,
#  'id:prison::O': 578,
#  'id:AP::B-org': 579,
#  'id:also::O': 580,
#  'id:since::O': 581,
#  'id:year::O': 582,
#  'id:serving::O': 583,
#  'id:half::O': 584,
#  'id:six-year::O': 585,
#  'id:sentence::O': 586,
#  'id:drug::O': 587,
#  'id:dealing::O': 588,
#  'id:Pakistani::B-gpe': 589,
#  'id:unidentified::O': 590,
#  'id:three::O': 591,
#  'id:minister::O': 592,
#  'id:semi-autonomous::O': 593,
#  'id:bordering::O': 594,
#  'id:prominent::O': 595,
#  'id:leader::O': 596,
#  'id:Malik::B-per': 597,
#  'id:Faridullah::I-per': 598,
#  'id:Khan::I-per': 599,
#  'id:traveling::O': 600,
#  'id:South::B-geo': 601,
#  'id:Waziristan::I-geo': 602,
#  'prev_tag:I-geo::B-tim': 603,
#  'id:vehicle::O': 604,
#  'id:ambushed::O': 605,
#  'id:Kani::B-geo': 606,
#  'id:Wam::I-geo': 607,
#  'id:area::O': 608,
#  'id:His::O': 609,
#  'id:driver::O': 610,
#  'id:elder::O': 611,
#  'id:No::O': 612,
#  'id:responsibility::O': 613,
#  'id:killings::O': 614,
#  'id:ambush::O': 615,
#  'id:commander::O': 616,
#  'id:army::O': 617,
#  'id:almost::O': 618,
#  'id:completely::O': 619,
#  'id:eliminated::O': 620,
#  'id:became::O': 621,
#  'id:refuge::O': 622,
#  'id:al-Qaida::B-org': 623,
#  'id:ousted::O': 624,
#  'id:2001::B-tim': 625,
#  'id:senior::O': 626,
#  'id:says::O': 627,
#  'id:Pakistan::B-gpe': 628,
#  'id:wants::O': 629,
#  'id:what::O': 630,
#  'id:sordid::O': 631,
#  'id:chapter::O': 632,
#  'id:proliferation::O': 633,
#  'id:top::O': 634,
#  'id:scientists::O': 635,
#  'id:behind::O': 636,
#  'id:build::O': 637,
#  'id:civilian::O': 638,
#  'id:ties::O': 639,
#  'id:United::B-gpe': 640,
#  'verb_ed::B-gpe': 641,
#  'id:States::I-gpe': 642,
#  'upper_ini::I-gpe': 643,
#  'prev_tag:B-gpe::I-gpe': 644,
#  'prev_tag:I-gpe::O': 645,
#  'id:But::O': 646,
#  'id:ready::O': 647,
#  'id:scientist::O': 648,
#  'id:Abdul::B-per': 649,
#  'id:Qadeer::I-per': 650,
#  'id:available::O': 651,
#  'id:direct::O': 652,
#  'id:questioning::O': 653,
#  'id:sale::O': 654,
#  'id:secrets::O': 655,
#  'id:states::O': 656,
#  'id:Libya::B-gpe': 657,
#  'id:North::B-gpe': 658,
#  'id:Korea::I-gpe': 659,
#  'id:He::O': 660,
#  'id:there::O': 661,
#  'id:reasons::O': 662,
#  'id:national::O': 663,
#  'id:sensitivities::O': 664,
#  'id:making::O': 665,
#  'id:him::O': 666,
#  'id:giving::O': 667,
#  'id:background::O': 668,
#  'id:briefing::O': 669,
#  'id:small::O': 670,
#  'id:group::O': 671,
#  'id:reporters::O': 672,
#  'id:Washington::B-geo': 673,
#  'init_tag:B-per': 674,
#  'id:Khan::B-per': 675,
#  'id:admitted::O': 676,
#  'id:2004::B-tim': 677,
#  'id:operated::O': 678,
#  'id:worldwide::O': 679,
#  'id:clandestine::O': 680,
#  'id:network::O': 681,
#  'id:sell::O': 682,
#  'id:technology::O': 683,
#  'id:market::O': 684,
#  'id:placed::O': 685,
#  'id:under::O': 686,
#  'id:house::O': 687,
#  'id:arrest::O': 688,
#  'id:Islamabad::B-geo': 689,
#  'id:because::O': 690,
#  'id:considered::O': 691,
#  'id:father::O': 692,
#  'id:bomb::O': 693,
#  'id:Army::B-org': 694,
#  'prev_tag:B-gpe::B-org': 695,
#  'id:renew::O': 696,
#  'id:controversial::O': 697,
#  'id:multi-billion::O': 698,
#  'id:dollar::O': 699,
#  'id:contract::O': 700,
#  'id:Halliburton::B-org': 701,
#  'id:company::O': 702,
#  'id:provide::O': 703,
#  'id:logistical::O': 704,
#  'id:support::O': 705,
#  'init_tag:B-org': 706,
#  'id:providing::O': 707,
#  'id:list::O': 708,
#  'id:meals::O': 709,
#  'id:communication::O': 710,
#  'id:several::O': 711,
#  'id:years::O': 712,
#  'id:Critics::O': 713,
#  'id:include::O': 714,
#  'id:auditors::O': 715,
#  'id:congressional::O': 716,
#  'id:Democrats::O': 717,
#  'id:produced::O': 718,
#  'id:some::O': 719,
#  'id:shoddy::O': 720,
#  'id:work::O': 721,
#  'id:charges::O': 722,
#  'id:too::O': 723,
#  'id:much::O': 724,
#  'id:money::O': 725,
#  'id:strongly::O': 726,
#  'id:denies::O': 727,
#  'id:allegations::O': 728,
#  'id:When::O': 729,
#  'id:re-bidding::O': 730,
#  'id:chance::O': 731,
#  'id:compete::O': 732,
#  'id:portions::O': 733,
#  'id:Representatives::O': 734,
#  'id:Asia::B-org': 735,
#  'id:Pacific::I-org': 736,
#  'id:Economic::I-org': 737,
#  'id:Cooperation::I-org': 738,
#  'id:Business::I-org': 739,
#  'id:Advisory::I-org': 740,
#  'id:holding::O': 741,
#  'id:meetings::O': 742,
#  'id:finalize::O': 743,
#  'id:report::O': 744,
#  'id:APEC::B-org': 745,
#  'id:leaders::O': 746,
#  'id:summit::O': 747,
#  'id:September::B-tim': 748,
#  'id:8::I-tim': 749,
#  'prev_tag:B-tim::I-tim': 750,
#  'prev_tag:I-tim::O': 751,
#  'id:9::B-tim': 752,
#  'id:VOA::B-org': 753,
#  'id:Nancy-Amelia::B-per': 754,
#  'hyphen::B-per': 755,
#  'id:Collins::I-per': 756,
#  'id:Sydney::B-geo': 757,
#  'id:Energy::O': 758,
#  'id:security::O': 759,
#  'id:climate::O': 760,
#  'id:change::O': 761,
#  'id:World::B-org': 762,
#  'id:Trade::I-org': 763,
#  'id:Organization::I-org': 764,
#  'id:stalled::O': 765,
#  'id:negotiations::O': 766,
#  'id:investment::O': 767,
#  'id:all::O': 768,
#  'id:expected::O': 769,
#  'id:among::O': 770,
#  'id:major::O': 771,
#  'id:topics::O': 772,
#  'id:ABAC::B-org': 773,
#  'id:Tim::B-per': 774,
#  'id:Harcourt::I-per': 775,
#  'id:chief::O': 776,
#  'id:economist::O': 777,
#  'id:Australian::B-org': 778,
#  'id:Commission::I-org': 779,
#  'id:plays::O': 780,
#  'id:important::O': 781,
#  'id:role::O': 782,
#  'id:informing::O': 783,
#  'id:governments::O': 784,
#  'id:problems::O': 785,
#  'id:most::O': 786,
#  'id:thing::O': 787,
#  'id:business::O': 788,
#  'id:do::O': 789,
#  'id:tell::O': 790,
#  'id:logjams::O': 791,
#  'id:obstacles::O': 792,
#  'id:things::O': 793,
#  'id:improve::O': 794,
#  'id:Harcourt::B-per': 795,
#  'id:I::O': 796,
#  'id:think::O': 797,
#  'id:actually::O': 798,
#  'id:played::O': 799,
#  'id:pretty::O': 800,
#  'id:good::O': 801,
#  'id:leadership::O': 802,
#  'id:talking::O': 803,
#  'id:about::O': 804,
#  'id:trade::O': 805,
#  'id:facilitation::O': 806,
#  'id:basically::O': 807,
#  'id:standards::O': 808,
#  'id:consistent::O': 809,
#  'id:harmonious::O': 810,
#  'id:across::O': 811,
#  'id:comprises::O': 812,
#  'id:private::O': 813,
#  'id:sector::O': 814,
#  'id:each::O': 815,
#  'id:21::O': 816,
#  'id:economies::O': 817,
#  'id:meets::O': 818,
#  'id:times::O': 819,
#  'id:made::O': 820,
#  'id:permanent::O': 821,
#  'id:body::O': 822,
#  'id:1995::B-tim': 823,
#  'id:perspective::O': 824,
#  'id:within::O': 825,
#  'id:Members::O': 826,
#  'id:represent::O': 827,
#  'id:range::O': 828,
#  'id:sectors::O': 829,
#  'id:medium::O': 830,
#  'id:businesses::O': 831,
#  'id:need::O': 832,
#  'id:energy::O': 833,
#  'id:efficiency::O': 834,
#  'id:encourage::O': 835,
#  'id:conservation::O': 836,
#  'id:practices::O': 837,
#  'id:discuss::O': 838,
#  'id:ways::O': 839,
#  'id:enhance::O': 840,
#  'id:regional::O': 841,
#  'id:cooperation::O': 842,
#  'id:reckon::O': 843,
#  "id:'ll::O": 844,
#  'id:talk::O': 845,
#  'id:little::O': 846,
#  'id:bit::O': 847,
#  'id:customs::O': 848,
#  'id:quarantine::O': 849,
#  'id:having::O': 850,
#  'id:arrangements::O': 851,
#  'id:around::O': 852,
#  'id:And::O': 853,
#  'id:want::O': 854,
#  'id:one-stop::O': 855,
#  'id:shop::O': 856,
#  'id:terms::O': 857,
#  'id:combining::O': 858,
#  'id:immigration::O': 859,
#  'id:together::O': 860,
#  'id:\x85::O': 861,
#  'id:just::O': 862,
#  'id:streamlined::O': 863,
#  'id:provides::O': 864,
#  'id:certainty::O': 865,
#  'id:non-governmental::O': 866,
#  'id:formal::O': 867,
#  'id:dialogue::O': 868,
#  'id:present::O': 869,
#  'id:meeting::O': 870,
#  'id:Sudan::B-gpe': 871,
#  'id:order::O': 872,
#  'id:Darfur::B-geo': 873,
#  'id:asking::O': 874,
#  'id:same::O': 875,
#  'id:Foreign::B-per': 876,
#  'id:Minister::I-per': 877,
#  'id:Mustafa::I-per': 878,
#  'id:Osman::I-per': 879,
#  'id:Ismail::I-per': 880,
#  'id:Sudanese::B-gpe': 881,
#  'id:withdraw::O': 882,
#  'id:positions::O': 883,
#  'id:held::O': 884,
#  'id:April::B-tim': 885,
#  'id:cease-fire::O': 886,
#  'id:western::O': 887,
#  'id:agree::O': 888,
#  'id:stop::O': 889,
#  'id:Mr.::B-per': 890,
#  'id:announced::O': 891,
#  'id:decision::O': 892,
#  'id:United::B-org': 893,
#  'id:Nations::I-org': 894,
#  'id:African::B-org': 895,
#  'id:Khartoum::B-geo': 896,
#  'id:weeks::O': 897,
#  'id:AU::B-org': 898,
#  'id:repeatedly::O': 899,
#  'id:truce::O': 900,
#  'init_tag:B-tim': 901,
#  'id:head::O': 902,
#  'id:accused::O': 903,
#  'id:helicopters::O': 904,
#  'id:bombing::O': 905,
#  'id:rebel::O': 906,
#  'id:sites::O': 907,
#  'id:Darfur::I-geo': 908,
#  'id:village::O': 909,
#  'id:Labado::B-geo': 910,
#  'id:Khartoum::B-gpe': 911,
#  'id:defending::O': 912,
#  'id:Aid::O': 913,
#  'id:relief::O': 914,
#  'id:efforts::O': 915,
#  'id:suspended::O': 916,
#  'id:due::O': 917,
#  'id:Indonesian::B-gpe': 918,
#  'id:men::O': 919,
#  'id:connection::O': 920,
#  'id:October::B-tim': 921,
#  'id:1::I-tim': 922,
#  'id:Bali::B-geo': 923,
#  'prev_tag:I-tim::B-geo': 924,
#  'id:left::O': 925,
#  'id:23::O': 926,
#  'id:dead::O': 927,
#  'id:flown::O': 928,
#  'id:Java::B-geo': 929,
#  'id:island::O': 930,
#  'id:headquarters::O': 931,
#  'id:Australian::B-gpe': 932,
#  'id:French::B-gpe': 933,
#  'id:agencies::O': 934,
#  'id:(::O': 935,
#  'id:Cholily::B-per': 936,
#  'adverb_ly::B-per': 937,
#  'id:)::O': 938,
#  'id:captured::O': 939,
#  'id:series::O': 940,
#  'id:counter-terrorism::O': 941,
#  'id:raids::O': 942,
#  'id:Indonesia::B-geo': 943,
#  'id:ended::O': 944,
#  'id:death::O': 945,
#  'id:alleged::O': 946,
#  'id:extremist::O': 947,
#  'id:bombmaker::O': 948,
#  'id:Azahari::B-per': 949,
#  'id:bin::I-per': 950,
#  'id:Husin::I-per': 951,
#  'id:authorities::O': 952,
#  'id:blame::O': 953,
#  'id:orchestrating::O': 954,
#  'id:month::O': 955,
#  'id:well::O': 956,
#  'id:2002::B-tim': 957,
#  'prev_tag:B-tim::B-geo': 958,
#  'id:Gunmen::O': 959,
#  'id:shot::O': 960,
#  'id:Roman::B-org': 961,
#  'id:Catholic::I-org': 962,
#  'id:nun::O': 963,
#  'id:her::O': 964,
#  'id:bodyguard::O': 965,
#  'id:hospital::O': 966,
#  'id:she::O': 967,
#  'id:worked::O': 968,
#  'id:Islamist-controlled::O': 969,
#  'id:Some::O': 970,
#  'id:witnesses::O': 971,
#  'id:shooting::O': 972,
#  'id:feared::O': 973,
#  'id:linked::O': 974,
#  'id:Muslim::O': 975,
#  'id:anger::O': 976,
#  'id:toward::O': 977,
#  'id:Pope::B-per': 978,
#  'id:Benedict::I-per': 979,
#  'id:pistols::O': 980,
#  'id:attacked::O': 981,
#  'id:Sister::B-per': 982,
#  'id:Leonella::I-per': 983,
#  'id:Sgorbati::I-per': 984,
#  'id:finished::O': 985,
#  'id:teaching::O': 986,
#  'id:medical::O': 987,
#  'id:school::O': 988,
#  'id:class::O': 989,
#  'id:suspect::O': 990,
#  'id:Vatican::B-org': 991,
#  'id:deplored::O': 992,
#  'id:hoped::O': 993,
#  'id:isolated::O': 994,
#  'id:event::O': 995,
#  'id:irrationality::O': 996,
#  'id:arising::O': 997,
#  'id:comments::O': 998,
#  'id:Pope::O': 999,
#  ...}

# %%
[x for x in list(ex_feature_mapper.feature_dict.keys()) if 'adverb_ly' in x]
# Out:
# ['adverb_ly::O',
#  'adverb_ly::B-per',
#  'adverb_ly::B-tim',
#  'adverb_ly::B-art',
#  'adverb_ly::B-geo',
#  'adverb_ly::I-tim',
#  'adverb_ly::I-org',
#  'adverb_ly::I-geo',
#  'adverb_ly::B-org',
#  'adverb_ly::I-art',
#  'adverb_ly::I-per']

# %% [markdown]
# #### Training structured perceptron

# %%
corpus = skseq.readers.pos_corpus.PostagCorpus()
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)

# %%
sp.get_num_states(), sp.get_num_observations()
# Out:
# (17, 30863)

# %%
# %%time
num_epochs = 15
sp.fit(ex_feature_mapper.dataset, num_epochs)
# Out:
# Epoch: 0 Accuracy: 0.929577
# Epoch: 1 Accuracy: 0.946066
# Epoch: 2 Accuracy: 0.950781
# Epoch: 3 Accuracy: 0.953661
# Epoch: 4 Accuracy: 0.955255
# Epoch: 5 Accuracy: 0.957026
# Epoch: 6 Accuracy: 0.958144
# Epoch: 7 Accuracy: 0.958909
# Epoch: 8 Accuracy: 0.959949
# Epoch: 9 Accuracy: 0.960881
# Epoch: 10 Accuracy: 0.961335
# Epoch: 11 Accuracy: 0.961938
# Epoch: 12 Accuracy: 0.962487
# Epoch: 13 Accuracy: 0.962931
# Epoch: 14 Accuracy: 0.963316
# Wall time: 1h 6min 7s

# %%
sp.save_model("perceptron_ex5")

# %%
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)
sp.load_model(dir="perceptron_ex5")

# %% [markdown]
# #### Testing

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

y_pred_2 = []
y_true = [item for x in Y_ids_test for item in x]
correct_sentences = 0
n_test = len(X_test)

for i in range(n_test):
    y_pred_aux = sp.predict_tags_given_words(X_test[i])
    y_pred_2.append(y_pred_aux)
    if list(y_pred_aux) == Y_ids_test[i]:
        correct_sentences += 1
    
y_pred = [item for x in y_pred_2 for item in x]
F1_score_multi = f1_score(y_true, y_pred, average=None)
Accuracy = accuracy_score(y_true, y_pred)
print('Accuracy for test is: ' + str(Accuracy))
print('F1-Score for test is: ' + str(np.mean(F1_score_multi)))
print('Correct sentences for test (%) : ' + str(correct_sentences/n_test))
# Out:
# Accuracy for test is: 0.9494170561238723
# F1-Score for test is: 0.6084984805919735
# Correct sentences for test (%) : 0.47414080747414084

# %%
ax = plot_confusion_matrix(y_true, y_pred, classes=list(sp.state_labels),
                      title='Confusion matrix')

# %% [markdown]
# #### SENTENCES TO TEST THE MODEL

# %% [markdown]
# We think that these are the tags that the model should obtain:
#
# 1. The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 2. The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 3. Jack/B-per London/I-per went/O to/O Parris./O
#
# 4. Jack/B-per London/I-per went/O to/O/O Paris./B-geo
#
# 5. We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
#
# 6. We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
#
# 7. The/O president/O of/O U.S.A/B-geo though/O they/O could/O win/O the/O war/O
#
# 8. The/O president/O of/O the/O United/B-geo States/B-geo of/B-geo America/B-geo though/O they/O could/O win/O the/O war/O
#
# 9. The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
#
# 10. Robin/B-per does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
for sentence in test_sentences:
    new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
    print(sp.viterbi_decode(new_seq)[0].to_words(sequence_list_train, only_tag_translation=True))
# Out:
# The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/O checker./O
# The/O programmers/O from/O Barchelona/B-org cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
# Jack/B-per London/B-geo went/O to/O Parris./B-eve
# Jack/B-per London/B-geo went/O to/O Paris./B-eve
# We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
# We/O never/O though/O Microsof/B-org would/O become/O such/O a/O big/O company./O
# The/O president/O of/O U.S.A/B-org though/O they/O could/O win/O the/O war/O
# The/O president/O of/O the/O United/B-geo States/I-geo of/I-geo America/I-geo though/O they/O could/O win/O the/O war/O
# The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
# Robin/B-org does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
# Here we can select the sentence in which we want to compare the true and the predicted tags
# Select a sentence between 1 and 10
i=1
sentence = test_sentences[i-1]
new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(sentence.split(), test_tags[i-1], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# The             (O    ): O
# programmers     (O    ): O
# from            (O    ): O
# Barcelona       (B-geo): B-geo
# might           (O    ): O
# write           (O    ): O
# a               (O    ): O
# sentence        (O    ): O
# without         (O    ): O
# a               (O    ): O
# spell           (O    ): O
# checker.        (O    ): O

# %% [markdown]
# #### Capital checking

# %%
new_seq = Sequence(x=X_test[0], y=[int(0) for w in X_test[0]])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(X_test[0], Y_test[0], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# Officials       (O    ): O
# said            (O    ): O
# Sunday          (B-tim): B-tim
# Jean            (B-per): B-per
# Rene            (I-per): I-per
# Anthony         (I-per): I-per
# was             (O    ): O
# killed          (O    ): O
# in              (O    ): O
# a               (O    ): O
# shootout        (O    ): O
# with            (O    ): O
# police          (O    ): O
# near            (O    ): O
# the             (O    ): O
# capital         (O    ): O
# city            (O    ): O
# of              (O    ): O
# Port-au-Prince  (B-geo): O
# .               (O    ): O
