# %% [markdown]
# # Task 2 - Natural Language Processing
#
# ## Structured Perceptron
#
# ### Rubén Barco Terrones - Aleix Casellas Comas - Andreu Masdeu Ninot - Pablo Lázaro Herrasti

# %% [markdown]
# ##### Imports

# %%
#### Basics
import pandas as pd
import numpy as np
# %matplotlib inline

import pickle
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

#### skseq Sequences
import scipy
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
import skseq
from skseq.sequences import sequence
from skseq.sequences.sequence import Sequence
from skseq.sequences.sequence_list import SequenceList
from skseq.sequences.label_dictionary import LabelDictionary

#### Feature mapper
import pprint
from skseq.sequences import extended_feature

#### Structured perceptron
import skseq.readers.pos_corpus
import skseq.sequences.structured_perceptron as spc

# %% [markdown]
# #### Functions:

# %%
from sklearn.utils.multiclass import unique_labels
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data

    fig, ax = plt.subplots()
    fig.set_figheight(20)
    fig.set_figwidth(20)
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %% [markdown]
# # TRAINING/TEST PREPROCESSING (NER_DATASET)

# %%
# data = pd.read_csv("ner_dataset.csv",encoding="latin1")
# data.head()

# %% [markdown]
# ### Preparing data

# %%
def build_word_to_pos(X):

    word_to_pos = {}
    i = 0
    for s in X:
        for w in s:
            if w not in word_to_pos:
                word_to_pos[w] = i
                i +=1
                
    pos_to_word = {v: k for k, v in word_to_pos.items()}
    return word_to_pos, pos_to_word
            
def build_tag_to_pos(Y):
    tag_to_pos = {}
    i = 0
    for s in Y:
        for t in s:
            if t not in tag_to_pos:
                tag_to_pos[t] = i
                i +=1
    pos_to_tag = {v: k for k, v in tag_to_pos.items()}

    return tag_to_pos, pos_to_tag

# %% [markdown]
# ### Train

# %%
# sentence_formatter = "Sentence: {}"

# last_n_train = 35971
# end_train   = data.index[data["Sentence #"] == sentence_formatter.format(last_n_train)][0]
# train = data[0:end_train]

# n_sentences_train = len(list(set(train["Sentence #"])))
# first_n_train = 1
# last_n_train = last_n_train -1
# print(n_sentences)

# %%
# n_sentences_train = len(list(set(train["Sentence #"])))

# %%
# %%time 
# sentence_formatter = "Sentence: {}"

# for s_id in  range(first_n_train, last_n_train):
#     print("current {}/{}".format(s_id,last_n_train), end="\r")
#     sentence_id = sentence_formatter.format(s_id)
#     sentence_id_next = sentence_formatter.format(s_id + 1)
#     start = train.index[train["Sentence #"] == sentence_id][0]
#     end   = train.index[train["Sentence #"] == sentence_id_next][0]
#     train["Sentence #"][start:end] = sentence_id
    
# sentence_id = sentence_formatter.format(last_n_train)
# start = train.index[train["Sentence #"] == sentence_id][0]
# end   = train.shape[0]
# train["Sentence #"][start:end] = sentence_id

# %%
# train.to_csv('train.csv', sep='\t')

# %%
# X_train = []
# Y_train = []

# sentence_formatter = "Sentence: {}"

# for i in range(1,n_sentences_train):
#     s = sentence_formatter.format(i)
#     X_train.append(list(train[train["Sentence #"]==s]["Word"].values))
#     Y_train.append(list(train[train["Sentence #"]==s]["Tag"].values))

# %%
# with open("X_train.txt", "wb") as fp:   #Pickling
#     pickle.dump(X_train, fp)
# with open("Y_train.txt", "wb") as fp:   #Pickling
#     pickle.dump(Y_train, fp)

# %%
with open("X_train.txt", "rb") as fp:   # Unpickling
    X_train = pickle.load(fp)
with open("Y_train.txt", "rb") as fp:   # Unpickling
    Y_train = pickle.load(fp)

# %%
i = 0
xy = ["{}/{}".format(x,y) for x,y in zip(X_train[i],Y_train[i])]
" ".join(xy)
# Out:
# 'Thousands/O of/O demonstrators/O have/O marched/O through/O London/B-geo to/O protest/O the/O war/O in/O Iraq/B-geo and/O demand/O the/O withdrawal/O of/O British/B-gpe troops/O from/O that/O country/O ./O'

# %%
word_to_pos, pos_to_word = build_word_to_pos(X_train)
tag_to_pos, pos_to_tag  = build_tag_to_pos(Y_train)

len(word_to_pos), len(tag_to_pos)
# Out:
# (30863, 17)

# %%
X_ids_train = [[word_to_pos[w] for w in s] for s in X_train]
Y_ids_train = [[tag_to_pos[t] for t in s] for s in Y_train]

# %%
# sequence_list = SequenceList(LabelDictionary(word_to_pos), LabelDictionary(tag_to_pos))
# for x,y in zip(X_train,Y_train):
#     sequence_list.add_sequence(x,y, LabelDictionary(word_to_pos), LabelDictionary(tag_to_pos))

# %%
# sequence_list[0].to_words(sequence_list=sequence_list)

# %%
# with open('sequence_list_train', 'wb') as sqq:
 
#     pickle.dump(sequence_list, sqq)

# %%
with open("sequence_list_train", "rb") as fp:   # Unpickling
    sequence_list_train = pickle.load(fp)

# %%
sequence_list_train[3]
# Out:
# 49/0 50/0 9/0 51/0 1/0 52/0 53/0 54/0 55/0 56/0 57/0 58/0 59/0 60/0 21/0

# %% [markdown]
# ### Test

# %%
# sentence_formatter = "Sentence: {}"

# test = data[end_train:len(data)]

# n_sentences_test = len(list(set(test["Sentence #"])))
# first_n_test = last_n_train + 1
# last_n_test = 47959
# print(n_sentences_test)

# %%
# %%time 
# sentence_formatter = "Sentence: {}"

# for s_id in  range(first_n_test, last_n_test):
#     print("current {}/{}".format(s_id,last_n_test), end="\r")
#     sentence_id = sentence_formatter.format(s_id)
#     sentence_id_next = sentence_formatter.format(s_id + 1)
#     start = data.index[data["Sentence #"] == sentence_id][0]
#     end   = data.index[data["Sentence #"] == sentence_id_next][0]
#     data["Sentence #"][start:end] = sentence_id
    
# sentence_id = sentence_formatter.format(last_n_test)
# start = data.index[data["Sentence #"] == sentence_id][0]
# end   = data.shape[0]
# data["Sentence #"][start:end] = sentence_id

# %%
# test.to_csv('test.csv', sep='\t')

# %%
# X_test = []
# Y_test = []

# sentence_formatter = "Sentence: {}"

# for i in range(n_sentences_train+1,n_sentences_train+n_sentences_test-1):
#     s = sentence_formatter.format(i)
#     X_test.append(list(data[data["Sentence #"]==s]["Word"].values))
#     Y_test.append(list(data[data["Sentence #"]==s]["Tag"].values))

# %%
# with open("X_test.txt", "wb") as fp:   #Pickling
#     pickle.dump(X_test, fp)
# with open("Y_test.txt", "wb") as fp:   #Pickling
#     pickle.dump(Y_test, fp)

# %%
with open("X_test.txt", "rb") as fp:   # Unpickling
    X_test = pickle.load(fp)
with open("Y_test.txt", "rb") as fp:   # Unpickling
    Y_test = pickle.load(fp)

# %%
i = 0
xy = ["{}/{}".format(x,y) for x,y in zip(X_test[i],Y_test[i])]
" ".join(xy)
# Out:
# 'Officials/O said/O Sunday/B-tim Jean/B-per Rene/I-per Anthony/I-per was/O killed/O in/O a/O shootout/O with/O police/O near/O the/O capital/O city/O of/O Port-au-Prince/B-geo ./O'

# %%
Y_ids_test = [[tag_to_pos[t] for t in s] for s in Y_test]

# %%
test_sentences = ["The programmers from Barcelona might write a sentence without a spell checker.", 
                  "The programmers from Barchelona cannot write a sentence without a spell checker.",
                  "Jack London went to Parris.",
                  "Jack London went to Paris.",
                  "We never though Microsoft would become such a big company.",
                  "We never though Microsof would become such a big company.",
                  "The president of U.S.A though they could win the war",
                  "The president of the United States of America though they could win the war",
                  "The king of Saudi Arabia wanted total control.",
                  "Robin does not want to go to Saudi Arabia."]

test_tags = [['O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['B-per', 'I-per', 'O', 'O', 'O'],
            ['B-per', 'I-per', 'O', 'O', 'B-geo'],
            ['O', 'O', 'O', 'B-org', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['O', 'O', 'O', 'O', 'B-geo', 'I-geo', 'I-geo', 'I-geo', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['O', 'O', 'O', 'B-geo', 'I-geo', 'O', 'O', 'O'],
            ['B-per', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'I-geo']]

# %%
def print_all_test_sentences(test_sents, model):
    for sentence in test_sents:
        new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
        print(model.viterbi_decode(new_seq)[0].to_words(sequence_list_train, only_tag_translation=True))
            
def compare_one_test_sentence(test_sents, test_tgs, model, pos_to_tag, i):
    sentence = test_sents[i-1]
    new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
    preds = model.viterbi_decode(new_seq)[0].y
    print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
    for word, true_tag, pred_tag in zip(sentence.split(), test_tgs[i-1], preds):
        print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))

# %% [markdown]
# # EXPERIMENT 1: Basic features

# %% [markdown]
# ##### Comments:
# In this first experiment we are going to use only the **default features** in the ExtendedFeatures class. We want to have this experiment as the base experiment in order to be able to see the errors and how to solve them and to compare the future results with this one.

# %% [markdown]
# ### Extended features

# %%
ex_feature_mapper = skseq.sequences.extended_feature.ExtendedFeatures(sequence_list_train) 
ex_feature_mapper.build_features()
pprint.pprint(list(ex_feature_mapper.__dict__.keys()))
# Out:
# ['feature_dict',
#  'feature_list',
#  'add_features',
#  'dataset',
#  'node_feature_cache',
#  'initial_state_feature_cache',
#  'final_state_feature_cache',
#  'edge_feature_cache']

# %%
len(ex_feature_mapper.feature_dict)
# Out:
# 38298

# %%
ex_feature_mapper.feature_dict
# Out:
# {'init_tag:O': 0,
#  'id:Thousands::O': 1,
#  'id:of::O': 2,
#  'prev_tag:O::O': 3,
#  'id:demonstrators::O': 4,
#  'id:have::O': 5,
#  'id:marched::O': 6,
#  'id:through::O': 7,
#  'id:London::B-geo': 8,
#  'prev_tag:O::B-geo': 9,
#  'id:to::O': 10,
#  'prev_tag:B-geo::O': 11,
#  'id:protest::O': 12,
#  'id:the::O': 13,
#  'id:war::O': 14,
#  'id:in::O': 15,
#  'id:Iraq::B-geo': 16,
#  'id:and::O': 17,
#  'id:demand::O': 18,
#  'id:withdrawal::O': 19,
#  'id:British::B-gpe': 20,
#  'prev_tag:O::B-gpe': 21,
#  'id:troops::O': 22,
#  'prev_tag:B-gpe::O': 23,
#  'id:from::O': 24,
#  'id:that::O': 25,
#  'id:country::O': 26,
#  'id:.::O': 27,
#  'final_prev_tag:O': 28,
#  'id:Families::O': 29,
#  'id:soldiers::O': 30,
#  'id:killed::O': 31,
#  'id:conflict::O': 32,
#  'id:joined::O': 33,
#  'id:protesters::O': 34,
#  'id:who::O': 35,
#  'id:carried::O': 36,
#  'id:banners::O': 37,
#  'id:with::O': 38,
#  'id:such::O': 39,
#  'id:slogans::O': 40,
#  'id:as::O': 41,
#  'id:"::O': 42,
#  'id:Bush::B-per': 43,
#  'prev_tag:O::B-per': 44,
#  'id:Number::O': 45,
#  'prev_tag:B-per::O': 46,
#  'id:One::O': 47,
#  'id:Terrorist::O': 48,
#  'id:Stop::O': 49,
#  'id:Bombings::O': 50,
#  'id:They::O': 51,
#  'id:Houses::O': 52,
#  'id:Parliament::O': 53,
#  'id:a::O': 54,
#  'id:rally::O': 55,
#  'id:Hyde::B-geo': 56,
#  'id:Park::I-geo': 57,
#  'prev_tag:B-geo::I-geo': 58,
#  'prev_tag:I-geo::O': 59,
#  'id:Police::O': 60,
#  'id:put::O': 61,
#  'id:number::O': 62,
#  'id:marchers::O': 63,
#  'id:at::O': 64,
#  'id:10,000::O': 65,
#  'id:while::O': 66,
#  'id:organizers::O': 67,
#  'id:claimed::O': 68,
#  'id:it::O': 69,
#  'id:was::O': 70,
#  'id:1,00,000::O': 71,
#  'id:The::O': 72,
#  'id:comes::O': 73,
#  'id:on::O': 74,
#  'id:eve::O': 75,
#  'id:annual::O': 76,
#  'id:conference::O': 77,
#  'id:Britain::B-geo': 78,
#  "id:'s::O": 79,
#  'id:ruling::O': 80,
#  'id:Labor::B-org': 81,
#  'prev_tag:O::B-org': 82,
#  'id:Party::I-org': 83,
#  'prev_tag:B-org::I-org': 84,
#  'prev_tag:I-org::O': 85,
#  'id:southern::O': 86,
#  'id:English::B-gpe': 87,
#  'id:seaside::O': 88,
#  'id:resort::O': 89,
#  'id:Brighton::B-geo': 90,
#  'id:party::O': 91,
#  'id:is::O': 92,
#  'id:divided::O': 93,
#  'id:over::O': 94,
#  'id:Britain::B-gpe': 95,
#  'id:participation::O': 96,
#  'id:continued::O': 97,
#  'id:deployment::O': 98,
#  'id:8,500::O': 99,
#  'id:march::O': 100,
#  'id:came::O': 101,
#  'id:ahead::O': 102,
#  'id:anti-war::O': 103,
#  'id:protests::O': 104,
#  'id:today::O': 105,
#  'id:other::O': 106,
#  'id:cities::O': 107,
#  'id:,::O': 108,
#  'id:including::O': 109,
#  'id:Rome::B-geo': 110,
#  'id:Paris::B-geo': 111,
#  'id:Madrid::B-geo': 112,
#  'id:International::B-org': 113,
#  'id:Atomic::I-org': 114,
#  'id:Energy::I-org': 115,
#  'prev_tag:I-org::I-org': 116,
#  'id:Agency::I-org': 117,
#  'id:hold::O': 118,
#  'id:second::O': 119,
#  'id:day::O': 120,
#  'id:talks::O': 121,
#  'id:Vienna::B-geo': 122,
#  'id:Wednesday::B-tim': 123,
#  'prev_tag:B-geo::B-tim': 124,
#  'prev_tag:B-tim::O': 125,
#  'id:how::O': 126,
#  'id:respond::O': 127,
#  'id:Iran::B-gpe': 128,
#  'id:resumption::O': 129,
#  'id:low-level::O': 130,
#  'id:uranium::O': 131,
#  'id:conversion::O': 132,
#  'init_tag:B-gpe': 133,
#  'id:this::O': 134,
#  'id:week::O': 135,
#  'id:restarted::O': 136,
#  'id:parts::O': 137,
#  'id:process::O': 138,
#  'id:its::O': 139,
#  'id:Isfahan::B-geo': 140,
#  'id:nuclear::O': 141,
#  'id:plant::O': 142,
#  'id:Iranian::B-gpe': 143,
#  'id:officials::O': 144,
#  'id:say::O': 145,
#  'id:they::O': 146,
#  'id:expect::O': 147,
#  'id:get::O': 148,
#  'id:access::O': 149,
#  'id:sealed::O': 150,
#  'id:sensitive::O': 151,
#  'prev_tag:O::B-tim': 152,
#  'id:after::O': 153,
#  'id:an::O': 154,
#  'id:IAEA::B-org': 155,
#  'id:surveillance::O': 156,
#  'prev_tag:B-org::O': 157,
#  'id:system::O': 158,
#  'id:begins::O': 159,
#  'id:functioning::O': 160,
#  'id:step::O': 161,
#  'id:will::O': 162,
#  'id:allow::O': 163,
#  'id:facility::O': 164,
#  'id:operate::O': 165,
#  'id:full::O': 166,
#  'id:capacity::O': 167,
#  'id:European::B-org': 168,
#  'id:Union::I-org': 169,
#  'id:U.S.::B-gpe': 170,
#  'id:backing::O': 171,
#  'id:has::O': 172,
#  'id:threatened::O': 173,
#  'id:refer::O': 174,
#  'id:U.N.::B-org': 175,
#  'id:Security::I-org': 176,
#  'id:Council::I-org': 177,
#  'id:which::O': 178,
#  'id:could::O': 179,
#  'id:impose::O': 180,
#  'id:sanctions::O': 181,
#  'id:if::O': 182,
#  'id:finds::O': 183,
#  'id:Tehran::B-gpe': 184,
#  'id:violated::O': 185,
#  'id:Nuclear::B-art': 186,
#  'prev_tag:O::B-art': 187,
#  'id:Non-Proliferation::I-art': 188,
#  'prev_tag:B-art::I-art': 189,
#  'id:treaty::O': 190,
#  'prev_tag:I-art::O': 191,
#  'id:new::O': 192,
#  'id:President::B-per': 193,
#  'id:Mahmoud::I-per': 194,
#  'prev_tag:B-per::I-per': 195,
#  'id:Ahmadinejad::I-per': 196,
#  'prev_tag:I-per::I-per': 197,
#  'id:said::O': 198,
#  'prev_tag:I-per::O': 199,
#  'id:Tuesday::B-tim': 200,
#  'id:European::B-gpe': 201,
#  'id:incentives::O': 202,
#  'id:aimed::O': 203,
#  'id:persuading::O': 204,
#  'id:end::O': 205,
#  'id:fuel::O': 206,
#  'id:program::O': 207,
#  'id:are::O': 208,
#  'id:insult::O': 209,
#  'id:nation::O': 210,
#  'id:Two::O': 211,
#  'id:Germans::B-gpe': 212,
#  'id:four::O': 213,
#  'id:Nigerian::B-gpe': 214,
#  'id:oil::O': 215,
#  'id:workers::O': 216,
#  'id:were::O': 217,
#  'id:kidnapped::O': 218,
#  'id:by::O': 219,
#  'id:armed::O': 220,
#  'id:militants::O': 221,
#  'id:during::O': 222,
#  'id:raid::O': 223,
#  'id:boat::O': 224,
#  'id:Nigeria::B-geo': 225,
#  'id:oil-rich::O': 226,
#  'id:Delta::B-geo': 227,
#  'id:region::O': 228,
#  'id:An::O': 229,
#  'id:official::O': 230,
#  'id:German::B-gpe': 231,
#  'id:firm::O': 232,
#  'id:Bilfinger::B-org': 233,
#  'id:Berger::I-org': 234,
#  'id:Thomas::B-per': 235,
#  'id:Horbach::I-per': 236,
#  'id:gunmen::O': 237,
#  'id:stopped::O': 238,
#  'id:supply::O': 239,
#  'id:sailed::O': 240,
#  'id:State::I-geo': 241,
#  'id:Bayelsa::B-geo': 242,
#  'id:inspect::O': 243,
#  'id:offshore::O': 244,
#  'id:field::O': 245,
#  'id:owned::O': 246,
#  'id:Royal-Dutch::B-org': 247,
#  'id:Shell::I-org': 248,
#  'id:works::O': 249,
#  'id:sub-contractor::O': 250,
#  'id:for::O': 251,
#  'id:Shell::B-org': 252,
#  'id:Militant::O': 253,
#  'id:groups::O': 254,
#  'id:frequently::O': 255,
#  'id:attack::O': 256,
#  'id:operations::O': 257,
#  'id:Niger::B-geo': 258,
#  'id:Delta::I-geo': 259,
#  'id:social::O': 260,
#  'id:services::O': 261,
#  'id:better::O': 262,
#  'id:job::O': 263,
#  'id:opportunities::O': 264,
#  'id:multinational::O': 265,
#  'id:companies::O': 266,
#  'id:Poor::O': 267,
#  'id:residents::O': 268,
#  'id:often::O': 269,
#  'id:complain::O': 270,
#  'id:been::O': 271,
#  'id:cheated::O': 272,
#  'id:out::O': 273,
#  'id:huge::O': 274,
#  'id:riches::O': 275,
#  'id:extracted::O': 276,
#  'id:their::O': 277,
#  'id:tribal::O': 278,
#  'id:lands::O': 279,
#  'id:-::O': 280,
#  'id:where::O': 281,
#  'id:bulk::O': 282,
#  'id:Nigeria::B-gpe': 283,
#  'id:2.3::O': 284,
#  'id:million::O': 285,
#  'id:barrels::O': 286,
#  'id:petroleum::O': 287,
#  'id:pumped::O': 288,
#  'id:daily::O': 289,
#  'id:Suspected::O': 290,
#  'id:Islamist::O': 291,
#  'id:rebels::O': 292,
#  'id:fired::O': 293,
#  'id:mortar::O': 294,
#  'id:shells::O': 295,
#  'id:palace::O': 296,
#  'id:used::O': 297,
#  'id:Somalia::B-geo': 298,
#  'id:interim::O': 299,
#  'id:Abdullahi::I-per': 300,
#  'id:Yusuf::I-per': 301,
#  'id:Ahmad::I-per': 302,
#  'id:It::O': 303,
#  'id:not::O': 304,
#  'id:immediately::O': 305,
#  'id:clear::O': 306,
#  'id:president::O': 307,
#  'id:Mogadishu::B-geo': 308,
#  'id:when::O': 309,
#  'id:occurred::O': 310,
#  'id:or::O': 311,
#  'id:anyone::O': 312,
#  'id:hurt::O': 313,
#  'id:Local::O': 314,
#  'id:news::O': 315,
#  'id:reports::O': 316,
#  'id:least::O': 317,
#  'id:five::O': 318,
#  'id:hit::O': 319,
#  'id:compound::O': 320,
#  'id:mortars::O': 321,
#  'id:elsewhere::O': 322,
#  'id:attacks::O': 323,
#  'id:government::O': 324,
#  'id:go::O': 325,
#  'id:reconciliation::O': 326,
#  'id:more::O': 327,
#  'id:than::O': 328,
#  'id:1,300::O': 329,
#  'id:Somali::B-gpe': 330,
#  'id:elders::O': 331,
#  'id:warlords::O': 332,
#  'id:politicians::O': 333,
#  'id:invited::O': 334,
#  'id:Iraqi::B-gpe': 335,
#  'id:military::O': 336,
#  'id:tanks::O': 337,
#  'id:arrived::O': 338,
#  'id:northern::O': 339,
#  'id:city::O': 340,
#  'id:Mosul::B-geo': 341,
#  'id:offensive::O': 342,
#  'id:against::O': 343,
#  'id:al::B-org': 344,
#  'id:Qaida::I-org': 345,
#  'id:in::I-org': 346,
#  'id:Iraq::I-org': 347,
#  'id:fighters::O': 348,
#  'id:Officials::O': 349,
#  'id:many::O': 350,
#  'id:Sunni::B-geo': 351,
#  'id:Arab::I-geo': 352,
#  'id:Kurdish::B-geo': 353,
#  'id:bombings::O': 354,
#  'id:last::O': 355,
#  'id:34::O': 356,
#  'id:people::O': 357,
#  'id:wounded::O': 358,
#  'id:200::O': 359,
#  'id:commanders::O': 360,
#  'id:explained::O': 361,
#  'id:American::B-gpe': 362,
#  'id:forces::O': 363,
#  'id:participate::O': 364,
#  'id:fled::O': 365,
#  'id:successful::O': 366,
#  'id:campaigns::O': 367,
#  'id:them::O': 368,
#  'id:Anbar::B-geo': 369,
#  'id:province::O': 370,
#  'id:Baghdad::B-geo': 371,
#  'id:provinces::O': 372,
#  'init_tag:B-geo': 373,
#  'id:largest::O': 374,
#  'id:north::O': 375,
#  'id:long::O': 376,
#  'id:stronghold::O': 377,
#  'id:Sunni::B-org': 378,
#  'id:militant::O': 379,
#  'id:In::O': 380,
#  'id:violence::O': 381,
#  'id:one::O': 382,
#  'id:soldier::O': 383,
#  'id:patrol::O': 384,
#  'id:Sunday::B-tim': 385,
#  'id:Egyptian::B-gpe': 386,
#  'id:police::O': 387,
#  'id:arrested::O': 388,
#  'id:16::O': 389,
#  'id:members::O': 390,
#  'id:opposition::O': 391,
#  'id:Muslim::B-org': 392,
#  'id:Brotherhood::I-org': 393,
#  'id:prepare::O': 394,
#  'id:parliamentary::O': 395,
#  'id:runoff::O': 396,
#  'id:elections::O': 397,
#  'id:Saturday::B-tim': 398,
#  'id:arrests::O': 399,
#  'id:Friday::B-tim': 400,
#  'id:Alexandria::B-geo': 401,
#  'id:A::O': 402,
#  'id:spokesman::O': 403,
#  'id:Brotherhood::B-org': 404,
#  'id:attempt::O': 405,
#  'id:cut::O': 406,
#  'id:off::O': 407,
#  'id:supporters::O': 408,
#  'id:punishment::O': 409,
#  'id:winning::O': 410,
#  'id:seats::O': 411,
#  'id:earlier::O': 412,
#  'id:tripled::O': 413,
#  'id:strength::O': 414,
#  'id:parliament::O': 415,
#  'id:recent::O': 416,
#  'id:raising::O': 417,
#  'id:total::O': 418,
#  'id:47::O': 419,
#  'id:voters::O': 420,
#  'id:cast::O': 421,
#  'id:ballots::O': 422,
#  'id:nine::O': 423,
#  'id:no::O': 424,
#  'id:candidate::O': 425,
#  'id:won::O': 426,
#  'id:majority::O': 427,
#  'id:previous::O': 428,
#  'id:round::O': 429,
#  'id:voting::O': 430,
#  'id:banned::O': 431,
#  'id:political::O': 432,
#  'id:but::O': 433,
#  'id:endorses::O': 434,
#  'id:so-called::O': 435,
#  'id:independent::O': 436,
#  'id:candidates::O': 437,
#  'id:whose::O': 438,
#  'id:allegiance::O': 439,
#  'id:known::O': 440,
#  'id:Hardline::O': 441,
#  'id:lawmakers::O': 442,
#  'id:Pakistan::B-geo': 443,
#  'id:North::B-geo': 444,
#  'id:West::I-geo': 445,
#  'id:Frontier::I-geo': 446,
#  'prev_tag:I-geo::I-geo': 447,
#  'id:Province::I-geo': 448,
#  'id:pushed::O': 449,
#  'id:law::O': 450,
#  'id:aims::O': 451,
#  'id:ensure::O': 452,
#  'id:Islamic::O': 453,
#  'id:correctness::O': 454,
#  'id:public::O': 455,
#  'id:places::O': 456,
#  'id:establishes::O': 457,
#  'id:morality::O': 458,
#  'id:enforce::O': 459,
#  'id:decent::O': 460,
#  'id:behavior::O': 461,
#  'id:six-party::O': 462,
#  'id:coalition::O': 463,
#  'id:religious::O': 464,
#  'id:based::O': 465,
#  'id:parties::O': 466,
#  'id:Mutahida::B-org': 467,
#  'id:Majlis-e-Amal::I-org': 468,
#  'id:dominates::O': 469,
#  'id:provincial::O': 470,
#  'id:assembly::O': 471,
#  'id:so::O': 472,
#  'id:bill::O': 473,
#  'id:easily::O': 474,
#  'id:passed::O': 475,
#  'id:Thursday::B-tim': 476,
#  'id:vote::O': 477,
#  'id:68-34::O': 478,
#  'id:governor::O': 479,
#  'id:must::O': 480,
#  'id:still::O': 481,
#  'id:sign::O': 482,
#  'id:before::O': 483,
#  'id:becomes::O': 484,
#  'id:seen::O': 485,
#  'id:only::O': 486,
#  'id:formality::O': 487,
#  'id:proposed::O': 488,
#  'id:calls::O': 489,
#  'id:setting::O': 490,
#  'id:up::O': 491,
#  'id:force::O': 492,
#  'id:make::O': 493,
#  'id:sure::O': 494,
#  'id:adhere::O': 495,
#  'id:values::O': 496,
#  'id:entertainment::O': 497,
#  'id:outlets::O': 498,
#  'id:close::O': 499,
#  'id:weekly::O': 500,
#  'id:prayers::O': 501,
#  'id:Violators::O': 502,
#  'id:be::O': 503,
#  'id:jailed::O': 504,
#  'id:six::O': 505,
#  'id:months::O': 506,
#  'id:denounced::O': 507,
#  'id:measure::O': 508,
#  'id:comparing::O': 509,
#  'id:draconian::O': 510,
#  'id:rule::O': 511,
#  'id:former::O': 512,
#  'id:Taleban::B-org': 513,
#  'id:neighboring::O': 514,
#  'id:Afghanistan::B-geo': 515,
#  'id:man::O': 516,
#  'id:dressed::O': 517,
#  'id:suicide::O': 518,
#  'id:bomber::O': 519,
#  'id:demonstration::O': 520,
#  'id:publication::O': 521,
#  'id:cartoons::O': 522,
#  'id:depicting::O': 523,
#  'id:Islam::B-org': 524,
#  'id:Prophet::B-per': 525,
#  'id:Muhammad::I-per': 526,
#  'id:Bedfordshire::B-gpe': 527,
#  'id:Omar::B-per': 528,
#  'id:Khayam::I-per': 529,
#  'id:Bedford::B-geo': 530,
#  'id:breaching::O': 531,
#  'id:conditions::O': 532,
#  'id:his::O': 533,
#  'id:parole::O': 534,
#  'id:British::B-org': 535,
#  'id:Home::I-org': 536,
#  'id:Office::I-org': 537,
#  'id:sought::O': 538,
#  'id:investigation::O': 539,
#  'id:Khayam::B-per': 540,
#  'id:he::O': 541,
#  'id:photographed::O': 542,
#  'id:fatigues::O': 543,
#  'id:black::O': 544,
#  'id:cap::O': 545,
#  'id:bulky::O': 546,
#  'id:belt::O': 547,
#  'id:Home::B-org': 548,
#  'id:told::O': 549,
#  'id:Associated::B-org': 550,
#  'id:Press::I-org': 551,
#  'id:paroled::O': 552,
#  'id:offender::O': 553,
#  'id:gives::O': 554,
#  'id:cause::O': 555,
#  'id:concern::O': 556,
#  'id:can::O': 557,
#  'id:sent::O': 558,
#  'id:back::O': 559,
#  'id:prison::O': 560,
#  'id:AP::B-org': 561,
#  'id:also::O': 562,
#  'id:since::O': 563,
#  'id:year::O': 564,
#  'id:serving::O': 565,
#  'id:half::O': 566,
#  'id:six-year::O': 567,
#  'id:sentence::O': 568,
#  'id:drug::O': 569,
#  'id:dealing::O': 570,
#  'id:Pakistani::B-gpe': 571,
#  'id:unidentified::O': 572,
#  'id:three::O': 573,
#  'id:minister::O': 574,
#  'id:semi-autonomous::O': 575,
#  'id:bordering::O': 576,
#  'id:prominent::O': 577,
#  'id:leader::O': 578,
#  'id:Malik::B-per': 579,
#  'id:Faridullah::I-per': 580,
#  'id:Khan::I-per': 581,
#  'id:traveling::O': 582,
#  'id:South::B-geo': 583,
#  'id:Waziristan::I-geo': 584,
#  'prev_tag:I-geo::B-tim': 585,
#  'id:vehicle::O': 586,
#  'id:ambushed::O': 587,
#  'id:Kani::B-geo': 588,
#  'id:Wam::I-geo': 589,
#  'id:area::O': 590,
#  'id:His::O': 591,
#  'id:driver::O': 592,
#  'id:elder::O': 593,
#  'id:No::O': 594,
#  'id:responsibility::O': 595,
#  'id:killings::O': 596,
#  'id:ambush::O': 597,
#  'id:commander::O': 598,
#  'id:army::O': 599,
#  'id:almost::O': 600,
#  'id:completely::O': 601,
#  'id:eliminated::O': 602,
#  'id:became::O': 603,
#  'id:refuge::O': 604,
#  'id:al-Qaida::B-org': 605,
#  'id:ousted::O': 606,
#  'id:2001::B-tim': 607,
#  'id:senior::O': 608,
#  'id:says::O': 609,
#  'id:Pakistan::B-gpe': 610,
#  'id:wants::O': 611,
#  'id:what::O': 612,
#  'id:sordid::O': 613,
#  'id:chapter::O': 614,
#  'id:proliferation::O': 615,
#  'id:top::O': 616,
#  'id:scientists::O': 617,
#  'id:behind::O': 618,
#  'id:build::O': 619,
#  'id:civilian::O': 620,
#  'id:ties::O': 621,
#  'id:United::B-gpe': 622,
#  'id:States::I-gpe': 623,
#  'prev_tag:B-gpe::I-gpe': 624,
#  'prev_tag:I-gpe::O': 625,
#  'id:But::O': 626,
#  'id:ready::O': 627,
#  'id:scientist::O': 628,
#  'id:Abdul::B-per': 629,
#  'id:Qadeer::I-per': 630,
#  'id:available::O': 631,
#  'id:direct::O': 632,
#  'id:questioning::O': 633,
#  'id:sale::O': 634,
#  'id:secrets::O': 635,
#  'id:states::O': 636,
#  'id:Libya::B-gpe': 637,
#  'id:North::B-gpe': 638,
#  'id:Korea::I-gpe': 639,
#  'id:He::O': 640,
#  'id:there::O': 641,
#  'id:reasons::O': 642,
#  'id:national::O': 643,
#  'id:sensitivities::O': 644,
#  'id:making::O': 645,
#  'id:him::O': 646,
#  'id:giving::O': 647,
#  'id:background::O': 648,
#  'id:briefing::O': 649,
#  'id:small::O': 650,
#  'id:group::O': 651,
#  'id:reporters::O': 652,
#  'id:Washington::B-geo': 653,
#  'init_tag:B-per': 654,
#  'id:Khan::B-per': 655,
#  'id:admitted::O': 656,
#  'id:2004::B-tim': 657,
#  'id:operated::O': 658,
#  'id:worldwide::O': 659,
#  'id:clandestine::O': 660,
#  'id:network::O': 661,
#  'id:sell::O': 662,
#  'id:technology::O': 663,
#  'id:market::O': 664,
#  'id:placed::O': 665,
#  'id:under::O': 666,
#  'id:house::O': 667,
#  'id:arrest::O': 668,
#  'id:Islamabad::B-geo': 669,
#  'id:because::O': 670,
#  'id:considered::O': 671,
#  'id:father::O': 672,
#  'id:bomb::O': 673,
#  'id:Army::B-org': 674,
#  'prev_tag:B-gpe::B-org': 675,
#  'id:renew::O': 676,
#  'id:controversial::O': 677,
#  'id:multi-billion::O': 678,
#  'id:dollar::O': 679,
#  'id:contract::O': 680,
#  'id:Halliburton::B-org': 681,
#  'id:company::O': 682,
#  'id:provide::O': 683,
#  'id:logistical::O': 684,
#  'id:support::O': 685,
#  'init_tag:B-org': 686,
#  'id:providing::O': 687,
#  'id:list::O': 688,
#  'id:meals::O': 689,
#  'id:communication::O': 690,
#  'id:several::O': 691,
#  'id:years::O': 692,
#  'id:Critics::O': 693,
#  'id:include::O': 694,
#  'id:auditors::O': 695,
#  'id:congressional::O': 696,
#  'id:Democrats::O': 697,
#  'id:produced::O': 698,
#  'id:some::O': 699,
#  'id:shoddy::O': 700,
#  'id:work::O': 701,
#  'id:charges::O': 702,
#  'id:too::O': 703,
#  'id:much::O': 704,
#  'id:money::O': 705,
#  'id:strongly::O': 706,
#  'id:denies::O': 707,
#  'id:allegations::O': 708,
#  'id:When::O': 709,
#  'id:re-bidding::O': 710,
#  'id:chance::O': 711,
#  'id:compete::O': 712,
#  'id:portions::O': 713,
#  'id:Representatives::O': 714,
#  'id:Asia::B-org': 715,
#  'id:Pacific::I-org': 716,
#  'id:Economic::I-org': 717,
#  'id:Cooperation::I-org': 718,
#  'id:Business::I-org': 719,
#  'id:Advisory::I-org': 720,
#  'id:holding::O': 721,
#  'id:meetings::O': 722,
#  'id:finalize::O': 723,
#  'id:report::O': 724,
#  'id:APEC::B-org': 725,
#  'id:leaders::O': 726,
#  'id:summit::O': 727,
#  'id:September::B-tim': 728,
#  'id:8::I-tim': 729,
#  'prev_tag:B-tim::I-tim': 730,
#  'prev_tag:I-tim::O': 731,
#  'id:9::B-tim': 732,
#  'id:VOA::B-org': 733,
#  'id:Nancy-Amelia::B-per': 734,
#  'id:Collins::I-per': 735,
#  'id:Sydney::B-geo': 736,
#  'id:Energy::O': 737,
#  'id:security::O': 738,
#  'id:climate::O': 739,
#  'id:change::O': 740,
#  'id:World::B-org': 741,
#  'id:Trade::I-org': 742,
#  'id:Organization::I-org': 743,
#  'id:stalled::O': 744,
#  'id:negotiations::O': 745,
#  'id:investment::O': 746,
#  'id:all::O': 747,
#  'id:expected::O': 748,
#  'id:among::O': 749,
#  'id:major::O': 750,
#  'id:topics::O': 751,
#  'id:ABAC::B-org': 752,
#  'id:Tim::B-per': 753,
#  'id:Harcourt::I-per': 754,
#  'id:chief::O': 755,
#  'id:economist::O': 756,
#  'id:Australian::B-org': 757,
#  'id:Commission::I-org': 758,
#  'id:plays::O': 759,
#  'id:important::O': 760,
#  'id:role::O': 761,
#  'id:informing::O': 762,
#  'id:governments::O': 763,
#  'id:problems::O': 764,
#  'id:most::O': 765,
#  'id:thing::O': 766,
#  'id:business::O': 767,
#  'id:do::O': 768,
#  'id:tell::O': 769,
#  'id:logjams::O': 770,
#  'id:obstacles::O': 771,
#  'id:things::O': 772,
#  'id:improve::O': 773,
#  'id:Harcourt::B-per': 774,
#  'id:I::O': 775,
#  'id:think::O': 776,
#  'id:actually::O': 777,
#  'id:played::O': 778,
#  'id:pretty::O': 779,
#  'id:good::O': 780,
#  'id:leadership::O': 781,
#  'id:talking::O': 782,
#  'id:about::O': 783,
#  'id:trade::O': 784,
#  'id:facilitation::O': 785,
#  'id:basically::O': 786,
#  'id:standards::O': 787,
#  'id:consistent::O': 788,
#  'id:harmonious::O': 789,
#  'id:across::O': 790,
#  'id:comprises::O': 791,
#  'id:private::O': 792,
#  'id:sector::O': 793,
#  'id:each::O': 794,
#  'id:21::O': 795,
#  'id:economies::O': 796,
#  'id:meets::O': 797,
#  'id:times::O': 798,
#  'id:made::O': 799,
#  'id:permanent::O': 800,
#  'id:body::O': 801,
#  'id:1995::B-tim': 802,
#  'id:perspective::O': 803,
#  'id:within::O': 804,
#  'id:Members::O': 805,
#  'id:represent::O': 806,
#  'id:range::O': 807,
#  'id:sectors::O': 808,
#  'id:medium::O': 809,
#  'id:businesses::O': 810,
#  'id:need::O': 811,
#  'id:energy::O': 812,
#  'id:efficiency::O': 813,
#  'id:encourage::O': 814,
#  'id:conservation::O': 815,
#  'id:practices::O': 816,
#  'id:discuss::O': 817,
#  'id:ways::O': 818,
#  'id:enhance::O': 819,
#  'id:regional::O': 820,
#  'id:cooperation::O': 821,
#  'id:reckon::O': 822,
#  "id:'ll::O": 823,
#  'id:talk::O': 824,
#  'id:little::O': 825,
#  'id:bit::O': 826,
#  'id:customs::O': 827,
#  'id:quarantine::O': 828,
#  'id:having::O': 829,
#  'id:arrangements::O': 830,
#  'id:around::O': 831,
#  'id:And::O': 832,
#  'id:want::O': 833,
#  'id:one-stop::O': 834,
#  'id:shop::O': 835,
#  'id:terms::O': 836,
#  'id:combining::O': 837,
#  'id:immigration::O': 838,
#  'id:together::O': 839,
#  'id:\x85::O': 840,
#  'id:just::O': 841,
#  'id:streamlined::O': 842,
#  'id:provides::O': 843,
#  'id:certainty::O': 844,
#  'id:non-governmental::O': 845,
#  'id:formal::O': 846,
#  'id:dialogue::O': 847,
#  'id:present::O': 848,
#  'id:meeting::O': 849,
#  'id:Sudan::B-gpe': 850,
#  'id:order::O': 851,
#  'id:Darfur::B-geo': 852,
#  'id:asking::O': 853,
#  'id:same::O': 854,
#  'id:Foreign::B-per': 855,
#  'id:Minister::I-per': 856,
#  'id:Mustafa::I-per': 857,
#  'id:Osman::I-per': 858,
#  'id:Ismail::I-per': 859,
#  'id:Sudanese::B-gpe': 860,
#  'id:withdraw::O': 861,
#  'id:positions::O': 862,
#  'id:held::O': 863,
#  'id:April::B-tim': 864,
#  'id:cease-fire::O': 865,
#  'id:western::O': 866,
#  'id:agree::O': 867,
#  'id:stop::O': 868,
#  'id:Mr.::B-per': 869,
#  'id:announced::O': 870,
#  'id:decision::O': 871,
#  'id:United::B-org': 872,
#  'id:Nations::I-org': 873,
#  'id:African::B-org': 874,
#  'id:Khartoum::B-geo': 875,
#  'id:weeks::O': 876,
#  'id:AU::B-org': 877,
#  'id:repeatedly::O': 878,
#  'id:truce::O': 879,
#  'init_tag:B-tim': 880,
#  'id:head::O': 881,
#  'id:accused::O': 882,
#  'id:helicopters::O': 883,
#  'id:bombing::O': 884,
#  'id:rebel::O': 885,
#  'id:sites::O': 886,
#  'id:Darfur::I-geo': 887,
#  'id:village::O': 888,
#  'id:Labado::B-geo': 889,
#  'id:Khartoum::B-gpe': 890,
#  'id:defending::O': 891,
#  'id:Aid::O': 892,
#  'id:relief::O': 893,
#  'id:efforts::O': 894,
#  'id:suspended::O': 895,
#  'id:due::O': 896,
#  'id:Indonesian::B-gpe': 897,
#  'id:men::O': 898,
#  'id:connection::O': 899,
#  'id:October::B-tim': 900,
#  'id:1::I-tim': 901,
#  'id:Bali::B-geo': 902,
#  'prev_tag:I-tim::B-geo': 903,
#  'id:left::O': 904,
#  'id:23::O': 905,
#  'id:dead::O': 906,
#  'id:flown::O': 907,
#  'id:Java::B-geo': 908,
#  'id:island::O': 909,
#  'id:headquarters::O': 910,
#  'id:Australian::B-gpe': 911,
#  'id:French::B-gpe': 912,
#  'id:agencies::O': 913,
#  'id:(::O': 914,
#  'id:Cholily::B-per': 915,
#  'id:)::O': 916,
#  'id:captured::O': 917,
#  'id:series::O': 918,
#  'id:counter-terrorism::O': 919,
#  'id:raids::O': 920,
#  'id:Indonesia::B-geo': 921,
#  'id:ended::O': 922,
#  'id:death::O': 923,
#  'id:alleged::O': 924,
#  'id:extremist::O': 925,
#  'id:bombmaker::O': 926,
#  'id:Azahari::B-per': 927,
#  'id:bin::I-per': 928,
#  'id:Husin::I-per': 929,
#  'id:authorities::O': 930,
#  'id:blame::O': 931,
#  'id:orchestrating::O': 932,
#  'id:month::O': 933,
#  'id:well::O': 934,
#  'id:2002::B-tim': 935,
#  'prev_tag:B-tim::B-geo': 936,
#  'id:Gunmen::O': 937,
#  'id:shot::O': 938,
#  'id:Roman::B-org': 939,
#  'id:Catholic::I-org': 940,
#  'id:nun::O': 941,
#  'id:her::O': 942,
#  'id:bodyguard::O': 943,
#  'id:hospital::O': 944,
#  'id:she::O': 945,
#  'id:worked::O': 946,
#  'id:Islamist-controlled::O': 947,
#  'id:Some::O': 948,
#  'id:witnesses::O': 949,
#  'id:shooting::O': 950,
#  'id:feared::O': 951,
#  'id:linked::O': 952,
#  'id:Muslim::O': 953,
#  'id:anger::O': 954,
#  'id:toward::O': 955,
#  'id:Pope::B-per': 956,
#  'id:Benedict::I-per': 957,
#  'id:pistols::O': 958,
#  'id:attacked::O': 959,
#  'id:Sister::B-per': 960,
#  'id:Leonella::I-per': 961,
#  'id:Sgorbati::I-per': 962,
#  'id:finished::O': 963,
#  'id:teaching::O': 964,
#  'id:medical::O': 965,
#  'id:school::O': 966,
#  'id:class::O': 967,
#  'id:suspect::O': 968,
#  'id:Vatican::B-org': 969,
#  'id:deplored::O': 970,
#  'id:hoped::O': 971,
#  'id:isolated::O': 972,
#  'id:event::O': 973,
#  'id:irrationality::O': 974,
#  'id:arising::O': 975,
#  'id:comments::O': 976,
#  'id:Pope::O': 977,
#  'id:angered::O': 978,
#  'id:Muslims::O': 979,
#  'id:Authorities::O': 980,
#  'id:determined::O': 981,
#  'id:motive::O': 982,
#  'id:pope::O': 983,
#  'id:meant::O': 984,
#  'id:offense::O': 985,
#  'id:quoted::O': 986,
#  'id:14::O': 987,
#  'id:century::O': 988,
#  'id:Byzantine::B-per': 989,
#  'id:emperor::O': 990,
#  'id:saying::O': 991,
#  'id:teachings::O': 992,
#  'id:Muhammed::I-per': 993,
#  'id:brought::O': 994,
#  'id:evil::O': 995,
#  'id:world::O': 996,
#  'id:targeted::O': 997,
#  'id:northwest::O': 998,
#  'id:third::O': 999,
#  ...}

# %% [markdown]
# #### Training structured perceptron

# %%
corpus = skseq.readers.pos_corpus.PostagCorpus()
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)

# %%
sp.get_num_states(), sp.get_num_observations()
# Out:
# (17, 30863)

# %%
# %%time
num_epochs = 15
sp.fit(ex_feature_mapper.dataset, num_epochs)
# Out:
# Epoch: 0 Accuracy: 0.892678
# Epoch: 1 Accuracy: 0.931972
# Epoch: 2 Accuracy: 0.941622
# Epoch: 3 Accuracy: 0.947549
# Epoch: 4 Accuracy: 0.950647
# Epoch: 5 Accuracy: 0.953512
# Epoch: 6 Accuracy: 0.955472
# Epoch: 7 Accuracy: 0.957134
# Epoch: 8 Accuracy: 0.958280
# Epoch: 9 Accuracy: 0.958821
# Epoch: 10 Accuracy: 0.959816
# Epoch: 11 Accuracy: 0.960872
# Epoch: 12 Accuracy: 0.961597
# Epoch: 13 Accuracy: 0.962109
# Epoch: 14 Accuracy: 0.962987
# Wall time: 1h 4min 12s

# %%
# sp.save_model("perceptron_ex1")

# %%
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)
sp.load_model(dir="perceptron_ex1")

# %% [markdown]
# #### Testing

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

y_pred_2 = []
y_true = [item for x in Y_ids_test for item in x]
correct_sentences = 0
n_test = len(X_test)

for i in range(n_test):
    y_pred_aux = sp.predict_tags_given_words(X_test[i])
    y_pred_2.append(y_pred_aux)
    if list(y_pred_aux) == Y_ids_test[i]:
        correct_sentences += 1
    
y_pred = [item for x in y_pred_2 for item in x]
F1_score_multi = f1_score(y_true, y_pred, average=None)
Accuracy = accuracy_score(y_true, y_pred)
print('Accuracy for test is: ' + str(Accuracy))
print('F1-Score for test is: ' + str(np.mean(F1_score_multi)))
print('Correct sentences for test (%) : ' + str(correct_sentences/n_test))
# Out:
# Accuracy for test is: 0.9497189411859115
# F1-Score for test is: 0.6325282666272773
# Correct sentences for test (%) : 0.4780613947280614

# %%
ax = plot_confusion_matrix(y_true, y_pred, classes=list(sp.state_labels),
                      title='Confusion matrix')

# %% [markdown]
# #### SENTENCES TO TEST THE MODEL

# %% [markdown]
# We think that these are the tags that the model should obtain:
#
# 1. The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 2. The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 3. Jack/B-per London/I-per went/O to/O Parris./O
#
# 4. Jack/B-per London/I-per went/O to/O/O Paris./B-geo
#
# 5. We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
#
# 6. We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
#
# 7. The/O president/O of/O U.S.A/B-geo though/O they/O could/O win/O the/O war/O
#
# 8. The/O president/O of/O the/O United/B-geo States/B-geo of/B-geo America/B-geo though/O they/O could/O win/O the/O war/O
#
# 9. The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
#
# 10. Robin/B-per does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
print_all_test_sentences(test_sentences, sp)
# Out:
# The/O programmers/O from/O Barcelona/B-org might/O write/O a/O sentence/O without/O a/O spell/B-per checker./I-per
# The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/B-per checker./I-per
# Jack/B-per London/B-geo went/O to/O Parris./O
# Jack/B-per London/B-geo went/O to/O Paris./O
# We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
# We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
# The/O president/O of/O U.S.A/B-org though/O they/O could/O win/O the/O war/O
# The/O president/O of/O the/O United/B-geo States/I-geo of/I-geo America/I-geo though/O they/O could/O win/O the/O war/O
# The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
# Robin/B-org does/O not/O want/O to/O go/O to/O Saudi/O Arabia./O

# %%
# Here we can select the sentence in which we want to compare the true and the predicted tags
# Select a sentence between 1 and 10
i=1
compare_one_test_sentence(test_sentences, test_tags, sp, pos_to_tag, i)
# Out:
# Word            (True ): Pred
# The             (O    ): O
# programmers     (O    ): O
# from            (O    ): O
# Barcelona       (B-geo): B-org
# might           (O    ): O
# write           (O    ): O
# a               (O    ): O
# sentence        (O    ): O
# without         (O    ): O
# a               (O    ): O
# spell           (O    ): B-per
# checker.        (O    ): I-per

# %% [markdown]
# #### Checking the first sentence of the corpus

# %%
new_seq = Sequence(x=X_test[0], y=[int(0) for w in X_test[0]])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(X_test[0], Y_test[0], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# Officials       (O    ): O
# said            (O    ): O
# Sunday          (B-tim): B-tim
# Jean            (B-per): B-per
# Rene            (I-per): I-per
# Anthony         (I-per): I-per
# was             (O    ): O
# killed          (O    ): O
# in              (O    ): O
# a               (O    ): O
# shootout        (O    ): O
# with            (O    ): O
# police          (O    ): O
# near            (O    ): O
# the             (O    ): O
# capital         (O    ): O
# city            (O    ): O
# of              (O    ): O
# Port-au-Prince  (B-geo): O
# .               (O    ): O

# %% [markdown]
# ##### Post-comments:
#
# In the next experiment we are going to add a hyphen feature, because as we can see in the first sentence of the Test corpus (Port-au-Prince) we are failing.

# %% [markdown]
# # EXPERIMENT 2: Adding a hyphen

# %% [markdown]
# ##### Comments:
# In the second experiment we are going to introduce the **hyphen features** to check if this information is useful or not and if it helps with the previous error.

# %% [markdown]
# ### Extended features

# %%
ex_feature_mapper = skseq.sequences.extended_feature.ExtendedFeatures(sequence_list_train) 
ex_feature_mapper.build_features()
pprint.pprint(list(ex_feature_mapper.__dict__.keys()))
# Out:
# ['feature_dict',
#  'feature_list',
#  'add_features',
#  'dataset',
#  'node_feature_cache',
#  'initial_state_feature_cache',
#  'final_state_feature_cache',
#  'edge_feature_cache']

# %%
len(ex_feature_mapper.feature_dict)
# Out:
# 38315

# %%
ex_feature_mapper.feature_dict
# Out:
# {'init_tag:O': 0,
#  'id:Thousands::O': 1,
#  'hyphen::O': 2,
#  'id:of::O': 3,
#  'prev_tag:O::O': 4,
#  'id:demonstrators::O': 5,
#  'id:have::O': 6,
#  'id:marched::O': 7,
#  'id:through::O': 8,
#  'id:London::B-geo': 9,
#  'hyphen::B-geo': 10,
#  'prev_tag:O::B-geo': 11,
#  'id:to::O': 12,
#  'prev_tag:B-geo::O': 13,
#  'id:protest::O': 14,
#  'id:the::O': 15,
#  'id:war::O': 16,
#  'id:in::O': 17,
#  'id:Iraq::B-geo': 18,
#  'id:and::O': 19,
#  'id:demand::O': 20,
#  'id:withdrawal::O': 21,
#  'id:British::B-gpe': 22,
#  'hyphen::B-gpe': 23,
#  'prev_tag:O::B-gpe': 24,
#  'id:troops::O': 25,
#  'prev_tag:B-gpe::O': 26,
#  'id:from::O': 27,
#  'id:that::O': 28,
#  'id:country::O': 29,
#  'id:.::O': 30,
#  'final_prev_tag:O': 31,
#  'id:Families::O': 32,
#  'id:soldiers::O': 33,
#  'id:killed::O': 34,
#  'id:conflict::O': 35,
#  'id:joined::O': 36,
#  'id:protesters::O': 37,
#  'id:who::O': 38,
#  'id:carried::O': 39,
#  'id:banners::O': 40,
#  'id:with::O': 41,
#  'id:such::O': 42,
#  'id:slogans::O': 43,
#  'id:as::O': 44,
#  'id:"::O': 45,
#  'id:Bush::B-per': 46,
#  'hyphen::B-per': 47,
#  'prev_tag:O::B-per': 48,
#  'id:Number::O': 49,
#  'prev_tag:B-per::O': 50,
#  'id:One::O': 51,
#  'id:Terrorist::O': 52,
#  'id:Stop::O': 53,
#  'id:Bombings::O': 54,
#  'id:They::O': 55,
#  'id:Houses::O': 56,
#  'id:Parliament::O': 57,
#  'id:a::O': 58,
#  'id:rally::O': 59,
#  'id:Hyde::B-geo': 60,
#  'id:Park::I-geo': 61,
#  'hyphen::I-geo': 62,
#  'prev_tag:B-geo::I-geo': 63,
#  'prev_tag:I-geo::O': 64,
#  'id:Police::O': 65,
#  'id:put::O': 66,
#  'id:number::O': 67,
#  'id:marchers::O': 68,
#  'id:at::O': 69,
#  'id:10,000::O': 70,
#  'id:while::O': 71,
#  'id:organizers::O': 72,
#  'id:claimed::O': 73,
#  'id:it::O': 74,
#  'id:was::O': 75,
#  'id:1,00,000::O': 76,
#  'id:The::O': 77,
#  'id:comes::O': 78,
#  'id:on::O': 79,
#  'id:eve::O': 80,
#  'id:annual::O': 81,
#  'id:conference::O': 82,
#  'id:Britain::B-geo': 83,
#  "id:'s::O": 84,
#  'id:ruling::O': 85,
#  'id:Labor::B-org': 86,
#  'hyphen::B-org': 87,
#  'prev_tag:O::B-org': 88,
#  'id:Party::I-org': 89,
#  'hyphen::I-org': 90,
#  'prev_tag:B-org::I-org': 91,
#  'prev_tag:I-org::O': 92,
#  'id:southern::O': 93,
#  'id:English::B-gpe': 94,
#  'id:seaside::O': 95,
#  'id:resort::O': 96,
#  'id:Brighton::B-geo': 97,
#  'id:party::O': 98,
#  'id:is::O': 99,
#  'id:divided::O': 100,
#  'id:over::O': 101,
#  'id:Britain::B-gpe': 102,
#  'id:participation::O': 103,
#  'id:continued::O': 104,
#  'id:deployment::O': 105,
#  'id:8,500::O': 106,
#  'id:march::O': 107,
#  'id:came::O': 108,
#  'id:ahead::O': 109,
#  'id:anti-war::O': 110,
#  'id:protests::O': 111,
#  'id:today::O': 112,
#  'id:other::O': 113,
#  'id:cities::O': 114,
#  'id:,::O': 115,
#  'id:including::O': 116,
#  'id:Rome::B-geo': 117,
#  'id:Paris::B-geo': 118,
#  'id:Madrid::B-geo': 119,
#  'id:International::B-org': 120,
#  'id:Atomic::I-org': 121,
#  'id:Energy::I-org': 122,
#  'prev_tag:I-org::I-org': 123,
#  'id:Agency::I-org': 124,
#  'id:hold::O': 125,
#  'id:second::O': 126,
#  'id:day::O': 127,
#  'id:talks::O': 128,
#  'id:Vienna::B-geo': 129,
#  'id:Wednesday::B-tim': 130,
#  'hyphen::B-tim': 131,
#  'prev_tag:B-geo::B-tim': 132,
#  'prev_tag:B-tim::O': 133,
#  'id:how::O': 134,
#  'id:respond::O': 135,
#  'id:Iran::B-gpe': 136,
#  'id:resumption::O': 137,
#  'id:low-level::O': 138,
#  'id:uranium::O': 139,
#  'id:conversion::O': 140,
#  'init_tag:B-gpe': 141,
#  'id:this::O': 142,
#  'id:week::O': 143,
#  'id:restarted::O': 144,
#  'id:parts::O': 145,
#  'id:process::O': 146,
#  'id:its::O': 147,
#  'id:Isfahan::B-geo': 148,
#  'id:nuclear::O': 149,
#  'id:plant::O': 150,
#  'id:Iranian::B-gpe': 151,
#  'id:officials::O': 152,
#  'id:say::O': 153,
#  'id:they::O': 154,
#  'id:expect::O': 155,
#  'id:get::O': 156,
#  'id:access::O': 157,
#  'id:sealed::O': 158,
#  'id:sensitive::O': 159,
#  'prev_tag:O::B-tim': 160,
#  'id:after::O': 161,
#  'id:an::O': 162,
#  'id:IAEA::B-org': 163,
#  'id:surveillance::O': 164,
#  'prev_tag:B-org::O': 165,
#  'id:system::O': 166,
#  'id:begins::O': 167,
#  'id:functioning::O': 168,
#  'id:step::O': 169,
#  'id:will::O': 170,
#  'id:allow::O': 171,
#  'id:facility::O': 172,
#  'id:operate::O': 173,
#  'id:full::O': 174,
#  'id:capacity::O': 175,
#  'id:European::B-org': 176,
#  'id:Union::I-org': 177,
#  'id:U.S.::B-gpe': 178,
#  'id:backing::O': 179,
#  'id:has::O': 180,
#  'id:threatened::O': 181,
#  'id:refer::O': 182,
#  'id:U.N.::B-org': 183,
#  'id:Security::I-org': 184,
#  'id:Council::I-org': 185,
#  'id:which::O': 186,
#  'id:could::O': 187,
#  'id:impose::O': 188,
#  'id:sanctions::O': 189,
#  'id:if::O': 190,
#  'id:finds::O': 191,
#  'id:Tehran::B-gpe': 192,
#  'id:violated::O': 193,
#  'id:Nuclear::B-art': 194,
#  'hyphen::B-art': 195,
#  'prev_tag:O::B-art': 196,
#  'id:Non-Proliferation::I-art': 197,
#  'hyphen::I-art': 198,
#  'prev_tag:B-art::I-art': 199,
#  'id:treaty::O': 200,
#  'prev_tag:I-art::O': 201,
#  'id:new::O': 202,
#  'id:President::B-per': 203,
#  'id:Mahmoud::I-per': 204,
#  'hyphen::I-per': 205,
#  'prev_tag:B-per::I-per': 206,
#  'id:Ahmadinejad::I-per': 207,
#  'prev_tag:I-per::I-per': 208,
#  'id:said::O': 209,
#  'prev_tag:I-per::O': 210,
#  'id:Tuesday::B-tim': 211,
#  'id:European::B-gpe': 212,
#  'id:incentives::O': 213,
#  'id:aimed::O': 214,
#  'id:persuading::O': 215,
#  'id:end::O': 216,
#  'id:fuel::O': 217,
#  'id:program::O': 218,
#  'id:are::O': 219,
#  'id:insult::O': 220,
#  'id:nation::O': 221,
#  'id:Two::O': 222,
#  'id:Germans::B-gpe': 223,
#  'id:four::O': 224,
#  'id:Nigerian::B-gpe': 225,
#  'id:oil::O': 226,
#  'id:workers::O': 227,
#  'id:were::O': 228,
#  'id:kidnapped::O': 229,
#  'id:by::O': 230,
#  'id:armed::O': 231,
#  'id:militants::O': 232,
#  'id:during::O': 233,
#  'id:raid::O': 234,
#  'id:boat::O': 235,
#  'id:Nigeria::B-geo': 236,
#  'id:oil-rich::O': 237,
#  'id:Delta::B-geo': 238,
#  'id:region::O': 239,
#  'id:An::O': 240,
#  'id:official::O': 241,
#  'id:German::B-gpe': 242,
#  'id:firm::O': 243,
#  'id:Bilfinger::B-org': 244,
#  'id:Berger::I-org': 245,
#  'id:Thomas::B-per': 246,
#  'id:Horbach::I-per': 247,
#  'id:gunmen::O': 248,
#  'id:stopped::O': 249,
#  'id:supply::O': 250,
#  'id:sailed::O': 251,
#  'id:State::I-geo': 252,
#  'id:Bayelsa::B-geo': 253,
#  'id:inspect::O': 254,
#  'id:offshore::O': 255,
#  'id:field::O': 256,
#  'id:owned::O': 257,
#  'id:Royal-Dutch::B-org': 258,
#  'id:Shell::I-org': 259,
#  'id:works::O': 260,
#  'id:sub-contractor::O': 261,
#  'id:for::O': 262,
#  'id:Shell::B-org': 263,
#  'id:Militant::O': 264,
#  'id:groups::O': 265,
#  'id:frequently::O': 266,
#  'id:attack::O': 267,
#  'id:operations::O': 268,
#  'id:Niger::B-geo': 269,
#  'id:Delta::I-geo': 270,
#  'id:social::O': 271,
#  'id:services::O': 272,
#  'id:better::O': 273,
#  'id:job::O': 274,
#  'id:opportunities::O': 275,
#  'id:multinational::O': 276,
#  'id:companies::O': 277,
#  'id:Poor::O': 278,
#  'id:residents::O': 279,
#  'id:often::O': 280,
#  'id:complain::O': 281,
#  'id:been::O': 282,
#  'id:cheated::O': 283,
#  'id:out::O': 284,
#  'id:huge::O': 285,
#  'id:riches::O': 286,
#  'id:extracted::O': 287,
#  'id:their::O': 288,
#  'id:tribal::O': 289,
#  'id:lands::O': 290,
#  'id:-::O': 291,
#  'id:where::O': 292,
#  'id:bulk::O': 293,
#  'id:Nigeria::B-gpe': 294,
#  'id:2.3::O': 295,
#  'id:million::O': 296,
#  'id:barrels::O': 297,
#  'id:petroleum::O': 298,
#  'id:pumped::O': 299,
#  'id:daily::O': 300,
#  'id:Suspected::O': 301,
#  'id:Islamist::O': 302,
#  'id:rebels::O': 303,
#  'id:fired::O': 304,
#  'id:mortar::O': 305,
#  'id:shells::O': 306,
#  'id:palace::O': 307,
#  'id:used::O': 308,
#  'id:Somalia::B-geo': 309,
#  'id:interim::O': 310,
#  'id:Abdullahi::I-per': 311,
#  'id:Yusuf::I-per': 312,
#  'id:Ahmad::I-per': 313,
#  'id:It::O': 314,
#  'id:not::O': 315,
#  'id:immediately::O': 316,
#  'id:clear::O': 317,
#  'id:president::O': 318,
#  'id:Mogadishu::B-geo': 319,
#  'id:when::O': 320,
#  'id:occurred::O': 321,
#  'id:or::O': 322,
#  'id:anyone::O': 323,
#  'id:hurt::O': 324,
#  'id:Local::O': 325,
#  'id:news::O': 326,
#  'id:reports::O': 327,
#  'id:least::O': 328,
#  'id:five::O': 329,
#  'id:hit::O': 330,
#  'id:compound::O': 331,
#  'id:mortars::O': 332,
#  'id:elsewhere::O': 333,
#  'id:attacks::O': 334,
#  'id:government::O': 335,
#  'id:go::O': 336,
#  'id:reconciliation::O': 337,
#  'id:more::O': 338,
#  'id:than::O': 339,
#  'id:1,300::O': 340,
#  'id:Somali::B-gpe': 341,
#  'id:elders::O': 342,
#  'id:warlords::O': 343,
#  'id:politicians::O': 344,
#  'id:invited::O': 345,
#  'id:Iraqi::B-gpe': 346,
#  'id:military::O': 347,
#  'id:tanks::O': 348,
#  'id:arrived::O': 349,
#  'id:northern::O': 350,
#  'id:city::O': 351,
#  'id:Mosul::B-geo': 352,
#  'id:offensive::O': 353,
#  'id:against::O': 354,
#  'id:al::B-org': 355,
#  'id:Qaida::I-org': 356,
#  'id:in::I-org': 357,
#  'id:Iraq::I-org': 358,
#  'id:fighters::O': 359,
#  'id:Officials::O': 360,
#  'id:many::O': 361,
#  'id:Sunni::B-geo': 362,
#  'id:Arab::I-geo': 363,
#  'id:Kurdish::B-geo': 364,
#  'id:bombings::O': 365,
#  'id:last::O': 366,
#  'id:34::O': 367,
#  'id:people::O': 368,
#  'id:wounded::O': 369,
#  'id:200::O': 370,
#  'id:commanders::O': 371,
#  'id:explained::O': 372,
#  'id:American::B-gpe': 373,
#  'id:forces::O': 374,
#  'id:participate::O': 375,
#  'id:fled::O': 376,
#  'id:successful::O': 377,
#  'id:campaigns::O': 378,
#  'id:them::O': 379,
#  'id:Anbar::B-geo': 380,
#  'id:province::O': 381,
#  'id:Baghdad::B-geo': 382,
#  'id:provinces::O': 383,
#  'init_tag:B-geo': 384,
#  'id:largest::O': 385,
#  'id:north::O': 386,
#  'id:long::O': 387,
#  'id:stronghold::O': 388,
#  'id:Sunni::B-org': 389,
#  'id:militant::O': 390,
#  'id:In::O': 391,
#  'id:violence::O': 392,
#  'id:one::O': 393,
#  'id:soldier::O': 394,
#  'id:patrol::O': 395,
#  'id:Sunday::B-tim': 396,
#  'id:Egyptian::B-gpe': 397,
#  'id:police::O': 398,
#  'id:arrested::O': 399,
#  'id:16::O': 400,
#  'id:members::O': 401,
#  'id:opposition::O': 402,
#  'id:Muslim::B-org': 403,
#  'id:Brotherhood::I-org': 404,
#  'id:prepare::O': 405,
#  'id:parliamentary::O': 406,
#  'id:runoff::O': 407,
#  'id:elections::O': 408,
#  'id:Saturday::B-tim': 409,
#  'id:arrests::O': 410,
#  'id:Friday::B-tim': 411,
#  'id:Alexandria::B-geo': 412,
#  'id:A::O': 413,
#  'id:spokesman::O': 414,
#  'id:Brotherhood::B-org': 415,
#  'id:attempt::O': 416,
#  'id:cut::O': 417,
#  'id:off::O': 418,
#  'id:supporters::O': 419,
#  'id:punishment::O': 420,
#  'id:winning::O': 421,
#  'id:seats::O': 422,
#  'id:earlier::O': 423,
#  'id:tripled::O': 424,
#  'id:strength::O': 425,
#  'id:parliament::O': 426,
#  'id:recent::O': 427,
#  'id:raising::O': 428,
#  'id:total::O': 429,
#  'id:47::O': 430,
#  'id:voters::O': 431,
#  'id:cast::O': 432,
#  'id:ballots::O': 433,
#  'id:nine::O': 434,
#  'id:no::O': 435,
#  'id:candidate::O': 436,
#  'id:won::O': 437,
#  'id:majority::O': 438,
#  'id:previous::O': 439,
#  'id:round::O': 440,
#  'id:voting::O': 441,
#  'id:banned::O': 442,
#  'id:political::O': 443,
#  'id:but::O': 444,
#  'id:endorses::O': 445,
#  'id:so-called::O': 446,
#  'id:independent::O': 447,
#  'id:candidates::O': 448,
#  'id:whose::O': 449,
#  'id:allegiance::O': 450,
#  'id:known::O': 451,
#  'id:Hardline::O': 452,
#  'id:lawmakers::O': 453,
#  'id:Pakistan::B-geo': 454,
#  'id:North::B-geo': 455,
#  'id:West::I-geo': 456,
#  'id:Frontier::I-geo': 457,
#  'prev_tag:I-geo::I-geo': 458,
#  'id:Province::I-geo': 459,
#  'id:pushed::O': 460,
#  'id:law::O': 461,
#  'id:aims::O': 462,
#  'id:ensure::O': 463,
#  'id:Islamic::O': 464,
#  'id:correctness::O': 465,
#  'id:public::O': 466,
#  'id:places::O': 467,
#  'id:establishes::O': 468,
#  'id:morality::O': 469,
#  'id:enforce::O': 470,
#  'id:decent::O': 471,
#  'id:behavior::O': 472,
#  'id:six-party::O': 473,
#  'id:coalition::O': 474,
#  'id:religious::O': 475,
#  'id:based::O': 476,
#  'id:parties::O': 477,
#  'id:Mutahida::B-org': 478,
#  'id:Majlis-e-Amal::I-org': 479,
#  'id:dominates::O': 480,
#  'id:provincial::O': 481,
#  'id:assembly::O': 482,
#  'id:so::O': 483,
#  'id:bill::O': 484,
#  'id:easily::O': 485,
#  'id:passed::O': 486,
#  'id:Thursday::B-tim': 487,
#  'id:vote::O': 488,
#  'id:68-34::O': 489,
#  'id:governor::O': 490,
#  'id:must::O': 491,
#  'id:still::O': 492,
#  'id:sign::O': 493,
#  'id:before::O': 494,
#  'id:becomes::O': 495,
#  'id:seen::O': 496,
#  'id:only::O': 497,
#  'id:formality::O': 498,
#  'id:proposed::O': 499,
#  'id:calls::O': 500,
#  'id:setting::O': 501,
#  'id:up::O': 502,
#  'id:force::O': 503,
#  'id:make::O': 504,
#  'id:sure::O': 505,
#  'id:adhere::O': 506,
#  'id:values::O': 507,
#  'id:entertainment::O': 508,
#  'id:outlets::O': 509,
#  'id:close::O': 510,
#  'id:weekly::O': 511,
#  'id:prayers::O': 512,
#  'id:Violators::O': 513,
#  'id:be::O': 514,
#  'id:jailed::O': 515,
#  'id:six::O': 516,
#  'id:months::O': 517,
#  'id:denounced::O': 518,
#  'id:measure::O': 519,
#  'id:comparing::O': 520,
#  'id:draconian::O': 521,
#  'id:rule::O': 522,
#  'id:former::O': 523,
#  'id:Taleban::B-org': 524,
#  'id:neighboring::O': 525,
#  'id:Afghanistan::B-geo': 526,
#  'id:man::O': 527,
#  'id:dressed::O': 528,
#  'id:suicide::O': 529,
#  'id:bomber::O': 530,
#  'id:demonstration::O': 531,
#  'id:publication::O': 532,
#  'id:cartoons::O': 533,
#  'id:depicting::O': 534,
#  'id:Islam::B-org': 535,
#  'id:Prophet::B-per': 536,
#  'id:Muhammad::I-per': 537,
#  'id:Bedfordshire::B-gpe': 538,
#  'id:Omar::B-per': 539,
#  'id:Khayam::I-per': 540,
#  'id:Bedford::B-geo': 541,
#  'id:breaching::O': 542,
#  'id:conditions::O': 543,
#  'id:his::O': 544,
#  'id:parole::O': 545,
#  'id:British::B-org': 546,
#  'id:Home::I-org': 547,
#  'id:Office::I-org': 548,
#  'id:sought::O': 549,
#  'id:investigation::O': 550,
#  'id:Khayam::B-per': 551,
#  'id:he::O': 552,
#  'id:photographed::O': 553,
#  'id:fatigues::O': 554,
#  'id:black::O': 555,
#  'id:cap::O': 556,
#  'id:bulky::O': 557,
#  'id:belt::O': 558,
#  'id:Home::B-org': 559,
#  'id:told::O': 560,
#  'id:Associated::B-org': 561,
#  'id:Press::I-org': 562,
#  'id:paroled::O': 563,
#  'id:offender::O': 564,
#  'id:gives::O': 565,
#  'id:cause::O': 566,
#  'id:concern::O': 567,
#  'id:can::O': 568,
#  'id:sent::O': 569,
#  'id:back::O': 570,
#  'id:prison::O': 571,
#  'id:AP::B-org': 572,
#  'id:also::O': 573,
#  'id:since::O': 574,
#  'id:year::O': 575,
#  'id:serving::O': 576,
#  'id:half::O': 577,
#  'id:six-year::O': 578,
#  'id:sentence::O': 579,
#  'id:drug::O': 580,
#  'id:dealing::O': 581,
#  'id:Pakistani::B-gpe': 582,
#  'id:unidentified::O': 583,
#  'id:three::O': 584,
#  'id:minister::O': 585,
#  'id:semi-autonomous::O': 586,
#  'id:bordering::O': 587,
#  'id:prominent::O': 588,
#  'id:leader::O': 589,
#  'id:Malik::B-per': 590,
#  'id:Faridullah::I-per': 591,
#  'id:Khan::I-per': 592,
#  'id:traveling::O': 593,
#  'id:South::B-geo': 594,
#  'id:Waziristan::I-geo': 595,
#  'prev_tag:I-geo::B-tim': 596,
#  'id:vehicle::O': 597,
#  'id:ambushed::O': 598,
#  'id:Kani::B-geo': 599,
#  'id:Wam::I-geo': 600,
#  'id:area::O': 601,
#  'id:His::O': 602,
#  'id:driver::O': 603,
#  'id:elder::O': 604,
#  'id:No::O': 605,
#  'id:responsibility::O': 606,
#  'id:killings::O': 607,
#  'id:ambush::O': 608,
#  'id:commander::O': 609,
#  'id:army::O': 610,
#  'id:almost::O': 611,
#  'id:completely::O': 612,
#  'id:eliminated::O': 613,
#  'id:became::O': 614,
#  'id:refuge::O': 615,
#  'id:al-Qaida::B-org': 616,
#  'id:ousted::O': 617,
#  'id:2001::B-tim': 618,
#  'id:senior::O': 619,
#  'id:says::O': 620,
#  'id:Pakistan::B-gpe': 621,
#  'id:wants::O': 622,
#  'id:what::O': 623,
#  'id:sordid::O': 624,
#  'id:chapter::O': 625,
#  'id:proliferation::O': 626,
#  'id:top::O': 627,
#  'id:scientists::O': 628,
#  'id:behind::O': 629,
#  'id:build::O': 630,
#  'id:civilian::O': 631,
#  'id:ties::O': 632,
#  'id:United::B-gpe': 633,
#  'id:States::I-gpe': 634,
#  'hyphen::I-gpe': 635,
#  'prev_tag:B-gpe::I-gpe': 636,
#  'prev_tag:I-gpe::O': 637,
#  'id:But::O': 638,
#  'id:ready::O': 639,
#  'id:scientist::O': 640,
#  'id:Abdul::B-per': 641,
#  'id:Qadeer::I-per': 642,
#  'id:available::O': 643,
#  'id:direct::O': 644,
#  'id:questioning::O': 645,
#  'id:sale::O': 646,
#  'id:secrets::O': 647,
#  'id:states::O': 648,
#  'id:Libya::B-gpe': 649,
#  'id:North::B-gpe': 650,
#  'id:Korea::I-gpe': 651,
#  'id:He::O': 652,
#  'id:there::O': 653,
#  'id:reasons::O': 654,
#  'id:national::O': 655,
#  'id:sensitivities::O': 656,
#  'id:making::O': 657,
#  'id:him::O': 658,
#  'id:giving::O': 659,
#  'id:background::O': 660,
#  'id:briefing::O': 661,
#  'id:small::O': 662,
#  'id:group::O': 663,
#  'id:reporters::O': 664,
#  'id:Washington::B-geo': 665,
#  'init_tag:B-per': 666,
#  'id:Khan::B-per': 667,
#  'id:admitted::O': 668,
#  'id:2004::B-tim': 669,
#  'id:operated::O': 670,
#  'id:worldwide::O': 671,
#  'id:clandestine::O': 672,
#  'id:network::O': 673,
#  'id:sell::O': 674,
#  'id:technology::O': 675,
#  'id:market::O': 676,
#  'id:placed::O': 677,
#  'id:under::O': 678,
#  'id:house::O': 679,
#  'id:arrest::O': 680,
#  'id:Islamabad::B-geo': 681,
#  'id:because::O': 682,
#  'id:considered::O': 683,
#  'id:father::O': 684,
#  'id:bomb::O': 685,
#  'id:Army::B-org': 686,
#  'prev_tag:B-gpe::B-org': 687,
#  'id:renew::O': 688,
#  'id:controversial::O': 689,
#  'id:multi-billion::O': 690,
#  'id:dollar::O': 691,
#  'id:contract::O': 692,
#  'id:Halliburton::B-org': 693,
#  'id:company::O': 694,
#  'id:provide::O': 695,
#  'id:logistical::O': 696,
#  'id:support::O': 697,
#  'init_tag:B-org': 698,
#  'id:providing::O': 699,
#  'id:list::O': 700,
#  'id:meals::O': 701,
#  'id:communication::O': 702,
#  'id:several::O': 703,
#  'id:years::O': 704,
#  'id:Critics::O': 705,
#  'id:include::O': 706,
#  'id:auditors::O': 707,
#  'id:congressional::O': 708,
#  'id:Democrats::O': 709,
#  'id:produced::O': 710,
#  'id:some::O': 711,
#  'id:shoddy::O': 712,
#  'id:work::O': 713,
#  'id:charges::O': 714,
#  'id:too::O': 715,
#  'id:much::O': 716,
#  'id:money::O': 717,
#  'id:strongly::O': 718,
#  'id:denies::O': 719,
#  'id:allegations::O': 720,
#  'id:When::O': 721,
#  'id:re-bidding::O': 722,
#  'id:chance::O': 723,
#  'id:compete::O': 724,
#  'id:portions::O': 725,
#  'id:Representatives::O': 726,
#  'id:Asia::B-org': 727,
#  'id:Pacific::I-org': 728,
#  'id:Economic::I-org': 729,
#  'id:Cooperation::I-org': 730,
#  'id:Business::I-org': 731,
#  'id:Advisory::I-org': 732,
#  'id:holding::O': 733,
#  'id:meetings::O': 734,
#  'id:finalize::O': 735,
#  'id:report::O': 736,
#  'id:APEC::B-org': 737,
#  'id:leaders::O': 738,
#  'id:summit::O': 739,
#  'id:September::B-tim': 740,
#  'id:8::I-tim': 741,
#  'hyphen::I-tim': 742,
#  'prev_tag:B-tim::I-tim': 743,
#  'prev_tag:I-tim::O': 744,
#  'id:9::B-tim': 745,
#  'id:VOA::B-org': 746,
#  'id:Nancy-Amelia::B-per': 747,
#  'id:Collins::I-per': 748,
#  'id:Sydney::B-geo': 749,
#  'id:Energy::O': 750,
#  'id:security::O': 751,
#  'id:climate::O': 752,
#  'id:change::O': 753,
#  'id:World::B-org': 754,
#  'id:Trade::I-org': 755,
#  'id:Organization::I-org': 756,
#  'id:stalled::O': 757,
#  'id:negotiations::O': 758,
#  'id:investment::O': 759,
#  'id:all::O': 760,
#  'id:expected::O': 761,
#  'id:among::O': 762,
#  'id:major::O': 763,
#  'id:topics::O': 764,
#  'id:ABAC::B-org': 765,
#  'id:Tim::B-per': 766,
#  'id:Harcourt::I-per': 767,
#  'id:chief::O': 768,
#  'id:economist::O': 769,
#  'id:Australian::B-org': 770,
#  'id:Commission::I-org': 771,
#  'id:plays::O': 772,
#  'id:important::O': 773,
#  'id:role::O': 774,
#  'id:informing::O': 775,
#  'id:governments::O': 776,
#  'id:problems::O': 777,
#  'id:most::O': 778,
#  'id:thing::O': 779,
#  'id:business::O': 780,
#  'id:do::O': 781,
#  'id:tell::O': 782,
#  'id:logjams::O': 783,
#  'id:obstacles::O': 784,
#  'id:things::O': 785,
#  'id:improve::O': 786,
#  'id:Harcourt::B-per': 787,
#  'id:I::O': 788,
#  'id:think::O': 789,
#  'id:actually::O': 790,
#  'id:played::O': 791,
#  'id:pretty::O': 792,
#  'id:good::O': 793,
#  'id:leadership::O': 794,
#  'id:talking::O': 795,
#  'id:about::O': 796,
#  'id:trade::O': 797,
#  'id:facilitation::O': 798,
#  'id:basically::O': 799,
#  'id:standards::O': 800,
#  'id:consistent::O': 801,
#  'id:harmonious::O': 802,
#  'id:across::O': 803,
#  'id:comprises::O': 804,
#  'id:private::O': 805,
#  'id:sector::O': 806,
#  'id:each::O': 807,
#  'id:21::O': 808,
#  'id:economies::O': 809,
#  'id:meets::O': 810,
#  'id:times::O': 811,
#  'id:made::O': 812,
#  'id:permanent::O': 813,
#  'id:body::O': 814,
#  'id:1995::B-tim': 815,
#  'id:perspective::O': 816,
#  'id:within::O': 817,
#  'id:Members::O': 818,
#  'id:represent::O': 819,
#  'id:range::O': 820,
#  'id:sectors::O': 821,
#  'id:medium::O': 822,
#  'id:businesses::O': 823,
#  'id:need::O': 824,
#  'id:energy::O': 825,
#  'id:efficiency::O': 826,
#  'id:encourage::O': 827,
#  'id:conservation::O': 828,
#  'id:practices::O': 829,
#  'id:discuss::O': 830,
#  'id:ways::O': 831,
#  'id:enhance::O': 832,
#  'id:regional::O': 833,
#  'id:cooperation::O': 834,
#  'id:reckon::O': 835,
#  "id:'ll::O": 836,
#  'id:talk::O': 837,
#  'id:little::O': 838,
#  'id:bit::O': 839,
#  'id:customs::O': 840,
#  'id:quarantine::O': 841,
#  'id:having::O': 842,
#  'id:arrangements::O': 843,
#  'id:around::O': 844,
#  'id:And::O': 845,
#  'id:want::O': 846,
#  'id:one-stop::O': 847,
#  'id:shop::O': 848,
#  'id:terms::O': 849,
#  'id:combining::O': 850,
#  'id:immigration::O': 851,
#  'id:together::O': 852,
#  'id:\x85::O': 853,
#  'id:just::O': 854,
#  'id:streamlined::O': 855,
#  'id:provides::O': 856,
#  'id:certainty::O': 857,
#  'id:non-governmental::O': 858,
#  'id:formal::O': 859,
#  'id:dialogue::O': 860,
#  'id:present::O': 861,
#  'id:meeting::O': 862,
#  'id:Sudan::B-gpe': 863,
#  'id:order::O': 864,
#  'id:Darfur::B-geo': 865,
#  'id:asking::O': 866,
#  'id:same::O': 867,
#  'id:Foreign::B-per': 868,
#  'id:Minister::I-per': 869,
#  'id:Mustafa::I-per': 870,
#  'id:Osman::I-per': 871,
#  'id:Ismail::I-per': 872,
#  'id:Sudanese::B-gpe': 873,
#  'id:withdraw::O': 874,
#  'id:positions::O': 875,
#  'id:held::O': 876,
#  'id:April::B-tim': 877,
#  'id:cease-fire::O': 878,
#  'id:western::O': 879,
#  'id:agree::O': 880,
#  'id:stop::O': 881,
#  'id:Mr.::B-per': 882,
#  'id:announced::O': 883,
#  'id:decision::O': 884,
#  'id:United::B-org': 885,
#  'id:Nations::I-org': 886,
#  'id:African::B-org': 887,
#  'id:Khartoum::B-geo': 888,
#  'id:weeks::O': 889,
#  'id:AU::B-org': 890,
#  'id:repeatedly::O': 891,
#  'id:truce::O': 892,
#  'init_tag:B-tim': 893,
#  'id:head::O': 894,
#  'id:accused::O': 895,
#  'id:helicopters::O': 896,
#  'id:bombing::O': 897,
#  'id:rebel::O': 898,
#  'id:sites::O': 899,
#  'id:Darfur::I-geo': 900,
#  'id:village::O': 901,
#  'id:Labado::B-geo': 902,
#  'id:Khartoum::B-gpe': 903,
#  'id:defending::O': 904,
#  'id:Aid::O': 905,
#  'id:relief::O': 906,
#  'id:efforts::O': 907,
#  'id:suspended::O': 908,
#  'id:due::O': 909,
#  'id:Indonesian::B-gpe': 910,
#  'id:men::O': 911,
#  'id:connection::O': 912,
#  'id:October::B-tim': 913,
#  'id:1::I-tim': 914,
#  'id:Bali::B-geo': 915,
#  'prev_tag:I-tim::B-geo': 916,
#  'id:left::O': 917,
#  'id:23::O': 918,
#  'id:dead::O': 919,
#  'id:flown::O': 920,
#  'id:Java::B-geo': 921,
#  'id:island::O': 922,
#  'id:headquarters::O': 923,
#  'id:Australian::B-gpe': 924,
#  'id:French::B-gpe': 925,
#  'id:agencies::O': 926,
#  'id:(::O': 927,
#  'id:Cholily::B-per': 928,
#  'id:)::O': 929,
#  'id:captured::O': 930,
#  'id:series::O': 931,
#  'id:counter-terrorism::O': 932,
#  'id:raids::O': 933,
#  'id:Indonesia::B-geo': 934,
#  'id:ended::O': 935,
#  'id:death::O': 936,
#  'id:alleged::O': 937,
#  'id:extremist::O': 938,
#  'id:bombmaker::O': 939,
#  'id:Azahari::B-per': 940,
#  'id:bin::I-per': 941,
#  'id:Husin::I-per': 942,
#  'id:authorities::O': 943,
#  'id:blame::O': 944,
#  'id:orchestrating::O': 945,
#  'id:month::O': 946,
#  'id:well::O': 947,
#  'id:2002::B-tim': 948,
#  'prev_tag:B-tim::B-geo': 949,
#  'id:Gunmen::O': 950,
#  'id:shot::O': 951,
#  'id:Roman::B-org': 952,
#  'id:Catholic::I-org': 953,
#  'id:nun::O': 954,
#  'id:her::O': 955,
#  'id:bodyguard::O': 956,
#  'id:hospital::O': 957,
#  'id:she::O': 958,
#  'id:worked::O': 959,
#  'id:Islamist-controlled::O': 960,
#  'id:Some::O': 961,
#  'id:witnesses::O': 962,
#  'id:shooting::O': 963,
#  'id:feared::O': 964,
#  'id:linked::O': 965,
#  'id:Muslim::O': 966,
#  'id:anger::O': 967,
#  'id:toward::O': 968,
#  'id:Pope::B-per': 969,
#  'id:Benedict::I-per': 970,
#  'id:pistols::O': 971,
#  'id:attacked::O': 972,
#  'id:Sister::B-per': 973,
#  'id:Leonella::I-per': 974,
#  'id:Sgorbati::I-per': 975,
#  'id:finished::O': 976,
#  'id:teaching::O': 977,
#  'id:medical::O': 978,
#  'id:school::O': 979,
#  'id:class::O': 980,
#  'id:suspect::O': 981,
#  'id:Vatican::B-org': 982,
#  'id:deplored::O': 983,
#  'id:hoped::O': 984,
#  'id:isolated::O': 985,
#  'id:event::O': 986,
#  'id:irrationality::O': 987,
#  'id:arising::O': 988,
#  'id:comments::O': 989,
#  'id:Pope::O': 990,
#  'id:angered::O': 991,
#  'id:Muslims::O': 992,
#  'id:Authorities::O': 993,
#  'id:determined::O': 994,
#  'id:motive::O': 995,
#  'id:pope::O': 996,
#  'id:meant::O': 997,
#  'id:offense::O': 998,
#  'id:quoted::O': 999,
#  ...}

# %%
[x for x in list(ex_feature_mapper.feature_dict.keys()) if 'hyphen' in x]
# Out:
# ['hyphen::O',
#  'hyphen::B-geo',
#  'hyphen::B-gpe',
#  'hyphen::B-per',
#  'hyphen::I-geo',
#  'hyphen::B-org',
#  'hyphen::I-org',
#  'hyphen::B-tim',
#  'hyphen::B-art',
#  'hyphen::I-art',
#  'hyphen::I-per',
#  'hyphen::I-gpe',
#  'hyphen::I-tim',
#  'hyphen::B-nat',
#  'hyphen::B-eve',
#  'hyphen::I-eve',
#  'hyphen::I-nat']

# %% [markdown]
# #### Training structured perceptron

# %%
corpus = skseq.readers.pos_corpus.PostagCorpus()
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)

# %%
sp.get_num_states(), sp.get_num_observations()
# Out:
# (17, 30863)

# %%
# %%time
num_epochs = 15
sp.fit(ex_feature_mapper.dataset, num_epochs)
# Out:
# Epoch: 0 Accuracy: 0.893649
# Epoch: 1 Accuracy: 0.932477
# Epoch: 2 Accuracy: 0.941703
# Epoch: 3 Accuracy: 0.947204
# Epoch: 4 Accuracy: 0.950647
# Epoch: 5 Accuracy: 0.953267
# Epoch: 6 Accuracy: 0.955126
# Epoch: 7 Accuracy: 0.956926
# Epoch: 8 Accuracy: 0.957718
# Epoch: 9 Accuracy: 0.959740
# Epoch: 10 Accuracy: 0.960284
# Epoch: 11 Accuracy: 0.960919
# Epoch: 12 Accuracy: 0.961542
# Epoch: 13 Accuracy: 0.962344
# Epoch: 14 Accuracy: 0.962593
# Wall time: 1h 6min 44s

# %%
# sp.save_model("perceptron_ex2")

# %%
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)
sp.load_model(dir="perceptron_ex2")

# %% [markdown]
# #### Testing

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

y_pred_2 = []
y_true = [item for x in Y_ids_test for item in x]
correct_sentences = 0
n_test = len(X_test)

for i in range(n_test):
    y_pred_aux = sp.predict_tags_given_words(X_test[i])
    y_pred_2.append(y_pred_aux)
    if list(y_pred_aux) == Y_ids_test[i]:
        correct_sentences += 1
    
y_pred = [item for x in y_pred_2 for item in x]
F1_score_multi = f1_score(y_true, y_pred, average=None)
Accuracy = accuracy_score(y_true, y_pred)
print('Accuracy for test is: ' + str(Accuracy))
print('F1-Score for test is: ' + str(np.mean(F1_score_multi)))
print('Correct sentences for test (%) : ' + str(correct_sentences/n_test))
# Out:
# Accuracy for test is: 0.950487028495657
# F1-Score for test is: 0.6293839019546097
# Correct sentences for test (%) : 0.48373373373373374

# %%
ax = plot_confusion_matrix(y_true, y_pred, classes=list(sp.state_labels),
                      title='Confusion matrix')

# %% [markdown]
# #### SENTENCES TO TEST THE MODEL

# %% [markdown]
# We think that these are the tags that the model should obtain:
#
# 1. The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 2. The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 3. Jack/B-per London/I-per went/O to/O Parris./O
#
# 4. Jack/B-per London/I-per went/O to/O/O Paris./B-geo
#
# 5. We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
#
# 6. We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
#
# 7. The/O president/O of/O U.S.A/B-geo though/O they/O could/O win/O the/O war/O
#
# 8. The/O president/O of/O the/O United/B-geo States/B-geo of/B-geo America/B-geo though/O they/O could/O win/O the/O war/O
#
# 9. The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
#
# 10. Robin/B-per does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
for sentence in test_sentences:
    new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
    print(sp.viterbi_decode(new_seq)[0].to_words(sequence_list_train, only_tag_translation=True))
# Out:
# The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/B-per checker./I-per
# The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/B-per checker./I-per
# Jack/B-per London/B-geo went/O to/O Parris./O
# Jack/B-per London/B-geo went/O to/O Paris./O
# We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
# We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
# The/O president/O of/O U.S.A/B-org though/O they/O could/O win/O the/O war/O
# The/O president/O of/O the/O United/B-geo States/I-geo of/I-geo America/I-geo though/O they/O could/O win/O the/O war/O
# The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
# Robin/B-org does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
# Here we can select the sentence in which we want to compare the true and the predicted tags
# Select a sentence between 1 and 10
i=1
sentence = test_sentences[i-1]
new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(sentence.split(), test_tags[i-1], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# The             (O    ): O
# programmers     (O    ): O
# from            (O    ): O
# Barcelona       (B-geo): B-geo
# might           (O    ): O
# write           (O    ): O
# a               (O    ): O
# sentence        (O    ): O
# without         (O    ): O
# a               (O    ): O
# spell           (O    ): B-per
# checker.        (O    ): I-per

# %% [markdown]
# #### Hyphen checking

# %%
new_seq = Sequence(x=X_test[0], y=[int(0) for w in X_test[0]])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(X_test[0], Y_test[0], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# Officials       (O    ): O
# said            (O    ): O
# Sunday          (B-tim): B-tim
# Jean            (B-per): B-geo
# Rene            (I-per): O
# Anthony         (I-per): B-gpe
# was             (O    ): O
# killed          (O    ): B-gpe
# in              (O    ): O
# a               (O    ): O
# shootout        (O    ): B-gpe
# with            (O    ): O
# police          (O    ): B-gpe
# near            (O    ): O
# the             (O    ): O
# capital         (O    ): B-gpe
# city            (O    ): O
# of              (O    ): O
# Port-au-Prince  (B-geo): B-geo
# .               (O    ): O

# %% [markdown]
# ##### Post-comments:
#
# As we can see we have fixed the error with the word Port-au-Prince. Now, we are going to fix the problem with capital letter at the begging. For example, when we have Jean Rene Anthony it does not recognize it as person. We are going to add in the next experiment a new feature with a capital letter at the beggining.

# %% [markdown]
# # EXPERIMENT 3: Adding a capital letter at the beggining

# %% [markdown]
# ##### Comments:
#
# Adding a **capital letter at the beggining** feature (without the point at the end) + Hyphen feature

# %% [markdown]
# ### Extended features

# %%
ex_feature_mapper = skseq.sequences.extended_feature.ExtendedFeatures(sequence_list_train) 
ex_feature_mapper.build_features()
pprint.pprint(list(ex_feature_mapper.__dict__.keys()))
# Out:
# ['feature_dict',
#  'feature_list',
#  'add_features',
#  'dataset',
#  'node_feature_cache',
#  'initial_state_feature_cache',
#  'final_state_feature_cache',
#  'edge_feature_cache']

# %%
len(ex_feature_mapper.feature_dict)
# Out:
# 38330

# %%
ex_feature_mapper.feature_dict
# Out:
# {'init_tag:O': 0,
#  'id:Thousands::O': 1,
#  'upper_ini::O': 2,
#  'id:of::O': 3,
#  'prev_tag:O::O': 4,
#  'id:demonstrators::O': 5,
#  'id:have::O': 6,
#  'id:marched::O': 7,
#  'id:through::O': 8,
#  'id:London::B-geo': 9,
#  'upper_ini::B-geo': 10,
#  'prev_tag:O::B-geo': 11,
#  'id:to::O': 12,
#  'prev_tag:B-geo::O': 13,
#  'id:protest::O': 14,
#  'id:the::O': 15,
#  'id:war::O': 16,
#  'id:in::O': 17,
#  'id:Iraq::B-geo': 18,
#  'id:and::O': 19,
#  'id:demand::O': 20,
#  'id:withdrawal::O': 21,
#  'id:British::B-gpe': 22,
#  'upper_ini::B-gpe': 23,
#  'prev_tag:O::B-gpe': 24,
#  'id:troops::O': 25,
#  'prev_tag:B-gpe::O': 26,
#  'id:from::O': 27,
#  'id:that::O': 28,
#  'id:country::O': 29,
#  'id:.::O': 30,
#  'final_prev_tag:O': 31,
#  'id:Families::O': 32,
#  'id:soldiers::O': 33,
#  'id:killed::O': 34,
#  'id:conflict::O': 35,
#  'id:joined::O': 36,
#  'id:protesters::O': 37,
#  'id:who::O': 38,
#  'id:carried::O': 39,
#  'id:banners::O': 40,
#  'id:with::O': 41,
#  'id:such::O': 42,
#  'id:slogans::O': 43,
#  'id:as::O': 44,
#  'id:"::O': 45,
#  'id:Bush::B-per': 46,
#  'upper_ini::B-per': 47,
#  'prev_tag:O::B-per': 48,
#  'id:Number::O': 49,
#  'prev_tag:B-per::O': 50,
#  'id:One::O': 51,
#  'id:Terrorist::O': 52,
#  'id:Stop::O': 53,
#  'id:Bombings::O': 54,
#  'id:They::O': 55,
#  'id:Houses::O': 56,
#  'id:Parliament::O': 57,
#  'id:a::O': 58,
#  'id:rally::O': 59,
#  'id:Hyde::B-geo': 60,
#  'id:Park::I-geo': 61,
#  'upper_ini::I-geo': 62,
#  'prev_tag:B-geo::I-geo': 63,
#  'prev_tag:I-geo::O': 64,
#  'id:Police::O': 65,
#  'id:put::O': 66,
#  'id:number::O': 67,
#  'id:marchers::O': 68,
#  'id:at::O': 69,
#  'id:10,000::O': 70,
#  'id:while::O': 71,
#  'id:organizers::O': 72,
#  'id:claimed::O': 73,
#  'id:it::O': 74,
#  'id:was::O': 75,
#  'id:1,00,000::O': 76,
#  'id:The::O': 77,
#  'id:comes::O': 78,
#  'id:on::O': 79,
#  'id:eve::O': 80,
#  'id:annual::O': 81,
#  'id:conference::O': 82,
#  'id:Britain::B-geo': 83,
#  "id:'s::O": 84,
#  'id:ruling::O': 85,
#  'id:Labor::B-org': 86,
#  'upper_ini::B-org': 87,
#  'prev_tag:O::B-org': 88,
#  'id:Party::I-org': 89,
#  'upper_ini::I-org': 90,
#  'prev_tag:B-org::I-org': 91,
#  'prev_tag:I-org::O': 92,
#  'id:southern::O': 93,
#  'id:English::B-gpe': 94,
#  'id:seaside::O': 95,
#  'id:resort::O': 96,
#  'id:Brighton::B-geo': 97,
#  'id:party::O': 98,
#  'id:is::O': 99,
#  'id:divided::O': 100,
#  'id:over::O': 101,
#  'id:Britain::B-gpe': 102,
#  'id:participation::O': 103,
#  'id:continued::O': 104,
#  'id:deployment::O': 105,
#  'id:8,500::O': 106,
#  'id:march::O': 107,
#  'id:came::O': 108,
#  'id:ahead::O': 109,
#  'id:anti-war::O': 110,
#  'hyphen::O': 111,
#  'id:protests::O': 112,
#  'id:today::O': 113,
#  'id:other::O': 114,
#  'id:cities::O': 115,
#  'id:,::O': 116,
#  'id:including::O': 117,
#  'id:Rome::B-geo': 118,
#  'id:Paris::B-geo': 119,
#  'id:Madrid::B-geo': 120,
#  'id:International::B-org': 121,
#  'id:Atomic::I-org': 122,
#  'id:Energy::I-org': 123,
#  'prev_tag:I-org::I-org': 124,
#  'id:Agency::I-org': 125,
#  'id:hold::O': 126,
#  'id:second::O': 127,
#  'id:day::O': 128,
#  'id:talks::O': 129,
#  'id:Vienna::B-geo': 130,
#  'id:Wednesday::B-tim': 131,
#  'upper_ini::B-tim': 132,
#  'prev_tag:B-geo::B-tim': 133,
#  'prev_tag:B-tim::O': 134,
#  'id:how::O': 135,
#  'id:respond::O': 136,
#  'id:Iran::B-gpe': 137,
#  'id:resumption::O': 138,
#  'id:low-level::O': 139,
#  'id:uranium::O': 140,
#  'id:conversion::O': 141,
#  'init_tag:B-gpe': 142,
#  'id:this::O': 143,
#  'id:week::O': 144,
#  'id:restarted::O': 145,
#  'id:parts::O': 146,
#  'id:process::O': 147,
#  'id:its::O': 148,
#  'id:Isfahan::B-geo': 149,
#  'id:nuclear::O': 150,
#  'id:plant::O': 151,
#  'id:Iranian::B-gpe': 152,
#  'id:officials::O': 153,
#  'id:say::O': 154,
#  'id:they::O': 155,
#  'id:expect::O': 156,
#  'id:get::O': 157,
#  'id:access::O': 158,
#  'id:sealed::O': 159,
#  'id:sensitive::O': 160,
#  'prev_tag:O::B-tim': 161,
#  'id:after::O': 162,
#  'id:an::O': 163,
#  'id:IAEA::B-org': 164,
#  'id:surveillance::O': 165,
#  'prev_tag:B-org::O': 166,
#  'id:system::O': 167,
#  'id:begins::O': 168,
#  'id:functioning::O': 169,
#  'id:step::O': 170,
#  'id:will::O': 171,
#  'id:allow::O': 172,
#  'id:facility::O': 173,
#  'id:operate::O': 174,
#  'id:full::O': 175,
#  'id:capacity::O': 176,
#  'id:European::B-org': 177,
#  'id:Union::I-org': 178,
#  'id:U.S.::B-gpe': 179,
#  'id:backing::O': 180,
#  'id:has::O': 181,
#  'id:threatened::O': 182,
#  'id:refer::O': 183,
#  'id:U.N.::B-org': 184,
#  'id:Security::I-org': 185,
#  'id:Council::I-org': 186,
#  'id:which::O': 187,
#  'id:could::O': 188,
#  'id:impose::O': 189,
#  'id:sanctions::O': 190,
#  'id:if::O': 191,
#  'id:finds::O': 192,
#  'id:Tehran::B-gpe': 193,
#  'id:violated::O': 194,
#  'id:Nuclear::B-art': 195,
#  'upper_ini::B-art': 196,
#  'prev_tag:O::B-art': 197,
#  'id:Non-Proliferation::I-art': 198,
#  'hyphen::I-art': 199,
#  'upper_ini::I-art': 200,
#  'prev_tag:B-art::I-art': 201,
#  'id:treaty::O': 202,
#  'prev_tag:I-art::O': 203,
#  'id:new::O': 204,
#  'id:President::B-per': 205,
#  'id:Mahmoud::I-per': 206,
#  'upper_ini::I-per': 207,
#  'prev_tag:B-per::I-per': 208,
#  'id:Ahmadinejad::I-per': 209,
#  'prev_tag:I-per::I-per': 210,
#  'id:said::O': 211,
#  'prev_tag:I-per::O': 212,
#  'id:Tuesday::B-tim': 213,
#  'id:European::B-gpe': 214,
#  'id:incentives::O': 215,
#  'id:aimed::O': 216,
#  'id:persuading::O': 217,
#  'id:end::O': 218,
#  'id:fuel::O': 219,
#  'id:program::O': 220,
#  'id:are::O': 221,
#  'id:insult::O': 222,
#  'id:nation::O': 223,
#  'id:Two::O': 224,
#  'id:Germans::B-gpe': 225,
#  'id:four::O': 226,
#  'id:Nigerian::B-gpe': 227,
#  'id:oil::O': 228,
#  'id:workers::O': 229,
#  'id:were::O': 230,
#  'id:kidnapped::O': 231,
#  'id:by::O': 232,
#  'id:armed::O': 233,
#  'id:militants::O': 234,
#  'id:during::O': 235,
#  'id:raid::O': 236,
#  'id:boat::O': 237,
#  'id:Nigeria::B-geo': 238,
#  'id:oil-rich::O': 239,
#  'id:Delta::B-geo': 240,
#  'id:region::O': 241,
#  'id:An::O': 242,
#  'id:official::O': 243,
#  'id:German::B-gpe': 244,
#  'id:firm::O': 245,
#  'id:Bilfinger::B-org': 246,
#  'id:Berger::I-org': 247,
#  'id:Thomas::B-per': 248,
#  'id:Horbach::I-per': 249,
#  'id:gunmen::O': 250,
#  'id:stopped::O': 251,
#  'id:supply::O': 252,
#  'id:sailed::O': 253,
#  'id:State::I-geo': 254,
#  'id:Bayelsa::B-geo': 255,
#  'id:inspect::O': 256,
#  'id:offshore::O': 257,
#  'id:field::O': 258,
#  'id:owned::O': 259,
#  'id:Royal-Dutch::B-org': 260,
#  'hyphen::B-org': 261,
#  'id:Shell::I-org': 262,
#  'id:works::O': 263,
#  'id:sub-contractor::O': 264,
#  'id:for::O': 265,
#  'id:Shell::B-org': 266,
#  'id:Militant::O': 267,
#  'id:groups::O': 268,
#  'id:frequently::O': 269,
#  'id:attack::O': 270,
#  'id:operations::O': 271,
#  'id:Niger::B-geo': 272,
#  'id:Delta::I-geo': 273,
#  'id:social::O': 274,
#  'id:services::O': 275,
#  'id:better::O': 276,
#  'id:job::O': 277,
#  'id:opportunities::O': 278,
#  'id:multinational::O': 279,
#  'id:companies::O': 280,
#  'id:Poor::O': 281,
#  'id:residents::O': 282,
#  'id:often::O': 283,
#  'id:complain::O': 284,
#  'id:been::O': 285,
#  'id:cheated::O': 286,
#  'id:out::O': 287,
#  'id:huge::O': 288,
#  'id:riches::O': 289,
#  'id:extracted::O': 290,
#  'id:their::O': 291,
#  'id:tribal::O': 292,
#  'id:lands::O': 293,
#  'id:-::O': 294,
#  'id:where::O': 295,
#  'id:bulk::O': 296,
#  'id:Nigeria::B-gpe': 297,
#  'id:2.3::O': 298,
#  'id:million::O': 299,
#  'id:barrels::O': 300,
#  'id:petroleum::O': 301,
#  'id:pumped::O': 302,
#  'id:daily::O': 303,
#  'id:Suspected::O': 304,
#  'id:Islamist::O': 305,
#  'id:rebels::O': 306,
#  'id:fired::O': 307,
#  'id:mortar::O': 308,
#  'id:shells::O': 309,
#  'id:palace::O': 310,
#  'id:used::O': 311,
#  'id:Somalia::B-geo': 312,
#  'id:interim::O': 313,
#  'id:Abdullahi::I-per': 314,
#  'id:Yusuf::I-per': 315,
#  'id:Ahmad::I-per': 316,
#  'id:It::O': 317,
#  'id:not::O': 318,
#  'id:immediately::O': 319,
#  'id:clear::O': 320,
#  'id:president::O': 321,
#  'id:Mogadishu::B-geo': 322,
#  'id:when::O': 323,
#  'id:occurred::O': 324,
#  'id:or::O': 325,
#  'id:anyone::O': 326,
#  'id:hurt::O': 327,
#  'id:Local::O': 328,
#  'id:news::O': 329,
#  'id:reports::O': 330,
#  'id:least::O': 331,
#  'id:five::O': 332,
#  'id:hit::O': 333,
#  'id:compound::O': 334,
#  'id:mortars::O': 335,
#  'id:elsewhere::O': 336,
#  'id:attacks::O': 337,
#  'id:government::O': 338,
#  'id:go::O': 339,
#  'id:reconciliation::O': 340,
#  'id:more::O': 341,
#  'id:than::O': 342,
#  'id:1,300::O': 343,
#  'id:Somali::B-gpe': 344,
#  'id:elders::O': 345,
#  'id:warlords::O': 346,
#  'id:politicians::O': 347,
#  'id:invited::O': 348,
#  'id:Iraqi::B-gpe': 349,
#  'id:military::O': 350,
#  'id:tanks::O': 351,
#  'id:arrived::O': 352,
#  'id:northern::O': 353,
#  'id:city::O': 354,
#  'id:Mosul::B-geo': 355,
#  'id:offensive::O': 356,
#  'id:against::O': 357,
#  'id:al::B-org': 358,
#  'id:Qaida::I-org': 359,
#  'id:in::I-org': 360,
#  'id:Iraq::I-org': 361,
#  'id:fighters::O': 362,
#  'id:Officials::O': 363,
#  'id:many::O': 364,
#  'id:Sunni::B-geo': 365,
#  'id:Arab::I-geo': 366,
#  'id:Kurdish::B-geo': 367,
#  'id:bombings::O': 368,
#  'id:last::O': 369,
#  'id:34::O': 370,
#  'id:people::O': 371,
#  'id:wounded::O': 372,
#  'id:200::O': 373,
#  'id:commanders::O': 374,
#  'id:explained::O': 375,
#  'id:American::B-gpe': 376,
#  'id:forces::O': 377,
#  'id:participate::O': 378,
#  'id:fled::O': 379,
#  'id:successful::O': 380,
#  'id:campaigns::O': 381,
#  'id:them::O': 382,
#  'id:Anbar::B-geo': 383,
#  'id:province::O': 384,
#  'id:Baghdad::B-geo': 385,
#  'id:provinces::O': 386,
#  'init_tag:B-geo': 387,
#  'id:largest::O': 388,
#  'id:north::O': 389,
#  'id:long::O': 390,
#  'id:stronghold::O': 391,
#  'id:Sunni::B-org': 392,
#  'id:militant::O': 393,
#  'id:In::O': 394,
#  'id:violence::O': 395,
#  'id:one::O': 396,
#  'id:soldier::O': 397,
#  'id:patrol::O': 398,
#  'id:Sunday::B-tim': 399,
#  'id:Egyptian::B-gpe': 400,
#  'id:police::O': 401,
#  'id:arrested::O': 402,
#  'id:16::O': 403,
#  'id:members::O': 404,
#  'id:opposition::O': 405,
#  'id:Muslim::B-org': 406,
#  'id:Brotherhood::I-org': 407,
#  'id:prepare::O': 408,
#  'id:parliamentary::O': 409,
#  'id:runoff::O': 410,
#  'id:elections::O': 411,
#  'id:Saturday::B-tim': 412,
#  'id:arrests::O': 413,
#  'id:Friday::B-tim': 414,
#  'id:Alexandria::B-geo': 415,
#  'id:A::O': 416,
#  'id:spokesman::O': 417,
#  'id:Brotherhood::B-org': 418,
#  'id:attempt::O': 419,
#  'id:cut::O': 420,
#  'id:off::O': 421,
#  'id:supporters::O': 422,
#  'id:punishment::O': 423,
#  'id:winning::O': 424,
#  'id:seats::O': 425,
#  'id:earlier::O': 426,
#  'id:tripled::O': 427,
#  'id:strength::O': 428,
#  'id:parliament::O': 429,
#  'id:recent::O': 430,
#  'id:raising::O': 431,
#  'id:total::O': 432,
#  'id:47::O': 433,
#  'id:voters::O': 434,
#  'id:cast::O': 435,
#  'id:ballots::O': 436,
#  'id:nine::O': 437,
#  'id:no::O': 438,
#  'id:candidate::O': 439,
#  'id:won::O': 440,
#  'id:majority::O': 441,
#  'id:previous::O': 442,
#  'id:round::O': 443,
#  'id:voting::O': 444,
#  'id:banned::O': 445,
#  'id:political::O': 446,
#  'id:but::O': 447,
#  'id:endorses::O': 448,
#  'id:so-called::O': 449,
#  'id:independent::O': 450,
#  'id:candidates::O': 451,
#  'id:whose::O': 452,
#  'id:allegiance::O': 453,
#  'id:known::O': 454,
#  'id:Hardline::O': 455,
#  'id:lawmakers::O': 456,
#  'id:Pakistan::B-geo': 457,
#  'id:North::B-geo': 458,
#  'id:West::I-geo': 459,
#  'id:Frontier::I-geo': 460,
#  'prev_tag:I-geo::I-geo': 461,
#  'id:Province::I-geo': 462,
#  'id:pushed::O': 463,
#  'id:law::O': 464,
#  'id:aims::O': 465,
#  'id:ensure::O': 466,
#  'id:Islamic::O': 467,
#  'id:correctness::O': 468,
#  'id:public::O': 469,
#  'id:places::O': 470,
#  'id:establishes::O': 471,
#  'id:morality::O': 472,
#  'id:enforce::O': 473,
#  'id:decent::O': 474,
#  'id:behavior::O': 475,
#  'id:six-party::O': 476,
#  'id:coalition::O': 477,
#  'id:religious::O': 478,
#  'id:based::O': 479,
#  'id:parties::O': 480,
#  'id:Mutahida::B-org': 481,
#  'id:Majlis-e-Amal::I-org': 482,
#  'hyphen::I-org': 483,
#  'id:dominates::O': 484,
#  'id:provincial::O': 485,
#  'id:assembly::O': 486,
#  'id:so::O': 487,
#  'id:bill::O': 488,
#  'id:easily::O': 489,
#  'id:passed::O': 490,
#  'id:Thursday::B-tim': 491,
#  'id:vote::O': 492,
#  'id:68-34::O': 493,
#  'id:governor::O': 494,
#  'id:must::O': 495,
#  'id:still::O': 496,
#  'id:sign::O': 497,
#  'id:before::O': 498,
#  'id:becomes::O': 499,
#  'id:seen::O': 500,
#  'id:only::O': 501,
#  'id:formality::O': 502,
#  'id:proposed::O': 503,
#  'id:calls::O': 504,
#  'id:setting::O': 505,
#  'id:up::O': 506,
#  'id:force::O': 507,
#  'id:make::O': 508,
#  'id:sure::O': 509,
#  'id:adhere::O': 510,
#  'id:values::O': 511,
#  'id:entertainment::O': 512,
#  'id:outlets::O': 513,
#  'id:close::O': 514,
#  'id:weekly::O': 515,
#  'id:prayers::O': 516,
#  'id:Violators::O': 517,
#  'id:be::O': 518,
#  'id:jailed::O': 519,
#  'id:six::O': 520,
#  'id:months::O': 521,
#  'id:denounced::O': 522,
#  'id:measure::O': 523,
#  'id:comparing::O': 524,
#  'id:draconian::O': 525,
#  'id:rule::O': 526,
#  'id:former::O': 527,
#  'id:Taleban::B-org': 528,
#  'id:neighboring::O': 529,
#  'id:Afghanistan::B-geo': 530,
#  'id:man::O': 531,
#  'id:dressed::O': 532,
#  'id:suicide::O': 533,
#  'id:bomber::O': 534,
#  'id:demonstration::O': 535,
#  'id:publication::O': 536,
#  'id:cartoons::O': 537,
#  'id:depicting::O': 538,
#  'id:Islam::B-org': 539,
#  'id:Prophet::B-per': 540,
#  'id:Muhammad::I-per': 541,
#  'id:Bedfordshire::B-gpe': 542,
#  'id:Omar::B-per': 543,
#  'id:Khayam::I-per': 544,
#  'id:Bedford::B-geo': 545,
#  'id:breaching::O': 546,
#  'id:conditions::O': 547,
#  'id:his::O': 548,
#  'id:parole::O': 549,
#  'id:British::B-org': 550,
#  'id:Home::I-org': 551,
#  'id:Office::I-org': 552,
#  'id:sought::O': 553,
#  'id:investigation::O': 554,
#  'id:Khayam::B-per': 555,
#  'id:he::O': 556,
#  'id:photographed::O': 557,
#  'id:fatigues::O': 558,
#  'id:black::O': 559,
#  'id:cap::O': 560,
#  'id:bulky::O': 561,
#  'id:belt::O': 562,
#  'id:Home::B-org': 563,
#  'id:told::O': 564,
#  'id:Associated::B-org': 565,
#  'id:Press::I-org': 566,
#  'id:paroled::O': 567,
#  'id:offender::O': 568,
#  'id:gives::O': 569,
#  'id:cause::O': 570,
#  'id:concern::O': 571,
#  'id:can::O': 572,
#  'id:sent::O': 573,
#  'id:back::O': 574,
#  'id:prison::O': 575,
#  'id:AP::B-org': 576,
#  'id:also::O': 577,
#  'id:since::O': 578,
#  'id:year::O': 579,
#  'id:serving::O': 580,
#  'id:half::O': 581,
#  'id:six-year::O': 582,
#  'id:sentence::O': 583,
#  'id:drug::O': 584,
#  'id:dealing::O': 585,
#  'id:Pakistani::B-gpe': 586,
#  'id:unidentified::O': 587,
#  'id:three::O': 588,
#  'id:minister::O': 589,
#  'id:semi-autonomous::O': 590,
#  'id:bordering::O': 591,
#  'id:prominent::O': 592,
#  'id:leader::O': 593,
#  'id:Malik::B-per': 594,
#  'id:Faridullah::I-per': 595,
#  'id:Khan::I-per': 596,
#  'id:traveling::O': 597,
#  'id:South::B-geo': 598,
#  'id:Waziristan::I-geo': 599,
#  'prev_tag:I-geo::B-tim': 600,
#  'id:vehicle::O': 601,
#  'id:ambushed::O': 602,
#  'id:Kani::B-geo': 603,
#  'id:Wam::I-geo': 604,
#  'id:area::O': 605,
#  'id:His::O': 606,
#  'id:driver::O': 607,
#  'id:elder::O': 608,
#  'id:No::O': 609,
#  'id:responsibility::O': 610,
#  'id:killings::O': 611,
#  'id:ambush::O': 612,
#  'id:commander::O': 613,
#  'id:army::O': 614,
#  'id:almost::O': 615,
#  'id:completely::O': 616,
#  'id:eliminated::O': 617,
#  'id:became::O': 618,
#  'id:refuge::O': 619,
#  'id:al-Qaida::B-org': 620,
#  'id:ousted::O': 621,
#  'id:2001::B-tim': 622,
#  'id:senior::O': 623,
#  'id:says::O': 624,
#  'id:Pakistan::B-gpe': 625,
#  'id:wants::O': 626,
#  'id:what::O': 627,
#  'id:sordid::O': 628,
#  'id:chapter::O': 629,
#  'id:proliferation::O': 630,
#  'id:top::O': 631,
#  'id:scientists::O': 632,
#  'id:behind::O': 633,
#  'id:build::O': 634,
#  'id:civilian::O': 635,
#  'id:ties::O': 636,
#  'id:United::B-gpe': 637,
#  'id:States::I-gpe': 638,
#  'upper_ini::I-gpe': 639,
#  'prev_tag:B-gpe::I-gpe': 640,
#  'prev_tag:I-gpe::O': 641,
#  'id:But::O': 642,
#  'id:ready::O': 643,
#  'id:scientist::O': 644,
#  'id:Abdul::B-per': 645,
#  'id:Qadeer::I-per': 646,
#  'id:available::O': 647,
#  'id:direct::O': 648,
#  'id:questioning::O': 649,
#  'id:sale::O': 650,
#  'id:secrets::O': 651,
#  'id:states::O': 652,
#  'id:Libya::B-gpe': 653,
#  'id:North::B-gpe': 654,
#  'id:Korea::I-gpe': 655,
#  'id:He::O': 656,
#  'id:there::O': 657,
#  'id:reasons::O': 658,
#  'id:national::O': 659,
#  'id:sensitivities::O': 660,
#  'id:making::O': 661,
#  'id:him::O': 662,
#  'id:giving::O': 663,
#  'id:background::O': 664,
#  'id:briefing::O': 665,
#  'id:small::O': 666,
#  'id:group::O': 667,
#  'id:reporters::O': 668,
#  'id:Washington::B-geo': 669,
#  'init_tag:B-per': 670,
#  'id:Khan::B-per': 671,
#  'id:admitted::O': 672,
#  'id:2004::B-tim': 673,
#  'id:operated::O': 674,
#  'id:worldwide::O': 675,
#  'id:clandestine::O': 676,
#  'id:network::O': 677,
#  'id:sell::O': 678,
#  'id:technology::O': 679,
#  'id:market::O': 680,
#  'id:placed::O': 681,
#  'id:under::O': 682,
#  'id:house::O': 683,
#  'id:arrest::O': 684,
#  'id:Islamabad::B-geo': 685,
#  'id:because::O': 686,
#  'id:considered::O': 687,
#  'id:father::O': 688,
#  'id:bomb::O': 689,
#  'id:Army::B-org': 690,
#  'prev_tag:B-gpe::B-org': 691,
#  'id:renew::O': 692,
#  'id:controversial::O': 693,
#  'id:multi-billion::O': 694,
#  'id:dollar::O': 695,
#  'id:contract::O': 696,
#  'id:Halliburton::B-org': 697,
#  'id:company::O': 698,
#  'id:provide::O': 699,
#  'id:logistical::O': 700,
#  'id:support::O': 701,
#  'init_tag:B-org': 702,
#  'id:providing::O': 703,
#  'id:list::O': 704,
#  'id:meals::O': 705,
#  'id:communication::O': 706,
#  'id:several::O': 707,
#  'id:years::O': 708,
#  'id:Critics::O': 709,
#  'id:include::O': 710,
#  'id:auditors::O': 711,
#  'id:congressional::O': 712,
#  'id:Democrats::O': 713,
#  'id:produced::O': 714,
#  'id:some::O': 715,
#  'id:shoddy::O': 716,
#  'id:work::O': 717,
#  'id:charges::O': 718,
#  'id:too::O': 719,
#  'id:much::O': 720,
#  'id:money::O': 721,
#  'id:strongly::O': 722,
#  'id:denies::O': 723,
#  'id:allegations::O': 724,
#  'id:When::O': 725,
#  'id:re-bidding::O': 726,
#  'id:chance::O': 727,
#  'id:compete::O': 728,
#  'id:portions::O': 729,
#  'id:Representatives::O': 730,
#  'id:Asia::B-org': 731,
#  'id:Pacific::I-org': 732,
#  'id:Economic::I-org': 733,
#  'id:Cooperation::I-org': 734,
#  'id:Business::I-org': 735,
#  'id:Advisory::I-org': 736,
#  'id:holding::O': 737,
#  'id:meetings::O': 738,
#  'id:finalize::O': 739,
#  'id:report::O': 740,
#  'id:APEC::B-org': 741,
#  'id:leaders::O': 742,
#  'id:summit::O': 743,
#  'id:September::B-tim': 744,
#  'id:8::I-tim': 745,
#  'prev_tag:B-tim::I-tim': 746,
#  'prev_tag:I-tim::O': 747,
#  'id:9::B-tim': 748,
#  'id:VOA::B-org': 749,
#  'id:Nancy-Amelia::B-per': 750,
#  'hyphen::B-per': 751,
#  'id:Collins::I-per': 752,
#  'id:Sydney::B-geo': 753,
#  'id:Energy::O': 754,
#  'id:security::O': 755,
#  'id:climate::O': 756,
#  'id:change::O': 757,
#  'id:World::B-org': 758,
#  'id:Trade::I-org': 759,
#  'id:Organization::I-org': 760,
#  'id:stalled::O': 761,
#  'id:negotiations::O': 762,
#  'id:investment::O': 763,
#  'id:all::O': 764,
#  'id:expected::O': 765,
#  'id:among::O': 766,
#  'id:major::O': 767,
#  'id:topics::O': 768,
#  'id:ABAC::B-org': 769,
#  'id:Tim::B-per': 770,
#  'id:Harcourt::I-per': 771,
#  'id:chief::O': 772,
#  'id:economist::O': 773,
#  'id:Australian::B-org': 774,
#  'id:Commission::I-org': 775,
#  'id:plays::O': 776,
#  'id:important::O': 777,
#  'id:role::O': 778,
#  'id:informing::O': 779,
#  'id:governments::O': 780,
#  'id:problems::O': 781,
#  'id:most::O': 782,
#  'id:thing::O': 783,
#  'id:business::O': 784,
#  'id:do::O': 785,
#  'id:tell::O': 786,
#  'id:logjams::O': 787,
#  'id:obstacles::O': 788,
#  'id:things::O': 789,
#  'id:improve::O': 790,
#  'id:Harcourt::B-per': 791,
#  'id:I::O': 792,
#  'id:think::O': 793,
#  'id:actually::O': 794,
#  'id:played::O': 795,
#  'id:pretty::O': 796,
#  'id:good::O': 797,
#  'id:leadership::O': 798,
#  'id:talking::O': 799,
#  'id:about::O': 800,
#  'id:trade::O': 801,
#  'id:facilitation::O': 802,
#  'id:basically::O': 803,
#  'id:standards::O': 804,
#  'id:consistent::O': 805,
#  'id:harmonious::O': 806,
#  'id:across::O': 807,
#  'id:comprises::O': 808,
#  'id:private::O': 809,
#  'id:sector::O': 810,
#  'id:each::O': 811,
#  'id:21::O': 812,
#  'id:economies::O': 813,
#  'id:meets::O': 814,
#  'id:times::O': 815,
#  'id:made::O': 816,
#  'id:permanent::O': 817,
#  'id:body::O': 818,
#  'id:1995::B-tim': 819,
#  'id:perspective::O': 820,
#  'id:within::O': 821,
#  'id:Members::O': 822,
#  'id:represent::O': 823,
#  'id:range::O': 824,
#  'id:sectors::O': 825,
#  'id:medium::O': 826,
#  'id:businesses::O': 827,
#  'id:need::O': 828,
#  'id:energy::O': 829,
#  'id:efficiency::O': 830,
#  'id:encourage::O': 831,
#  'id:conservation::O': 832,
#  'id:practices::O': 833,
#  'id:discuss::O': 834,
#  'id:ways::O': 835,
#  'id:enhance::O': 836,
#  'id:regional::O': 837,
#  'id:cooperation::O': 838,
#  'id:reckon::O': 839,
#  "id:'ll::O": 840,
#  'id:talk::O': 841,
#  'id:little::O': 842,
#  'id:bit::O': 843,
#  'id:customs::O': 844,
#  'id:quarantine::O': 845,
#  'id:having::O': 846,
#  'id:arrangements::O': 847,
#  'id:around::O': 848,
#  'id:And::O': 849,
#  'id:want::O': 850,
#  'id:one-stop::O': 851,
#  'id:shop::O': 852,
#  'id:terms::O': 853,
#  'id:combining::O': 854,
#  'id:immigration::O': 855,
#  'id:together::O': 856,
#  'id:\x85::O': 857,
#  'id:just::O': 858,
#  'id:streamlined::O': 859,
#  'id:provides::O': 860,
#  'id:certainty::O': 861,
#  'id:non-governmental::O': 862,
#  'id:formal::O': 863,
#  'id:dialogue::O': 864,
#  'id:present::O': 865,
#  'id:meeting::O': 866,
#  'id:Sudan::B-gpe': 867,
#  'id:order::O': 868,
#  'id:Darfur::B-geo': 869,
#  'id:asking::O': 870,
#  'id:same::O': 871,
#  'id:Foreign::B-per': 872,
#  'id:Minister::I-per': 873,
#  'id:Mustafa::I-per': 874,
#  'id:Osman::I-per': 875,
#  'id:Ismail::I-per': 876,
#  'id:Sudanese::B-gpe': 877,
#  'id:withdraw::O': 878,
#  'id:positions::O': 879,
#  'id:held::O': 880,
#  'id:April::B-tim': 881,
#  'id:cease-fire::O': 882,
#  'id:western::O': 883,
#  'id:agree::O': 884,
#  'id:stop::O': 885,
#  'id:Mr.::B-per': 886,
#  'id:announced::O': 887,
#  'id:decision::O': 888,
#  'id:United::B-org': 889,
#  'id:Nations::I-org': 890,
#  'id:African::B-org': 891,
#  'id:Khartoum::B-geo': 892,
#  'id:weeks::O': 893,
#  'id:AU::B-org': 894,
#  'id:repeatedly::O': 895,
#  'id:truce::O': 896,
#  'init_tag:B-tim': 897,
#  'id:head::O': 898,
#  'id:accused::O': 899,
#  'id:helicopters::O': 900,
#  'id:bombing::O': 901,
#  'id:rebel::O': 902,
#  'id:sites::O': 903,
#  'id:Darfur::I-geo': 904,
#  'id:village::O': 905,
#  'id:Labado::B-geo': 906,
#  'id:Khartoum::B-gpe': 907,
#  'id:defending::O': 908,
#  'id:Aid::O': 909,
#  'id:relief::O': 910,
#  'id:efforts::O': 911,
#  'id:suspended::O': 912,
#  'id:due::O': 913,
#  'id:Indonesian::B-gpe': 914,
#  'id:men::O': 915,
#  'id:connection::O': 916,
#  'id:October::B-tim': 917,
#  'id:1::I-tim': 918,
#  'id:Bali::B-geo': 919,
#  'prev_tag:I-tim::B-geo': 920,
#  'id:left::O': 921,
#  'id:23::O': 922,
#  'id:dead::O': 923,
#  'id:flown::O': 924,
#  'id:Java::B-geo': 925,
#  'id:island::O': 926,
#  'id:headquarters::O': 927,
#  'id:Australian::B-gpe': 928,
#  'id:French::B-gpe': 929,
#  'id:agencies::O': 930,
#  'id:(::O': 931,
#  'id:Cholily::B-per': 932,
#  'id:)::O': 933,
#  'id:captured::O': 934,
#  'id:series::O': 935,
#  'id:counter-terrorism::O': 936,
#  'id:raids::O': 937,
#  'id:Indonesia::B-geo': 938,
#  'id:ended::O': 939,
#  'id:death::O': 940,
#  'id:alleged::O': 941,
#  'id:extremist::O': 942,
#  'id:bombmaker::O': 943,
#  'id:Azahari::B-per': 944,
#  'id:bin::I-per': 945,
#  'id:Husin::I-per': 946,
#  'id:authorities::O': 947,
#  'id:blame::O': 948,
#  'id:orchestrating::O': 949,
#  'id:month::O': 950,
#  'id:well::O': 951,
#  'id:2002::B-tim': 952,
#  'prev_tag:B-tim::B-geo': 953,
#  'id:Gunmen::O': 954,
#  'id:shot::O': 955,
#  'id:Roman::B-org': 956,
#  'id:Catholic::I-org': 957,
#  'id:nun::O': 958,
#  'id:her::O': 959,
#  'id:bodyguard::O': 960,
#  'id:hospital::O': 961,
#  'id:she::O': 962,
#  'id:worked::O': 963,
#  'id:Islamist-controlled::O': 964,
#  'id:Some::O': 965,
#  'id:witnesses::O': 966,
#  'id:shooting::O': 967,
#  'id:feared::O': 968,
#  'id:linked::O': 969,
#  'id:Muslim::O': 970,
#  'id:anger::O': 971,
#  'id:toward::O': 972,
#  'id:Pope::B-per': 973,
#  'id:Benedict::I-per': 974,
#  'id:pistols::O': 975,
#  'id:attacked::O': 976,
#  'id:Sister::B-per': 977,
#  'id:Leonella::I-per': 978,
#  'id:Sgorbati::I-per': 979,
#  'id:finished::O': 980,
#  'id:teaching::O': 981,
#  'id:medical::O': 982,
#  'id:school::O': 983,
#  'id:class::O': 984,
#  'id:suspect::O': 985,
#  'id:Vatican::B-org': 986,
#  'id:deplored::O': 987,
#  'id:hoped::O': 988,
#  'id:isolated::O': 989,
#  'id:event::O': 990,
#  'id:irrationality::O': 991,
#  'id:arising::O': 992,
#  'id:comments::O': 993,
#  'id:Pope::O': 994,
#  'id:angered::O': 995,
#  'id:Muslims::O': 996,
#  'id:Authorities::O': 997,
#  'id:determined::O': 998,
#  'id:motive::O': 999,
#  ...}

# %%
[x for x in list(ex_feature_mapper.feature_dict.keys()) if 'upper_ini' in x]
# Out:
# ['upper_ini::O',
#  'upper_ini::B-geo',
#  'upper_ini::B-gpe',
#  'upper_ini::B-per',
#  'upper_ini::I-geo',
#  'upper_ini::B-org',
#  'upper_ini::I-org',
#  'upper_ini::B-tim',
#  'upper_ini::B-art',
#  'upper_ini::I-art',
#  'upper_ini::I-per',
#  'upper_ini::I-gpe',
#  'upper_ini::B-nat',
#  'upper_ini::I-eve',
#  'upper_ini::B-eve',
#  'upper_ini::I-nat',
#  'upper_ini::I-tim']

# %% [markdown]
# #### Training structured perceptron

# %%
corpus = skseq.readers.pos_corpus.PostagCorpus()
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)

# %%
sp.get_num_states(), sp.get_num_observations()
# Out:
# (17, 30863)

# %%
# %%time
num_epochs = 15
sp.fit(ex_feature_mapper.dataset, num_epochs)
# Out:
# Epoch: 0 Accuracy: 0.929550
# Epoch: 1 Accuracy: 0.945799
# Epoch: 2 Accuracy: 0.950572
# Epoch: 3 Accuracy: 0.953116
# Epoch: 4 Accuracy: 0.955269
# Epoch: 5 Accuracy: 0.956869
# Epoch: 6 Accuracy: 0.957414
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\Documents\Máster Data Science\Segundo Cuatrimestre\Natural Language Processing\skseq\sequences\structured_perceptron.py in fit(self, dataset, num_epochs)
#      45
#      46         for epoch in range(num_epochs):
# ---> 47             acc = self.fit_epoch(dataset)
#      48             print("Epoch: %i Accuracy: %f" % (epoch, acc))
#      49
#
# ~\Documents\Máster Data Science\Segundo Cuatrimestre\Natural Language Processing\skseq\sequences\structured_perceptron.py in fit_epoch(self, dataset)
#      81         for i in range(num_examples):
#      82             sequence = dataset.seq_list[i]
# ---> 83             num_labels, num_mistakes = self.perceptron_update(sequence)
#      84             num_labels_total += num_labels
#      85             num_mistakes_total += num_mistakes
#
# ~\Documents\Máster Data Science\Segundo Cuatrimestre\Natural Language Processing\skseq\sequences\structured_perceptron.py in perceptron_update(self, sequence)
#     117         num_mistakes = 0
#     118
# --> 119         predicted_sequence, _ = self.viterbi_decode(sequence)
#     120
#     121         y_hat = predicted_sequence.y
#
# ~\Documents\Máster Data Science\Segundo Cuatrimestre\Natural Language Processing\skseq\sequences\sequence_classifier.py in viterbi_decode(self, sequence)
#     134                                                             transition_scores,
#     135                                                             final_scores,
# --> 136                                                             emission_scores)
#     137
#     138         predicted_sequence = sequence.copy_sequence()
#
# ~\Documents\Máster Data Science\Segundo Cuatrimestre\Natural Language Processing\skseq\sequences\sequence_classification_decoder.py in run_viterbi(self, initial_scores, transition_scores, final_scores, emission_scores)
#     108                 viterbi_scores[pos, current_state] += emission_scores[pos, current_state]
#     109                 viterbi_paths[pos, current_state] = \
# --> 110                     np.argmax(viterbi_scores[pos-1, :] + transition_scores[pos-1, current_state, :])
#     111         # Termination.
#     112         best_score = np.max(viterbi_scores[length-1, :] + final_scores)
#
# D:\Program Files\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in argmax(a, axis, out)
#    1101
#    1102     """
# -> 1103     return _wrapfunc(a, 'argmax', axis=axis, out=out)
#    1104
#    1105
#
# D:\Program Files\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      54 def _wrapfunc(obj, method, *args, **kwds):
#      55     try:
# ---> 56         return getattr(obj, method)(*args, **kwds)
#      57
#      58     # An AttributeError occurs if the object does not have
#
# KeyboardInterrupt:

# %%
sp.save_model("perceptron_ex3")

# %%
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)
sp.load_model(dir="perceptron_ex3")

# %% [markdown]
# #### Testing

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

y_pred_2 = []
y_true = [item for x in Y_ids_test for item in x]
correct_sentences = 0
n_test = len(X_test)

for i in range(n_test):
    y_pred_aux = sp.predict_tags_given_words(X_test[i])
    y_pred_2.append(y_pred_aux)
    if list(y_pred_aux) == Y_ids_test[i]:
        correct_sentences += 1
    
y_pred = [item for x in y_pred_2 for item in x]
F1_score_multi = f1_score(y_true, y_pred, average=None)
Accuracy = accuracy_score(y_true, y_pred)
print('Accuracy for test is: ' + str(Accuracy))
print('F1-Score for test is: ' + str(np.mean(F1_score_multi)))
print('Correct sentences for test (%) : ' + str(correct_sentences/n_test))
# Out:
# Accuracy for test is: 0.9485992915254366
# F1-Score for test is: 0.6063765749610461
# Correct sentences for test (%) : 0.46137804471137805

# %%
ax = plot_confusion_matrix(y_true, y_pred, classes=list(sp.state_labels),
                      title='Confusion matrix')

# %% [markdown]
# #### SENTENCES TO TEST THE MODEL

# %% [markdown]
# We think that these are the tags that the model should obtain:
#
# 1. The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 2. The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 3. Jack/B-per London/I-per went/O to/O Parris./O
#
# 4. Jack/B-per London/I-per went/O to/O/O Paris./B-geo
#
# 5. We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
#
# 6. We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
#
# 7. The/O president/O of/O U.S.A/B-geo though/O they/O could/O win/O the/O war/O
#
# 8. The/O president/O of/O the/O United/B-geo States/B-geo of/B-geo America/B-geo though/O they/O could/O win/O the/O war/O
#
# 9. The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
#
# 10. Robin/B-per does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
for sentence in test_sentences:
    new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
    print(sp.viterbi_decode(new_seq)[0].to_words(sequence_list_train, only_tag_translation=True))
# Out:
# The/O programmers/O from/O Barcelona/B-org might/O write/O a/O sentence/O without/O a/O spell/O checker./O
# The/O programmers/O from/O Barchelona/B-org cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
# Jack/B-per London/B-geo went/O to/O Parris./B-geo
# Jack/B-per London/B-geo went/O to/O Paris./B-geo
# We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
# We/O never/O though/O Microsof/B-org would/O become/O such/O a/O big/O company./O
# The/O president/O of/O U.S.A/B-org though/O they/O could/O win/O the/O war/O
# The/O president/O of/O the/O United/B-geo States/I-geo of/I-geo America/I-geo though/O they/O could/O win/O the/O war/O
# The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
# Robin/B-org does/O not/O want/O to/O go/O to/O Saudi/B-per Arabia./I-per

# %%
# Here we can select the sentence in which we want to compare the true and the predicted tags
# Select a sentence between 1 and 10
i=1
sentence = test_sentences[i-1]
new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(sentence.split(), test_tags[i-1], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# The             (O    ): O
# programmers     (O    ): O
# from            (O    ): O
# Barcelona       (B-geo): B-org
# might           (O    ): O
# write           (O    ): O
# a               (O    ): O
# sentence        (O    ): O
# without         (O    ): O
# a               (O    ): O
# spell           (O    ): O
# checker.        (O    ): O

# %% [markdown]
# #### Capital checking

# %%
new_seq = Sequence(x=X_test[0], y=[int(0) for w in X_test[0]])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(X_test[0], Y_test[0], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# Officials       (O    ): O
# said            (O    ): O
# Sunday          (B-tim): B-tim
# Jean            (B-per): B-per
# Rene            (I-per): I-per
# Anthony         (I-per): I-per
# was             (O    ): O
# killed          (O    ): O
# in              (O    ): O
# a               (O    ): O
# shootout        (O    ): O
# with            (O    ): O
# police          (O    ): O
# near            (O    ): O
# the             (O    ): O
# capital         (O    ): O
# city            (O    ): O
# of              (O    ): O
# Port-au-Prince  (B-geo): O
# .               (O    ): O

# %% [markdown]
# ##### Comments:
#
# We have solved the problem with Jean Rene Anthony but now we have again problems with Port-au-Prince. As well, we have changed the output of Barcelona and now we have it wrong. In the next experiments we are going to fix this problem.

# %% [markdown]
# # EXPERIMENT 4: -ED END

# %% [markdown]
# ##### Comments:

# %% [markdown]
# ### Extended features

# %%
ex_feature_mapper = skseq.sequences.extended_feature.ExtendedFeatures(sequence_list_train) 
ex_feature_mapper.build_features()
pprint.pprint(list(ex_feature_mapper.__dict__.keys()))
# Out:
# ['feature_dict',
#  'feature_list',
#  'add_features',
#  'dataset',
#  'node_feature_cache',
#  'initial_state_feature_cache',
#  'final_state_feature_cache',
#  'edge_feature_cache']

# %%
len(ex_feature_mapper.feature_dict)
# Out:
# 38342

# %%
ex_feature_mapper.feature_dict
# Out:
# {'init_tag:O': 0,
#  'id:Thousands::O': 1,
#  'upper_ini::O': 2,
#  'id:of::O': 3,
#  'prev_tag:O::O': 4,
#  'id:demonstrators::O': 5,
#  'id:have::O': 6,
#  'id:marched::O': 7,
#  'verb_ed::O': 8,
#  'id:through::O': 9,
#  'id:London::B-geo': 10,
#  'upper_ini::B-geo': 11,
#  'prev_tag:O::B-geo': 12,
#  'id:to::O': 13,
#  'prev_tag:B-geo::O': 14,
#  'id:protest::O': 15,
#  'id:the::O': 16,
#  'id:war::O': 17,
#  'id:in::O': 18,
#  'id:Iraq::B-geo': 19,
#  'id:and::O': 20,
#  'id:demand::O': 21,
#  'id:withdrawal::O': 22,
#  'id:British::B-gpe': 23,
#  'upper_ini::B-gpe': 24,
#  'prev_tag:O::B-gpe': 25,
#  'id:troops::O': 26,
#  'prev_tag:B-gpe::O': 27,
#  'id:from::O': 28,
#  'id:that::O': 29,
#  'id:country::O': 30,
#  'id:.::O': 31,
#  'final_prev_tag:O': 32,
#  'id:Families::O': 33,
#  'id:soldiers::O': 34,
#  'id:killed::O': 35,
#  'id:conflict::O': 36,
#  'id:joined::O': 37,
#  'id:protesters::O': 38,
#  'id:who::O': 39,
#  'id:carried::O': 40,
#  'id:banners::O': 41,
#  'id:with::O': 42,
#  'id:such::O': 43,
#  'id:slogans::O': 44,
#  'id:as::O': 45,
#  'id:"::O': 46,
#  'id:Bush::B-per': 47,
#  'upper_ini::B-per': 48,
#  'prev_tag:O::B-per': 49,
#  'id:Number::O': 50,
#  'prev_tag:B-per::O': 51,
#  'id:One::O': 52,
#  'id:Terrorist::O': 53,
#  'id:Stop::O': 54,
#  'id:Bombings::O': 55,
#  'id:They::O': 56,
#  'id:Houses::O': 57,
#  'id:Parliament::O': 58,
#  'id:a::O': 59,
#  'id:rally::O': 60,
#  'id:Hyde::B-geo': 61,
#  'id:Park::I-geo': 62,
#  'upper_ini::I-geo': 63,
#  'prev_tag:B-geo::I-geo': 64,
#  'prev_tag:I-geo::O': 65,
#  'id:Police::O': 66,
#  'id:put::O': 67,
#  'id:number::O': 68,
#  'id:marchers::O': 69,
#  'id:at::O': 70,
#  'id:10,000::O': 71,
#  'id:while::O': 72,
#  'id:organizers::O': 73,
#  'id:claimed::O': 74,
#  'id:it::O': 75,
#  'id:was::O': 76,
#  'id:1,00,000::O': 77,
#  'id:The::O': 78,
#  'id:comes::O': 79,
#  'id:on::O': 80,
#  'id:eve::O': 81,
#  'id:annual::O': 82,
#  'id:conference::O': 83,
#  'id:Britain::B-geo': 84,
#  "id:'s::O": 85,
#  'id:ruling::O': 86,
#  'id:Labor::B-org': 87,
#  'upper_ini::B-org': 88,
#  'prev_tag:O::B-org': 89,
#  'id:Party::I-org': 90,
#  'upper_ini::I-org': 91,
#  'prev_tag:B-org::I-org': 92,
#  'prev_tag:I-org::O': 93,
#  'id:southern::O': 94,
#  'id:English::B-gpe': 95,
#  'id:seaside::O': 96,
#  'id:resort::O': 97,
#  'id:Brighton::B-geo': 98,
#  'id:party::O': 99,
#  'id:is::O': 100,
#  'id:divided::O': 101,
#  'id:over::O': 102,
#  'id:Britain::B-gpe': 103,
#  'id:participation::O': 104,
#  'id:continued::O': 105,
#  'id:deployment::O': 106,
#  'id:8,500::O': 107,
#  'id:march::O': 108,
#  'id:came::O': 109,
#  'id:ahead::O': 110,
#  'id:anti-war::O': 111,
#  'hyphen::O': 112,
#  'id:protests::O': 113,
#  'id:today::O': 114,
#  'id:other::O': 115,
#  'id:cities::O': 116,
#  'id:,::O': 117,
#  'id:including::O': 118,
#  'id:Rome::B-geo': 119,
#  'id:Paris::B-geo': 120,
#  'id:Madrid::B-geo': 121,
#  'id:International::B-org': 122,
#  'id:Atomic::I-org': 123,
#  'id:Energy::I-org': 124,
#  'prev_tag:I-org::I-org': 125,
#  'id:Agency::I-org': 126,
#  'id:hold::O': 127,
#  'id:second::O': 128,
#  'id:day::O': 129,
#  'id:talks::O': 130,
#  'id:Vienna::B-geo': 131,
#  'id:Wednesday::B-tim': 132,
#  'upper_ini::B-tim': 133,
#  'prev_tag:B-geo::B-tim': 134,
#  'prev_tag:B-tim::O': 135,
#  'id:how::O': 136,
#  'id:respond::O': 137,
#  'id:Iran::B-gpe': 138,
#  'id:resumption::O': 139,
#  'id:low-level::O': 140,
#  'id:uranium::O': 141,
#  'id:conversion::O': 142,
#  'init_tag:B-gpe': 143,
#  'id:this::O': 144,
#  'id:week::O': 145,
#  'id:restarted::O': 146,
#  'id:parts::O': 147,
#  'id:process::O': 148,
#  'id:its::O': 149,
#  'id:Isfahan::B-geo': 150,
#  'id:nuclear::O': 151,
#  'id:plant::O': 152,
#  'id:Iranian::B-gpe': 153,
#  'id:officials::O': 154,
#  'id:say::O': 155,
#  'id:they::O': 156,
#  'id:expect::O': 157,
#  'id:get::O': 158,
#  'id:access::O': 159,
#  'id:sealed::O': 160,
#  'id:sensitive::O': 161,
#  'prev_tag:O::B-tim': 162,
#  'id:after::O': 163,
#  'id:an::O': 164,
#  'id:IAEA::B-org': 165,
#  'id:surveillance::O': 166,
#  'prev_tag:B-org::O': 167,
#  'id:system::O': 168,
#  'id:begins::O': 169,
#  'id:functioning::O': 170,
#  'id:step::O': 171,
#  'id:will::O': 172,
#  'id:allow::O': 173,
#  'id:facility::O': 174,
#  'id:operate::O': 175,
#  'id:full::O': 176,
#  'id:capacity::O': 177,
#  'id:European::B-org': 178,
#  'id:Union::I-org': 179,
#  'id:U.S.::B-gpe': 180,
#  'id:backing::O': 181,
#  'id:has::O': 182,
#  'id:threatened::O': 183,
#  'id:refer::O': 184,
#  'id:U.N.::B-org': 185,
#  'id:Security::I-org': 186,
#  'id:Council::I-org': 187,
#  'id:which::O': 188,
#  'id:could::O': 189,
#  'id:impose::O': 190,
#  'id:sanctions::O': 191,
#  'id:if::O': 192,
#  'id:finds::O': 193,
#  'id:Tehran::B-gpe': 194,
#  'id:violated::O': 195,
#  'id:Nuclear::B-art': 196,
#  'upper_ini::B-art': 197,
#  'prev_tag:O::B-art': 198,
#  'id:Non-Proliferation::I-art': 199,
#  'hyphen::I-art': 200,
#  'upper_ini::I-art': 201,
#  'prev_tag:B-art::I-art': 202,
#  'id:treaty::O': 203,
#  'prev_tag:I-art::O': 204,
#  'id:new::O': 205,
#  'id:President::B-per': 206,
#  'id:Mahmoud::I-per': 207,
#  'upper_ini::I-per': 208,
#  'prev_tag:B-per::I-per': 209,
#  'id:Ahmadinejad::I-per': 210,
#  'prev_tag:I-per::I-per': 211,
#  'id:said::O': 212,
#  'prev_tag:I-per::O': 213,
#  'id:Tuesday::B-tim': 214,
#  'id:European::B-gpe': 215,
#  'id:incentives::O': 216,
#  'id:aimed::O': 217,
#  'id:persuading::O': 218,
#  'id:end::O': 219,
#  'id:fuel::O': 220,
#  'id:program::O': 221,
#  'id:are::O': 222,
#  'id:insult::O': 223,
#  'id:nation::O': 224,
#  'id:Two::O': 225,
#  'id:Germans::B-gpe': 226,
#  'id:four::O': 227,
#  'id:Nigerian::B-gpe': 228,
#  'id:oil::O': 229,
#  'id:workers::O': 230,
#  'id:were::O': 231,
#  'id:kidnapped::O': 232,
#  'id:by::O': 233,
#  'id:armed::O': 234,
#  'id:militants::O': 235,
#  'id:during::O': 236,
#  'id:raid::O': 237,
#  'id:boat::O': 238,
#  'id:Nigeria::B-geo': 239,
#  'id:oil-rich::O': 240,
#  'id:Delta::B-geo': 241,
#  'id:region::O': 242,
#  'id:An::O': 243,
#  'id:official::O': 244,
#  'id:German::B-gpe': 245,
#  'id:firm::O': 246,
#  'id:Bilfinger::B-org': 247,
#  'id:Berger::I-org': 248,
#  'id:Thomas::B-per': 249,
#  'id:Horbach::I-per': 250,
#  'id:gunmen::O': 251,
#  'id:stopped::O': 252,
#  'id:supply::O': 253,
#  'id:sailed::O': 254,
#  'id:State::I-geo': 255,
#  'id:Bayelsa::B-geo': 256,
#  'id:inspect::O': 257,
#  'id:offshore::O': 258,
#  'id:field::O': 259,
#  'id:owned::O': 260,
#  'id:Royal-Dutch::B-org': 261,
#  'hyphen::B-org': 262,
#  'id:Shell::I-org': 263,
#  'id:works::O': 264,
#  'id:sub-contractor::O': 265,
#  'id:for::O': 266,
#  'id:Shell::B-org': 267,
#  'id:Militant::O': 268,
#  'id:groups::O': 269,
#  'id:frequently::O': 270,
#  'id:attack::O': 271,
#  'id:operations::O': 272,
#  'id:Niger::B-geo': 273,
#  'id:Delta::I-geo': 274,
#  'id:social::O': 275,
#  'id:services::O': 276,
#  'id:better::O': 277,
#  'id:job::O': 278,
#  'id:opportunities::O': 279,
#  'id:multinational::O': 280,
#  'id:companies::O': 281,
#  'id:Poor::O': 282,
#  'id:residents::O': 283,
#  'id:often::O': 284,
#  'id:complain::O': 285,
#  'id:been::O': 286,
#  'id:cheated::O': 287,
#  'id:out::O': 288,
#  'id:huge::O': 289,
#  'id:riches::O': 290,
#  'id:extracted::O': 291,
#  'id:their::O': 292,
#  'id:tribal::O': 293,
#  'id:lands::O': 294,
#  'id:-::O': 295,
#  'id:where::O': 296,
#  'id:bulk::O': 297,
#  'id:Nigeria::B-gpe': 298,
#  'id:2.3::O': 299,
#  'id:million::O': 300,
#  'id:barrels::O': 301,
#  'id:petroleum::O': 302,
#  'id:pumped::O': 303,
#  'id:daily::O': 304,
#  'id:Suspected::O': 305,
#  'id:Islamist::O': 306,
#  'id:rebels::O': 307,
#  'id:fired::O': 308,
#  'id:mortar::O': 309,
#  'id:shells::O': 310,
#  'id:palace::O': 311,
#  'id:used::O': 312,
#  'id:Somalia::B-geo': 313,
#  'id:interim::O': 314,
#  'id:Abdullahi::I-per': 315,
#  'id:Yusuf::I-per': 316,
#  'id:Ahmad::I-per': 317,
#  'id:It::O': 318,
#  'id:not::O': 319,
#  'id:immediately::O': 320,
#  'id:clear::O': 321,
#  'id:president::O': 322,
#  'id:Mogadishu::B-geo': 323,
#  'id:when::O': 324,
#  'id:occurred::O': 325,
#  'id:or::O': 326,
#  'id:anyone::O': 327,
#  'id:hurt::O': 328,
#  'id:Local::O': 329,
#  'id:news::O': 330,
#  'id:reports::O': 331,
#  'id:least::O': 332,
#  'id:five::O': 333,
#  'id:hit::O': 334,
#  'id:compound::O': 335,
#  'id:mortars::O': 336,
#  'id:elsewhere::O': 337,
#  'id:attacks::O': 338,
#  'id:government::O': 339,
#  'id:go::O': 340,
#  'id:reconciliation::O': 341,
#  'id:more::O': 342,
#  'id:than::O': 343,
#  'id:1,300::O': 344,
#  'id:Somali::B-gpe': 345,
#  'id:elders::O': 346,
#  'id:warlords::O': 347,
#  'id:politicians::O': 348,
#  'id:invited::O': 349,
#  'id:Iraqi::B-gpe': 350,
#  'id:military::O': 351,
#  'id:tanks::O': 352,
#  'id:arrived::O': 353,
#  'id:northern::O': 354,
#  'id:city::O': 355,
#  'id:Mosul::B-geo': 356,
#  'id:offensive::O': 357,
#  'id:against::O': 358,
#  'id:al::B-org': 359,
#  'id:Qaida::I-org': 360,
#  'id:in::I-org': 361,
#  'id:Iraq::I-org': 362,
#  'id:fighters::O': 363,
#  'id:Officials::O': 364,
#  'id:many::O': 365,
#  'id:Sunni::B-geo': 366,
#  'id:Arab::I-geo': 367,
#  'id:Kurdish::B-geo': 368,
#  'id:bombings::O': 369,
#  'id:last::O': 370,
#  'id:34::O': 371,
#  'id:people::O': 372,
#  'id:wounded::O': 373,
#  'id:200::O': 374,
#  'id:commanders::O': 375,
#  'id:explained::O': 376,
#  'id:American::B-gpe': 377,
#  'id:forces::O': 378,
#  'id:participate::O': 379,
#  'id:fled::O': 380,
#  'id:successful::O': 381,
#  'id:campaigns::O': 382,
#  'id:them::O': 383,
#  'id:Anbar::B-geo': 384,
#  'id:province::O': 385,
#  'id:Baghdad::B-geo': 386,
#  'id:provinces::O': 387,
#  'init_tag:B-geo': 388,
#  'id:largest::O': 389,
#  'id:north::O': 390,
#  'id:long::O': 391,
#  'id:stronghold::O': 392,
#  'id:Sunni::B-org': 393,
#  'id:militant::O': 394,
#  'id:In::O': 395,
#  'id:violence::O': 396,
#  'id:one::O': 397,
#  'id:soldier::O': 398,
#  'id:patrol::O': 399,
#  'id:Sunday::B-tim': 400,
#  'id:Egyptian::B-gpe': 401,
#  'id:police::O': 402,
#  'id:arrested::O': 403,
#  'id:16::O': 404,
#  'id:members::O': 405,
#  'id:opposition::O': 406,
#  'id:Muslim::B-org': 407,
#  'id:Brotherhood::I-org': 408,
#  'id:prepare::O': 409,
#  'id:parliamentary::O': 410,
#  'id:runoff::O': 411,
#  'id:elections::O': 412,
#  'id:Saturday::B-tim': 413,
#  'id:arrests::O': 414,
#  'id:Friday::B-tim': 415,
#  'id:Alexandria::B-geo': 416,
#  'id:A::O': 417,
#  'id:spokesman::O': 418,
#  'id:Brotherhood::B-org': 419,
#  'id:attempt::O': 420,
#  'id:cut::O': 421,
#  'id:off::O': 422,
#  'id:supporters::O': 423,
#  'id:punishment::O': 424,
#  'id:winning::O': 425,
#  'id:seats::O': 426,
#  'id:earlier::O': 427,
#  'id:tripled::O': 428,
#  'id:strength::O': 429,
#  'id:parliament::O': 430,
#  'id:recent::O': 431,
#  'id:raising::O': 432,
#  'id:total::O': 433,
#  'id:47::O': 434,
#  'id:voters::O': 435,
#  'id:cast::O': 436,
#  'id:ballots::O': 437,
#  'id:nine::O': 438,
#  'id:no::O': 439,
#  'id:candidate::O': 440,
#  'id:won::O': 441,
#  'id:majority::O': 442,
#  'id:previous::O': 443,
#  'id:round::O': 444,
#  'id:voting::O': 445,
#  'id:banned::O': 446,
#  'id:political::O': 447,
#  'id:but::O': 448,
#  'id:endorses::O': 449,
#  'id:so-called::O': 450,
#  'id:independent::O': 451,
#  'id:candidates::O': 452,
#  'id:whose::O': 453,
#  'id:allegiance::O': 454,
#  'id:known::O': 455,
#  'id:Hardline::O': 456,
#  'id:lawmakers::O': 457,
#  'id:Pakistan::B-geo': 458,
#  'id:North::B-geo': 459,
#  'id:West::I-geo': 460,
#  'id:Frontier::I-geo': 461,
#  'prev_tag:I-geo::I-geo': 462,
#  'id:Province::I-geo': 463,
#  'id:pushed::O': 464,
#  'id:law::O': 465,
#  'id:aims::O': 466,
#  'id:ensure::O': 467,
#  'id:Islamic::O': 468,
#  'id:correctness::O': 469,
#  'id:public::O': 470,
#  'id:places::O': 471,
#  'id:establishes::O': 472,
#  'id:morality::O': 473,
#  'id:enforce::O': 474,
#  'id:decent::O': 475,
#  'id:behavior::O': 476,
#  'id:six-party::O': 477,
#  'id:coalition::O': 478,
#  'id:religious::O': 479,
#  'id:based::O': 480,
#  'id:parties::O': 481,
#  'id:Mutahida::B-org': 482,
#  'id:Majlis-e-Amal::I-org': 483,
#  'hyphen::I-org': 484,
#  'id:dominates::O': 485,
#  'id:provincial::O': 486,
#  'id:assembly::O': 487,
#  'id:so::O': 488,
#  'id:bill::O': 489,
#  'id:easily::O': 490,
#  'id:passed::O': 491,
#  'id:Thursday::B-tim': 492,
#  'id:vote::O': 493,
#  'id:68-34::O': 494,
#  'id:governor::O': 495,
#  'id:must::O': 496,
#  'id:still::O': 497,
#  'id:sign::O': 498,
#  'id:before::O': 499,
#  'id:becomes::O': 500,
#  'id:seen::O': 501,
#  'id:only::O': 502,
#  'id:formality::O': 503,
#  'id:proposed::O': 504,
#  'id:calls::O': 505,
#  'id:setting::O': 506,
#  'id:up::O': 507,
#  'id:force::O': 508,
#  'id:make::O': 509,
#  'id:sure::O': 510,
#  'id:adhere::O': 511,
#  'id:values::O': 512,
#  'id:entertainment::O': 513,
#  'id:outlets::O': 514,
#  'id:close::O': 515,
#  'id:weekly::O': 516,
#  'id:prayers::O': 517,
#  'id:Violators::O': 518,
#  'id:be::O': 519,
#  'id:jailed::O': 520,
#  'id:six::O': 521,
#  'id:months::O': 522,
#  'id:denounced::O': 523,
#  'id:measure::O': 524,
#  'id:comparing::O': 525,
#  'id:draconian::O': 526,
#  'id:rule::O': 527,
#  'id:former::O': 528,
#  'id:Taleban::B-org': 529,
#  'id:neighboring::O': 530,
#  'id:Afghanistan::B-geo': 531,
#  'id:man::O': 532,
#  'id:dressed::O': 533,
#  'id:suicide::O': 534,
#  'id:bomber::O': 535,
#  'id:demonstration::O': 536,
#  'id:publication::O': 537,
#  'id:cartoons::O': 538,
#  'id:depicting::O': 539,
#  'id:Islam::B-org': 540,
#  'id:Prophet::B-per': 541,
#  'id:Muhammad::I-per': 542,
#  'id:Bedfordshire::B-gpe': 543,
#  'id:Omar::B-per': 544,
#  'id:Khayam::I-per': 545,
#  'id:Bedford::B-geo': 546,
#  'id:breaching::O': 547,
#  'id:conditions::O': 548,
#  'id:his::O': 549,
#  'id:parole::O': 550,
#  'id:British::B-org': 551,
#  'id:Home::I-org': 552,
#  'id:Office::I-org': 553,
#  'id:sought::O': 554,
#  'id:investigation::O': 555,
#  'id:Khayam::B-per': 556,
#  'id:he::O': 557,
#  'id:photographed::O': 558,
#  'id:fatigues::O': 559,
#  'id:black::O': 560,
#  'id:cap::O': 561,
#  'id:bulky::O': 562,
#  'id:belt::O': 563,
#  'id:Home::B-org': 564,
#  'id:told::O': 565,
#  'id:Associated::B-org': 566,
#  'verb_ed::B-org': 567,
#  'id:Press::I-org': 568,
#  'id:paroled::O': 569,
#  'id:offender::O': 570,
#  'id:gives::O': 571,
#  'id:cause::O': 572,
#  'id:concern::O': 573,
#  'id:can::O': 574,
#  'id:sent::O': 575,
#  'id:back::O': 576,
#  'id:prison::O': 577,
#  'id:AP::B-org': 578,
#  'id:also::O': 579,
#  'id:since::O': 580,
#  'id:year::O': 581,
#  'id:serving::O': 582,
#  'id:half::O': 583,
#  'id:six-year::O': 584,
#  'id:sentence::O': 585,
#  'id:drug::O': 586,
#  'id:dealing::O': 587,
#  'id:Pakistani::B-gpe': 588,
#  'id:unidentified::O': 589,
#  'id:three::O': 590,
#  'id:minister::O': 591,
#  'id:semi-autonomous::O': 592,
#  'id:bordering::O': 593,
#  'id:prominent::O': 594,
#  'id:leader::O': 595,
#  'id:Malik::B-per': 596,
#  'id:Faridullah::I-per': 597,
#  'id:Khan::I-per': 598,
#  'id:traveling::O': 599,
#  'id:South::B-geo': 600,
#  'id:Waziristan::I-geo': 601,
#  'prev_tag:I-geo::B-tim': 602,
#  'id:vehicle::O': 603,
#  'id:ambushed::O': 604,
#  'id:Kani::B-geo': 605,
#  'id:Wam::I-geo': 606,
#  'id:area::O': 607,
#  'id:His::O': 608,
#  'id:driver::O': 609,
#  'id:elder::O': 610,
#  'id:No::O': 611,
#  'id:responsibility::O': 612,
#  'id:killings::O': 613,
#  'id:ambush::O': 614,
#  'id:commander::O': 615,
#  'id:army::O': 616,
#  'id:almost::O': 617,
#  'id:completely::O': 618,
#  'id:eliminated::O': 619,
#  'id:became::O': 620,
#  'id:refuge::O': 621,
#  'id:al-Qaida::B-org': 622,
#  'id:ousted::O': 623,
#  'id:2001::B-tim': 624,
#  'id:senior::O': 625,
#  'id:says::O': 626,
#  'id:Pakistan::B-gpe': 627,
#  'id:wants::O': 628,
#  'id:what::O': 629,
#  'id:sordid::O': 630,
#  'id:chapter::O': 631,
#  'id:proliferation::O': 632,
#  'id:top::O': 633,
#  'id:scientists::O': 634,
#  'id:behind::O': 635,
#  'id:build::O': 636,
#  'id:civilian::O': 637,
#  'id:ties::O': 638,
#  'id:United::B-gpe': 639,
#  'verb_ed::B-gpe': 640,
#  'id:States::I-gpe': 641,
#  'upper_ini::I-gpe': 642,
#  'prev_tag:B-gpe::I-gpe': 643,
#  'prev_tag:I-gpe::O': 644,
#  'id:But::O': 645,
#  'id:ready::O': 646,
#  'id:scientist::O': 647,
#  'id:Abdul::B-per': 648,
#  'id:Qadeer::I-per': 649,
#  'id:available::O': 650,
#  'id:direct::O': 651,
#  'id:questioning::O': 652,
#  'id:sale::O': 653,
#  'id:secrets::O': 654,
#  'id:states::O': 655,
#  'id:Libya::B-gpe': 656,
#  'id:North::B-gpe': 657,
#  'id:Korea::I-gpe': 658,
#  'id:He::O': 659,
#  'id:there::O': 660,
#  'id:reasons::O': 661,
#  'id:national::O': 662,
#  'id:sensitivities::O': 663,
#  'id:making::O': 664,
#  'id:him::O': 665,
#  'id:giving::O': 666,
#  'id:background::O': 667,
#  'id:briefing::O': 668,
#  'id:small::O': 669,
#  'id:group::O': 670,
#  'id:reporters::O': 671,
#  'id:Washington::B-geo': 672,
#  'init_tag:B-per': 673,
#  'id:Khan::B-per': 674,
#  'id:admitted::O': 675,
#  'id:2004::B-tim': 676,
#  'id:operated::O': 677,
#  'id:worldwide::O': 678,
#  'id:clandestine::O': 679,
#  'id:network::O': 680,
#  'id:sell::O': 681,
#  'id:technology::O': 682,
#  'id:market::O': 683,
#  'id:placed::O': 684,
#  'id:under::O': 685,
#  'id:house::O': 686,
#  'id:arrest::O': 687,
#  'id:Islamabad::B-geo': 688,
#  'id:because::O': 689,
#  'id:considered::O': 690,
#  'id:father::O': 691,
#  'id:bomb::O': 692,
#  'id:Army::B-org': 693,
#  'prev_tag:B-gpe::B-org': 694,
#  'id:renew::O': 695,
#  'id:controversial::O': 696,
#  'id:multi-billion::O': 697,
#  'id:dollar::O': 698,
#  'id:contract::O': 699,
#  'id:Halliburton::B-org': 700,
#  'id:company::O': 701,
#  'id:provide::O': 702,
#  'id:logistical::O': 703,
#  'id:support::O': 704,
#  'init_tag:B-org': 705,
#  'id:providing::O': 706,
#  'id:list::O': 707,
#  'id:meals::O': 708,
#  'id:communication::O': 709,
#  'id:several::O': 710,
#  'id:years::O': 711,
#  'id:Critics::O': 712,
#  'id:include::O': 713,
#  'id:auditors::O': 714,
#  'id:congressional::O': 715,
#  'id:Democrats::O': 716,
#  'id:produced::O': 717,
#  'id:some::O': 718,
#  'id:shoddy::O': 719,
#  'id:work::O': 720,
#  'id:charges::O': 721,
#  'id:too::O': 722,
#  'id:much::O': 723,
#  'id:money::O': 724,
#  'id:strongly::O': 725,
#  'id:denies::O': 726,
#  'id:allegations::O': 727,
#  'id:When::O': 728,
#  'id:re-bidding::O': 729,
#  'id:chance::O': 730,
#  'id:compete::O': 731,
#  'id:portions::O': 732,
#  'id:Representatives::O': 733,
#  'id:Asia::B-org': 734,
#  'id:Pacific::I-org': 735,
#  'id:Economic::I-org': 736,
#  'id:Cooperation::I-org': 737,
#  'id:Business::I-org': 738,
#  'id:Advisory::I-org': 739,
#  'id:holding::O': 740,
#  'id:meetings::O': 741,
#  'id:finalize::O': 742,
#  'id:report::O': 743,
#  'id:APEC::B-org': 744,
#  'id:leaders::O': 745,
#  'id:summit::O': 746,
#  'id:September::B-tim': 747,
#  'id:8::I-tim': 748,
#  'prev_tag:B-tim::I-tim': 749,
#  'prev_tag:I-tim::O': 750,
#  'id:9::B-tim': 751,
#  'id:VOA::B-org': 752,
#  'id:Nancy-Amelia::B-per': 753,
#  'hyphen::B-per': 754,
#  'id:Collins::I-per': 755,
#  'id:Sydney::B-geo': 756,
#  'id:Energy::O': 757,
#  'id:security::O': 758,
#  'id:climate::O': 759,
#  'id:change::O': 760,
#  'id:World::B-org': 761,
#  'id:Trade::I-org': 762,
#  'id:Organization::I-org': 763,
#  'id:stalled::O': 764,
#  'id:negotiations::O': 765,
#  'id:investment::O': 766,
#  'id:all::O': 767,
#  'id:expected::O': 768,
#  'id:among::O': 769,
#  'id:major::O': 770,
#  'id:topics::O': 771,
#  'id:ABAC::B-org': 772,
#  'id:Tim::B-per': 773,
#  'id:Harcourt::I-per': 774,
#  'id:chief::O': 775,
#  'id:economist::O': 776,
#  'id:Australian::B-org': 777,
#  'id:Commission::I-org': 778,
#  'id:plays::O': 779,
#  'id:important::O': 780,
#  'id:role::O': 781,
#  'id:informing::O': 782,
#  'id:governments::O': 783,
#  'id:problems::O': 784,
#  'id:most::O': 785,
#  'id:thing::O': 786,
#  'id:business::O': 787,
#  'id:do::O': 788,
#  'id:tell::O': 789,
#  'id:logjams::O': 790,
#  'id:obstacles::O': 791,
#  'id:things::O': 792,
#  'id:improve::O': 793,
#  'id:Harcourt::B-per': 794,
#  'id:I::O': 795,
#  'id:think::O': 796,
#  'id:actually::O': 797,
#  'id:played::O': 798,
#  'id:pretty::O': 799,
#  'id:good::O': 800,
#  'id:leadership::O': 801,
#  'id:talking::O': 802,
#  'id:about::O': 803,
#  'id:trade::O': 804,
#  'id:facilitation::O': 805,
#  'id:basically::O': 806,
#  'id:standards::O': 807,
#  'id:consistent::O': 808,
#  'id:harmonious::O': 809,
#  'id:across::O': 810,
#  'id:comprises::O': 811,
#  'id:private::O': 812,
#  'id:sector::O': 813,
#  'id:each::O': 814,
#  'id:21::O': 815,
#  'id:economies::O': 816,
#  'id:meets::O': 817,
#  'id:times::O': 818,
#  'id:made::O': 819,
#  'id:permanent::O': 820,
#  'id:body::O': 821,
#  'id:1995::B-tim': 822,
#  'id:perspective::O': 823,
#  'id:within::O': 824,
#  'id:Members::O': 825,
#  'id:represent::O': 826,
#  'id:range::O': 827,
#  'id:sectors::O': 828,
#  'id:medium::O': 829,
#  'id:businesses::O': 830,
#  'id:need::O': 831,
#  'id:energy::O': 832,
#  'id:efficiency::O': 833,
#  'id:encourage::O': 834,
#  'id:conservation::O': 835,
#  'id:practices::O': 836,
#  'id:discuss::O': 837,
#  'id:ways::O': 838,
#  'id:enhance::O': 839,
#  'id:regional::O': 840,
#  'id:cooperation::O': 841,
#  'id:reckon::O': 842,
#  "id:'ll::O": 843,
#  'id:talk::O': 844,
#  'id:little::O': 845,
#  'id:bit::O': 846,
#  'id:customs::O': 847,
#  'id:quarantine::O': 848,
#  'id:having::O': 849,
#  'id:arrangements::O': 850,
#  'id:around::O': 851,
#  'id:And::O': 852,
#  'id:want::O': 853,
#  'id:one-stop::O': 854,
#  'id:shop::O': 855,
#  'id:terms::O': 856,
#  'id:combining::O': 857,
#  'id:immigration::O': 858,
#  'id:together::O': 859,
#  'id:\x85::O': 860,
#  'id:just::O': 861,
#  'id:streamlined::O': 862,
#  'id:provides::O': 863,
#  'id:certainty::O': 864,
#  'id:non-governmental::O': 865,
#  'id:formal::O': 866,
#  'id:dialogue::O': 867,
#  'id:present::O': 868,
#  'id:meeting::O': 869,
#  'id:Sudan::B-gpe': 870,
#  'id:order::O': 871,
#  'id:Darfur::B-geo': 872,
#  'id:asking::O': 873,
#  'id:same::O': 874,
#  'id:Foreign::B-per': 875,
#  'id:Minister::I-per': 876,
#  'id:Mustafa::I-per': 877,
#  'id:Osman::I-per': 878,
#  'id:Ismail::I-per': 879,
#  'id:Sudanese::B-gpe': 880,
#  'id:withdraw::O': 881,
#  'id:positions::O': 882,
#  'id:held::O': 883,
#  'id:April::B-tim': 884,
#  'id:cease-fire::O': 885,
#  'id:western::O': 886,
#  'id:agree::O': 887,
#  'id:stop::O': 888,
#  'id:Mr.::B-per': 889,
#  'id:announced::O': 890,
#  'id:decision::O': 891,
#  'id:United::B-org': 892,
#  'id:Nations::I-org': 893,
#  'id:African::B-org': 894,
#  'id:Khartoum::B-geo': 895,
#  'id:weeks::O': 896,
#  'id:AU::B-org': 897,
#  'id:repeatedly::O': 898,
#  'id:truce::O': 899,
#  'init_tag:B-tim': 900,
#  'id:head::O': 901,
#  'id:accused::O': 902,
#  'id:helicopters::O': 903,
#  'id:bombing::O': 904,
#  'id:rebel::O': 905,
#  'id:sites::O': 906,
#  'id:Darfur::I-geo': 907,
#  'id:village::O': 908,
#  'id:Labado::B-geo': 909,
#  'id:Khartoum::B-gpe': 910,
#  'id:defending::O': 911,
#  'id:Aid::O': 912,
#  'id:relief::O': 913,
#  'id:efforts::O': 914,
#  'id:suspended::O': 915,
#  'id:due::O': 916,
#  'id:Indonesian::B-gpe': 917,
#  'id:men::O': 918,
#  'id:connection::O': 919,
#  'id:October::B-tim': 920,
#  'id:1::I-tim': 921,
#  'id:Bali::B-geo': 922,
#  'prev_tag:I-tim::B-geo': 923,
#  'id:left::O': 924,
#  'id:23::O': 925,
#  'id:dead::O': 926,
#  'id:flown::O': 927,
#  'id:Java::B-geo': 928,
#  'id:island::O': 929,
#  'id:headquarters::O': 930,
#  'id:Australian::B-gpe': 931,
#  'id:French::B-gpe': 932,
#  'id:agencies::O': 933,
#  'id:(::O': 934,
#  'id:Cholily::B-per': 935,
#  'id:)::O': 936,
#  'id:captured::O': 937,
#  'id:series::O': 938,
#  'id:counter-terrorism::O': 939,
#  'id:raids::O': 940,
#  'id:Indonesia::B-geo': 941,
#  'id:ended::O': 942,
#  'id:death::O': 943,
#  'id:alleged::O': 944,
#  'id:extremist::O': 945,
#  'id:bombmaker::O': 946,
#  'id:Azahari::B-per': 947,
#  'id:bin::I-per': 948,
#  'id:Husin::I-per': 949,
#  'id:authorities::O': 950,
#  'id:blame::O': 951,
#  'id:orchestrating::O': 952,
#  'id:month::O': 953,
#  'id:well::O': 954,
#  'id:2002::B-tim': 955,
#  'prev_tag:B-tim::B-geo': 956,
#  'id:Gunmen::O': 957,
#  'id:shot::O': 958,
#  'id:Roman::B-org': 959,
#  'id:Catholic::I-org': 960,
#  'id:nun::O': 961,
#  'id:her::O': 962,
#  'id:bodyguard::O': 963,
#  'id:hospital::O': 964,
#  'id:she::O': 965,
#  'id:worked::O': 966,
#  'id:Islamist-controlled::O': 967,
#  'id:Some::O': 968,
#  'id:witnesses::O': 969,
#  'id:shooting::O': 970,
#  'id:feared::O': 971,
#  'id:linked::O': 972,
#  'id:Muslim::O': 973,
#  'id:anger::O': 974,
#  'id:toward::O': 975,
#  'id:Pope::B-per': 976,
#  'id:Benedict::I-per': 977,
#  'id:pistols::O': 978,
#  'id:attacked::O': 979,
#  'id:Sister::B-per': 980,
#  'id:Leonella::I-per': 981,
#  'id:Sgorbati::I-per': 982,
#  'id:finished::O': 983,
#  'id:teaching::O': 984,
#  'id:medical::O': 985,
#  'id:school::O': 986,
#  'id:class::O': 987,
#  'id:suspect::O': 988,
#  'id:Vatican::B-org': 989,
#  'id:deplored::O': 990,
#  'id:hoped::O': 991,
#  'id:isolated::O': 992,
#  'id:event::O': 993,
#  'id:irrationality::O': 994,
#  'id:arising::O': 995,
#  'id:comments::O': 996,
#  'id:Pope::O': 997,
#  'id:angered::O': 998,
#  'id:Muslims::O': 999,
#  ...}

# %%
[x for x in list(ex_feature_mapper.feature_dict.keys()) if 'verb_ed' in x]
# Out:
# ['verb_ed::O',
#  'verb_ed::B-org',
#  'verb_ed::B-gpe',
#  'verb_ed::I-per',
#  'verb_ed::B-per',
#  'verb_ed::I-org',
#  'verb_ed::B-geo',
#  'verb_ed::B-art',
#  'verb_ed::B-tim',
#  'verb_ed::I-tim',
#  'verb_ed::I-geo',
#  'verb_ed::B-eve']

# %% [markdown]
# #### Training structured perceptron

# %%
corpus = skseq.readers.pos_corpus.PostagCorpus()
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)

# %%
sp.get_num_states(), sp.get_num_observations()
# Out:
# (17, 30863)

# %%
# %%time
num_epochs = 15
sp.fit(ex_feature_mapper.dataset, num_epochs)
# Out:
# Epoch: 0 Accuracy: 0.929893
# Epoch: 1 Accuracy: 0.945859
# Epoch: 2 Accuracy: 0.950447
# Epoch: 3 Accuracy: 0.953116
# Epoch: 4 Accuracy: 0.955520
# Epoch: 5 Accuracy: 0.956555
# Epoch: 6 Accuracy: 0.958235
# Epoch: 7 Accuracy: 0.959212
# Epoch: 8 Accuracy: 0.959951
# Epoch: 9 Accuracy: 0.960900
# Epoch: 10 Accuracy: 0.961482
# Epoch: 11 Accuracy: 0.961900
# Epoch: 12 Accuracy: 0.962931
# Epoch: 13 Accuracy: 0.963072
# Epoch: 14 Accuracy: 0.963401
# Wall time: 1h 10min 54s

# %%
sp.save_model("perceptron_ex4")

# %%
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)
sp.load_model(dir="perceptron_ex4")

# %% [markdown]
# #### Testing

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

y_pred_2 = []
y_true = [item for x in Y_ids_test for item in x]
correct_sentences = 0
n_test = len(X_test)

for i in range(n_test):
    y_pred_aux = sp.predict_tags_given_words(X_test[i])
    y_pred_2.append(y_pred_aux)
    if list(y_pred_aux) == Y_ids_test[i]:
        correct_sentences += 1
    
y_pred = [item for x in y_pred_2 for item in x]
F1_score_multi = f1_score(y_true, y_pred, average=None)
Accuracy = accuracy_score(y_true, y_pred)
print('Accuracy for test is: ' + str(Accuracy))
print('F1-Score for test is: ' + str(np.mean(F1_score_multi)))
print('Correct sentences for test (%) : ' + str(correct_sentences/n_test))
# Out:
# Accuracy for test is: 0.9489546752060652
# F1-Score for test is: 0.6005716000744572
# Correct sentences for test (%) : 0.46838505171838507

# %%
ax = plot_confusion_matrix(y_true, y_pred, classes=list(sp.state_labels),
                      title='Confusion matrix')

# %% [markdown]
# #### SENTENCES TO TEST THE MODEL

# %% [markdown]
# We think that these are the tags that the model should obtain:
#
# 1. The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 2. The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 3. Jack/B-per London/I-per went/O to/O Parris./O
#
# 4. Jack/B-per London/I-per went/O to/O/O Paris./B-geo
#
# 5. We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
#
# 6. We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
#
# 7. The/O president/O of/O U.S.A/B-geo though/O they/O could/O win/O the/O war/O
#
# 8. The/O president/O of/O the/O United/B-geo States/B-geo of/B-geo America/B-geo though/O they/O could/O win/O the/O war/O
#
# 9. The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
#
# 10. Robin/B-per does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
for sentence in test_sentences:
    new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
    print(sp.viterbi_decode(new_seq)[0].to_words(sequence_list_train, only_tag_translation=True))
# Out:
# The/O programmers/O from/O Barcelona/B-org might/O write/O a/O sentence/O without/O a/O spell/O checker./O
# The/O programmers/O from/O Barchelona/B-org cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
# Jack/B-per London/B-geo went/O to/O Parris./B-eve
# Jack/B-per London/B-geo went/O to/O Paris./B-eve
# We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
# We/O never/O though/O Microsof/B-org would/O become/O such/O a/O big/O company./O
# The/O president/O of/O U.S.A/B-org though/O they/O could/O win/O the/O war/O
# The/O president/O of/O the/O United/B-geo States/I-geo of/I-geo America/I-geo though/O they/O could/O win/O the/O war/O
# The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
# Robin/B-org does/O not/O want/O to/O go/O to/O Saudi/B-per Arabia./I-per

# %%
# Here we can select the sentence in which we want to compare the true and the predicted tags
# Select a sentence between 1 and 10
i=1
sentence = test_sentences[i-1]
new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(sentence.split(), test_tags[i-1], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# The             (O    ): O
# programmers     (O    ): O
# from            (O    ): O
# Barcelona       (B-geo): B-org
# might           (O    ): O
# write           (O    ): O
# a               (O    ): O
# sentence        (O    ): O
# without         (O    ): O
# a               (O    ): O
# spell           (O    ): O
# checker.        (O    ): O

# %% [markdown]
# #### Capital checking

# %%
new_seq = Sequence(x=X_test[0], y=[int(0) for w in X_test[0]])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(X_test[0], Y_test[0], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# Officials       (O    ): O
# said            (O    ): O
# Sunday          (B-tim): B-tim
# Jean            (B-per): B-per
# Rene            (I-per): I-per
# Anthony         (I-per): I-per
# was             (O    ): O
# killed          (O    ): O
# in              (O    ): O
# a               (O    ): O
# shootout        (O    ): O
# with            (O    ): O
# police          (O    ): O
# near            (O    ): O
# the             (O    ): O
# capital         (O    ): O
# city            (O    ): O
# of              (O    ): O
# Port-au-Prince  (B-geo): O
# .               (O    ): O
