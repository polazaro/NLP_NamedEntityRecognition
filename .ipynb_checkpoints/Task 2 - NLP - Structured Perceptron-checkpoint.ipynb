# %% [markdown]
# # Task 2 - Natural Language Processing
#
# ## Structured Perceptron
#
# ### Rubén Barco Terrones - Aleix Casellas Comas - Andreu Masdeu Ninot - Pablo Lázaro Herrasti

# %% [markdown]
# ##### Imports

# %%
#### Basics
import pandas as pd
import numpy as np
# %matplotlib inline

import pickle
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

#### skseq Sequences
import scipy
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
import skseq
from skseq.sequences import sequence
from skseq.sequences.sequence import Sequence
from skseq.sequences.sequence_list import SequenceList
from skseq.sequences.label_dictionary import LabelDictionary

#### Feature mapper
import pprint
from skseq.sequences import extended_feature

#### Structured perceptron
import skseq.readers.pos_corpus
import skseq.sequences.structured_perceptron as spc

# %% [markdown]
# #### Functions:

# %%
from sklearn.utils.multiclass import unique_labels
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data

    fig, ax = plt.subplots()
    fig.set_figheight(20)
    fig.set_figwidth(20)
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %% [markdown]
# # TEST AND PREPROCESSING (NER_DATASET)

# %%
# data = pd.read_csv("ner_dataset.csv",encoding="latin1")
# data.head()

# %% [markdown]
# ### Preparing data

# %%
def build_word_to_pos(X):

    word_to_pos = {}
    i = 0
    for s in X:
        for w in s:
            if w not in word_to_pos:
                word_to_pos[w] = i
                i +=1
                
    pos_to_word = {v: k for k, v in word_to_pos.items()}
    return word_to_pos, pos_to_word
            
def build_tag_to_pos(Y):
    tag_to_pos = {}
    i = 0
    for s in Y:
        for t in s:
            if t not in tag_to_pos:
                tag_to_pos[t] = i
                i +=1
    pos_to_tag = {v: k for k, v in tag_to_pos.items()}

    return tag_to_pos, pos_to_tag

# %% [markdown]
# ### Train

# %%
# sentence_formatter = "Sentence: {}"

# last_n_train = 35971
# end_train   = data.index[data["Sentence #"] == sentence_formatter.format(last_n_train)][0]
# train = data[0:end_train]

# n_sentences_train = len(list(set(train["Sentence #"])))
# first_n_train = 1
# last_n_train = last_n_train -1
# print(n_sentences)

# %%
# n_sentences_train = len(list(set(train["Sentence #"])))

# %%
# %%time 
# sentence_formatter = "Sentence: {}"

# for s_id in  range(first_n_train, last_n_train):
#     print("current {}/{}".format(s_id,last_n_train), end="\r")
#     sentence_id = sentence_formatter.format(s_id)
#     sentence_id_next = sentence_formatter.format(s_id + 1)
#     start = train.index[train["Sentence #"] == sentence_id][0]
#     end   = train.index[train["Sentence #"] == sentence_id_next][0]
#     train["Sentence #"][start:end] = sentence_id
    
# sentence_id = sentence_formatter.format(last_n_train)
# start = train.index[train["Sentence #"] == sentence_id][0]
# end   = train.shape[0]
# train["Sentence #"][start:end] = sentence_id

# %%
# train.to_csv('train.csv', sep='\t')

# %%
# X_train = []
# Y_train = []

# sentence_formatter = "Sentence: {}"

# for i in range(1,n_sentences_train):
#     s = sentence_formatter.format(i)
#     X_train.append(list(train[train["Sentence #"]==s]["Word"].values))
#     Y_train.append(list(train[train["Sentence #"]==s]["Tag"].values))

# %%
# with open("X_train.txt", "wb") as fp:   #Pickling
#     pickle.dump(X_train, fp)
# with open("Y_train.txt", "wb") as fp:   #Pickling
#     pickle.dump(Y_train, fp)

# %%
with open("X_train.txt", "rb") as fp:   # Unpickling
    X_train = pickle.load(fp)
with open("Y_train.txt", "rb") as fp:   # Unpickling
    Y_train = pickle.load(fp)

# %%
i = 0
xy = ["{}/{}".format(x,y) for x,y in zip(X_train[i],Y_train[i])]
" ".join(xy)
# Out:
# 'Thousands/O of/O demonstrators/O have/O marched/O through/O London/B-geo to/O protest/O the/O war/O in/O Iraq/B-geo and/O demand/O the/O withdrawal/O of/O British/B-gpe troops/O from/O that/O country/O ./O'

# %%
word_to_pos, pos_to_word = build_word_to_pos(X_train)
tag_to_pos, pos_to_tag  = build_tag_to_pos(Y_train)

len(word_to_pos), len(tag_to_pos)
# Out:
# (30863, 17)

# %%
X_ids_train = [[word_to_pos[w] for w in s] for s in X_train]
Y_ids_train = [[tag_to_pos[t] for t in s] for s in Y_train]

# %%
# sequence_list = SequenceList(LabelDictionary(word_to_pos), LabelDictionary(tag_to_pos))
# for x,y in zip(X_train,Y_train):
#     sequence_list.add_sequence(x,y, LabelDictionary(word_to_pos), LabelDictionary(tag_to_pos))

# %%
# sequence_list[0].to_words(sequence_list=sequence_list)

# %%
# with open('sequence_list_train', 'wb') as sqq:
 
#     pickle.dump(sequence_list, sqq)

# %%
with open("sequence_list_train", "rb") as fp:   # Unpickling
    sequence_list_train = pickle.load(fp)

# %%
sequence_list_train[3]
# Out:
# 49/0 50/0 9/0 51/0 1/0 52/0 53/0 54/0 55/0 56/0 57/0 58/0 59/0 60/0 21/0

# %% [markdown]
# ### Test

# %%
# sentence_formatter = "Sentence: {}"

# test = data[end_train:len(data)]

# n_sentences_test = len(list(set(test["Sentence #"])))
# first_n_test = last_n_train + 1
# last_n_test = 47959
# print(n_sentences_test)

# %%
# %%time 
# sentence_formatter = "Sentence: {}"

# for s_id in  range(first_n_test, last_n_test):
#     print("current {}/{}".format(s_id,last_n_test), end="\r")
#     sentence_id = sentence_formatter.format(s_id)
#     sentence_id_next = sentence_formatter.format(s_id + 1)
#     start = data.index[data["Sentence #"] == sentence_id][0]
#     end   = data.index[data["Sentence #"] == sentence_id_next][0]
#     data["Sentence #"][start:end] = sentence_id
    
# sentence_id = sentence_formatter.format(last_n_test)
# start = data.index[data["Sentence #"] == sentence_id][0]
# end   = data.shape[0]
# data["Sentence #"][start:end] = sentence_id

# %%
# test.to_csv('test.csv', sep='\t')

# %%
# X_test = []
# Y_test = []

# sentence_formatter = "Sentence: {}"

# for i in range(n_sentences_train+1,n_sentences_train+n_sentences_test-1):
#     s = sentence_formatter.format(i)
#     X_test.append(list(data[data["Sentence #"]==s]["Word"].values))
#     Y_test.append(list(data[data["Sentence #"]==s]["Tag"].values))

# %%
# with open("X_test.txt", "wb") as fp:   #Pickling
#     pickle.dump(X_test, fp)
# with open("Y_test.txt", "wb") as fp:   #Pickling
#     pickle.dump(Y_test, fp)

# %%
with open("X_test.txt", "rb") as fp:   # Unpickling
    X_test = pickle.load(fp)
with open("Y_test.txt", "rb") as fp:   # Unpickling
    Y_test = pickle.load(fp)

# %%
i = 0
xy = ["{}/{}".format(x,y) for x,y in zip(X_test[i],Y_test[i])]
" ".join(xy)
# Out:
# 'Officials/O said/O Sunday/B-tim Jean/B-per Rene/I-per Anthony/I-per was/O killed/O in/O a/O shootout/O with/O police/O near/O the/O capital/O city/O of/O Port-au-Prince/B-geo ./O'

# %%
Y_ids_test = [[tag_to_pos[t] for t in s] for s in Y_test]

# %% [markdown]
# # EXPERIMENT 1: Basic features

# %% [markdown]
# ##### Comments:
# In this first experiment we are going to use only the **default features** in the ExtendedFeatures class. We want to have this experiment as the base experiment in order to be able to see the errors and how to solve them and to compare the future results with this one.

# %% [markdown]
# ### Extended features

# %%
ex_feature_mapper = skseq.sequences.extended_feature.ExtendedFeatures(sequence_list_train) 
ex_feature_mapper.build_features()
pprint.pprint(list(ex_feature_mapper.__dict__.keys()))
# Out:
# ['feature_dict',
#  'feature_list',
#  'add_features',
#  'dataset',
#  'node_feature_cache',
#  'initial_state_feature_cache',
#  'final_state_feature_cache',
#  'edge_feature_cache']

# %%
len(ex_feature_mapper.feature_dict)
# Out:
# 38298

# %%
ex_feature_mapper.feature_dict
# Out:
# {'init_tag:O': 0,
#  'id:Thousands::O': 1,
#  'id:of::O': 2,
#  'prev_tag:O::O': 3,
#  'id:demonstrators::O': 4,
#  'id:have::O': 5,
#  'id:marched::O': 6,
#  'id:through::O': 7,
#  'id:London::B-geo': 8,
#  'prev_tag:O::B-geo': 9,
#  'id:to::O': 10,
#  'prev_tag:B-geo::O': 11,
#  'id:protest::O': 12,
#  'id:the::O': 13,
#  'id:war::O': 14,
#  'id:in::O': 15,
#  'id:Iraq::B-geo': 16,
#  'id:and::O': 17,
#  'id:demand::O': 18,
#  'id:withdrawal::O': 19,
#  'id:British::B-gpe': 20,
#  'prev_tag:O::B-gpe': 21,
#  'id:troops::O': 22,
#  'prev_tag:B-gpe::O': 23,
#  'id:from::O': 24,
#  'id:that::O': 25,
#  'id:country::O': 26,
#  'id:.::O': 27,
#  'final_prev_tag:O': 28,
#  'id:Families::O': 29,
#  'id:soldiers::O': 30,
#  'id:killed::O': 31,
#  'id:conflict::O': 32,
#  'id:joined::O': 33,
#  'id:protesters::O': 34,
#  'id:who::O': 35,
#  'id:carried::O': 36,
#  'id:banners::O': 37,
#  'id:with::O': 38,
#  'id:such::O': 39,
#  'id:slogans::O': 40,
#  'id:as::O': 41,
#  'id:"::O': 42,
#  'id:Bush::B-per': 43,
#  'prev_tag:O::B-per': 44,
#  'id:Number::O': 45,
#  'prev_tag:B-per::O': 46,
#  'id:One::O': 47,
#  'id:Terrorist::O': 48,
#  'id:Stop::O': 49,
#  'id:Bombings::O': 50,
#  'id:They::O': 51,
#  'id:Houses::O': 52,
#  'id:Parliament::O': 53,
#  'id:a::O': 54,
#  'id:rally::O': 55,
#  'id:Hyde::B-geo': 56,
#  'id:Park::I-geo': 57,
#  'prev_tag:B-geo::I-geo': 58,
#  'prev_tag:I-geo::O': 59,
#  'id:Police::O': 60,
#  'id:put::O': 61,
#  'id:number::O': 62,
#  'id:marchers::O': 63,
#  'id:at::O': 64,
#  'id:10,000::O': 65,
#  'id:while::O': 66,
#  'id:organizers::O': 67,
#  'id:claimed::O': 68,
#  'id:it::O': 69,
#  'id:was::O': 70,
#  'id:1,00,000::O': 71,
#  'id:The::O': 72,
#  'id:comes::O': 73,
#  'id:on::O': 74,
#  'id:eve::O': 75,
#  'id:annual::O': 76,
#  'id:conference::O': 77,
#  'id:Britain::B-geo': 78,
#  "id:'s::O": 79,
#  'id:ruling::O': 80,
#  'id:Labor::B-org': 81,
#  'prev_tag:O::B-org': 82,
#  'id:Party::I-org': 83,
#  'prev_tag:B-org::I-org': 84,
#  'prev_tag:I-org::O': 85,
#  'id:southern::O': 86,
#  'id:English::B-gpe': 87,
#  'id:seaside::O': 88,
#  'id:resort::O': 89,
#  'id:Brighton::B-geo': 90,
#  'id:party::O': 91,
#  'id:is::O': 92,
#  'id:divided::O': 93,
#  'id:over::O': 94,
#  'id:Britain::B-gpe': 95,
#  'id:participation::O': 96,
#  'id:continued::O': 97,
#  'id:deployment::O': 98,
#  'id:8,500::O': 99,
#  'id:march::O': 100,
#  'id:came::O': 101,
#  'id:ahead::O': 102,
#  'id:anti-war::O': 103,
#  'id:protests::O': 104,
#  'id:today::O': 105,
#  'id:other::O': 106,
#  'id:cities::O': 107,
#  'id:,::O': 108,
#  'id:including::O': 109,
#  'id:Rome::B-geo': 110,
#  'id:Paris::B-geo': 111,
#  'id:Madrid::B-geo': 112,
#  'id:International::B-org': 113,
#  'id:Atomic::I-org': 114,
#  'id:Energy::I-org': 115,
#  'prev_tag:I-org::I-org': 116,
#  'id:Agency::I-org': 117,
#  'id:hold::O': 118,
#  'id:second::O': 119,
#  'id:day::O': 120,
#  'id:talks::O': 121,
#  'id:Vienna::B-geo': 122,
#  'id:Wednesday::B-tim': 123,
#  'prev_tag:B-geo::B-tim': 124,
#  'prev_tag:B-tim::O': 125,
#  'id:how::O': 126,
#  'id:respond::O': 127,
#  'id:Iran::B-gpe': 128,
#  'id:resumption::O': 129,
#  'id:low-level::O': 130,
#  'id:uranium::O': 131,
#  'id:conversion::O': 132,
#  'init_tag:B-gpe': 133,
#  'id:this::O': 134,
#  'id:week::O': 135,
#  'id:restarted::O': 136,
#  'id:parts::O': 137,
#  'id:process::O': 138,
#  'id:its::O': 139,
#  'id:Isfahan::B-geo': 140,
#  'id:nuclear::O': 141,
#  'id:plant::O': 142,
#  'id:Iranian::B-gpe': 143,
#  'id:officials::O': 144,
#  'id:say::O': 145,
#  'id:they::O': 146,
#  'id:expect::O': 147,
#  'id:get::O': 148,
#  'id:access::O': 149,
#  'id:sealed::O': 150,
#  'id:sensitive::O': 151,
#  'prev_tag:O::B-tim': 152,
#  'id:after::O': 153,
#  'id:an::O': 154,
#  'id:IAEA::B-org': 155,
#  'id:surveillance::O': 156,
#  'prev_tag:B-org::O': 157,
#  'id:system::O': 158,
#  'id:begins::O': 159,
#  'id:functioning::O': 160,
#  'id:step::O': 161,
#  'id:will::O': 162,
#  'id:allow::O': 163,
#  'id:facility::O': 164,
#  'id:operate::O': 165,
#  'id:full::O': 166,
#  'id:capacity::O': 167,
#  'id:European::B-org': 168,
#  'id:Union::I-org': 169,
#  'id:U.S.::B-gpe': 170,
#  'id:backing::O': 171,
#  'id:has::O': 172,
#  'id:threatened::O': 173,
#  'id:refer::O': 174,
#  'id:U.N.::B-org': 175,
#  'id:Security::I-org': 176,
#  'id:Council::I-org': 177,
#  'id:which::O': 178,
#  'id:could::O': 179,
#  'id:impose::O': 180,
#  'id:sanctions::O': 181,
#  'id:if::O': 182,
#  'id:finds::O': 183,
#  'id:Tehran::B-gpe': 184,
#  'id:violated::O': 185,
#  'id:Nuclear::B-art': 186,
#  'prev_tag:O::B-art': 187,
#  'id:Non-Proliferation::I-art': 188,
#  'prev_tag:B-art::I-art': 189,
#  'id:treaty::O': 190,
#  'prev_tag:I-art::O': 191,
#  'id:new::O': 192,
#  'id:President::B-per': 193,
#  'id:Mahmoud::I-per': 194,
#  'prev_tag:B-per::I-per': 195,
#  'id:Ahmadinejad::I-per': 196,
#  'prev_tag:I-per::I-per': 197,
#  'id:said::O': 198,
#  'prev_tag:I-per::O': 199,
#  'id:Tuesday::B-tim': 200,
#  'id:European::B-gpe': 201,
#  'id:incentives::O': 202,
#  'id:aimed::O': 203,
#  'id:persuading::O': 204,
#  'id:end::O': 205,
#  'id:fuel::O': 206,
#  'id:program::O': 207,
#  'id:are::O': 208,
#  'id:insult::O': 209,
#  'id:nation::O': 210,
#  'id:Two::O': 211,
#  'id:Germans::B-gpe': 212,
#  'id:four::O': 213,
#  'id:Nigerian::B-gpe': 214,
#  'id:oil::O': 215,
#  'id:workers::O': 216,
#  'id:were::O': 217,
#  'id:kidnapped::O': 218,
#  'id:by::O': 219,
#  'id:armed::O': 220,
#  'id:militants::O': 221,
#  'id:during::O': 222,
#  'id:raid::O': 223,
#  'id:boat::O': 224,
#  'id:Nigeria::B-geo': 225,
#  'id:oil-rich::O': 226,
#  'id:Delta::B-geo': 227,
#  'id:region::O': 228,
#  'id:An::O': 229,
#  'id:official::O': 230,
#  'id:German::B-gpe': 231,
#  'id:firm::O': 232,
#  'id:Bilfinger::B-org': 233,
#  'id:Berger::I-org': 234,
#  'id:Thomas::B-per': 235,
#  'id:Horbach::I-per': 236,
#  'id:gunmen::O': 237,
#  'id:stopped::O': 238,
#  'id:supply::O': 239,
#  'id:sailed::O': 240,
#  'id:State::I-geo': 241,
#  'id:Bayelsa::B-geo': 242,
#  'id:inspect::O': 243,
#  'id:offshore::O': 244,
#  'id:field::O': 245,
#  'id:owned::O': 246,
#  'id:Royal-Dutch::B-org': 247,
#  'id:Shell::I-org': 248,
#  'id:works::O': 249,
#  'id:sub-contractor::O': 250,
#  'id:for::O': 251,
#  'id:Shell::B-org': 252,
#  'id:Militant::O': 253,
#  'id:groups::O': 254,
#  'id:frequently::O': 255,
#  'id:attack::O': 256,
#  'id:operations::O': 257,
#  'id:Niger::B-geo': 258,
#  'id:Delta::I-geo': 259,
#  'id:social::O': 260,
#  'id:services::O': 261,
#  'id:better::O': 262,
#  'id:job::O': 263,
#  'id:opportunities::O': 264,
#  'id:multinational::O': 265,
#  'id:companies::O': 266,
#  'id:Poor::O': 267,
#  'id:residents::O': 268,
#  'id:often::O': 269,
#  'id:complain::O': 270,
#  'id:been::O': 271,
#  'id:cheated::O': 272,
#  'id:out::O': 273,
#  'id:huge::O': 274,
#  'id:riches::O': 275,
#  'id:extracted::O': 276,
#  'id:their::O': 277,
#  'id:tribal::O': 278,
#  'id:lands::O': 279,
#  'id:-::O': 280,
#  'id:where::O': 281,
#  'id:bulk::O': 282,
#  'id:Nigeria::B-gpe': 283,
#  'id:2.3::O': 284,
#  'id:million::O': 285,
#  'id:barrels::O': 286,
#  'id:petroleum::O': 287,
#  'id:pumped::O': 288,
#  'id:daily::O': 289,
#  'id:Suspected::O': 290,
#  'id:Islamist::O': 291,
#  'id:rebels::O': 292,
#  'id:fired::O': 293,
#  'id:mortar::O': 294,
#  'id:shells::O': 295,
#  'id:palace::O': 296,
#  'id:used::O': 297,
#  'id:Somalia::B-geo': 298,
#  'id:interim::O': 299,
#  'id:Abdullahi::I-per': 300,
#  'id:Yusuf::I-per': 301,
#  'id:Ahmad::I-per': 302,
#  'id:It::O': 303,
#  'id:not::O': 304,
#  'id:immediately::O': 305,
#  'id:clear::O': 306,
#  'id:president::O': 307,
#  'id:Mogadishu::B-geo': 308,
#  'id:when::O': 309,
#  'id:occurred::O': 310,
#  'id:or::O': 311,
#  'id:anyone::O': 312,
#  'id:hurt::O': 313,
#  'id:Local::O': 314,
#  'id:news::O': 315,
#  'id:reports::O': 316,
#  'id:least::O': 317,
#  'id:five::O': 318,
#  'id:hit::O': 319,
#  'id:compound::O': 320,
#  'id:mortars::O': 321,
#  'id:elsewhere::O': 322,
#  'id:attacks::O': 323,
#  'id:government::O': 324,
#  'id:go::O': 325,
#  'id:reconciliation::O': 326,
#  'id:more::O': 327,
#  'id:than::O': 328,
#  'id:1,300::O': 329,
#  'id:Somali::B-gpe': 330,
#  'id:elders::O': 331,
#  'id:warlords::O': 332,
#  'id:politicians::O': 333,
#  'id:invited::O': 334,
#  'id:Iraqi::B-gpe': 335,
#  'id:military::O': 336,
#  'id:tanks::O': 337,
#  'id:arrived::O': 338,
#  'id:northern::O': 339,
#  'id:city::O': 340,
#  'id:Mosul::B-geo': 341,
#  'id:offensive::O': 342,
#  'id:against::O': 343,
#  'id:al::B-org': 344,
#  'id:Qaida::I-org': 345,
#  'id:in::I-org': 346,
#  'id:Iraq::I-org': 347,
#  'id:fighters::O': 348,
#  'id:Officials::O': 349,
#  'id:many::O': 350,
#  'id:Sunni::B-geo': 351,
#  'id:Arab::I-geo': 352,
#  'id:Kurdish::B-geo': 353,
#  'id:bombings::O': 354,
#  'id:last::O': 355,
#  'id:34::O': 356,
#  'id:people::O': 357,
#  'id:wounded::O': 358,
#  'id:200::O': 359,
#  'id:commanders::O': 360,
#  'id:explained::O': 361,
#  'id:American::B-gpe': 362,
#  'id:forces::O': 363,
#  'id:participate::O': 364,
#  'id:fled::O': 365,
#  'id:successful::O': 366,
#  'id:campaigns::O': 367,
#  'id:them::O': 368,
#  'id:Anbar::B-geo': 369,
#  'id:province::O': 370,
#  'id:Baghdad::B-geo': 371,
#  'id:provinces::O': 372,
#  'init_tag:B-geo': 373,
#  'id:largest::O': 374,
#  'id:north::O': 375,
#  'id:long::O': 376,
#  'id:stronghold::O': 377,
#  'id:Sunni::B-org': 378,
#  'id:militant::O': 379,
#  'id:In::O': 380,
#  'id:violence::O': 381,
#  'id:one::O': 382,
#  'id:soldier::O': 383,
#  'id:patrol::O': 384,
#  'id:Sunday::B-tim': 385,
#  'id:Egyptian::B-gpe': 386,
#  'id:police::O': 387,
#  'id:arrested::O': 388,
#  'id:16::O': 389,
#  'id:members::O': 390,
#  'id:opposition::O': 391,
#  'id:Muslim::B-org': 392,
#  'id:Brotherhood::I-org': 393,
#  'id:prepare::O': 394,
#  'id:parliamentary::O': 395,
#  'id:runoff::O': 396,
#  'id:elections::O': 397,
#  'id:Saturday::B-tim': 398,
#  'id:arrests::O': 399,
#  'id:Friday::B-tim': 400,
#  'id:Alexandria::B-geo': 401,
#  'id:A::O': 402,
#  'id:spokesman::O': 403,
#  'id:Brotherhood::B-org': 404,
#  'id:attempt::O': 405,
#  'id:cut::O': 406,
#  'id:off::O': 407,
#  'id:supporters::O': 408,
#  'id:punishment::O': 409,
#  'id:winning::O': 410,
#  'id:seats::O': 411,
#  'id:earlier::O': 412,
#  'id:tripled::O': 413,
#  'id:strength::O': 414,
#  'id:parliament::O': 415,
#  'id:recent::O': 416,
#  'id:raising::O': 417,
#  'id:total::O': 418,
#  'id:47::O': 419,
#  'id:voters::O': 420,
#  'id:cast::O': 421,
#  'id:ballots::O': 422,
#  'id:nine::O': 423,
#  'id:no::O': 424,
#  'id:candidate::O': 425,
#  'id:won::O': 426,
#  'id:majority::O': 427,
#  'id:previous::O': 428,
#  'id:round::O': 429,
#  'id:voting::O': 430,
#  'id:banned::O': 431,
#  'id:political::O': 432,
#  'id:but::O': 433,
#  'id:endorses::O': 434,
#  'id:so-called::O': 435,
#  'id:independent::O': 436,
#  'id:candidates::O': 437,
#  'id:whose::O': 438,
#  'id:allegiance::O': 439,
#  'id:known::O': 440,
#  'id:Hardline::O': 441,
#  'id:lawmakers::O': 442,
#  'id:Pakistan::B-geo': 443,
#  'id:North::B-geo': 444,
#  'id:West::I-geo': 445,
#  'id:Frontier::I-geo': 446,
#  'prev_tag:I-geo::I-geo': 447,
#  'id:Province::I-geo': 448,
#  'id:pushed::O': 449,
#  'id:law::O': 450,
#  'id:aims::O': 451,
#  'id:ensure::O': 452,
#  'id:Islamic::O': 453,
#  'id:correctness::O': 454,
#  'id:public::O': 455,
#  'id:places::O': 456,
#  'id:establishes::O': 457,
#  'id:morality::O': 458,
#  'id:enforce::O': 459,
#  'id:decent::O': 460,
#  'id:behavior::O': 461,
#  'id:six-party::O': 462,
#  'id:coalition::O': 463,
#  'id:religious::O': 464,
#  'id:based::O': 465,
#  'id:parties::O': 466,
#  'id:Mutahida::B-org': 467,
#  'id:Majlis-e-Amal::I-org': 468,
#  'id:dominates::O': 469,
#  'id:provincial::O': 470,
#  'id:assembly::O': 471,
#  'id:so::O': 472,
#  'id:bill::O': 473,
#  'id:easily::O': 474,
#  'id:passed::O': 475,
#  'id:Thursday::B-tim': 476,
#  'id:vote::O': 477,
#  'id:68-34::O': 478,
#  'id:governor::O': 479,
#  'id:must::O': 480,
#  'id:still::O': 481,
#  'id:sign::O': 482,
#  'id:before::O': 483,
#  'id:becomes::O': 484,
#  'id:seen::O': 485,
#  'id:only::O': 486,
#  'id:formality::O': 487,
#  'id:proposed::O': 488,
#  'id:calls::O': 489,
#  'id:setting::O': 490,
#  'id:up::O': 491,
#  'id:force::O': 492,
#  'id:make::O': 493,
#  'id:sure::O': 494,
#  'id:adhere::O': 495,
#  'id:values::O': 496,
#  'id:entertainment::O': 497,
#  'id:outlets::O': 498,
#  'id:close::O': 499,
#  'id:weekly::O': 500,
#  'id:prayers::O': 501,
#  'id:Violators::O': 502,
#  'id:be::O': 503,
#  'id:jailed::O': 504,
#  'id:six::O': 505,
#  'id:months::O': 506,
#  'id:denounced::O': 507,
#  'id:measure::O': 508,
#  'id:comparing::O': 509,
#  'id:draconian::O': 510,
#  'id:rule::O': 511,
#  'id:former::O': 512,
#  'id:Taleban::B-org': 513,
#  'id:neighboring::O': 514,
#  'id:Afghanistan::B-geo': 515,
#  'id:man::O': 516,
#  'id:dressed::O': 517,
#  'id:suicide::O': 518,
#  'id:bomber::O': 519,
#  'id:demonstration::O': 520,
#  'id:publication::O': 521,
#  'id:cartoons::O': 522,
#  'id:depicting::O': 523,
#  'id:Islam::B-org': 524,
#  'id:Prophet::B-per': 525,
#  'id:Muhammad::I-per': 526,
#  'id:Bedfordshire::B-gpe': 527,
#  'id:Omar::B-per': 528,
#  'id:Khayam::I-per': 529,
#  'id:Bedford::B-geo': 530,
#  'id:breaching::O': 531,
#  'id:conditions::O': 532,
#  'id:his::O': 533,
#  'id:parole::O': 534,
#  'id:British::B-org': 535,
#  'id:Home::I-org': 536,
#  'id:Office::I-org': 537,
#  'id:sought::O': 538,
#  'id:investigation::O': 539,
#  'id:Khayam::B-per': 540,
#  'id:he::O': 541,
#  'id:photographed::O': 542,
#  'id:fatigues::O': 543,
#  'id:black::O': 544,
#  'id:cap::O': 545,
#  'id:bulky::O': 546,
#  'id:belt::O': 547,
#  'id:Home::B-org': 548,
#  'id:told::O': 549,
#  'id:Associated::B-org': 550,
#  'id:Press::I-org': 551,
#  'id:paroled::O': 552,
#  'id:offender::O': 553,
#  'id:gives::O': 554,
#  'id:cause::O': 555,
#  'id:concern::O': 556,
#  'id:can::O': 557,
#  'id:sent::O': 558,
#  'id:back::O': 559,
#  'id:prison::O': 560,
#  'id:AP::B-org': 561,
#  'id:also::O': 562,
#  'id:since::O': 563,
#  'id:year::O': 564,
#  'id:serving::O': 565,
#  'id:half::O': 566,
#  'id:six-year::O': 567,
#  'id:sentence::O': 568,
#  'id:drug::O': 569,
#  'id:dealing::O': 570,
#  'id:Pakistani::B-gpe': 571,
#  'id:unidentified::O': 572,
#  'id:three::O': 573,
#  'id:minister::O': 574,
#  'id:semi-autonomous::O': 575,
#  'id:bordering::O': 576,
#  'id:prominent::O': 577,
#  'id:leader::O': 578,
#  'id:Malik::B-per': 579,
#  'id:Faridullah::I-per': 580,
#  'id:Khan::I-per': 581,
#  'id:traveling::O': 582,
#  'id:South::B-geo': 583,
#  'id:Waziristan::I-geo': 584,
#  'prev_tag:I-geo::B-tim': 585,
#  'id:vehicle::O': 586,
#  'id:ambushed::O': 587,
#  'id:Kani::B-geo': 588,
#  'id:Wam::I-geo': 589,
#  'id:area::O': 590,
#  'id:His::O': 591,
#  'id:driver::O': 592,
#  'id:elder::O': 593,
#  'id:No::O': 594,
#  'id:responsibility::O': 595,
#  'id:killings::O': 596,
#  'id:ambush::O': 597,
#  'id:commander::O': 598,
#  'id:army::O': 599,
#  'id:almost::O': 600,
#  'id:completely::O': 601,
#  'id:eliminated::O': 602,
#  'id:became::O': 603,
#  'id:refuge::O': 604,
#  'id:al-Qaida::B-org': 605,
#  'id:ousted::O': 606,
#  'id:2001::B-tim': 607,
#  'id:senior::O': 608,
#  'id:says::O': 609,
#  'id:Pakistan::B-gpe': 610,
#  'id:wants::O': 611,
#  'id:what::O': 612,
#  'id:sordid::O': 613,
#  'id:chapter::O': 614,
#  'id:proliferation::O': 615,
#  'id:top::O': 616,
#  'id:scientists::O': 617,
#  'id:behind::O': 618,
#  'id:build::O': 619,
#  'id:civilian::O': 620,
#  'id:ties::O': 621,
#  'id:United::B-gpe': 622,
#  'id:States::I-gpe': 623,
#  'prev_tag:B-gpe::I-gpe': 624,
#  'prev_tag:I-gpe::O': 625,
#  'id:But::O': 626,
#  'id:ready::O': 627,
#  'id:scientist::O': 628,
#  'id:Abdul::B-per': 629,
#  'id:Qadeer::I-per': 630,
#  'id:available::O': 631,
#  'id:direct::O': 632,
#  'id:questioning::O': 633,
#  'id:sale::O': 634,
#  'id:secrets::O': 635,
#  'id:states::O': 636,
#  'id:Libya::B-gpe': 637,
#  'id:North::B-gpe': 638,
#  'id:Korea::I-gpe': 639,
#  'id:He::O': 640,
#  'id:there::O': 641,
#  'id:reasons::O': 642,
#  'id:national::O': 643,
#  'id:sensitivities::O': 644,
#  'id:making::O': 645,
#  'id:him::O': 646,
#  'id:giving::O': 647,
#  'id:background::O': 648,
#  'id:briefing::O': 649,
#  'id:small::O': 650,
#  'id:group::O': 651,
#  'id:reporters::O': 652,
#  'id:Washington::B-geo': 653,
#  'init_tag:B-per': 654,
#  'id:Khan::B-per': 655,
#  'id:admitted::O': 656,
#  'id:2004::B-tim': 657,
#  'id:operated::O': 658,
#  'id:worldwide::O': 659,
#  'id:clandestine::O': 660,
#  'id:network::O': 661,
#  'id:sell::O': 662,
#  'id:technology::O': 663,
#  'id:market::O': 664,
#  'id:placed::O': 665,
#  'id:under::O': 666,
#  'id:house::O': 667,
#  'id:arrest::O': 668,
#  'id:Islamabad::B-geo': 669,
#  'id:because::O': 670,
#  'id:considered::O': 671,
#  'id:father::O': 672,
#  'id:bomb::O': 673,
#  'id:Army::B-org': 674,
#  'prev_tag:B-gpe::B-org': 675,
#  'id:renew::O': 676,
#  'id:controversial::O': 677,
#  'id:multi-billion::O': 678,
#  'id:dollar::O': 679,
#  'id:contract::O': 680,
#  'id:Halliburton::B-org': 681,
#  'id:company::O': 682,
#  'id:provide::O': 683,
#  'id:logistical::O': 684,
#  'id:support::O': 685,
#  'init_tag:B-org': 686,
#  'id:providing::O': 687,
#  'id:list::O': 688,
#  'id:meals::O': 689,
#  'id:communication::O': 690,
#  'id:several::O': 691,
#  'id:years::O': 692,
#  'id:Critics::O': 693,
#  'id:include::O': 694,
#  'id:auditors::O': 695,
#  'id:congressional::O': 696,
#  'id:Democrats::O': 697,
#  'id:produced::O': 698,
#  'id:some::O': 699,
#  'id:shoddy::O': 700,
#  'id:work::O': 701,
#  'id:charges::O': 702,
#  'id:too::O': 703,
#  'id:much::O': 704,
#  'id:money::O': 705,
#  'id:strongly::O': 706,
#  'id:denies::O': 707,
#  'id:allegations::O': 708,
#  'id:When::O': 709,
#  'id:re-bidding::O': 710,
#  'id:chance::O': 711,
#  'id:compete::O': 712,
#  'id:portions::O': 713,
#  'id:Representatives::O': 714,
#  'id:Asia::B-org': 715,
#  'id:Pacific::I-org': 716,
#  'id:Economic::I-org': 717,
#  'id:Cooperation::I-org': 718,
#  'id:Business::I-org': 719,
#  'id:Advisory::I-org': 720,
#  'id:holding::O': 721,
#  'id:meetings::O': 722,
#  'id:finalize::O': 723,
#  'id:report::O': 724,
#  'id:APEC::B-org': 725,
#  'id:leaders::O': 726,
#  'id:summit::O': 727,
#  'id:September::B-tim': 728,
#  'id:8::I-tim': 729,
#  'prev_tag:B-tim::I-tim': 730,
#  'prev_tag:I-tim::O': 731,
#  'id:9::B-tim': 732,
#  'id:VOA::B-org': 733,
#  'id:Nancy-Amelia::B-per': 734,
#  'id:Collins::I-per': 735,
#  'id:Sydney::B-geo': 736,
#  'id:Energy::O': 737,
#  'id:security::O': 738,
#  'id:climate::O': 739,
#  'id:change::O': 740,
#  'id:World::B-org': 741,
#  'id:Trade::I-org': 742,
#  'id:Organization::I-org': 743,
#  'id:stalled::O': 744,
#  'id:negotiations::O': 745,
#  'id:investment::O': 746,
#  'id:all::O': 747,
#  'id:expected::O': 748,
#  'id:among::O': 749,
#  'id:major::O': 750,
#  'id:topics::O': 751,
#  'id:ABAC::B-org': 752,
#  'id:Tim::B-per': 753,
#  'id:Harcourt::I-per': 754,
#  'id:chief::O': 755,
#  'id:economist::O': 756,
#  'id:Australian::B-org': 757,
#  'id:Commission::I-org': 758,
#  'id:plays::O': 759,
#  'id:important::O': 760,
#  'id:role::O': 761,
#  'id:informing::O': 762,
#  'id:governments::O': 763,
#  'id:problems::O': 764,
#  'id:most::O': 765,
#  'id:thing::O': 766,
#  'id:business::O': 767,
#  'id:do::O': 768,
#  'id:tell::O': 769,
#  'id:logjams::O': 770,
#  'id:obstacles::O': 771,
#  'id:things::O': 772,
#  'id:improve::O': 773,
#  'id:Harcourt::B-per': 774,
#  'id:I::O': 775,
#  'id:think::O': 776,
#  'id:actually::O': 777,
#  'id:played::O': 778,
#  'id:pretty::O': 779,
#  'id:good::O': 780,
#  'id:leadership::O': 781,
#  'id:talking::O': 782,
#  'id:about::O': 783,
#  'id:trade::O': 784,
#  'id:facilitation::O': 785,
#  'id:basically::O': 786,
#  'id:standards::O': 787,
#  'id:consistent::O': 788,
#  'id:harmonious::O': 789,
#  'id:across::O': 790,
#  'id:comprises::O': 791,
#  'id:private::O': 792,
#  'id:sector::O': 793,
#  'id:each::O': 794,
#  'id:21::O': 795,
#  'id:economies::O': 796,
#  'id:meets::O': 797,
#  'id:times::O': 798,
#  'id:made::O': 799,
#  'id:permanent::O': 800,
#  'id:body::O': 801,
#  'id:1995::B-tim': 802,
#  'id:perspective::O': 803,
#  'id:within::O': 804,
#  'id:Members::O': 805,
#  'id:represent::O': 806,
#  'id:range::O': 807,
#  'id:sectors::O': 808,
#  'id:medium::O': 809,
#  'id:businesses::O': 810,
#  'id:need::O': 811,
#  'id:energy::O': 812,
#  'id:efficiency::O': 813,
#  'id:encourage::O': 814,
#  'id:conservation::O': 815,
#  'id:practices::O': 816,
#  'id:discuss::O': 817,
#  'id:ways::O': 818,
#  'id:enhance::O': 819,
#  'id:regional::O': 820,
#  'id:cooperation::O': 821,
#  'id:reckon::O': 822,
#  "id:'ll::O": 823,
#  'id:talk::O': 824,
#  'id:little::O': 825,
#  'id:bit::O': 826,
#  'id:customs::O': 827,
#  'id:quarantine::O': 828,
#  'id:having::O': 829,
#  'id:arrangements::O': 830,
#  'id:around::O': 831,
#  'id:And::O': 832,
#  'id:want::O': 833,
#  'id:one-stop::O': 834,
#  'id:shop::O': 835,
#  'id:terms::O': 836,
#  'id:combining::O': 837,
#  'id:immigration::O': 838,
#  'id:together::O': 839,
#  'id:\x85::O': 840,
#  'id:just::O': 841,
#  'id:streamlined::O': 842,
#  'id:provides::O': 843,
#  'id:certainty::O': 844,
#  'id:non-governmental::O': 845,
#  'id:formal::O': 846,
#  'id:dialogue::O': 847,
#  'id:present::O': 848,
#  'id:meeting::O': 849,
#  'id:Sudan::B-gpe': 850,
#  'id:order::O': 851,
#  'id:Darfur::B-geo': 852,
#  'id:asking::O': 853,
#  'id:same::O': 854,
#  'id:Foreign::B-per': 855,
#  'id:Minister::I-per': 856,
#  'id:Mustafa::I-per': 857,
#  'id:Osman::I-per': 858,
#  'id:Ismail::I-per': 859,
#  'id:Sudanese::B-gpe': 860,
#  'id:withdraw::O': 861,
#  'id:positions::O': 862,
#  'id:held::O': 863,
#  'id:April::B-tim': 864,
#  'id:cease-fire::O': 865,
#  'id:western::O': 866,
#  'id:agree::O': 867,
#  'id:stop::O': 868,
#  'id:Mr.::B-per': 869,
#  'id:announced::O': 870,
#  'id:decision::O': 871,
#  'id:United::B-org': 872,
#  'id:Nations::I-org': 873,
#  'id:African::B-org': 874,
#  'id:Khartoum::B-geo': 875,
#  'id:weeks::O': 876,
#  'id:AU::B-org': 877,
#  'id:repeatedly::O': 878,
#  'id:truce::O': 879,
#  'init_tag:B-tim': 880,
#  'id:head::O': 881,
#  'id:accused::O': 882,
#  'id:helicopters::O': 883,
#  'id:bombing::O': 884,
#  'id:rebel::O': 885,
#  'id:sites::O': 886,
#  'id:Darfur::I-geo': 887,
#  'id:village::O': 888,
#  'id:Labado::B-geo': 889,
#  'id:Khartoum::B-gpe': 890,
#  'id:defending::O': 891,
#  'id:Aid::O': 892,
#  'id:relief::O': 893,
#  'id:efforts::O': 894,
#  'id:suspended::O': 895,
#  'id:due::O': 896,
#  'id:Indonesian::B-gpe': 897,
#  'id:men::O': 898,
#  'id:connection::O': 899,
#  'id:October::B-tim': 900,
#  'id:1::I-tim': 901,
#  'id:Bali::B-geo': 902,
#  'prev_tag:I-tim::B-geo': 903,
#  'id:left::O': 904,
#  'id:23::O': 905,
#  'id:dead::O': 906,
#  'id:flown::O': 907,
#  'id:Java::B-geo': 908,
#  'id:island::O': 909,
#  'id:headquarters::O': 910,
#  'id:Australian::B-gpe': 911,
#  'id:French::B-gpe': 912,
#  'id:agencies::O': 913,
#  'id:(::O': 914,
#  'id:Cholily::B-per': 915,
#  'id:)::O': 916,
#  'id:captured::O': 917,
#  'id:series::O': 918,
#  'id:counter-terrorism::O': 919,
#  'id:raids::O': 920,
#  'id:Indonesia::B-geo': 921,
#  'id:ended::O': 922,
#  'id:death::O': 923,
#  'id:alleged::O': 924,
#  'id:extremist::O': 925,
#  'id:bombmaker::O': 926,
#  'id:Azahari::B-per': 927,
#  'id:bin::I-per': 928,
#  'id:Husin::I-per': 929,
#  'id:authorities::O': 930,
#  'id:blame::O': 931,
#  'id:orchestrating::O': 932,
#  'id:month::O': 933,
#  'id:well::O': 934,
#  'id:2002::B-tim': 935,
#  'prev_tag:B-tim::B-geo': 936,
#  'id:Gunmen::O': 937,
#  'id:shot::O': 938,
#  'id:Roman::B-org': 939,
#  'id:Catholic::I-org': 940,
#  'id:nun::O': 941,
#  'id:her::O': 942,
#  'id:bodyguard::O': 943,
#  'id:hospital::O': 944,
#  'id:she::O': 945,
#  'id:worked::O': 946,
#  'id:Islamist-controlled::O': 947,
#  'id:Some::O': 948,
#  'id:witnesses::O': 949,
#  'id:shooting::O': 950,
#  'id:feared::O': 951,
#  'id:linked::O': 952,
#  'id:Muslim::O': 953,
#  'id:anger::O': 954,
#  'id:toward::O': 955,
#  'id:Pope::B-per': 956,
#  'id:Benedict::I-per': 957,
#  'id:pistols::O': 958,
#  'id:attacked::O': 959,
#  'id:Sister::B-per': 960,
#  'id:Leonella::I-per': 961,
#  'id:Sgorbati::I-per': 962,
#  'id:finished::O': 963,
#  'id:teaching::O': 964,
#  'id:medical::O': 965,
#  'id:school::O': 966,
#  'id:class::O': 967,
#  'id:suspect::O': 968,
#  'id:Vatican::B-org': 969,
#  'id:deplored::O': 970,
#  'id:hoped::O': 971,
#  'id:isolated::O': 972,
#  'id:event::O': 973,
#  'id:irrationality::O': 974,
#  'id:arising::O': 975,
#  'id:comments::O': 976,
#  'id:Pope::O': 977,
#  'id:angered::O': 978,
#  'id:Muslims::O': 979,
#  'id:Authorities::O': 980,
#  'id:determined::O': 981,
#  'id:motive::O': 982,
#  'id:pope::O': 983,
#  'id:meant::O': 984,
#  'id:offense::O': 985,
#  'id:quoted::O': 986,
#  'id:14::O': 987,
#  'id:century::O': 988,
#  'id:Byzantine::B-per': 989,
#  'id:emperor::O': 990,
#  'id:saying::O': 991,
#  'id:teachings::O': 992,
#  'id:Muhammed::I-per': 993,
#  'id:brought::O': 994,
#  'id:evil::O': 995,
#  'id:world::O': 996,
#  'id:targeted::O': 997,
#  'id:northwest::O': 998,
#  'id:third::O': 999,
#  ...}

# %% [markdown]
# #### Training structured perceptron

# %%
corpus = skseq.readers.pos_corpus.PostagCorpus()
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)

# %%
sp.get_num_states(), sp.get_num_observations()
# Out:
# (17, 30863)

# %%
# %%time
num_epochs = 15
sp.fit(ex_feature_mapper.dataset, num_epochs)
# Out:
# Epoch: 0 Accuracy: 0.892678
# Epoch: 1 Accuracy: 0.931972
# Epoch: 2 Accuracy: 0.941622
# Epoch: 3 Accuracy: 0.947549
# Epoch: 4 Accuracy: 0.950647
# Epoch: 5 Accuracy: 0.953512
# Epoch: 6 Accuracy: 0.955472
# Epoch: 7 Accuracy: 0.957134
# Epoch: 8 Accuracy: 0.958280
# Epoch: 9 Accuracy: 0.958821
# Epoch: 10 Accuracy: 0.959816
# Epoch: 11 Accuracy: 0.960872
# Epoch: 12 Accuracy: 0.961597
# Epoch: 13 Accuracy: 0.962109
# Epoch: 14 Accuracy: 0.962987
# Wall time: 1h 4min 12s

# %%
sp.save_model("perceptron_ex1")

# %%
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)
sp.load_model(dir="perceptron_ex1")

# %% [markdown]
# #### Testing

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

y_pred_2 = []
y_true = [item for x in Y_ids_test for item in x]
correct_sentences = 0
n_test = len(X_test)

for i in range(n_test):
    y_pred_aux = sp.predict_tags_given_words(X_test[i])
    y_pred_2.append(y_pred_aux)
    if list(y_pred_aux) == Y_ids_test[i]:
        correct_sentences += 1
    
y_pred = [item for x in y_pred_2 for item in x]
F1_score_multi = f1_score(y_true, y_pred, average=None)
Accuracy = accuracy_score(y_true, y_pred)
print('Accuracy for test is: ' + str(Accuracy))
print('F1-Score for test is: ' + str(np.mean(F1_score_multi)))
print('Correct sentences for test (%) : ' + str(correct_sentences/n_test))
# Out:
# Accuracy for test is: 0.9497189411859115
# F1-Score for test is: 0.6325282666272773
# Correct sentences for test (%) : 0.4780613947280614

# %%
ax = plot_confusion_matrix(y_true, y_pred, classes=list(sp.state_labels),
                      title='Confusion matrix')

# %% [markdown]
# #### SENTENCES TO TEST THE MODEL

# %% [markdown]
# We think that these are the tags that the model should obtain:
#
# 1. The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 2. The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 3. Jack/B-per London/I-per went/O to/O Parris./O
#
# 4. Jack/B-per London/I-per went/O to/O/O Paris./B-geo
#
# 5. We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
#
# 6. We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
#
# 7. The/O president/O of/O U.S.A/B-geo though/O they/O could/O win/O the/O war/O
#
# 8. The/O president/O of/O the/O United/B-geo States/B-geo of/B-geo America/B-geo though/O they/O could/O win/O the/O war/O
#
# 9. The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
#
# 10. Robin/B-per does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
test_sentences = ["The programmers from Barcelona might write a sentence without a spell checker.", 
                  "The programmers from Barchelona cannot write a sentence without a spell checker.",
                  "Jack London went to Parris.",
                  "Jack London went to Paris.",
                  "We never though Microsoft would become such a big company.",
                  "We never though Microsof would become such a big company.",
                  "The president of U.S.A though they could win the war",
                  "The president of the United States of America though they could win the war",
                  "The king of Saudi Arabia wanted total control.",
                  "Robin does not want to go to Saudi Arabia."]

test_tags = [['O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['B-per', 'I-per', 'O', 'O', 'O'],
            ['B-per', 'I-per', 'O', 'O', 'B-geo'],
            ['O', 'O', 'O', 'B-org', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['O', 'O', 'O', 'O', 'B-geo', 'I-geo', 'I-geo', 'I-geo', 'O', 'O', 'O', 'O', 'O', 'O'],
            ['O', 'O', 'O', 'B-geo', 'I-geo', 'O', 'O', 'O'],
            ['B-per', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'I-geo']]

# %%
for sentence in test_sentences:
    new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
    print(sp.viterbi_decode(new_seq)[0].to_words(sequence_list_train, only_tag_translation=True))
# Out:
# The/O programmers/O from/O Barcelona/B-org might/O write/O a/O sentence/O without/O a/O spell/B-per checker./I-per
# The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/B-per checker./I-per
# Jack/B-per London/B-geo went/O to/O Parris./O
# Jack/B-per London/B-geo went/O to/O Paris./O
# We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
# We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
# The/O president/O of/O U.S.A/B-org though/O they/O could/O win/O the/O war/O
# The/O president/O of/O the/O United/B-geo States/I-geo of/I-geo America/I-geo though/O they/O could/O win/O the/O war/O
# The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
# Robin/B-org does/O not/O want/O to/O go/O to/O Saudi/O Arabia./O

# %%
# Here we can select the sentence in which we want to compare the true and the predicted tags
# Select a sentence between 1 and 10
i=1
sentence = test_sentences[i-1]
new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(sentence.split(), test_tags[i-1], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# The             (O    ): O
# programmers     (O    ): O
# from            (O    ): O
# Barcelona       (B-geo): B-org
# might           (O    ): O
# write           (O    ): O
# a               (O    ): O
# sentence        (O    ): O
# without         (O    ): O
# a               (O    ): O
# spell           (O    ): B-per
# checker.        (O    ): I-per

# %% [markdown]
# # EXPERIMENT 2:

# %% [markdown]
# ##### Comments:
# In the second experiment we are going to introduce the **hyphen features** to check if this information is useful or not.

# %% [markdown]
# ### Extended features

# %%
ex_feature_mapper = skseq.sequences.extended_feature.ExtendedFeatures(sequence_list_train) 
ex_feature_mapper.build_features()
pprint.pprint(list(ex_feature_mapper.__dict__.keys()))
# Out:
# ['feature_dict',
#  'feature_list',
#  'add_features',
#  'dataset',
#  'node_feature_cache',
#  'initial_state_feature_cache',
#  'final_state_feature_cache',
#  'edge_feature_cache']

# %%
len(ex_feature_mapper.feature_dict)
# Out:
# 38313

# %%
ex_feature_mapper.feature_dict
# Out:
# {'init_tag:O': 0,
#  'id:Thousands::O': 1,
#  'id:of::O': 2,
#  'prev_tag:O::O': 3,
#  'id:demonstrators::O': 4,
#  'id:have::O': 5,
#  'id:marched::O': 6,
#  'id:through::O': 7,
#  'id:London::B-geo': 8,
#  'prev_tag:O::B-geo': 9,
#  'id:to::O': 10,
#  'prev_tag:B-geo::O': 11,
#  'id:protest::O': 12,
#  'id:the::O': 13,
#  'id:war::O': 14,
#  'id:in::O': 15,
#  'id:Iraq::B-geo': 16,
#  'id:and::O': 17,
#  'id:demand::O': 18,
#  'id:withdrawal::O': 19,
#  'id:British::B-gpe': 20,
#  'prev_tag:O::B-gpe': 21,
#  'id:troops::O': 22,
#  'prev_tag:B-gpe::O': 23,
#  'id:from::O': 24,
#  'id:that::O': 25,
#  'id:country::O': 26,
#  'id:.::O': 27,
#  'final_prev_tag:O': 28,
#  'id:Families::O': 29,
#  'id:soldiers::O': 30,
#  'id:killed::O': 31,
#  'id:conflict::O': 32,
#  'id:joined::O': 33,
#  'id:protesters::O': 34,
#  'id:who::O': 35,
#  'id:carried::O': 36,
#  'id:banners::O': 37,
#  'id:with::O': 38,
#  'id:such::O': 39,
#  'id:slogans::O': 40,
#  'id:as::O': 41,
#  'id:"::O': 42,
#  'id:Bush::B-per': 43,
#  'prev_tag:O::B-per': 44,
#  'id:Number::O': 45,
#  'prev_tag:B-per::O': 46,
#  'id:One::O': 47,
#  'id:Terrorist::O': 48,
#  'id:Stop::O': 49,
#  'id:Bombings::O': 50,
#  'id:They::O': 51,
#  'id:Houses::O': 52,
#  'id:Parliament::O': 53,
#  'id:a::O': 54,
#  'id:rally::O': 55,
#  'id:Hyde::B-geo': 56,
#  'id:Park::I-geo': 57,
#  'prev_tag:B-geo::I-geo': 58,
#  'prev_tag:I-geo::O': 59,
#  'id:Police::O': 60,
#  'id:put::O': 61,
#  'id:number::O': 62,
#  'id:marchers::O': 63,
#  'id:at::O': 64,
#  'id:10,000::O': 65,
#  'id:while::O': 66,
#  'id:organizers::O': 67,
#  'id:claimed::O': 68,
#  'id:it::O': 69,
#  'id:was::O': 70,
#  'id:1,00,000::O': 71,
#  'id:The::O': 72,
#  'id:comes::O': 73,
#  'id:on::O': 74,
#  'id:eve::O': 75,
#  'id:annual::O': 76,
#  'id:conference::O': 77,
#  'id:Britain::B-geo': 78,
#  "id:'s::O": 79,
#  'id:ruling::O': 80,
#  'id:Labor::B-org': 81,
#  'prev_tag:O::B-org': 82,
#  'id:Party::I-org': 83,
#  'prev_tag:B-org::I-org': 84,
#  'prev_tag:I-org::O': 85,
#  'id:southern::O': 86,
#  'id:English::B-gpe': 87,
#  'id:seaside::O': 88,
#  'id:resort::O': 89,
#  'id:Brighton::B-geo': 90,
#  'id:party::O': 91,
#  'id:is::O': 92,
#  'id:divided::O': 93,
#  'id:over::O': 94,
#  'id:Britain::B-gpe': 95,
#  'id:participation::O': 96,
#  'id:continued::O': 97,
#  'id:deployment::O': 98,
#  'id:8,500::O': 99,
#  'id:march::O': 100,
#  'id:came::O': 101,
#  'id:ahead::O': 102,
#  'id:anti-war::O': 103,
#  'hyphen::O': 104,
#  'id:protests::O': 105,
#  'id:today::O': 106,
#  'id:other::O': 107,
#  'id:cities::O': 108,
#  'id:,::O': 109,
#  'id:including::O': 110,
#  'id:Rome::B-geo': 111,
#  'id:Paris::B-geo': 112,
#  'id:Madrid::B-geo': 113,
#  'id:International::B-org': 114,
#  'id:Atomic::I-org': 115,
#  'id:Energy::I-org': 116,
#  'prev_tag:I-org::I-org': 117,
#  'id:Agency::I-org': 118,
#  'id:hold::O': 119,
#  'id:second::O': 120,
#  'id:day::O': 121,
#  'id:talks::O': 122,
#  'id:Vienna::B-geo': 123,
#  'id:Wednesday::B-tim': 124,
#  'prev_tag:B-geo::B-tim': 125,
#  'prev_tag:B-tim::O': 126,
#  'id:how::O': 127,
#  'id:respond::O': 128,
#  'id:Iran::B-gpe': 129,
#  'id:resumption::O': 130,
#  'id:low-level::O': 131,
#  'id:uranium::O': 132,
#  'id:conversion::O': 133,
#  'init_tag:B-gpe': 134,
#  'id:this::O': 135,
#  'id:week::O': 136,
#  'id:restarted::O': 137,
#  'id:parts::O': 138,
#  'id:process::O': 139,
#  'id:its::O': 140,
#  'id:Isfahan::B-geo': 141,
#  'id:nuclear::O': 142,
#  'id:plant::O': 143,
#  'id:Iranian::B-gpe': 144,
#  'id:officials::O': 145,
#  'id:say::O': 146,
#  'id:they::O': 147,
#  'id:expect::O': 148,
#  'id:get::O': 149,
#  'id:access::O': 150,
#  'id:sealed::O': 151,
#  'id:sensitive::O': 152,
#  'prev_tag:O::B-tim': 153,
#  'id:after::O': 154,
#  'id:an::O': 155,
#  'id:IAEA::B-org': 156,
#  'id:surveillance::O': 157,
#  'prev_tag:B-org::O': 158,
#  'id:system::O': 159,
#  'id:begins::O': 160,
#  'id:functioning::O': 161,
#  'id:step::O': 162,
#  'id:will::O': 163,
#  'id:allow::O': 164,
#  'id:facility::O': 165,
#  'id:operate::O': 166,
#  'id:full::O': 167,
#  'id:capacity::O': 168,
#  'id:European::B-org': 169,
#  'id:Union::I-org': 170,
#  'id:U.S.::B-gpe': 171,
#  'id:backing::O': 172,
#  'id:has::O': 173,
#  'id:threatened::O': 174,
#  'id:refer::O': 175,
#  'id:U.N.::B-org': 176,
#  'id:Security::I-org': 177,
#  'id:Council::I-org': 178,
#  'id:which::O': 179,
#  'id:could::O': 180,
#  'id:impose::O': 181,
#  'id:sanctions::O': 182,
#  'id:if::O': 183,
#  'id:finds::O': 184,
#  'id:Tehran::B-gpe': 185,
#  'id:violated::O': 186,
#  'id:Nuclear::B-art': 187,
#  'prev_tag:O::B-art': 188,
#  'id:Non-Proliferation::I-art': 189,
#  'hyphen::I-art': 190,
#  'prev_tag:B-art::I-art': 191,
#  'id:treaty::O': 192,
#  'prev_tag:I-art::O': 193,
#  'id:new::O': 194,
#  'id:President::B-per': 195,
#  'id:Mahmoud::I-per': 196,
#  'prev_tag:B-per::I-per': 197,
#  'id:Ahmadinejad::I-per': 198,
#  'prev_tag:I-per::I-per': 199,
#  'id:said::O': 200,
#  'prev_tag:I-per::O': 201,
#  'id:Tuesday::B-tim': 202,
#  'id:European::B-gpe': 203,
#  'id:incentives::O': 204,
#  'id:aimed::O': 205,
#  'id:persuading::O': 206,
#  'id:end::O': 207,
#  'id:fuel::O': 208,
#  'id:program::O': 209,
#  'id:are::O': 210,
#  'id:insult::O': 211,
#  'id:nation::O': 212,
#  'id:Two::O': 213,
#  'id:Germans::B-gpe': 214,
#  'id:four::O': 215,
#  'id:Nigerian::B-gpe': 216,
#  'id:oil::O': 217,
#  'id:workers::O': 218,
#  'id:were::O': 219,
#  'id:kidnapped::O': 220,
#  'id:by::O': 221,
#  'id:armed::O': 222,
#  'id:militants::O': 223,
#  'id:during::O': 224,
#  'id:raid::O': 225,
#  'id:boat::O': 226,
#  'id:Nigeria::B-geo': 227,
#  'id:oil-rich::O': 228,
#  'id:Delta::B-geo': 229,
#  'id:region::O': 230,
#  'id:An::O': 231,
#  'id:official::O': 232,
#  'id:German::B-gpe': 233,
#  'id:firm::O': 234,
#  'id:Bilfinger::B-org': 235,
#  'id:Berger::I-org': 236,
#  'id:Thomas::B-per': 237,
#  'id:Horbach::I-per': 238,
#  'id:gunmen::O': 239,
#  'id:stopped::O': 240,
#  'id:supply::O': 241,
#  'id:sailed::O': 242,
#  'id:State::I-geo': 243,
#  'id:Bayelsa::B-geo': 244,
#  'id:inspect::O': 245,
#  'id:offshore::O': 246,
#  'id:field::O': 247,
#  'id:owned::O': 248,
#  'id:Royal-Dutch::B-org': 249,
#  'hyphen::B-org': 250,
#  'id:Shell::I-org': 251,
#  'id:works::O': 252,
#  'id:sub-contractor::O': 253,
#  'id:for::O': 254,
#  'id:Shell::B-org': 255,
#  'id:Militant::O': 256,
#  'id:groups::O': 257,
#  'id:frequently::O': 258,
#  'id:attack::O': 259,
#  'id:operations::O': 260,
#  'id:Niger::B-geo': 261,
#  'id:Delta::I-geo': 262,
#  'id:social::O': 263,
#  'id:services::O': 264,
#  'id:better::O': 265,
#  'id:job::O': 266,
#  'id:opportunities::O': 267,
#  'id:multinational::O': 268,
#  'id:companies::O': 269,
#  'id:Poor::O': 270,
#  'id:residents::O': 271,
#  'id:often::O': 272,
#  'id:complain::O': 273,
#  'id:been::O': 274,
#  'id:cheated::O': 275,
#  'id:out::O': 276,
#  'id:huge::O': 277,
#  'id:riches::O': 278,
#  'id:extracted::O': 279,
#  'id:their::O': 280,
#  'id:tribal::O': 281,
#  'id:lands::O': 282,
#  'id:-::O': 283,
#  'id:where::O': 284,
#  'id:bulk::O': 285,
#  'id:Nigeria::B-gpe': 286,
#  'id:2.3::O': 287,
#  'id:million::O': 288,
#  'id:barrels::O': 289,
#  'id:petroleum::O': 290,
#  'id:pumped::O': 291,
#  'id:daily::O': 292,
#  'id:Suspected::O': 293,
#  'id:Islamist::O': 294,
#  'id:rebels::O': 295,
#  'id:fired::O': 296,
#  'id:mortar::O': 297,
#  'id:shells::O': 298,
#  'id:palace::O': 299,
#  'id:used::O': 300,
#  'id:Somalia::B-geo': 301,
#  'id:interim::O': 302,
#  'id:Abdullahi::I-per': 303,
#  'id:Yusuf::I-per': 304,
#  'id:Ahmad::I-per': 305,
#  'id:It::O': 306,
#  'id:not::O': 307,
#  'id:immediately::O': 308,
#  'id:clear::O': 309,
#  'id:president::O': 310,
#  'id:Mogadishu::B-geo': 311,
#  'id:when::O': 312,
#  'id:occurred::O': 313,
#  'id:or::O': 314,
#  'id:anyone::O': 315,
#  'id:hurt::O': 316,
#  'id:Local::O': 317,
#  'id:news::O': 318,
#  'id:reports::O': 319,
#  'id:least::O': 320,
#  'id:five::O': 321,
#  'id:hit::O': 322,
#  'id:compound::O': 323,
#  'id:mortars::O': 324,
#  'id:elsewhere::O': 325,
#  'id:attacks::O': 326,
#  'id:government::O': 327,
#  'id:go::O': 328,
#  'id:reconciliation::O': 329,
#  'id:more::O': 330,
#  'id:than::O': 331,
#  'id:1,300::O': 332,
#  'id:Somali::B-gpe': 333,
#  'id:elders::O': 334,
#  'id:warlords::O': 335,
#  'id:politicians::O': 336,
#  'id:invited::O': 337,
#  'id:Iraqi::B-gpe': 338,
#  'id:military::O': 339,
#  'id:tanks::O': 340,
#  'id:arrived::O': 341,
#  'id:northern::O': 342,
#  'id:city::O': 343,
#  'id:Mosul::B-geo': 344,
#  'id:offensive::O': 345,
#  'id:against::O': 346,
#  'id:al::B-org': 347,
#  'id:Qaida::I-org': 348,
#  'id:in::I-org': 349,
#  'id:Iraq::I-org': 350,
#  'id:fighters::O': 351,
#  'id:Officials::O': 352,
#  'id:many::O': 353,
#  'id:Sunni::B-geo': 354,
#  'id:Arab::I-geo': 355,
#  'id:Kurdish::B-geo': 356,
#  'id:bombings::O': 357,
#  'id:last::O': 358,
#  'id:34::O': 359,
#  'id:people::O': 360,
#  'id:wounded::O': 361,
#  'id:200::O': 362,
#  'id:commanders::O': 363,
#  'id:explained::O': 364,
#  'id:American::B-gpe': 365,
#  'id:forces::O': 366,
#  'id:participate::O': 367,
#  'id:fled::O': 368,
#  'id:successful::O': 369,
#  'id:campaigns::O': 370,
#  'id:them::O': 371,
#  'id:Anbar::B-geo': 372,
#  'id:province::O': 373,
#  'id:Baghdad::B-geo': 374,
#  'id:provinces::O': 375,
#  'init_tag:B-geo': 376,
#  'id:largest::O': 377,
#  'id:north::O': 378,
#  'id:long::O': 379,
#  'id:stronghold::O': 380,
#  'id:Sunni::B-org': 381,
#  'id:militant::O': 382,
#  'id:In::O': 383,
#  'id:violence::O': 384,
#  'id:one::O': 385,
#  'id:soldier::O': 386,
#  'id:patrol::O': 387,
#  'id:Sunday::B-tim': 388,
#  'id:Egyptian::B-gpe': 389,
#  'id:police::O': 390,
#  'id:arrested::O': 391,
#  'id:16::O': 392,
#  'id:members::O': 393,
#  'id:opposition::O': 394,
#  'id:Muslim::B-org': 395,
#  'id:Brotherhood::I-org': 396,
#  'id:prepare::O': 397,
#  'id:parliamentary::O': 398,
#  'id:runoff::O': 399,
#  'id:elections::O': 400,
#  'id:Saturday::B-tim': 401,
#  'id:arrests::O': 402,
#  'id:Friday::B-tim': 403,
#  'id:Alexandria::B-geo': 404,
#  'id:A::O': 405,
#  'id:spokesman::O': 406,
#  'id:Brotherhood::B-org': 407,
#  'id:attempt::O': 408,
#  'id:cut::O': 409,
#  'id:off::O': 410,
#  'id:supporters::O': 411,
#  'id:punishment::O': 412,
#  'id:winning::O': 413,
#  'id:seats::O': 414,
#  'id:earlier::O': 415,
#  'id:tripled::O': 416,
#  'id:strength::O': 417,
#  'id:parliament::O': 418,
#  'id:recent::O': 419,
#  'id:raising::O': 420,
#  'id:total::O': 421,
#  'id:47::O': 422,
#  'id:voters::O': 423,
#  'id:cast::O': 424,
#  'id:ballots::O': 425,
#  'id:nine::O': 426,
#  'id:no::O': 427,
#  'id:candidate::O': 428,
#  'id:won::O': 429,
#  'id:majority::O': 430,
#  'id:previous::O': 431,
#  'id:round::O': 432,
#  'id:voting::O': 433,
#  'id:banned::O': 434,
#  'id:political::O': 435,
#  'id:but::O': 436,
#  'id:endorses::O': 437,
#  'id:so-called::O': 438,
#  'id:independent::O': 439,
#  'id:candidates::O': 440,
#  'id:whose::O': 441,
#  'id:allegiance::O': 442,
#  'id:known::O': 443,
#  'id:Hardline::O': 444,
#  'id:lawmakers::O': 445,
#  'id:Pakistan::B-geo': 446,
#  'id:North::B-geo': 447,
#  'id:West::I-geo': 448,
#  'id:Frontier::I-geo': 449,
#  'prev_tag:I-geo::I-geo': 450,
#  'id:Province::I-geo': 451,
#  'id:pushed::O': 452,
#  'id:law::O': 453,
#  'id:aims::O': 454,
#  'id:ensure::O': 455,
#  'id:Islamic::O': 456,
#  'id:correctness::O': 457,
#  'id:public::O': 458,
#  'id:places::O': 459,
#  'id:establishes::O': 460,
#  'id:morality::O': 461,
#  'id:enforce::O': 462,
#  'id:decent::O': 463,
#  'id:behavior::O': 464,
#  'id:six-party::O': 465,
#  'id:coalition::O': 466,
#  'id:religious::O': 467,
#  'id:based::O': 468,
#  'id:parties::O': 469,
#  'id:Mutahida::B-org': 470,
#  'id:Majlis-e-Amal::I-org': 471,
#  'hyphen::I-org': 472,
#  'id:dominates::O': 473,
#  'id:provincial::O': 474,
#  'id:assembly::O': 475,
#  'id:so::O': 476,
#  'id:bill::O': 477,
#  'id:easily::O': 478,
#  'id:passed::O': 479,
#  'id:Thursday::B-tim': 480,
#  'id:vote::O': 481,
#  'id:68-34::O': 482,
#  'id:governor::O': 483,
#  'id:must::O': 484,
#  'id:still::O': 485,
#  'id:sign::O': 486,
#  'id:before::O': 487,
#  'id:becomes::O': 488,
#  'id:seen::O': 489,
#  'id:only::O': 490,
#  'id:formality::O': 491,
#  'id:proposed::O': 492,
#  'id:calls::O': 493,
#  'id:setting::O': 494,
#  'id:up::O': 495,
#  'id:force::O': 496,
#  'id:make::O': 497,
#  'id:sure::O': 498,
#  'id:adhere::O': 499,
#  'id:values::O': 500,
#  'id:entertainment::O': 501,
#  'id:outlets::O': 502,
#  'id:close::O': 503,
#  'id:weekly::O': 504,
#  'id:prayers::O': 505,
#  'id:Violators::O': 506,
#  'id:be::O': 507,
#  'id:jailed::O': 508,
#  'id:six::O': 509,
#  'id:months::O': 510,
#  'id:denounced::O': 511,
#  'id:measure::O': 512,
#  'id:comparing::O': 513,
#  'id:draconian::O': 514,
#  'id:rule::O': 515,
#  'id:former::O': 516,
#  'id:Taleban::B-org': 517,
#  'id:neighboring::O': 518,
#  'id:Afghanistan::B-geo': 519,
#  'id:man::O': 520,
#  'id:dressed::O': 521,
#  'id:suicide::O': 522,
#  'id:bomber::O': 523,
#  'id:demonstration::O': 524,
#  'id:publication::O': 525,
#  'id:cartoons::O': 526,
#  'id:depicting::O': 527,
#  'id:Islam::B-org': 528,
#  'id:Prophet::B-per': 529,
#  'id:Muhammad::I-per': 530,
#  'id:Bedfordshire::B-gpe': 531,
#  'id:Omar::B-per': 532,
#  'id:Khayam::I-per': 533,
#  'id:Bedford::B-geo': 534,
#  'id:breaching::O': 535,
#  'id:conditions::O': 536,
#  'id:his::O': 537,
#  'id:parole::O': 538,
#  'id:British::B-org': 539,
#  'id:Home::I-org': 540,
#  'id:Office::I-org': 541,
#  'id:sought::O': 542,
#  'id:investigation::O': 543,
#  'id:Khayam::B-per': 544,
#  'id:he::O': 545,
#  'id:photographed::O': 546,
#  'id:fatigues::O': 547,
#  'id:black::O': 548,
#  'id:cap::O': 549,
#  'id:bulky::O': 550,
#  'id:belt::O': 551,
#  'id:Home::B-org': 552,
#  'id:told::O': 553,
#  'id:Associated::B-org': 554,
#  'id:Press::I-org': 555,
#  'id:paroled::O': 556,
#  'id:offender::O': 557,
#  'id:gives::O': 558,
#  'id:cause::O': 559,
#  'id:concern::O': 560,
#  'id:can::O': 561,
#  'id:sent::O': 562,
#  'id:back::O': 563,
#  'id:prison::O': 564,
#  'id:AP::B-org': 565,
#  'id:also::O': 566,
#  'id:since::O': 567,
#  'id:year::O': 568,
#  'id:serving::O': 569,
#  'id:half::O': 570,
#  'id:six-year::O': 571,
#  'id:sentence::O': 572,
#  'id:drug::O': 573,
#  'id:dealing::O': 574,
#  'id:Pakistani::B-gpe': 575,
#  'id:unidentified::O': 576,
#  'id:three::O': 577,
#  'id:minister::O': 578,
#  'id:semi-autonomous::O': 579,
#  'id:bordering::O': 580,
#  'id:prominent::O': 581,
#  'id:leader::O': 582,
#  'id:Malik::B-per': 583,
#  'id:Faridullah::I-per': 584,
#  'id:Khan::I-per': 585,
#  'id:traveling::O': 586,
#  'id:South::B-geo': 587,
#  'id:Waziristan::I-geo': 588,
#  'prev_tag:I-geo::B-tim': 589,
#  'id:vehicle::O': 590,
#  'id:ambushed::O': 591,
#  'id:Kani::B-geo': 592,
#  'id:Wam::I-geo': 593,
#  'id:area::O': 594,
#  'id:His::O': 595,
#  'id:driver::O': 596,
#  'id:elder::O': 597,
#  'id:No::O': 598,
#  'id:responsibility::O': 599,
#  'id:killings::O': 600,
#  'id:ambush::O': 601,
#  'id:commander::O': 602,
#  'id:army::O': 603,
#  'id:almost::O': 604,
#  'id:completely::O': 605,
#  'id:eliminated::O': 606,
#  'id:became::O': 607,
#  'id:refuge::O': 608,
#  'id:al-Qaida::B-org': 609,
#  'id:ousted::O': 610,
#  'id:2001::B-tim': 611,
#  'id:senior::O': 612,
#  'id:says::O': 613,
#  'id:Pakistan::B-gpe': 614,
#  'id:wants::O': 615,
#  'id:what::O': 616,
#  'id:sordid::O': 617,
#  'id:chapter::O': 618,
#  'id:proliferation::O': 619,
#  'id:top::O': 620,
#  'id:scientists::O': 621,
#  'id:behind::O': 622,
#  'id:build::O': 623,
#  'id:civilian::O': 624,
#  'id:ties::O': 625,
#  'id:United::B-gpe': 626,
#  'id:States::I-gpe': 627,
#  'prev_tag:B-gpe::I-gpe': 628,
#  'prev_tag:I-gpe::O': 629,
#  'id:But::O': 630,
#  'id:ready::O': 631,
#  'id:scientist::O': 632,
#  'id:Abdul::B-per': 633,
#  'id:Qadeer::I-per': 634,
#  'id:available::O': 635,
#  'id:direct::O': 636,
#  'id:questioning::O': 637,
#  'id:sale::O': 638,
#  'id:secrets::O': 639,
#  'id:states::O': 640,
#  'id:Libya::B-gpe': 641,
#  'id:North::B-gpe': 642,
#  'id:Korea::I-gpe': 643,
#  'id:He::O': 644,
#  'id:there::O': 645,
#  'id:reasons::O': 646,
#  'id:national::O': 647,
#  'id:sensitivities::O': 648,
#  'id:making::O': 649,
#  'id:him::O': 650,
#  'id:giving::O': 651,
#  'id:background::O': 652,
#  'id:briefing::O': 653,
#  'id:small::O': 654,
#  'id:group::O': 655,
#  'id:reporters::O': 656,
#  'id:Washington::B-geo': 657,
#  'init_tag:B-per': 658,
#  'id:Khan::B-per': 659,
#  'id:admitted::O': 660,
#  'id:2004::B-tim': 661,
#  'id:operated::O': 662,
#  'id:worldwide::O': 663,
#  'id:clandestine::O': 664,
#  'id:network::O': 665,
#  'id:sell::O': 666,
#  'id:technology::O': 667,
#  'id:market::O': 668,
#  'id:placed::O': 669,
#  'id:under::O': 670,
#  'id:house::O': 671,
#  'id:arrest::O': 672,
#  'id:Islamabad::B-geo': 673,
#  'id:because::O': 674,
#  'id:considered::O': 675,
#  'id:father::O': 676,
#  'id:bomb::O': 677,
#  'id:Army::B-org': 678,
#  'prev_tag:B-gpe::B-org': 679,
#  'id:renew::O': 680,
#  'id:controversial::O': 681,
#  'id:multi-billion::O': 682,
#  'id:dollar::O': 683,
#  'id:contract::O': 684,
#  'id:Halliburton::B-org': 685,
#  'id:company::O': 686,
#  'id:provide::O': 687,
#  'id:logistical::O': 688,
#  'id:support::O': 689,
#  'init_tag:B-org': 690,
#  'id:providing::O': 691,
#  'id:list::O': 692,
#  'id:meals::O': 693,
#  'id:communication::O': 694,
#  'id:several::O': 695,
#  'id:years::O': 696,
#  'id:Critics::O': 697,
#  'id:include::O': 698,
#  'id:auditors::O': 699,
#  'id:congressional::O': 700,
#  'id:Democrats::O': 701,
#  'id:produced::O': 702,
#  'id:some::O': 703,
#  'id:shoddy::O': 704,
#  'id:work::O': 705,
#  'id:charges::O': 706,
#  'id:too::O': 707,
#  'id:much::O': 708,
#  'id:money::O': 709,
#  'id:strongly::O': 710,
#  'id:denies::O': 711,
#  'id:allegations::O': 712,
#  'id:When::O': 713,
#  'id:re-bidding::O': 714,
#  'id:chance::O': 715,
#  'id:compete::O': 716,
#  'id:portions::O': 717,
#  'id:Representatives::O': 718,
#  'id:Asia::B-org': 719,
#  'id:Pacific::I-org': 720,
#  'id:Economic::I-org': 721,
#  'id:Cooperation::I-org': 722,
#  'id:Business::I-org': 723,
#  'id:Advisory::I-org': 724,
#  'id:holding::O': 725,
#  'id:meetings::O': 726,
#  'id:finalize::O': 727,
#  'id:report::O': 728,
#  'id:APEC::B-org': 729,
#  'id:leaders::O': 730,
#  'id:summit::O': 731,
#  'id:September::B-tim': 732,
#  'id:8::I-tim': 733,
#  'prev_tag:B-tim::I-tim': 734,
#  'prev_tag:I-tim::O': 735,
#  'id:9::B-tim': 736,
#  'id:VOA::B-org': 737,
#  'id:Nancy-Amelia::B-per': 738,
#  'hyphen::B-per': 739,
#  'id:Collins::I-per': 740,
#  'id:Sydney::B-geo': 741,
#  'id:Energy::O': 742,
#  'id:security::O': 743,
#  'id:climate::O': 744,
#  'id:change::O': 745,
#  'id:World::B-org': 746,
#  'id:Trade::I-org': 747,
#  'id:Organization::I-org': 748,
#  'id:stalled::O': 749,
#  'id:negotiations::O': 750,
#  'id:investment::O': 751,
#  'id:all::O': 752,
#  'id:expected::O': 753,
#  'id:among::O': 754,
#  'id:major::O': 755,
#  'id:topics::O': 756,
#  'id:ABAC::B-org': 757,
#  'id:Tim::B-per': 758,
#  'id:Harcourt::I-per': 759,
#  'id:chief::O': 760,
#  'id:economist::O': 761,
#  'id:Australian::B-org': 762,
#  'id:Commission::I-org': 763,
#  'id:plays::O': 764,
#  'id:important::O': 765,
#  'id:role::O': 766,
#  'id:informing::O': 767,
#  'id:governments::O': 768,
#  'id:problems::O': 769,
#  'id:most::O': 770,
#  'id:thing::O': 771,
#  'id:business::O': 772,
#  'id:do::O': 773,
#  'id:tell::O': 774,
#  'id:logjams::O': 775,
#  'id:obstacles::O': 776,
#  'id:things::O': 777,
#  'id:improve::O': 778,
#  'id:Harcourt::B-per': 779,
#  'id:I::O': 780,
#  'id:think::O': 781,
#  'id:actually::O': 782,
#  'id:played::O': 783,
#  'id:pretty::O': 784,
#  'id:good::O': 785,
#  'id:leadership::O': 786,
#  'id:talking::O': 787,
#  'id:about::O': 788,
#  'id:trade::O': 789,
#  'id:facilitation::O': 790,
#  'id:basically::O': 791,
#  'id:standards::O': 792,
#  'id:consistent::O': 793,
#  'id:harmonious::O': 794,
#  'id:across::O': 795,
#  'id:comprises::O': 796,
#  'id:private::O': 797,
#  'id:sector::O': 798,
#  'id:each::O': 799,
#  'id:21::O': 800,
#  'id:economies::O': 801,
#  'id:meets::O': 802,
#  'id:times::O': 803,
#  'id:made::O': 804,
#  'id:permanent::O': 805,
#  'id:body::O': 806,
#  'id:1995::B-tim': 807,
#  'id:perspective::O': 808,
#  'id:within::O': 809,
#  'id:Members::O': 810,
#  'id:represent::O': 811,
#  'id:range::O': 812,
#  'id:sectors::O': 813,
#  'id:medium::O': 814,
#  'id:businesses::O': 815,
#  'id:need::O': 816,
#  'id:energy::O': 817,
#  'id:efficiency::O': 818,
#  'id:encourage::O': 819,
#  'id:conservation::O': 820,
#  'id:practices::O': 821,
#  'id:discuss::O': 822,
#  'id:ways::O': 823,
#  'id:enhance::O': 824,
#  'id:regional::O': 825,
#  'id:cooperation::O': 826,
#  'id:reckon::O': 827,
#  "id:'ll::O": 828,
#  'id:talk::O': 829,
#  'id:little::O': 830,
#  'id:bit::O': 831,
#  'id:customs::O': 832,
#  'id:quarantine::O': 833,
#  'id:having::O': 834,
#  'id:arrangements::O': 835,
#  'id:around::O': 836,
#  'id:And::O': 837,
#  'id:want::O': 838,
#  'id:one-stop::O': 839,
#  'id:shop::O': 840,
#  'id:terms::O': 841,
#  'id:combining::O': 842,
#  'id:immigration::O': 843,
#  'id:together::O': 844,
#  'id:\x85::O': 845,
#  'id:just::O': 846,
#  'id:streamlined::O': 847,
#  'id:provides::O': 848,
#  'id:certainty::O': 849,
#  'id:non-governmental::O': 850,
#  'id:formal::O': 851,
#  'id:dialogue::O': 852,
#  'id:present::O': 853,
#  'id:meeting::O': 854,
#  'id:Sudan::B-gpe': 855,
#  'id:order::O': 856,
#  'id:Darfur::B-geo': 857,
#  'id:asking::O': 858,
#  'id:same::O': 859,
#  'id:Foreign::B-per': 860,
#  'id:Minister::I-per': 861,
#  'id:Mustafa::I-per': 862,
#  'id:Osman::I-per': 863,
#  'id:Ismail::I-per': 864,
#  'id:Sudanese::B-gpe': 865,
#  'id:withdraw::O': 866,
#  'id:positions::O': 867,
#  'id:held::O': 868,
#  'id:April::B-tim': 869,
#  'id:cease-fire::O': 870,
#  'id:western::O': 871,
#  'id:agree::O': 872,
#  'id:stop::O': 873,
#  'id:Mr.::B-per': 874,
#  'id:announced::O': 875,
#  'id:decision::O': 876,
#  'id:United::B-org': 877,
#  'id:Nations::I-org': 878,
#  'id:African::B-org': 879,
#  'id:Khartoum::B-geo': 880,
#  'id:weeks::O': 881,
#  'id:AU::B-org': 882,
#  'id:repeatedly::O': 883,
#  'id:truce::O': 884,
#  'init_tag:B-tim': 885,
#  'id:head::O': 886,
#  'id:accused::O': 887,
#  'id:helicopters::O': 888,
#  'id:bombing::O': 889,
#  'id:rebel::O': 890,
#  'id:sites::O': 891,
#  'id:Darfur::I-geo': 892,
#  'id:village::O': 893,
#  'id:Labado::B-geo': 894,
#  'id:Khartoum::B-gpe': 895,
#  'id:defending::O': 896,
#  'id:Aid::O': 897,
#  'id:relief::O': 898,
#  'id:efforts::O': 899,
#  'id:suspended::O': 900,
#  'id:due::O': 901,
#  'id:Indonesian::B-gpe': 902,
#  'id:men::O': 903,
#  'id:connection::O': 904,
#  'id:October::B-tim': 905,
#  'id:1::I-tim': 906,
#  'id:Bali::B-geo': 907,
#  'prev_tag:I-tim::B-geo': 908,
#  'id:left::O': 909,
#  'id:23::O': 910,
#  'id:dead::O': 911,
#  'id:flown::O': 912,
#  'id:Java::B-geo': 913,
#  'id:island::O': 914,
#  'id:headquarters::O': 915,
#  'id:Australian::B-gpe': 916,
#  'id:French::B-gpe': 917,
#  'id:agencies::O': 918,
#  'id:(::O': 919,
#  'id:Cholily::B-per': 920,
#  'id:)::O': 921,
#  'id:captured::O': 922,
#  'id:series::O': 923,
#  'id:counter-terrorism::O': 924,
#  'id:raids::O': 925,
#  'id:Indonesia::B-geo': 926,
#  'id:ended::O': 927,
#  'id:death::O': 928,
#  'id:alleged::O': 929,
#  'id:extremist::O': 930,
#  'id:bombmaker::O': 931,
#  'id:Azahari::B-per': 932,
#  'id:bin::I-per': 933,
#  'id:Husin::I-per': 934,
#  'id:authorities::O': 935,
#  'id:blame::O': 936,
#  'id:orchestrating::O': 937,
#  'id:month::O': 938,
#  'id:well::O': 939,
#  'id:2002::B-tim': 940,
#  'prev_tag:B-tim::B-geo': 941,
#  'id:Gunmen::O': 942,
#  'id:shot::O': 943,
#  'id:Roman::B-org': 944,
#  'id:Catholic::I-org': 945,
#  'id:nun::O': 946,
#  'id:her::O': 947,
#  'id:bodyguard::O': 948,
#  'id:hospital::O': 949,
#  'id:she::O': 950,
#  'id:worked::O': 951,
#  'id:Islamist-controlled::O': 952,
#  'id:Some::O': 953,
#  'id:witnesses::O': 954,
#  'id:shooting::O': 955,
#  'id:feared::O': 956,
#  'id:linked::O': 957,
#  'id:Muslim::O': 958,
#  'id:anger::O': 959,
#  'id:toward::O': 960,
#  'id:Pope::B-per': 961,
#  'id:Benedict::I-per': 962,
#  'id:pistols::O': 963,
#  'id:attacked::O': 964,
#  'id:Sister::B-per': 965,
#  'id:Leonella::I-per': 966,
#  'id:Sgorbati::I-per': 967,
#  'id:finished::O': 968,
#  'id:teaching::O': 969,
#  'id:medical::O': 970,
#  'id:school::O': 971,
#  'id:class::O': 972,
#  'id:suspect::O': 973,
#  'id:Vatican::B-org': 974,
#  'id:deplored::O': 975,
#  'id:hoped::O': 976,
#  'id:isolated::O': 977,
#  'id:event::O': 978,
#  'id:irrationality::O': 979,
#  'id:arising::O': 980,
#  'id:comments::O': 981,
#  'id:Pope::O': 982,
#  'id:angered::O': 983,
#  'id:Muslims::O': 984,
#  'id:Authorities::O': 985,
#  'id:determined::O': 986,
#  'id:motive::O': 987,
#  'id:pope::O': 988,
#  'id:meant::O': 989,
#  'id:offense::O': 990,
#  'id:quoted::O': 991,
#  'id:14::O': 992,
#  'id:century::O': 993,
#  'id:Byzantine::B-per': 994,
#  'id:emperor::O': 995,
#  'id:saying::O': 996,
#  'id:teachings::O': 997,
#  'id:Muhammed::I-per': 998,
#  'id:brought::O': 999,
#  ...}

# %%
[x for x in list(ex_feature_mapper.feature_dict.keys()) if 'hyphen' in x]
# Out:
# ['hyphen::O',
#  'hyphen::I-art',
#  'hyphen::B-org',
#  'hyphen::I-org',
#  'hyphen::B-per',
#  'hyphen::B-geo',
#  'hyphen::I-per',
#  'hyphen::B-gpe',
#  'hyphen::I-tim',
#  'hyphen::B-art',
#  'hyphen::B-tim',
#  'hyphen::I-geo',
#  'hyphen::B-nat',
#  'hyphen::B-eve',
#  'hyphen::I-eve']

# %% [markdown]
# #### Training structured perceptron

# %%
corpus = skseq.readers.pos_corpus.PostagCorpus()
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)

# %%
sp.get_num_states(), sp.get_num_observations()
# Out:
# (17, 30863)

# %%
# %%time
num_epochs = 15
sp.fit(ex_feature_mapper.dataset, num_epochs)
# Out:
# Epoch: 0 Accuracy: 0.893649
# Epoch: 1 Accuracy: 0.932477
# Epoch: 2 Accuracy: 0.941703
# Epoch: 3 Accuracy: 0.947204
# Epoch: 4 Accuracy: 0.950647
# Epoch: 5 Accuracy: 0.953267
# Epoch: 6 Accuracy: 0.955126
# Epoch: 7 Accuracy: 0.956926
# Epoch: 8 Accuracy: 0.957718
# Epoch: 9 Accuracy: 0.959740
# Epoch: 10 Accuracy: 0.960284
# Epoch: 11 Accuracy: 0.960919
# Epoch: 12 Accuracy: 0.961542
# Epoch: 13 Accuracy: 0.962344
# Epoch: 14 Accuracy: 0.962593
# Wall time: 1h 6min 44s

# %%
sp.save_model("perceptron_ex2")

# %%
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)
sp.load_model(dir="perceptron_ex2")

# %% [markdown]
# #### Testing

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

y_pred_2 = []
y_true = [item for x in Y_ids_test for item in x]
correct_sentences = 0
n_test = len(X_test)

for i in range(n_test):
    y_pred_aux = sp.predict_tags_given_words(X_test[i])
    y_pred_2.append(y_pred_aux)
    if list(y_pred_aux) == Y_ids_test[i]:
        correct_sentences += 1
    
y_pred = [item for x in y_pred_2 for item in x]
F1_score_multi = f1_score(y_true, y_pred, average=None)
Accuracy = accuracy_score(y_true, y_pred)
print('Accuracy for test is: ' + str(Accuracy))
print('F1-Score for test is: ' + str(np.mean(F1_score_multi)))
print('Correct sentences for test (%) : ' + str(correct_sentences/n_test))
# Out:
# Accuracy for test is: 0.950487028495657
# F1-Score for test is: 0.6293839019546097
# Correct sentences for test (%) : 0.48373373373373374

# %%
ax = plot_confusion_matrix(y_true, y_pred, classes=list(sp.state_labels),
                      title='Confusion matrix')

# %% [markdown]
# #### SENTENCES TO TEST THE MODEL

# %% [markdown]
# We think that these are the tags that the model should obtain:
#
# 1. The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 2. The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 3. Jack/B-per London/I-per went/O to/O Parris./O
#
# 4. Jack/B-per London/I-per went/O to/O/O Paris./B-geo
#
# 5. We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
#
# 6. We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
#
# 7. The/O president/O of/O U.S.A/B-geo though/O they/O could/O win/O the/O war/O
#
# 8. The/O president/O of/O the/O United/B-geo States/B-geo of/B-geo America/B-geo though/O they/O could/O win/O the/O war/O
#
# 9. The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
#
# 10. Robin/B-per does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
for sentence in test_sentences:
    new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
    print(sp.viterbi_decode(new_seq)[0].to_words(sequence_list_train, only_tag_translation=True))
# Out:
# The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/B-per checker./I-per
# The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/B-per checker./I-per
# Jack/B-per London/B-geo went/O to/O Parris./O
# Jack/B-per London/B-geo went/O to/O Paris./O
# We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
# We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
# The/O president/O of/O U.S.A/B-org though/O they/O could/O win/O the/O war/O
# The/O president/O of/O the/O United/B-geo States/I-geo of/I-geo America/I-geo though/O they/O could/O win/O the/O war/O
# The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
# Robin/B-org does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
# Here we can select the sentence in which we want to compare the true and the predicted tags
# Select a sentence between 1 and 10
i=1
sentence = test_sentences[i-1]
new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(sentence.split(), test_tags[i-1], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# The             (O    ): O
# programmers     (O    ): O
# from            (O    ): O
# Barcelona       (B-geo): B-geo
# might           (O    ): O
# write           (O    ): O
# a               (O    ): O
# sentence        (O    ): O
# without         (O    ): O
# a               (O    ): O
# spell           (O    ): B-per
# checker.        (O    ): I-per

# %% [markdown]
# # EXPERIMENT 3:

# %% [markdown]
# ##### Comments:
# In the third experiment we are going to include (to the previous features, including the hyphen one) a feature indicating if the word has an **upper letter** and another one indicating if the word **ends with a point** or not.

# %% [markdown]
# ### Extended features

# %%
ex_feature_mapper = skseq.sequences.extended_feature.ExtendedFeatures(sequence_list_train) 
ex_feature_mapper.build_features()
pprint.pprint(list(ex_feature_mapper.__dict__.keys()))
# Out:
# ['feature_dict',
#  'feature_list',
#  'add_features',
#  'dataset',
#  'node_feature_cache',
#  'initial_state_feature_cache',
#  'final_state_feature_cache',
#  'edge_feature_cache']

# %%
len(ex_feature_mapper.feature_dict)
# Out:
# 38344

# %%
ex_feature_mapper.feature_dict
# Out:
# {'init_tag:O': 0,
#  'id:Thousands::O': 1,
#  'hyphen::O': 2,
#  'upper::O': 3,
#  'id:of::O': 4,
#  'prev_tag:O::O': 5,
#  'id:demonstrators::O': 6,
#  'id:have::O': 7,
#  'id:marched::O': 8,
#  'id:through::O': 9,
#  'id:London::B-geo': 10,
#  'hyphen::B-geo': 11,
#  'upper::B-geo': 12,
#  'prev_tag:O::B-geo': 13,
#  'id:to::O': 14,
#  'prev_tag:B-geo::O': 15,
#  'id:protest::O': 16,
#  'id:the::O': 17,
#  'id:war::O': 18,
#  'id:in::O': 19,
#  'id:Iraq::B-geo': 20,
#  'id:and::O': 21,
#  'id:demand::O': 22,
#  'id:withdrawal::O': 23,
#  'id:British::B-gpe': 24,
#  'hyphen::B-gpe': 25,
#  'upper::B-gpe': 26,
#  'prev_tag:O::B-gpe': 27,
#  'id:troops::O': 28,
#  'prev_tag:B-gpe::O': 29,
#  'id:from::O': 30,
#  'id:that::O': 31,
#  'id:country::O': 32,
#  'id:.::O': 33,
#  'endpoint::O': 34,
#  'final_prev_tag:O': 35,
#  'id:Families::O': 36,
#  'id:soldiers::O': 37,
#  'id:killed::O': 38,
#  'id:conflict::O': 39,
#  'id:joined::O': 40,
#  'id:protesters::O': 41,
#  'id:who::O': 42,
#  'id:carried::O': 43,
#  'id:banners::O': 44,
#  'id:with::O': 45,
#  'id:such::O': 46,
#  'id:slogans::O': 47,
#  'id:as::O': 48,
#  'id:"::O': 49,
#  'id:Bush::B-per': 50,
#  'hyphen::B-per': 51,
#  'upper::B-per': 52,
#  'prev_tag:O::B-per': 53,
#  'id:Number::O': 54,
#  'prev_tag:B-per::O': 55,
#  'id:One::O': 56,
#  'id:Terrorist::O': 57,
#  'id:Stop::O': 58,
#  'id:Bombings::O': 59,
#  'id:They::O': 60,
#  'id:Houses::O': 61,
#  'id:Parliament::O': 62,
#  'id:a::O': 63,
#  'id:rally::O': 64,
#  'id:Hyde::B-geo': 65,
#  'id:Park::I-geo': 66,
#  'hyphen::I-geo': 67,
#  'upper::I-geo': 68,
#  'prev_tag:B-geo::I-geo': 69,
#  'prev_tag:I-geo::O': 70,
#  'id:Police::O': 71,
#  'id:put::O': 72,
#  'id:number::O': 73,
#  'id:marchers::O': 74,
#  'id:at::O': 75,
#  'id:10,000::O': 76,
#  'id:while::O': 77,
#  'id:organizers::O': 78,
#  'id:claimed::O': 79,
#  'id:it::O': 80,
#  'id:was::O': 81,
#  'id:1,00,000::O': 82,
#  'id:The::O': 83,
#  'id:comes::O': 84,
#  'id:on::O': 85,
#  'id:eve::O': 86,
#  'id:annual::O': 87,
#  'id:conference::O': 88,
#  'id:Britain::B-geo': 89,
#  "id:'s::O": 90,
#  'id:ruling::O': 91,
#  'id:Labor::B-org': 92,
#  'hyphen::B-org': 93,
#  'upper::B-org': 94,
#  'prev_tag:O::B-org': 95,
#  'id:Party::I-org': 96,
#  'hyphen::I-org': 97,
#  'upper::I-org': 98,
#  'prev_tag:B-org::I-org': 99,
#  'prev_tag:I-org::O': 100,
#  'id:southern::O': 101,
#  'id:English::B-gpe': 102,
#  'id:seaside::O': 103,
#  'id:resort::O': 104,
#  'id:Brighton::B-geo': 105,
#  'id:party::O': 106,
#  'id:is::O': 107,
#  'id:divided::O': 108,
#  'id:over::O': 109,
#  'id:Britain::B-gpe': 110,
#  'id:participation::O': 111,
#  'id:continued::O': 112,
#  'id:deployment::O': 113,
#  'id:8,500::O': 114,
#  'id:march::O': 115,
#  'id:came::O': 116,
#  'id:ahead::O': 117,
#  'id:anti-war::O': 118,
#  'id:protests::O': 119,
#  'id:today::O': 120,
#  'id:other::O': 121,
#  'id:cities::O': 122,
#  'id:,::O': 123,
#  'id:including::O': 124,
#  'id:Rome::B-geo': 125,
#  'id:Paris::B-geo': 126,
#  'id:Madrid::B-geo': 127,
#  'id:International::B-org': 128,
#  'id:Atomic::I-org': 129,
#  'id:Energy::I-org': 130,
#  'prev_tag:I-org::I-org': 131,
#  'id:Agency::I-org': 132,
#  'id:hold::O': 133,
#  'id:second::O': 134,
#  'id:day::O': 135,
#  'id:talks::O': 136,
#  'id:Vienna::B-geo': 137,
#  'id:Wednesday::B-tim': 138,
#  'hyphen::B-tim': 139,
#  'upper::B-tim': 140,
#  'prev_tag:B-geo::B-tim': 141,
#  'prev_tag:B-tim::O': 142,
#  'id:how::O': 143,
#  'id:respond::O': 144,
#  'id:Iran::B-gpe': 145,
#  'id:resumption::O': 146,
#  'id:low-level::O': 147,
#  'id:uranium::O': 148,
#  'id:conversion::O': 149,
#  'init_tag:B-gpe': 150,
#  'id:this::O': 151,
#  'id:week::O': 152,
#  'id:restarted::O': 153,
#  'id:parts::O': 154,
#  'id:process::O': 155,
#  'id:its::O': 156,
#  'id:Isfahan::B-geo': 157,
#  'id:nuclear::O': 158,
#  'id:plant::O': 159,
#  'id:Iranian::B-gpe': 160,
#  'id:officials::O': 161,
#  'id:say::O': 162,
#  'id:they::O': 163,
#  'id:expect::O': 164,
#  'id:get::O': 165,
#  'id:access::O': 166,
#  'id:sealed::O': 167,
#  'id:sensitive::O': 168,
#  'prev_tag:O::B-tim': 169,
#  'id:after::O': 170,
#  'id:an::O': 171,
#  'id:IAEA::B-org': 172,
#  'id:surveillance::O': 173,
#  'prev_tag:B-org::O': 174,
#  'id:system::O': 175,
#  'id:begins::O': 176,
#  'id:functioning::O': 177,
#  'id:step::O': 178,
#  'id:will::O': 179,
#  'id:allow::O': 180,
#  'id:facility::O': 181,
#  'id:operate::O': 182,
#  'id:full::O': 183,
#  'id:capacity::O': 184,
#  'id:European::B-org': 185,
#  'id:Union::I-org': 186,
#  'id:U.S.::B-gpe': 187,
#  'endpoint::B-gpe': 188,
#  'id:backing::O': 189,
#  'id:has::O': 190,
#  'id:threatened::O': 191,
#  'id:refer::O': 192,
#  'id:U.N.::B-org': 193,
#  'endpoint::B-org': 194,
#  'id:Security::I-org': 195,
#  'id:Council::I-org': 196,
#  'id:which::O': 197,
#  'id:could::O': 198,
#  'id:impose::O': 199,
#  'id:sanctions::O': 200,
#  'id:if::O': 201,
#  'id:finds::O': 202,
#  'id:Tehran::B-gpe': 203,
#  'id:violated::O': 204,
#  'id:Nuclear::B-art': 205,
#  'hyphen::B-art': 206,
#  'upper::B-art': 207,
#  'prev_tag:O::B-art': 208,
#  'id:Non-Proliferation::I-art': 209,
#  'hyphen::I-art': 210,
#  'upper::I-art': 211,
#  'prev_tag:B-art::I-art': 212,
#  'id:treaty::O': 213,
#  'prev_tag:I-art::O': 214,
#  'id:new::O': 215,
#  'id:President::B-per': 216,
#  'id:Mahmoud::I-per': 217,
#  'hyphen::I-per': 218,
#  'upper::I-per': 219,
#  'prev_tag:B-per::I-per': 220,
#  'id:Ahmadinejad::I-per': 221,
#  'prev_tag:I-per::I-per': 222,
#  'id:said::O': 223,
#  'prev_tag:I-per::O': 224,
#  'id:Tuesday::B-tim': 225,
#  'id:European::B-gpe': 226,
#  'id:incentives::O': 227,
#  'id:aimed::O': 228,
#  'id:persuading::O': 229,
#  'id:end::O': 230,
#  'id:fuel::O': 231,
#  'id:program::O': 232,
#  'id:are::O': 233,
#  'id:insult::O': 234,
#  'id:nation::O': 235,
#  'id:Two::O': 236,
#  'id:Germans::B-gpe': 237,
#  'id:four::O': 238,
#  'id:Nigerian::B-gpe': 239,
#  'id:oil::O': 240,
#  'id:workers::O': 241,
#  'id:were::O': 242,
#  'id:kidnapped::O': 243,
#  'id:by::O': 244,
#  'id:armed::O': 245,
#  'id:militants::O': 246,
#  'id:during::O': 247,
#  'id:raid::O': 248,
#  'id:boat::O': 249,
#  'id:Nigeria::B-geo': 250,
#  'id:oil-rich::O': 251,
#  'id:Delta::B-geo': 252,
#  'id:region::O': 253,
#  'id:An::O': 254,
#  'id:official::O': 255,
#  'id:German::B-gpe': 256,
#  'id:firm::O': 257,
#  'id:Bilfinger::B-org': 258,
#  'id:Berger::I-org': 259,
#  'id:Thomas::B-per': 260,
#  'id:Horbach::I-per': 261,
#  'id:gunmen::O': 262,
#  'id:stopped::O': 263,
#  'id:supply::O': 264,
#  'id:sailed::O': 265,
#  'id:State::I-geo': 266,
#  'id:Bayelsa::B-geo': 267,
#  'id:inspect::O': 268,
#  'id:offshore::O': 269,
#  'id:field::O': 270,
#  'id:owned::O': 271,
#  'id:Royal-Dutch::B-org': 272,
#  'id:Shell::I-org': 273,
#  'id:works::O': 274,
#  'id:sub-contractor::O': 275,
#  'id:for::O': 276,
#  'id:Shell::B-org': 277,
#  'id:Militant::O': 278,
#  'id:groups::O': 279,
#  'id:frequently::O': 280,
#  'id:attack::O': 281,
#  'id:operations::O': 282,
#  'id:Niger::B-geo': 283,
#  'id:Delta::I-geo': 284,
#  'id:social::O': 285,
#  'id:services::O': 286,
#  'id:better::O': 287,
#  'id:job::O': 288,
#  'id:opportunities::O': 289,
#  'id:multinational::O': 290,
#  'id:companies::O': 291,
#  'id:Poor::O': 292,
#  'id:residents::O': 293,
#  'id:often::O': 294,
#  'id:complain::O': 295,
#  'id:been::O': 296,
#  'id:cheated::O': 297,
#  'id:out::O': 298,
#  'id:huge::O': 299,
#  'id:riches::O': 300,
#  'id:extracted::O': 301,
#  'id:their::O': 302,
#  'id:tribal::O': 303,
#  'id:lands::O': 304,
#  'id:-::O': 305,
#  'id:where::O': 306,
#  'id:bulk::O': 307,
#  'id:Nigeria::B-gpe': 308,
#  'id:2.3::O': 309,
#  'id:million::O': 310,
#  'id:barrels::O': 311,
#  'id:petroleum::O': 312,
#  'id:pumped::O': 313,
#  'id:daily::O': 314,
#  'id:Suspected::O': 315,
#  'id:Islamist::O': 316,
#  'id:rebels::O': 317,
#  'id:fired::O': 318,
#  'id:mortar::O': 319,
#  'id:shells::O': 320,
#  'id:palace::O': 321,
#  'id:used::O': 322,
#  'id:Somalia::B-geo': 323,
#  'id:interim::O': 324,
#  'id:Abdullahi::I-per': 325,
#  'id:Yusuf::I-per': 326,
#  'id:Ahmad::I-per': 327,
#  'id:It::O': 328,
#  'id:not::O': 329,
#  'id:immediately::O': 330,
#  'id:clear::O': 331,
#  'id:president::O': 332,
#  'id:Mogadishu::B-geo': 333,
#  'id:when::O': 334,
#  'id:occurred::O': 335,
#  'id:or::O': 336,
#  'id:anyone::O': 337,
#  'id:hurt::O': 338,
#  'id:Local::O': 339,
#  'id:news::O': 340,
#  'id:reports::O': 341,
#  'id:least::O': 342,
#  'id:five::O': 343,
#  'id:hit::O': 344,
#  'id:compound::O': 345,
#  'id:mortars::O': 346,
#  'id:elsewhere::O': 347,
#  'id:attacks::O': 348,
#  'id:government::O': 349,
#  'id:go::O': 350,
#  'id:reconciliation::O': 351,
#  'id:more::O': 352,
#  'id:than::O': 353,
#  'id:1,300::O': 354,
#  'id:Somali::B-gpe': 355,
#  'id:elders::O': 356,
#  'id:warlords::O': 357,
#  'id:politicians::O': 358,
#  'id:invited::O': 359,
#  'id:Iraqi::B-gpe': 360,
#  'id:military::O': 361,
#  'id:tanks::O': 362,
#  'id:arrived::O': 363,
#  'id:northern::O': 364,
#  'id:city::O': 365,
#  'id:Mosul::B-geo': 366,
#  'id:offensive::O': 367,
#  'id:against::O': 368,
#  'id:al::B-org': 369,
#  'id:Qaida::I-org': 370,
#  'id:in::I-org': 371,
#  'id:Iraq::I-org': 372,
#  'id:fighters::O': 373,
#  'id:Officials::O': 374,
#  'id:many::O': 375,
#  'id:Sunni::B-geo': 376,
#  'id:Arab::I-geo': 377,
#  'id:Kurdish::B-geo': 378,
#  'id:bombings::O': 379,
#  'id:last::O': 380,
#  'id:34::O': 381,
#  'id:people::O': 382,
#  'id:wounded::O': 383,
#  'id:200::O': 384,
#  'id:commanders::O': 385,
#  'id:explained::O': 386,
#  'id:American::B-gpe': 387,
#  'id:forces::O': 388,
#  'id:participate::O': 389,
#  'id:fled::O': 390,
#  'id:successful::O': 391,
#  'id:campaigns::O': 392,
#  'id:them::O': 393,
#  'id:Anbar::B-geo': 394,
#  'id:province::O': 395,
#  'id:Baghdad::B-geo': 396,
#  'id:provinces::O': 397,
#  'init_tag:B-geo': 398,
#  'id:largest::O': 399,
#  'id:north::O': 400,
#  'id:long::O': 401,
#  'id:stronghold::O': 402,
#  'id:Sunni::B-org': 403,
#  'id:militant::O': 404,
#  'id:In::O': 405,
#  'id:violence::O': 406,
#  'id:one::O': 407,
#  'id:soldier::O': 408,
#  'id:patrol::O': 409,
#  'id:Sunday::B-tim': 410,
#  'id:Egyptian::B-gpe': 411,
#  'id:police::O': 412,
#  'id:arrested::O': 413,
#  'id:16::O': 414,
#  'id:members::O': 415,
#  'id:opposition::O': 416,
#  'id:Muslim::B-org': 417,
#  'id:Brotherhood::I-org': 418,
#  'id:prepare::O': 419,
#  'id:parliamentary::O': 420,
#  'id:runoff::O': 421,
#  'id:elections::O': 422,
#  'id:Saturday::B-tim': 423,
#  'id:arrests::O': 424,
#  'id:Friday::B-tim': 425,
#  'id:Alexandria::B-geo': 426,
#  'id:A::O': 427,
#  'id:spokesman::O': 428,
#  'id:Brotherhood::B-org': 429,
#  'id:attempt::O': 430,
#  'id:cut::O': 431,
#  'id:off::O': 432,
#  'id:supporters::O': 433,
#  'id:punishment::O': 434,
#  'id:winning::O': 435,
#  'id:seats::O': 436,
#  'id:earlier::O': 437,
#  'id:tripled::O': 438,
#  'id:strength::O': 439,
#  'id:parliament::O': 440,
#  'id:recent::O': 441,
#  'id:raising::O': 442,
#  'id:total::O': 443,
#  'id:47::O': 444,
#  'id:voters::O': 445,
#  'id:cast::O': 446,
#  'id:ballots::O': 447,
#  'id:nine::O': 448,
#  'id:no::O': 449,
#  'id:candidate::O': 450,
#  'id:won::O': 451,
#  'id:majority::O': 452,
#  'id:previous::O': 453,
#  'id:round::O': 454,
#  'id:voting::O': 455,
#  'id:banned::O': 456,
#  'id:political::O': 457,
#  'id:but::O': 458,
#  'id:endorses::O': 459,
#  'id:so-called::O': 460,
#  'id:independent::O': 461,
#  'id:candidates::O': 462,
#  'id:whose::O': 463,
#  'id:allegiance::O': 464,
#  'id:known::O': 465,
#  'id:Hardline::O': 466,
#  'id:lawmakers::O': 467,
#  'id:Pakistan::B-geo': 468,
#  'id:North::B-geo': 469,
#  'id:West::I-geo': 470,
#  'id:Frontier::I-geo': 471,
#  'prev_tag:I-geo::I-geo': 472,
#  'id:Province::I-geo': 473,
#  'id:pushed::O': 474,
#  'id:law::O': 475,
#  'id:aims::O': 476,
#  'id:ensure::O': 477,
#  'id:Islamic::O': 478,
#  'id:correctness::O': 479,
#  'id:public::O': 480,
#  'id:places::O': 481,
#  'id:establishes::O': 482,
#  'id:morality::O': 483,
#  'id:enforce::O': 484,
#  'id:decent::O': 485,
#  'id:behavior::O': 486,
#  'id:six-party::O': 487,
#  'id:coalition::O': 488,
#  'id:religious::O': 489,
#  'id:based::O': 490,
#  'id:parties::O': 491,
#  'id:Mutahida::B-org': 492,
#  'id:Majlis-e-Amal::I-org': 493,
#  'id:dominates::O': 494,
#  'id:provincial::O': 495,
#  'id:assembly::O': 496,
#  'id:so::O': 497,
#  'id:bill::O': 498,
#  'id:easily::O': 499,
#  'id:passed::O': 500,
#  'id:Thursday::B-tim': 501,
#  'id:vote::O': 502,
#  'id:68-34::O': 503,
#  'id:governor::O': 504,
#  'id:must::O': 505,
#  'id:still::O': 506,
#  'id:sign::O': 507,
#  'id:before::O': 508,
#  'id:becomes::O': 509,
#  'id:seen::O': 510,
#  'id:only::O': 511,
#  'id:formality::O': 512,
#  'id:proposed::O': 513,
#  'id:calls::O': 514,
#  'id:setting::O': 515,
#  'id:up::O': 516,
#  'id:force::O': 517,
#  'id:make::O': 518,
#  'id:sure::O': 519,
#  'id:adhere::O': 520,
#  'id:values::O': 521,
#  'id:entertainment::O': 522,
#  'id:outlets::O': 523,
#  'id:close::O': 524,
#  'id:weekly::O': 525,
#  'id:prayers::O': 526,
#  'id:Violators::O': 527,
#  'id:be::O': 528,
#  'id:jailed::O': 529,
#  'id:six::O': 530,
#  'id:months::O': 531,
#  'id:denounced::O': 532,
#  'id:measure::O': 533,
#  'id:comparing::O': 534,
#  'id:draconian::O': 535,
#  'id:rule::O': 536,
#  'id:former::O': 537,
#  'id:Taleban::B-org': 538,
#  'id:neighboring::O': 539,
#  'id:Afghanistan::B-geo': 540,
#  'id:man::O': 541,
#  'id:dressed::O': 542,
#  'id:suicide::O': 543,
#  'id:bomber::O': 544,
#  'id:demonstration::O': 545,
#  'id:publication::O': 546,
#  'id:cartoons::O': 547,
#  'id:depicting::O': 548,
#  'id:Islam::B-org': 549,
#  'id:Prophet::B-per': 550,
#  'id:Muhammad::I-per': 551,
#  'id:Bedfordshire::B-gpe': 552,
#  'id:Omar::B-per': 553,
#  'id:Khayam::I-per': 554,
#  'id:Bedford::B-geo': 555,
#  'id:breaching::O': 556,
#  'id:conditions::O': 557,
#  'id:his::O': 558,
#  'id:parole::O': 559,
#  'id:British::B-org': 560,
#  'id:Home::I-org': 561,
#  'id:Office::I-org': 562,
#  'id:sought::O': 563,
#  'id:investigation::O': 564,
#  'id:Khayam::B-per': 565,
#  'id:he::O': 566,
#  'id:photographed::O': 567,
#  'id:fatigues::O': 568,
#  'id:black::O': 569,
#  'id:cap::O': 570,
#  'id:bulky::O': 571,
#  'id:belt::O': 572,
#  'id:Home::B-org': 573,
#  'id:told::O': 574,
#  'id:Associated::B-org': 575,
#  'id:Press::I-org': 576,
#  'id:paroled::O': 577,
#  'id:offender::O': 578,
#  'id:gives::O': 579,
#  'id:cause::O': 580,
#  'id:concern::O': 581,
#  'id:can::O': 582,
#  'id:sent::O': 583,
#  'id:back::O': 584,
#  'id:prison::O': 585,
#  'id:AP::B-org': 586,
#  'id:also::O': 587,
#  'id:since::O': 588,
#  'id:year::O': 589,
#  'id:serving::O': 590,
#  'id:half::O': 591,
#  'id:six-year::O': 592,
#  'id:sentence::O': 593,
#  'id:drug::O': 594,
#  'id:dealing::O': 595,
#  'id:Pakistani::B-gpe': 596,
#  'id:unidentified::O': 597,
#  'id:three::O': 598,
#  'id:minister::O': 599,
#  'id:semi-autonomous::O': 600,
#  'id:bordering::O': 601,
#  'id:prominent::O': 602,
#  'id:leader::O': 603,
#  'id:Malik::B-per': 604,
#  'id:Faridullah::I-per': 605,
#  'id:Khan::I-per': 606,
#  'id:traveling::O': 607,
#  'id:South::B-geo': 608,
#  'id:Waziristan::I-geo': 609,
#  'prev_tag:I-geo::B-tim': 610,
#  'id:vehicle::O': 611,
#  'id:ambushed::O': 612,
#  'id:Kani::B-geo': 613,
#  'id:Wam::I-geo': 614,
#  'id:area::O': 615,
#  'id:His::O': 616,
#  'id:driver::O': 617,
#  'id:elder::O': 618,
#  'id:No::O': 619,
#  'id:responsibility::O': 620,
#  'id:killings::O': 621,
#  'id:ambush::O': 622,
#  'id:commander::O': 623,
#  'id:army::O': 624,
#  'id:almost::O': 625,
#  'id:completely::O': 626,
#  'id:eliminated::O': 627,
#  'id:became::O': 628,
#  'id:refuge::O': 629,
#  'id:al-Qaida::B-org': 630,
#  'id:ousted::O': 631,
#  'id:2001::B-tim': 632,
#  'id:senior::O': 633,
#  'id:says::O': 634,
#  'id:Pakistan::B-gpe': 635,
#  'id:wants::O': 636,
#  'id:what::O': 637,
#  'id:sordid::O': 638,
#  'id:chapter::O': 639,
#  'id:proliferation::O': 640,
#  'id:top::O': 641,
#  'id:scientists::O': 642,
#  'id:behind::O': 643,
#  'id:build::O': 644,
#  'id:civilian::O': 645,
#  'id:ties::O': 646,
#  'id:United::B-gpe': 647,
#  'id:States::I-gpe': 648,
#  'hyphen::I-gpe': 649,
#  'upper::I-gpe': 650,
#  'prev_tag:B-gpe::I-gpe': 651,
#  'prev_tag:I-gpe::O': 652,
#  'id:But::O': 653,
#  'id:ready::O': 654,
#  'id:scientist::O': 655,
#  'id:Abdul::B-per': 656,
#  'id:Qadeer::I-per': 657,
#  'id:available::O': 658,
#  'id:direct::O': 659,
#  'id:questioning::O': 660,
#  'id:sale::O': 661,
#  'id:secrets::O': 662,
#  'id:states::O': 663,
#  'id:Libya::B-gpe': 664,
#  'id:North::B-gpe': 665,
#  'id:Korea::I-gpe': 666,
#  'id:He::O': 667,
#  'id:there::O': 668,
#  'id:reasons::O': 669,
#  'id:national::O': 670,
#  'id:sensitivities::O': 671,
#  'id:making::O': 672,
#  'id:him::O': 673,
#  'id:giving::O': 674,
#  'id:background::O': 675,
#  'id:briefing::O': 676,
#  'id:small::O': 677,
#  'id:group::O': 678,
#  'id:reporters::O': 679,
#  'id:Washington::B-geo': 680,
#  'init_tag:B-per': 681,
#  'id:Khan::B-per': 682,
#  'id:admitted::O': 683,
#  'id:2004::B-tim': 684,
#  'id:operated::O': 685,
#  'id:worldwide::O': 686,
#  'id:clandestine::O': 687,
#  'id:network::O': 688,
#  'id:sell::O': 689,
#  'id:technology::O': 690,
#  'id:market::O': 691,
#  'id:placed::O': 692,
#  'id:under::O': 693,
#  'id:house::O': 694,
#  'id:arrest::O': 695,
#  'id:Islamabad::B-geo': 696,
#  'id:because::O': 697,
#  'id:considered::O': 698,
#  'id:father::O': 699,
#  'id:bomb::O': 700,
#  'id:Army::B-org': 701,
#  'prev_tag:B-gpe::B-org': 702,
#  'id:renew::O': 703,
#  'id:controversial::O': 704,
#  'id:multi-billion::O': 705,
#  'id:dollar::O': 706,
#  'id:contract::O': 707,
#  'id:Halliburton::B-org': 708,
#  'id:company::O': 709,
#  'id:provide::O': 710,
#  'id:logistical::O': 711,
#  'id:support::O': 712,
#  'init_tag:B-org': 713,
#  'id:providing::O': 714,
#  'id:list::O': 715,
#  'id:meals::O': 716,
#  'id:communication::O': 717,
#  'id:several::O': 718,
#  'id:years::O': 719,
#  'id:Critics::O': 720,
#  'id:include::O': 721,
#  'id:auditors::O': 722,
#  'id:congressional::O': 723,
#  'id:Democrats::O': 724,
#  'id:produced::O': 725,
#  'id:some::O': 726,
#  'id:shoddy::O': 727,
#  'id:work::O': 728,
#  'id:charges::O': 729,
#  'id:too::O': 730,
#  'id:much::O': 731,
#  'id:money::O': 732,
#  'id:strongly::O': 733,
#  'id:denies::O': 734,
#  'id:allegations::O': 735,
#  'id:When::O': 736,
#  'id:re-bidding::O': 737,
#  'id:chance::O': 738,
#  'id:compete::O': 739,
#  'id:portions::O': 740,
#  'id:Representatives::O': 741,
#  'id:Asia::B-org': 742,
#  'id:Pacific::I-org': 743,
#  'id:Economic::I-org': 744,
#  'id:Cooperation::I-org': 745,
#  'id:Business::I-org': 746,
#  'id:Advisory::I-org': 747,
#  'id:holding::O': 748,
#  'id:meetings::O': 749,
#  'id:finalize::O': 750,
#  'id:report::O': 751,
#  'id:APEC::B-org': 752,
#  'id:leaders::O': 753,
#  'id:summit::O': 754,
#  'id:September::B-tim': 755,
#  'id:8::I-tim': 756,
#  'hyphen::I-tim': 757,
#  'upper::I-tim': 758,
#  'prev_tag:B-tim::I-tim': 759,
#  'prev_tag:I-tim::O': 760,
#  'id:9::B-tim': 761,
#  'id:VOA::B-org': 762,
#  'id:Nancy-Amelia::B-per': 763,
#  'id:Collins::I-per': 764,
#  'id:Sydney::B-geo': 765,
#  'id:Energy::O': 766,
#  'id:security::O': 767,
#  'id:climate::O': 768,
#  'id:change::O': 769,
#  'id:World::B-org': 770,
#  'id:Trade::I-org': 771,
#  'id:Organization::I-org': 772,
#  'id:stalled::O': 773,
#  'id:negotiations::O': 774,
#  'id:investment::O': 775,
#  'id:all::O': 776,
#  'id:expected::O': 777,
#  'id:among::O': 778,
#  'id:major::O': 779,
#  'id:topics::O': 780,
#  'id:ABAC::B-org': 781,
#  'id:Tim::B-per': 782,
#  'id:Harcourt::I-per': 783,
#  'id:chief::O': 784,
#  'id:economist::O': 785,
#  'id:Australian::B-org': 786,
#  'id:Commission::I-org': 787,
#  'id:plays::O': 788,
#  'id:important::O': 789,
#  'id:role::O': 790,
#  'id:informing::O': 791,
#  'id:governments::O': 792,
#  'id:problems::O': 793,
#  'id:most::O': 794,
#  'id:thing::O': 795,
#  'id:business::O': 796,
#  'id:do::O': 797,
#  'id:tell::O': 798,
#  'id:logjams::O': 799,
#  'id:obstacles::O': 800,
#  'id:things::O': 801,
#  'id:improve::O': 802,
#  'id:Harcourt::B-per': 803,
#  'id:I::O': 804,
#  'id:think::O': 805,
#  'id:actually::O': 806,
#  'id:played::O': 807,
#  'id:pretty::O': 808,
#  'id:good::O': 809,
#  'id:leadership::O': 810,
#  'id:talking::O': 811,
#  'id:about::O': 812,
#  'id:trade::O': 813,
#  'id:facilitation::O': 814,
#  'id:basically::O': 815,
#  'id:standards::O': 816,
#  'id:consistent::O': 817,
#  'id:harmonious::O': 818,
#  'id:across::O': 819,
#  'id:comprises::O': 820,
#  'id:private::O': 821,
#  'id:sector::O': 822,
#  'id:each::O': 823,
#  'id:21::O': 824,
#  'id:economies::O': 825,
#  'id:meets::O': 826,
#  'id:times::O': 827,
#  'id:made::O': 828,
#  'id:permanent::O': 829,
#  'id:body::O': 830,
#  'id:1995::B-tim': 831,
#  'id:perspective::O': 832,
#  'id:within::O': 833,
#  'id:Members::O': 834,
#  'id:represent::O': 835,
#  'id:range::O': 836,
#  'id:sectors::O': 837,
#  'id:medium::O': 838,
#  'id:businesses::O': 839,
#  'id:need::O': 840,
#  'id:energy::O': 841,
#  'id:efficiency::O': 842,
#  'id:encourage::O': 843,
#  'id:conservation::O': 844,
#  'id:practices::O': 845,
#  'id:discuss::O': 846,
#  'id:ways::O': 847,
#  'id:enhance::O': 848,
#  'id:regional::O': 849,
#  'id:cooperation::O': 850,
#  'id:reckon::O': 851,
#  "id:'ll::O": 852,
#  'id:talk::O': 853,
#  'id:little::O': 854,
#  'id:bit::O': 855,
#  'id:customs::O': 856,
#  'id:quarantine::O': 857,
#  'id:having::O': 858,
#  'id:arrangements::O': 859,
#  'id:around::O': 860,
#  'id:And::O': 861,
#  'id:want::O': 862,
#  'id:one-stop::O': 863,
#  'id:shop::O': 864,
#  'id:terms::O': 865,
#  'id:combining::O': 866,
#  'id:immigration::O': 867,
#  'id:together::O': 868,
#  'id:\x85::O': 869,
#  'id:just::O': 870,
#  'id:streamlined::O': 871,
#  'id:provides::O': 872,
#  'id:certainty::O': 873,
#  'id:non-governmental::O': 874,
#  'id:formal::O': 875,
#  'id:dialogue::O': 876,
#  'id:present::O': 877,
#  'id:meeting::O': 878,
#  'id:Sudan::B-gpe': 879,
#  'id:order::O': 880,
#  'id:Darfur::B-geo': 881,
#  'id:asking::O': 882,
#  'id:same::O': 883,
#  'id:Foreign::B-per': 884,
#  'id:Minister::I-per': 885,
#  'id:Mustafa::I-per': 886,
#  'id:Osman::I-per': 887,
#  'id:Ismail::I-per': 888,
#  'id:Sudanese::B-gpe': 889,
#  'id:withdraw::O': 890,
#  'id:positions::O': 891,
#  'id:held::O': 892,
#  'id:April::B-tim': 893,
#  'id:cease-fire::O': 894,
#  'id:western::O': 895,
#  'id:agree::O': 896,
#  'id:stop::O': 897,
#  'id:Mr.::B-per': 898,
#  'endpoint::B-per': 899,
#  'id:announced::O': 900,
#  'id:decision::O': 901,
#  'id:United::B-org': 902,
#  'id:Nations::I-org': 903,
#  'id:African::B-org': 904,
#  'id:Khartoum::B-geo': 905,
#  'id:weeks::O': 906,
#  'id:AU::B-org': 907,
#  'id:repeatedly::O': 908,
#  'id:truce::O': 909,
#  'init_tag:B-tim': 910,
#  'id:head::O': 911,
#  'id:accused::O': 912,
#  'id:helicopters::O': 913,
#  'id:bombing::O': 914,
#  'id:rebel::O': 915,
#  'id:sites::O': 916,
#  'id:Darfur::I-geo': 917,
#  'id:village::O': 918,
#  'id:Labado::B-geo': 919,
#  'id:Khartoum::B-gpe': 920,
#  'id:defending::O': 921,
#  'id:Aid::O': 922,
#  'id:relief::O': 923,
#  'id:efforts::O': 924,
#  'id:suspended::O': 925,
#  'id:due::O': 926,
#  'id:Indonesian::B-gpe': 927,
#  'id:men::O': 928,
#  'id:connection::O': 929,
#  'id:October::B-tim': 930,
#  'id:1::I-tim': 931,
#  'id:Bali::B-geo': 932,
#  'prev_tag:I-tim::B-geo': 933,
#  'id:left::O': 934,
#  'id:23::O': 935,
#  'id:dead::O': 936,
#  'id:flown::O': 937,
#  'id:Java::B-geo': 938,
#  'id:island::O': 939,
#  'id:headquarters::O': 940,
#  'id:Australian::B-gpe': 941,
#  'id:French::B-gpe': 942,
#  'id:agencies::O': 943,
#  'id:(::O': 944,
#  'id:Cholily::B-per': 945,
#  'id:)::O': 946,
#  'id:captured::O': 947,
#  'id:series::O': 948,
#  'id:counter-terrorism::O': 949,
#  'id:raids::O': 950,
#  'id:Indonesia::B-geo': 951,
#  'id:ended::O': 952,
#  'id:death::O': 953,
#  'id:alleged::O': 954,
#  'id:extremist::O': 955,
#  'id:bombmaker::O': 956,
#  'id:Azahari::B-per': 957,
#  'id:bin::I-per': 958,
#  'id:Husin::I-per': 959,
#  'id:authorities::O': 960,
#  'id:blame::O': 961,
#  'id:orchestrating::O': 962,
#  'id:month::O': 963,
#  'id:well::O': 964,
#  'id:2002::B-tim': 965,
#  'prev_tag:B-tim::B-geo': 966,
#  'id:Gunmen::O': 967,
#  'id:shot::O': 968,
#  'id:Roman::B-org': 969,
#  'id:Catholic::I-org': 970,
#  'id:nun::O': 971,
#  'id:her::O': 972,
#  'id:bodyguard::O': 973,
#  'id:hospital::O': 974,
#  'id:she::O': 975,
#  'id:worked::O': 976,
#  'id:Islamist-controlled::O': 977,
#  'id:Some::O': 978,
#  'id:witnesses::O': 979,
#  'id:shooting::O': 980,
#  'id:feared::O': 981,
#  'id:linked::O': 982,
#  'id:Muslim::O': 983,
#  'id:anger::O': 984,
#  'id:toward::O': 985,
#  'id:Pope::B-per': 986,
#  'id:Benedict::I-per': 987,
#  'id:pistols::O': 988,
#  'id:attacked::O': 989,
#  'id:Sister::B-per': 990,
#  'id:Leonella::I-per': 991,
#  'id:Sgorbati::I-per': 992,
#  'id:finished::O': 993,
#  'id:teaching::O': 994,
#  'id:medical::O': 995,
#  'id:school::O': 996,
#  'id:class::O': 997,
#  'id:suspect::O': 998,
#  'id:Vatican::B-org': 999,
#  ...}

# %%
[x for x in list(ex_feature_mapper.feature_dict.keys()) if 'endpoint' in x]
# Out:
# ['endpoint::O',
#  'endpoint::B-gpe',
#  'endpoint::B-org',
#  'endpoint::B-per',
#  'endpoint::B-geo',
#  'endpoint::B-tim',
#  'endpoint::I-geo',
#  'endpoint::I-per',
#  'endpoint::I-tim',
#  'endpoint::I-org',
#  'endpoint::B-art',
#  'endpoint::I-art']

# %%
[x for x in list(ex_feature_mapper.feature_dict.keys()) if 'upper' in x]
# Out:
# ['upper::O',
#  'upper::B-geo',
#  'upper::B-gpe',
#  'upper::B-per',
#  'upper::I-geo',
#  'upper::B-org',
#  'upper::I-org',
#  'upper::B-tim',
#  'upper::B-art',
#  'upper::I-art',
#  'upper::I-per',
#  'upper::I-gpe',
#  'upper::I-tim',
#  'upper::B-nat',
#  'upper::B-eve',
#  'upper::I-eve',
#  'upper::I-nat',
#  'id:upper::O',
#  'id:Supper::O',
#  'id:upper-middle::O']

# %% [markdown]
# #### Training structured perceptron

# %%
corpus = skseq.readers.pos_corpus.PostagCorpus()
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)

# %%
sp.get_num_states(), sp.get_num_observations()
# Out:
# (17, 30863)

# %%
# %%time
num_epochs = 15
sp.fit(ex_feature_mapper.dataset, num_epochs)
# Out:
# Epoch: 0 Accuracy: 0.923455
# Epoch: 1 Accuracy: 0.942283
# Epoch: 2 Accuracy: 0.947269
# Epoch: 3 Accuracy: 0.950621
# Epoch: 4 Accuracy: 0.952520
# Epoch: 5 Accuracy: 0.954238
# Epoch: 6 Accuracy: 0.955599
# Epoch: 7 Accuracy: 0.956591
# Epoch: 8 Accuracy: 0.957633
# Epoch: 9 Accuracy: 0.958394
# Epoch: 10 Accuracy: 0.959223
# Epoch: 11 Accuracy: 0.959782
# Epoch: 12 Accuracy: 0.960260
# Epoch: 13 Accuracy: 0.961111
# Epoch: 14 Accuracy: 0.961801
# Wall time: 1h 5min 35s

# %%
sp.save_model("perceptron_ex3")

# %%
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)
sp.load_model(dir="perceptron_ex3")

# %% [markdown]
# #### Testing

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

y_pred_2 = []
y_true = [item for x in Y_ids_test for item in x]
correct_sentences = 0
n_test = len(X_test)

for i in range(n_test):
    y_pred_aux = sp.predict_tags_given_words(X_test[i])
    y_pred_2.append(y_pred_aux)
    if list(y_pred_aux) == Y_ids_test[i]:
        correct_sentences += 1
    
y_pred = [item for x in y_pred_2 for item in x]
F1_score_multi = f1_score(y_true, y_pred, average=None)
Accuracy = accuracy_score(y_true, y_pred)
print('Accuracy for test is: ' + str(Accuracy))
print('F1-Score for test is: ' + str(np.mean(F1_score_multi)))
print('Correct sentences for test (%) : ' + str(correct_sentences/n_test))
# Out:
# Accuracy for test is: 0.949115171061833
# F1-Score for test is: 0.6088066050010064
# Correct sentences for test (%) : 0.46396396396396394

# %%
ax = plot_confusion_matrix(y_true, y_pred, classes=list(sp.state_labels),
                      title='Confusion matrix')

# %% [markdown]
# #### SENTENCES TO TEST THE MODEL

# %% [markdown]
# We think that these are the tags that the model should obtain:
#
# 1. The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 2. The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 3. Jack/B-per London/I-per went/O to/O Parris./O
#
# 4. Jack/B-per London/I-per went/O to/O/O Paris./B-geo
#
# 5. We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
#
# 6. We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
#
# 7. The/O president/O of/O U.S.A/B-geo though/O they/O could/O win/O the/O war/O
#
# 8. The/O president/O of/O the/O United/B-geo States/B-geo of/B-geo America/B-geo though/O they/O could/O win/O the/O war/O
#
# 9. The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
#
# 10. Robin/B-per does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
for sentence in test_sentences:
    new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
    print(sp.viterbi_decode(new_seq)[0].to_words(sequence_list_train, only_tag_translation=True))
# Out:
# The/O programmers/O from/O Barcelona/B-org might/O write/O a/O sentence/O without/O a/O spell/O checker./O
# The/O programmers/O from/O Barchelona/B-org cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
# Jack/B-per London/B-geo went/O to/O Parris./B-geo
# Jack/B-per London/B-geo went/O to/O Paris./B-geo
# We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
# We/O never/O though/O Microsof/B-org would/O become/O such/O a/O big/O company./O
# The/O president/O of/O U.S.A/B-org though/O they/O could/O win/O the/O war/O
# The/O president/O of/O the/O United/B-geo States/I-geo of/I-geo America/I-geo though/O they/O could/O win/O the/O war/O
# The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
# Robin/B-org does/O not/O want/O to/O go/O to/O Saudi/B-per Arabia./I-per

# %%
# Here we can select the sentence in which we want to compare the true and the predicted tags
# Select a sentence between 1 and 10
i=1
sentence = test_sentences[i-1]
new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(sentence.split(), test_tags[i-1], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# The             (O    ): O
# programmers     (O    ): O
# from            (O    ): O
# Barcelona       (B-geo): B-org
# might           (O    ): O
# write           (O    ): O
# a               (O    ): O
# sentence        (O    ): O
# without         (O    ): O
# a               (O    ): O
# spell           (O    ): O
# checker.        (O    ): O

# %% [markdown]
# # EXPERIMENT 4:

# %% [markdown]
# ##### Comments:
# In the third experiment we are going to include (to the previous features, including the hyphen one) a feature indicating if the word has an **upper letter** and another one indicating if the word **ends with a point** or not.

# %% [markdown]
# ### Extended features

# %%
ex_feature_mapper = skseq.sequences.extended_feature.ExtendedFeatures(sequence_list_train) 
ex_feature_mapper.build_features()
pprint.pprint(list(ex_feature_mapper.__dict__.keys()))
# Out:
# ['feature_dict',
#  'feature_list',
#  'add_features',
#  'dataset',
#  'node_feature_cache',
#  'initial_state_feature_cache',
#  'final_state_feature_cache',
#  'edge_feature_cache']

# %%
len(ex_feature_mapper.feature_dict)
# Out:
# 38344

# %%
ex_feature_mapper.feature_dict
# Out:
# {'init_tag:O': 0,
#  'id:Thousands::O': 1,
#  'hyphen::O': 2,
#  'upper::O': 3,
#  'id:of::O': 4,
#  'prev_tag:O::O': 5,
#  'id:demonstrators::O': 6,
#  'id:have::O': 7,
#  'id:marched::O': 8,
#  'id:through::O': 9,
#  'id:London::B-geo': 10,
#  'hyphen::B-geo': 11,
#  'upper::B-geo': 12,
#  'prev_tag:O::B-geo': 13,
#  'id:to::O': 14,
#  'prev_tag:B-geo::O': 15,
#  'id:protest::O': 16,
#  'id:the::O': 17,
#  'id:war::O': 18,
#  'id:in::O': 19,
#  'id:Iraq::B-geo': 20,
#  'id:and::O': 21,
#  'id:demand::O': 22,
#  'id:withdrawal::O': 23,
#  'id:British::B-gpe': 24,
#  'hyphen::B-gpe': 25,
#  'upper::B-gpe': 26,
#  'prev_tag:O::B-gpe': 27,
#  'id:troops::O': 28,
#  'prev_tag:B-gpe::O': 29,
#  'id:from::O': 30,
#  'id:that::O': 31,
#  'id:country::O': 32,
#  'id:.::O': 33,
#  'endpoint::O': 34,
#  'final_prev_tag:O': 35,
#  'id:Families::O': 36,
#  'id:soldiers::O': 37,
#  'id:killed::O': 38,
#  'id:conflict::O': 39,
#  'id:joined::O': 40,
#  'id:protesters::O': 41,
#  'id:who::O': 42,
#  'id:carried::O': 43,
#  'id:banners::O': 44,
#  'id:with::O': 45,
#  'id:such::O': 46,
#  'id:slogans::O': 47,
#  'id:as::O': 48,
#  'id:"::O': 49,
#  'id:Bush::B-per': 50,
#  'hyphen::B-per': 51,
#  'upper::B-per': 52,
#  'prev_tag:O::B-per': 53,
#  'id:Number::O': 54,
#  'prev_tag:B-per::O': 55,
#  'id:One::O': 56,
#  'id:Terrorist::O': 57,
#  'id:Stop::O': 58,
#  'id:Bombings::O': 59,
#  'id:They::O': 60,
#  'id:Houses::O': 61,
#  'id:Parliament::O': 62,
#  'id:a::O': 63,
#  'id:rally::O': 64,
#  'id:Hyde::B-geo': 65,
#  'id:Park::I-geo': 66,
#  'hyphen::I-geo': 67,
#  'upper::I-geo': 68,
#  'prev_tag:B-geo::I-geo': 69,
#  'prev_tag:I-geo::O': 70,
#  'id:Police::O': 71,
#  'id:put::O': 72,
#  'id:number::O': 73,
#  'id:marchers::O': 74,
#  'id:at::O': 75,
#  'id:10,000::O': 76,
#  'id:while::O': 77,
#  'id:organizers::O': 78,
#  'id:claimed::O': 79,
#  'id:it::O': 80,
#  'id:was::O': 81,
#  'id:1,00,000::O': 82,
#  'id:The::O': 83,
#  'id:comes::O': 84,
#  'id:on::O': 85,
#  'id:eve::O': 86,
#  'id:annual::O': 87,
#  'id:conference::O': 88,
#  'id:Britain::B-geo': 89,
#  "id:'s::O": 90,
#  'id:ruling::O': 91,
#  'id:Labor::B-org': 92,
#  'hyphen::B-org': 93,
#  'upper::B-org': 94,
#  'prev_tag:O::B-org': 95,
#  'id:Party::I-org': 96,
#  'hyphen::I-org': 97,
#  'upper::I-org': 98,
#  'prev_tag:B-org::I-org': 99,
#  'prev_tag:I-org::O': 100,
#  'id:southern::O': 101,
#  'id:English::B-gpe': 102,
#  'id:seaside::O': 103,
#  'id:resort::O': 104,
#  'id:Brighton::B-geo': 105,
#  'id:party::O': 106,
#  'id:is::O': 107,
#  'id:divided::O': 108,
#  'id:over::O': 109,
#  'id:Britain::B-gpe': 110,
#  'id:participation::O': 111,
#  'id:continued::O': 112,
#  'id:deployment::O': 113,
#  'id:8,500::O': 114,
#  'id:march::O': 115,
#  'id:came::O': 116,
#  'id:ahead::O': 117,
#  'id:anti-war::O': 118,
#  'id:protests::O': 119,
#  'id:today::O': 120,
#  'id:other::O': 121,
#  'id:cities::O': 122,
#  'id:,::O': 123,
#  'id:including::O': 124,
#  'id:Rome::B-geo': 125,
#  'id:Paris::B-geo': 126,
#  'id:Madrid::B-geo': 127,
#  'id:International::B-org': 128,
#  'id:Atomic::I-org': 129,
#  'id:Energy::I-org': 130,
#  'prev_tag:I-org::I-org': 131,
#  'id:Agency::I-org': 132,
#  'id:hold::O': 133,
#  'id:second::O': 134,
#  'id:day::O': 135,
#  'id:talks::O': 136,
#  'id:Vienna::B-geo': 137,
#  'id:Wednesday::B-tim': 138,
#  'hyphen::B-tim': 139,
#  'upper::B-tim': 140,
#  'prev_tag:B-geo::B-tim': 141,
#  'prev_tag:B-tim::O': 142,
#  'id:how::O': 143,
#  'id:respond::O': 144,
#  'id:Iran::B-gpe': 145,
#  'id:resumption::O': 146,
#  'id:low-level::O': 147,
#  'id:uranium::O': 148,
#  'id:conversion::O': 149,
#  'init_tag:B-gpe': 150,
#  'id:this::O': 151,
#  'id:week::O': 152,
#  'id:restarted::O': 153,
#  'id:parts::O': 154,
#  'id:process::O': 155,
#  'id:its::O': 156,
#  'id:Isfahan::B-geo': 157,
#  'id:nuclear::O': 158,
#  'id:plant::O': 159,
#  'id:Iranian::B-gpe': 160,
#  'id:officials::O': 161,
#  'id:say::O': 162,
#  'id:they::O': 163,
#  'id:expect::O': 164,
#  'id:get::O': 165,
#  'id:access::O': 166,
#  'id:sealed::O': 167,
#  'id:sensitive::O': 168,
#  'prev_tag:O::B-tim': 169,
#  'id:after::O': 170,
#  'id:an::O': 171,
#  'id:IAEA::B-org': 172,
#  'id:surveillance::O': 173,
#  'prev_tag:B-org::O': 174,
#  'id:system::O': 175,
#  'id:begins::O': 176,
#  'id:functioning::O': 177,
#  'id:step::O': 178,
#  'id:will::O': 179,
#  'id:allow::O': 180,
#  'id:facility::O': 181,
#  'id:operate::O': 182,
#  'id:full::O': 183,
#  'id:capacity::O': 184,
#  'id:European::B-org': 185,
#  'id:Union::I-org': 186,
#  'id:U.S.::B-gpe': 187,
#  'endpoint::B-gpe': 188,
#  'id:backing::O': 189,
#  'id:has::O': 190,
#  'id:threatened::O': 191,
#  'id:refer::O': 192,
#  'id:U.N.::B-org': 193,
#  'endpoint::B-org': 194,
#  'id:Security::I-org': 195,
#  'id:Council::I-org': 196,
#  'id:which::O': 197,
#  'id:could::O': 198,
#  'id:impose::O': 199,
#  'id:sanctions::O': 200,
#  'id:if::O': 201,
#  'id:finds::O': 202,
#  'id:Tehran::B-gpe': 203,
#  'id:violated::O': 204,
#  'id:Nuclear::B-art': 205,
#  'hyphen::B-art': 206,
#  'upper::B-art': 207,
#  'prev_tag:O::B-art': 208,
#  'id:Non-Proliferation::I-art': 209,
#  'hyphen::I-art': 210,
#  'upper::I-art': 211,
#  'prev_tag:B-art::I-art': 212,
#  'id:treaty::O': 213,
#  'prev_tag:I-art::O': 214,
#  'id:new::O': 215,
#  'id:President::B-per': 216,
#  'id:Mahmoud::I-per': 217,
#  'hyphen::I-per': 218,
#  'upper::I-per': 219,
#  'prev_tag:B-per::I-per': 220,
#  'id:Ahmadinejad::I-per': 221,
#  'prev_tag:I-per::I-per': 222,
#  'id:said::O': 223,
#  'prev_tag:I-per::O': 224,
#  'id:Tuesday::B-tim': 225,
#  'id:European::B-gpe': 226,
#  'id:incentives::O': 227,
#  'id:aimed::O': 228,
#  'id:persuading::O': 229,
#  'id:end::O': 230,
#  'id:fuel::O': 231,
#  'id:program::O': 232,
#  'id:are::O': 233,
#  'id:insult::O': 234,
#  'id:nation::O': 235,
#  'id:Two::O': 236,
#  'id:Germans::B-gpe': 237,
#  'id:four::O': 238,
#  'id:Nigerian::B-gpe': 239,
#  'id:oil::O': 240,
#  'id:workers::O': 241,
#  'id:were::O': 242,
#  'id:kidnapped::O': 243,
#  'id:by::O': 244,
#  'id:armed::O': 245,
#  'id:militants::O': 246,
#  'id:during::O': 247,
#  'id:raid::O': 248,
#  'id:boat::O': 249,
#  'id:Nigeria::B-geo': 250,
#  'id:oil-rich::O': 251,
#  'id:Delta::B-geo': 252,
#  'id:region::O': 253,
#  'id:An::O': 254,
#  'id:official::O': 255,
#  'id:German::B-gpe': 256,
#  'id:firm::O': 257,
#  'id:Bilfinger::B-org': 258,
#  'id:Berger::I-org': 259,
#  'id:Thomas::B-per': 260,
#  'id:Horbach::I-per': 261,
#  'id:gunmen::O': 262,
#  'id:stopped::O': 263,
#  'id:supply::O': 264,
#  'id:sailed::O': 265,
#  'id:State::I-geo': 266,
#  'id:Bayelsa::B-geo': 267,
#  'id:inspect::O': 268,
#  'id:offshore::O': 269,
#  'id:field::O': 270,
#  'id:owned::O': 271,
#  'id:Royal-Dutch::B-org': 272,
#  'id:Shell::I-org': 273,
#  'id:works::O': 274,
#  'id:sub-contractor::O': 275,
#  'id:for::O': 276,
#  'id:Shell::B-org': 277,
#  'id:Militant::O': 278,
#  'id:groups::O': 279,
#  'id:frequently::O': 280,
#  'id:attack::O': 281,
#  'id:operations::O': 282,
#  'id:Niger::B-geo': 283,
#  'id:Delta::I-geo': 284,
#  'id:social::O': 285,
#  'id:services::O': 286,
#  'id:better::O': 287,
#  'id:job::O': 288,
#  'id:opportunities::O': 289,
#  'id:multinational::O': 290,
#  'id:companies::O': 291,
#  'id:Poor::O': 292,
#  'id:residents::O': 293,
#  'id:often::O': 294,
#  'id:complain::O': 295,
#  'id:been::O': 296,
#  'id:cheated::O': 297,
#  'id:out::O': 298,
#  'id:huge::O': 299,
#  'id:riches::O': 300,
#  'id:extracted::O': 301,
#  'id:their::O': 302,
#  'id:tribal::O': 303,
#  'id:lands::O': 304,
#  'id:-::O': 305,
#  'id:where::O': 306,
#  'id:bulk::O': 307,
#  'id:Nigeria::B-gpe': 308,
#  'id:2.3::O': 309,
#  'id:million::O': 310,
#  'id:barrels::O': 311,
#  'id:petroleum::O': 312,
#  'id:pumped::O': 313,
#  'id:daily::O': 314,
#  'id:Suspected::O': 315,
#  'id:Islamist::O': 316,
#  'id:rebels::O': 317,
#  'id:fired::O': 318,
#  'id:mortar::O': 319,
#  'id:shells::O': 320,
#  'id:palace::O': 321,
#  'id:used::O': 322,
#  'id:Somalia::B-geo': 323,
#  'id:interim::O': 324,
#  'id:Abdullahi::I-per': 325,
#  'id:Yusuf::I-per': 326,
#  'id:Ahmad::I-per': 327,
#  'id:It::O': 328,
#  'id:not::O': 329,
#  'id:immediately::O': 330,
#  'id:clear::O': 331,
#  'id:president::O': 332,
#  'id:Mogadishu::B-geo': 333,
#  'id:when::O': 334,
#  'id:occurred::O': 335,
#  'id:or::O': 336,
#  'id:anyone::O': 337,
#  'id:hurt::O': 338,
#  'id:Local::O': 339,
#  'id:news::O': 340,
#  'id:reports::O': 341,
#  'id:least::O': 342,
#  'id:five::O': 343,
#  'id:hit::O': 344,
#  'id:compound::O': 345,
#  'id:mortars::O': 346,
#  'id:elsewhere::O': 347,
#  'id:attacks::O': 348,
#  'id:government::O': 349,
#  'id:go::O': 350,
#  'id:reconciliation::O': 351,
#  'id:more::O': 352,
#  'id:than::O': 353,
#  'id:1,300::O': 354,
#  'id:Somali::B-gpe': 355,
#  'id:elders::O': 356,
#  'id:warlords::O': 357,
#  'id:politicians::O': 358,
#  'id:invited::O': 359,
#  'id:Iraqi::B-gpe': 360,
#  'id:military::O': 361,
#  'id:tanks::O': 362,
#  'id:arrived::O': 363,
#  'id:northern::O': 364,
#  'id:city::O': 365,
#  'id:Mosul::B-geo': 366,
#  'id:offensive::O': 367,
#  'id:against::O': 368,
#  'id:al::B-org': 369,
#  'id:Qaida::I-org': 370,
#  'id:in::I-org': 371,
#  'id:Iraq::I-org': 372,
#  'id:fighters::O': 373,
#  'id:Officials::O': 374,
#  'id:many::O': 375,
#  'id:Sunni::B-geo': 376,
#  'id:Arab::I-geo': 377,
#  'id:Kurdish::B-geo': 378,
#  'id:bombings::O': 379,
#  'id:last::O': 380,
#  'id:34::O': 381,
#  'id:people::O': 382,
#  'id:wounded::O': 383,
#  'id:200::O': 384,
#  'id:commanders::O': 385,
#  'id:explained::O': 386,
#  'id:American::B-gpe': 387,
#  'id:forces::O': 388,
#  'id:participate::O': 389,
#  'id:fled::O': 390,
#  'id:successful::O': 391,
#  'id:campaigns::O': 392,
#  'id:them::O': 393,
#  'id:Anbar::B-geo': 394,
#  'id:province::O': 395,
#  'id:Baghdad::B-geo': 396,
#  'id:provinces::O': 397,
#  'init_tag:B-geo': 398,
#  'id:largest::O': 399,
#  'id:north::O': 400,
#  'id:long::O': 401,
#  'id:stronghold::O': 402,
#  'id:Sunni::B-org': 403,
#  'id:militant::O': 404,
#  'id:In::O': 405,
#  'id:violence::O': 406,
#  'id:one::O': 407,
#  'id:soldier::O': 408,
#  'id:patrol::O': 409,
#  'id:Sunday::B-tim': 410,
#  'id:Egyptian::B-gpe': 411,
#  'id:police::O': 412,
#  'id:arrested::O': 413,
#  'id:16::O': 414,
#  'id:members::O': 415,
#  'id:opposition::O': 416,
#  'id:Muslim::B-org': 417,
#  'id:Brotherhood::I-org': 418,
#  'id:prepare::O': 419,
#  'id:parliamentary::O': 420,
#  'id:runoff::O': 421,
#  'id:elections::O': 422,
#  'id:Saturday::B-tim': 423,
#  'id:arrests::O': 424,
#  'id:Friday::B-tim': 425,
#  'id:Alexandria::B-geo': 426,
#  'id:A::O': 427,
#  'id:spokesman::O': 428,
#  'id:Brotherhood::B-org': 429,
#  'id:attempt::O': 430,
#  'id:cut::O': 431,
#  'id:off::O': 432,
#  'id:supporters::O': 433,
#  'id:punishment::O': 434,
#  'id:winning::O': 435,
#  'id:seats::O': 436,
#  'id:earlier::O': 437,
#  'id:tripled::O': 438,
#  'id:strength::O': 439,
#  'id:parliament::O': 440,
#  'id:recent::O': 441,
#  'id:raising::O': 442,
#  'id:total::O': 443,
#  'id:47::O': 444,
#  'id:voters::O': 445,
#  'id:cast::O': 446,
#  'id:ballots::O': 447,
#  'id:nine::O': 448,
#  'id:no::O': 449,
#  'id:candidate::O': 450,
#  'id:won::O': 451,
#  'id:majority::O': 452,
#  'id:previous::O': 453,
#  'id:round::O': 454,
#  'id:voting::O': 455,
#  'id:banned::O': 456,
#  'id:political::O': 457,
#  'id:but::O': 458,
#  'id:endorses::O': 459,
#  'id:so-called::O': 460,
#  'id:independent::O': 461,
#  'id:candidates::O': 462,
#  'id:whose::O': 463,
#  'id:allegiance::O': 464,
#  'id:known::O': 465,
#  'id:Hardline::O': 466,
#  'id:lawmakers::O': 467,
#  'id:Pakistan::B-geo': 468,
#  'id:North::B-geo': 469,
#  'id:West::I-geo': 470,
#  'id:Frontier::I-geo': 471,
#  'prev_tag:I-geo::I-geo': 472,
#  'id:Province::I-geo': 473,
#  'id:pushed::O': 474,
#  'id:law::O': 475,
#  'id:aims::O': 476,
#  'id:ensure::O': 477,
#  'id:Islamic::O': 478,
#  'id:correctness::O': 479,
#  'id:public::O': 480,
#  'id:places::O': 481,
#  'id:establishes::O': 482,
#  'id:morality::O': 483,
#  'id:enforce::O': 484,
#  'id:decent::O': 485,
#  'id:behavior::O': 486,
#  'id:six-party::O': 487,
#  'id:coalition::O': 488,
#  'id:religious::O': 489,
#  'id:based::O': 490,
#  'id:parties::O': 491,
#  'id:Mutahida::B-org': 492,
#  'id:Majlis-e-Amal::I-org': 493,
#  'id:dominates::O': 494,
#  'id:provincial::O': 495,
#  'id:assembly::O': 496,
#  'id:so::O': 497,
#  'id:bill::O': 498,
#  'id:easily::O': 499,
#  'id:passed::O': 500,
#  'id:Thursday::B-tim': 501,
#  'id:vote::O': 502,
#  'id:68-34::O': 503,
#  'id:governor::O': 504,
#  'id:must::O': 505,
#  'id:still::O': 506,
#  'id:sign::O': 507,
#  'id:before::O': 508,
#  'id:becomes::O': 509,
#  'id:seen::O': 510,
#  'id:only::O': 511,
#  'id:formality::O': 512,
#  'id:proposed::O': 513,
#  'id:calls::O': 514,
#  'id:setting::O': 515,
#  'id:up::O': 516,
#  'id:force::O': 517,
#  'id:make::O': 518,
#  'id:sure::O': 519,
#  'id:adhere::O': 520,
#  'id:values::O': 521,
#  'id:entertainment::O': 522,
#  'id:outlets::O': 523,
#  'id:close::O': 524,
#  'id:weekly::O': 525,
#  'id:prayers::O': 526,
#  'id:Violators::O': 527,
#  'id:be::O': 528,
#  'id:jailed::O': 529,
#  'id:six::O': 530,
#  'id:months::O': 531,
#  'id:denounced::O': 532,
#  'id:measure::O': 533,
#  'id:comparing::O': 534,
#  'id:draconian::O': 535,
#  'id:rule::O': 536,
#  'id:former::O': 537,
#  'id:Taleban::B-org': 538,
#  'id:neighboring::O': 539,
#  'id:Afghanistan::B-geo': 540,
#  'id:man::O': 541,
#  'id:dressed::O': 542,
#  'id:suicide::O': 543,
#  'id:bomber::O': 544,
#  'id:demonstration::O': 545,
#  'id:publication::O': 546,
#  'id:cartoons::O': 547,
#  'id:depicting::O': 548,
#  'id:Islam::B-org': 549,
#  'id:Prophet::B-per': 550,
#  'id:Muhammad::I-per': 551,
#  'id:Bedfordshire::B-gpe': 552,
#  'id:Omar::B-per': 553,
#  'id:Khayam::I-per': 554,
#  'id:Bedford::B-geo': 555,
#  'id:breaching::O': 556,
#  'id:conditions::O': 557,
#  'id:his::O': 558,
#  'id:parole::O': 559,
#  'id:British::B-org': 560,
#  'id:Home::I-org': 561,
#  'id:Office::I-org': 562,
#  'id:sought::O': 563,
#  'id:investigation::O': 564,
#  'id:Khayam::B-per': 565,
#  'id:he::O': 566,
#  'id:photographed::O': 567,
#  'id:fatigues::O': 568,
#  'id:black::O': 569,
#  'id:cap::O': 570,
#  'id:bulky::O': 571,
#  'id:belt::O': 572,
#  'id:Home::B-org': 573,
#  'id:told::O': 574,
#  'id:Associated::B-org': 575,
#  'id:Press::I-org': 576,
#  'id:paroled::O': 577,
#  'id:offender::O': 578,
#  'id:gives::O': 579,
#  'id:cause::O': 580,
#  'id:concern::O': 581,
#  'id:can::O': 582,
#  'id:sent::O': 583,
#  'id:back::O': 584,
#  'id:prison::O': 585,
#  'id:AP::B-org': 586,
#  'id:also::O': 587,
#  'id:since::O': 588,
#  'id:year::O': 589,
#  'id:serving::O': 590,
#  'id:half::O': 591,
#  'id:six-year::O': 592,
#  'id:sentence::O': 593,
#  'id:drug::O': 594,
#  'id:dealing::O': 595,
#  'id:Pakistani::B-gpe': 596,
#  'id:unidentified::O': 597,
#  'id:three::O': 598,
#  'id:minister::O': 599,
#  'id:semi-autonomous::O': 600,
#  'id:bordering::O': 601,
#  'id:prominent::O': 602,
#  'id:leader::O': 603,
#  'id:Malik::B-per': 604,
#  'id:Faridullah::I-per': 605,
#  'id:Khan::I-per': 606,
#  'id:traveling::O': 607,
#  'id:South::B-geo': 608,
#  'id:Waziristan::I-geo': 609,
#  'prev_tag:I-geo::B-tim': 610,
#  'id:vehicle::O': 611,
#  'id:ambushed::O': 612,
#  'id:Kani::B-geo': 613,
#  'id:Wam::I-geo': 614,
#  'id:area::O': 615,
#  'id:His::O': 616,
#  'id:driver::O': 617,
#  'id:elder::O': 618,
#  'id:No::O': 619,
#  'id:responsibility::O': 620,
#  'id:killings::O': 621,
#  'id:ambush::O': 622,
#  'id:commander::O': 623,
#  'id:army::O': 624,
#  'id:almost::O': 625,
#  'id:completely::O': 626,
#  'id:eliminated::O': 627,
#  'id:became::O': 628,
#  'id:refuge::O': 629,
#  'id:al-Qaida::B-org': 630,
#  'id:ousted::O': 631,
#  'id:2001::B-tim': 632,
#  'id:senior::O': 633,
#  'id:says::O': 634,
#  'id:Pakistan::B-gpe': 635,
#  'id:wants::O': 636,
#  'id:what::O': 637,
#  'id:sordid::O': 638,
#  'id:chapter::O': 639,
#  'id:proliferation::O': 640,
#  'id:top::O': 641,
#  'id:scientists::O': 642,
#  'id:behind::O': 643,
#  'id:build::O': 644,
#  'id:civilian::O': 645,
#  'id:ties::O': 646,
#  'id:United::B-gpe': 647,
#  'id:States::I-gpe': 648,
#  'hyphen::I-gpe': 649,
#  'upper::I-gpe': 650,
#  'prev_tag:B-gpe::I-gpe': 651,
#  'prev_tag:I-gpe::O': 652,
#  'id:But::O': 653,
#  'id:ready::O': 654,
#  'id:scientist::O': 655,
#  'id:Abdul::B-per': 656,
#  'id:Qadeer::I-per': 657,
#  'id:available::O': 658,
#  'id:direct::O': 659,
#  'id:questioning::O': 660,
#  'id:sale::O': 661,
#  'id:secrets::O': 662,
#  'id:states::O': 663,
#  'id:Libya::B-gpe': 664,
#  'id:North::B-gpe': 665,
#  'id:Korea::I-gpe': 666,
#  'id:He::O': 667,
#  'id:there::O': 668,
#  'id:reasons::O': 669,
#  'id:national::O': 670,
#  'id:sensitivities::O': 671,
#  'id:making::O': 672,
#  'id:him::O': 673,
#  'id:giving::O': 674,
#  'id:background::O': 675,
#  'id:briefing::O': 676,
#  'id:small::O': 677,
#  'id:group::O': 678,
#  'id:reporters::O': 679,
#  'id:Washington::B-geo': 680,
#  'init_tag:B-per': 681,
#  'id:Khan::B-per': 682,
#  'id:admitted::O': 683,
#  'id:2004::B-tim': 684,
#  'id:operated::O': 685,
#  'id:worldwide::O': 686,
#  'id:clandestine::O': 687,
#  'id:network::O': 688,
#  'id:sell::O': 689,
#  'id:technology::O': 690,
#  'id:market::O': 691,
#  'id:placed::O': 692,
#  'id:under::O': 693,
#  'id:house::O': 694,
#  'id:arrest::O': 695,
#  'id:Islamabad::B-geo': 696,
#  'id:because::O': 697,
#  'id:considered::O': 698,
#  'id:father::O': 699,
#  'id:bomb::O': 700,
#  'id:Army::B-org': 701,
#  'prev_tag:B-gpe::B-org': 702,
#  'id:renew::O': 703,
#  'id:controversial::O': 704,
#  'id:multi-billion::O': 705,
#  'id:dollar::O': 706,
#  'id:contract::O': 707,
#  'id:Halliburton::B-org': 708,
#  'id:company::O': 709,
#  'id:provide::O': 710,
#  'id:logistical::O': 711,
#  'id:support::O': 712,
#  'init_tag:B-org': 713,
#  'id:providing::O': 714,
#  'id:list::O': 715,
#  'id:meals::O': 716,
#  'id:communication::O': 717,
#  'id:several::O': 718,
#  'id:years::O': 719,
#  'id:Critics::O': 720,
#  'id:include::O': 721,
#  'id:auditors::O': 722,
#  'id:congressional::O': 723,
#  'id:Democrats::O': 724,
#  'id:produced::O': 725,
#  'id:some::O': 726,
#  'id:shoddy::O': 727,
#  'id:work::O': 728,
#  'id:charges::O': 729,
#  'id:too::O': 730,
#  'id:much::O': 731,
#  'id:money::O': 732,
#  'id:strongly::O': 733,
#  'id:denies::O': 734,
#  'id:allegations::O': 735,
#  'id:When::O': 736,
#  'id:re-bidding::O': 737,
#  'id:chance::O': 738,
#  'id:compete::O': 739,
#  'id:portions::O': 740,
#  'id:Representatives::O': 741,
#  'id:Asia::B-org': 742,
#  'id:Pacific::I-org': 743,
#  'id:Economic::I-org': 744,
#  'id:Cooperation::I-org': 745,
#  'id:Business::I-org': 746,
#  'id:Advisory::I-org': 747,
#  'id:holding::O': 748,
#  'id:meetings::O': 749,
#  'id:finalize::O': 750,
#  'id:report::O': 751,
#  'id:APEC::B-org': 752,
#  'id:leaders::O': 753,
#  'id:summit::O': 754,
#  'id:September::B-tim': 755,
#  'id:8::I-tim': 756,
#  'hyphen::I-tim': 757,
#  'upper::I-tim': 758,
#  'prev_tag:B-tim::I-tim': 759,
#  'prev_tag:I-tim::O': 760,
#  'id:9::B-tim': 761,
#  'id:VOA::B-org': 762,
#  'id:Nancy-Amelia::B-per': 763,
#  'id:Collins::I-per': 764,
#  'id:Sydney::B-geo': 765,
#  'id:Energy::O': 766,
#  'id:security::O': 767,
#  'id:climate::O': 768,
#  'id:change::O': 769,
#  'id:World::B-org': 770,
#  'id:Trade::I-org': 771,
#  'id:Organization::I-org': 772,
#  'id:stalled::O': 773,
#  'id:negotiations::O': 774,
#  'id:investment::O': 775,
#  'id:all::O': 776,
#  'id:expected::O': 777,
#  'id:among::O': 778,
#  'id:major::O': 779,
#  'id:topics::O': 780,
#  'id:ABAC::B-org': 781,
#  'id:Tim::B-per': 782,
#  'id:Harcourt::I-per': 783,
#  'id:chief::O': 784,
#  'id:economist::O': 785,
#  'id:Australian::B-org': 786,
#  'id:Commission::I-org': 787,
#  'id:plays::O': 788,
#  'id:important::O': 789,
#  'id:role::O': 790,
#  'id:informing::O': 791,
#  'id:governments::O': 792,
#  'id:problems::O': 793,
#  'id:most::O': 794,
#  'id:thing::O': 795,
#  'id:business::O': 796,
#  'id:do::O': 797,
#  'id:tell::O': 798,
#  'id:logjams::O': 799,
#  'id:obstacles::O': 800,
#  'id:things::O': 801,
#  'id:improve::O': 802,
#  'id:Harcourt::B-per': 803,
#  'id:I::O': 804,
#  'id:think::O': 805,
#  'id:actually::O': 806,
#  'id:played::O': 807,
#  'id:pretty::O': 808,
#  'id:good::O': 809,
#  'id:leadership::O': 810,
#  'id:talking::O': 811,
#  'id:about::O': 812,
#  'id:trade::O': 813,
#  'id:facilitation::O': 814,
#  'id:basically::O': 815,
#  'id:standards::O': 816,
#  'id:consistent::O': 817,
#  'id:harmonious::O': 818,
#  'id:across::O': 819,
#  'id:comprises::O': 820,
#  'id:private::O': 821,
#  'id:sector::O': 822,
#  'id:each::O': 823,
#  'id:21::O': 824,
#  'id:economies::O': 825,
#  'id:meets::O': 826,
#  'id:times::O': 827,
#  'id:made::O': 828,
#  'id:permanent::O': 829,
#  'id:body::O': 830,
#  'id:1995::B-tim': 831,
#  'id:perspective::O': 832,
#  'id:within::O': 833,
#  'id:Members::O': 834,
#  'id:represent::O': 835,
#  'id:range::O': 836,
#  'id:sectors::O': 837,
#  'id:medium::O': 838,
#  'id:businesses::O': 839,
#  'id:need::O': 840,
#  'id:energy::O': 841,
#  'id:efficiency::O': 842,
#  'id:encourage::O': 843,
#  'id:conservation::O': 844,
#  'id:practices::O': 845,
#  'id:discuss::O': 846,
#  'id:ways::O': 847,
#  'id:enhance::O': 848,
#  'id:regional::O': 849,
#  'id:cooperation::O': 850,
#  'id:reckon::O': 851,
#  "id:'ll::O": 852,
#  'id:talk::O': 853,
#  'id:little::O': 854,
#  'id:bit::O': 855,
#  'id:customs::O': 856,
#  'id:quarantine::O': 857,
#  'id:having::O': 858,
#  'id:arrangements::O': 859,
#  'id:around::O': 860,
#  'id:And::O': 861,
#  'id:want::O': 862,
#  'id:one-stop::O': 863,
#  'id:shop::O': 864,
#  'id:terms::O': 865,
#  'id:combining::O': 866,
#  'id:immigration::O': 867,
#  'id:together::O': 868,
#  'id:\x85::O': 869,
#  'id:just::O': 870,
#  'id:streamlined::O': 871,
#  'id:provides::O': 872,
#  'id:certainty::O': 873,
#  'id:non-governmental::O': 874,
#  'id:formal::O': 875,
#  'id:dialogue::O': 876,
#  'id:present::O': 877,
#  'id:meeting::O': 878,
#  'id:Sudan::B-gpe': 879,
#  'id:order::O': 880,
#  'id:Darfur::B-geo': 881,
#  'id:asking::O': 882,
#  'id:same::O': 883,
#  'id:Foreign::B-per': 884,
#  'id:Minister::I-per': 885,
#  'id:Mustafa::I-per': 886,
#  'id:Osman::I-per': 887,
#  'id:Ismail::I-per': 888,
#  'id:Sudanese::B-gpe': 889,
#  'id:withdraw::O': 890,
#  'id:positions::O': 891,
#  'id:held::O': 892,
#  'id:April::B-tim': 893,
#  'id:cease-fire::O': 894,
#  'id:western::O': 895,
#  'id:agree::O': 896,
#  'id:stop::O': 897,
#  'id:Mr.::B-per': 898,
#  'endpoint::B-per': 899,
#  'id:announced::O': 900,
#  'id:decision::O': 901,
#  'id:United::B-org': 902,
#  'id:Nations::I-org': 903,
#  'id:African::B-org': 904,
#  'id:Khartoum::B-geo': 905,
#  'id:weeks::O': 906,
#  'id:AU::B-org': 907,
#  'id:repeatedly::O': 908,
#  'id:truce::O': 909,
#  'init_tag:B-tim': 910,
#  'id:head::O': 911,
#  'id:accused::O': 912,
#  'id:helicopters::O': 913,
#  'id:bombing::O': 914,
#  'id:rebel::O': 915,
#  'id:sites::O': 916,
#  'id:Darfur::I-geo': 917,
#  'id:village::O': 918,
#  'id:Labado::B-geo': 919,
#  'id:Khartoum::B-gpe': 920,
#  'id:defending::O': 921,
#  'id:Aid::O': 922,
#  'id:relief::O': 923,
#  'id:efforts::O': 924,
#  'id:suspended::O': 925,
#  'id:due::O': 926,
#  'id:Indonesian::B-gpe': 927,
#  'id:men::O': 928,
#  'id:connection::O': 929,
#  'id:October::B-tim': 930,
#  'id:1::I-tim': 931,
#  'id:Bali::B-geo': 932,
#  'prev_tag:I-tim::B-geo': 933,
#  'id:left::O': 934,
#  'id:23::O': 935,
#  'id:dead::O': 936,
#  'id:flown::O': 937,
#  'id:Java::B-geo': 938,
#  'id:island::O': 939,
#  'id:headquarters::O': 940,
#  'id:Australian::B-gpe': 941,
#  'id:French::B-gpe': 942,
#  'id:agencies::O': 943,
#  'id:(::O': 944,
#  'id:Cholily::B-per': 945,
#  'id:)::O': 946,
#  'id:captured::O': 947,
#  'id:series::O': 948,
#  'id:counter-terrorism::O': 949,
#  'id:raids::O': 950,
#  'id:Indonesia::B-geo': 951,
#  'id:ended::O': 952,
#  'id:death::O': 953,
#  'id:alleged::O': 954,
#  'id:extremist::O': 955,
#  'id:bombmaker::O': 956,
#  'id:Azahari::B-per': 957,
#  'id:bin::I-per': 958,
#  'id:Husin::I-per': 959,
#  'id:authorities::O': 960,
#  'id:blame::O': 961,
#  'id:orchestrating::O': 962,
#  'id:month::O': 963,
#  'id:well::O': 964,
#  'id:2002::B-tim': 965,
#  'prev_tag:B-tim::B-geo': 966,
#  'id:Gunmen::O': 967,
#  'id:shot::O': 968,
#  'id:Roman::B-org': 969,
#  'id:Catholic::I-org': 970,
#  'id:nun::O': 971,
#  'id:her::O': 972,
#  'id:bodyguard::O': 973,
#  'id:hospital::O': 974,
#  'id:she::O': 975,
#  'id:worked::O': 976,
#  'id:Islamist-controlled::O': 977,
#  'id:Some::O': 978,
#  'id:witnesses::O': 979,
#  'id:shooting::O': 980,
#  'id:feared::O': 981,
#  'id:linked::O': 982,
#  'id:Muslim::O': 983,
#  'id:anger::O': 984,
#  'id:toward::O': 985,
#  'id:Pope::B-per': 986,
#  'id:Benedict::I-per': 987,
#  'id:pistols::O': 988,
#  'id:attacked::O': 989,
#  'id:Sister::B-per': 990,
#  'id:Leonella::I-per': 991,
#  'id:Sgorbati::I-per': 992,
#  'id:finished::O': 993,
#  'id:teaching::O': 994,
#  'id:medical::O': 995,
#  'id:school::O': 996,
#  'id:class::O': 997,
#  'id:suspect::O': 998,
#  'id:Vatican::B-org': 999,
#  ...}

# %%
[x for x in list(ex_feature_mapper.feature_dict.keys()) if 'upper' in x]
# Out:
# ['upper::O',
#  'upper::B-geo',
#  'upper::B-gpe',
#  'upper::B-per',
#  'upper::I-geo',
#  'upper::B-org',
#  'upper::I-org',
#  'upper::B-tim',
#  'upper::B-art',
#  'upper::I-art',
#  'upper::I-per',
#  'upper::I-gpe',
#  'upper::I-tim',
#  'upper::B-nat',
#  'upper::B-eve',
#  'upper::I-eve',
#  'upper::I-nat',
#  'id:upper::O',
#  'id:Supper::O',
#  'id:upper-middle::O']

# %% [markdown]
# #### Training structured perceptron

# %%
corpus = skseq.readers.pos_corpus.PostagCorpus()
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)

# %%
sp.get_num_states(), sp.get_num_observations()
# Out:
# (17, 30863)

# %%
# %%time
num_epochs = 15
sp.fit(ex_feature_mapper.dataset, num_epochs)
# Out:
# Epoch: 0 Accuracy: 0.923455
# Epoch: 1 Accuracy: 0.942283
# Epoch: 2 Accuracy: 0.947269
# Epoch: 3 Accuracy: 0.950621
# Epoch: 4 Accuracy: 0.952520
# Epoch: 5 Accuracy: 0.954238
# Epoch: 6 Accuracy: 0.955599
# Epoch: 7 Accuracy: 0.956591
# Epoch: 8 Accuracy: 0.957633
# Epoch: 9 Accuracy: 0.958394
# Epoch: 10 Accuracy: 0.959223
# Epoch: 11 Accuracy: 0.959782
# Epoch: 12 Accuracy: 0.960260
# Epoch: 13 Accuracy: 0.961111
# Epoch: 14 Accuracy: 0.961801
# Wall time: 1h 5min 35s

# %%
sp.save_model("perceptron_ex4")

# %%
sp = spc.StructuredPerceptron(word_to_pos, tag_to_pos, ex_feature_mapper)
sp.load_model(dir="perceptron_ex4")

# %% [markdown]
# #### Testing

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

y_pred_2 = []
y_true = [item for x in Y_ids_test for item in x]
correct_sentences = 0
n_test = len(X_test)

for i in range(n_test):
    y_pred_aux = sp.predict_tags_given_words(X_test[i])
    y_pred_2.append(y_pred_aux)
    if list(y_pred_aux) == Y_ids_test[i]:
        correct_sentences += 1
    
y_pred = [item for x in y_pred_2 for item in x]
F1_score_multi = f1_score(y_true, y_pred, average=None)
Accuracy = accuracy_score(y_true, y_pred)
print('Accuracy for test is: ' + str(Accuracy))
print('F1-Score for test is: ' + str(np.mean(F1_score_multi)))
print('Correct sentences for test (%) : ' + str(correct_sentences/n_test))
# Out:
# Accuracy for test is: 0.949115171061833
# F1-Score for test is: 0.6088066050010064
# Correct sentences for test (%) : 0.46396396396396394

# %%
ax = plot_confusion_matrix(y_true, y_pred, classes=list(sp.state_labels),
                      title='Confusion matrix')

# %% [markdown]
# #### SENTENCES TO TEST THE MODEL

# %% [markdown]
# We think that these are the tags that the model should obtain:
#
# 1. The/O programmers/O from/O Barcelona/B-geo might/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 2. The/O programmers/O from/O Barchelona/O cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
#
# 3. Jack/B-per London/I-per went/O to/O Parris./O
#
# 4. Jack/B-per London/I-per went/O to/O/O Paris./B-geo
#
# 5. We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
#
# 6. We/O never/O though/O Microsof/O would/O become/O such/O a/O big/O company./O
#
# 7. The/O president/O of/O U.S.A/B-geo though/O they/O could/O win/O the/O war/O
#
# 8. The/O president/O of/O the/O United/B-geo States/B-geo of/B-geo America/B-geo though/O they/O could/O win/O the/O war/O
#
# 9. The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
#
# 10. Robin/B-per does/O not/O want/O to/O go/O to/O Saudi/B-geo Arabia./I-geo

# %%
for sentence in test_sentences:
    new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
    print(sp.viterbi_decode(new_seq)[0].to_words(sequence_list_train, only_tag_translation=True))
# Out:
# The/O programmers/O from/O Barcelona/B-org might/O write/O a/O sentence/O without/O a/O spell/O checker./O
# The/O programmers/O from/O Barchelona/B-org cannot/O write/O a/O sentence/O without/O a/O spell/O checker./O
# Jack/B-per London/B-geo went/O to/O Parris./B-geo
# Jack/B-per London/B-geo went/O to/O Paris./B-geo
# We/O never/O though/O Microsoft/B-org would/O become/O such/O a/O big/O company./O
# We/O never/O though/O Microsof/B-org would/O become/O such/O a/O big/O company./O
# The/O president/O of/O U.S.A/B-org though/O they/O could/O win/O the/O war/O
# The/O president/O of/O the/O United/B-geo States/I-geo of/I-geo America/I-geo though/O they/O could/O win/O the/O war/O
# The/O king/O of/O Saudi/B-geo Arabia/I-geo wanted/O total/O control./O
# Robin/B-org does/O not/O want/O to/O go/O to/O Saudi/B-per Arabia./I-per

# %%
# Here we can select the sentence in which we want to compare the true and the predicted tags
# Select a sentence between 1 and 10
i=1
sentence = test_sentences[i-1]
new_seq = Sequence(x=sentence.split(), y=[int(0) for w in sentence.split()])
preds = sp.viterbi_decode(new_seq)[0].y
print("{:15} ({:5}): {}".format("Word", "True", "Pred"))
for word, true_tag, pred_tag in zip(sentence.split(), test_tags[i-1], preds):
    print("{:15} ({:5}): {}".format(word, true_tag, pos_to_tag[pred_tag]))
# Out:
# Word            (True ): Pred
# The             (O    ): O
# programmers     (O    ): O
# from            (O    ): O
# Barcelona       (B-geo): B-org
# might           (O    ): O
# write           (O    ): O
# a               (O    ): O
# sentence        (O    ): O
# without         (O    ): O
# a               (O    ): O
# spell           (O    ): O
# checker.        (O    ): O
